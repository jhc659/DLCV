# %%
import os
import glob
import json 
import time
import math
import random

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
import torchvision
import torchvision.transforms as transforms
import pandas as pd
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np
from tensorboardX import SummaryWriter


from byol_pytorch import BYOL
from torchvision import models

# %%
train_path = "/data/dlcv/hw4/office/train"
valid_path = "/data/dlcv/hw4/office/val"
train_csv = "/data/dlcv/hw4/office/train.csv"
valid_csv = "/data/dlcv/hw4/office/val.csv"
label2id_path = "./label2id.json"
ckpt_path = "./ckpt/finetune"
pretrained_path = "/data/jhccc/dlcv/hw4-jhc659/ckpt/uma/resnetLast.pth"
retrain_path = "/data/jhccc/dlcv/hw4-jhc659/ckpt/finetune/settingC_best.pth"
os.makedirs(ckpt_path, exist_ok=True)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
torch.cuda.set_device(3)
print('Device used:', device)

img_size = 128
train_bz = 128
valid_bz = 200
# Out:
# Device used: cuda

# %%
class dataset(Dataset):
    def __init__(self, inputPath, csvPath, label2idPath, transform=None):
        self.inputPath = inputPath
        self.transform = transform
        with open(label2idPath, 'r') as j:
            self.label2id = json.loads(j.read())
        self.inputName = []
        df = pd.read_csv(csvPath)
        for i in range(len(df)):
            self.inputName.append((df.loc[i].filename, self.label2id[df.loc[i].label]))
        print(self.inputName[0])
        
    def __getitem__(self, index):
        img = Image.open(os.path.join(self.inputPath, self.inputName[index][0]))
        if self.transform:
            img = self.transform(img)
        id = self.inputName[index][1]
        return img, id

    def __len__(self):
        return len(self.inputName)

img_transform = transforms.Compose([
    transforms.Resize(size=128),
    transforms.CenterCrop(128),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485,0.456,0.406], std=[0.229,0.224,0.225])
])

def imshow(img):
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))

def save_checkpoint(ckpt_path, model, optimizer):
    state = {'model_state_dict': model.state_dict(),
             'optimizer_state_dict': optimizer.state_dict(),}
    torch.save(state, ckpt_path)

def load_checkpoint(ckpt_path, device=device):
    ckpt = torch.load(ckpt_path, map_location=device)
    return ckpt

def epoch_time(start_time, end_time):
    elapsed_time = end_time - start_time
    elapsed_mins = int(elapsed_time / 60)
    elapsed_secs = int(elapsed_time - (elapsed_mins * 60))
    return elapsed_mins, elapsed_secs

# %%
trainDS = dataset(inputPath=train_path, csvPath=train_csv, label2idPath=label2id_path, transform=img_transform)
trainLoader = DataLoader(dataset=trainDS, batch_size=train_bz, shuffle=True, num_workers=4)
validDS = dataset(inputPath=valid_path, csvPath=valid_csv, label2idPath=label2id_path, transform=img_transform)
validLoader = DataLoader(dataset=validDS, batch_size=valid_bz, shuffle=False, num_workers=1)
print('# images in trainset:', len(trainDS))
print('# images in validset:', len(validDS))

# dataiter = iter(validLoader)
# images, labels = dataiter.next()
# # print(labels)
# print('Image tensor in each batch:', images.shape, images.dtype)
# print('Label tensor in each batch:', labels.shape, labels.dtype)
# Out:
# ('Couch00015.jpg', 13)
# ('Fork00005.jpg', 24)
# # images in trainset: 3951
# # images in validset: 406

# %%
class settingC(nn.Module):
    def __init__(self, ckpt_path=None) -> None:
        super().__init__()
        self.resnet = models.resnet50(weights=None)
        ckpt = load_checkpoint(ckpt_path, device)
        self.resnet.load_state_dict(ckpt['model_state_dict'])
        # self.resnet = nn.Sequential(*list(self.resnet.children())[:-1])
        self.classifier = nn.Sequential(
            nn.Linear(self.resnet.fc.out_features, 65)
        )
        # self.classifier = nn.Linear(2048, 65)
    def forward(self, x):
        x = self.resnet(x).flatten(1)
        return self.classifier(x)

class settingC_test(nn.Module):
    def __init__(self, ckpt_path=None) -> None:
        super().__init__()
        self.resnet = models.resnet50(weights=None)
        ckpt = load_checkpoint(ckpt_path, device)
        self.resnet.load_state_dict(ckpt['model_state_dict'])
        self.resnet = nn.Sequential(*list(self.resnet.children())[:-1])
        # self.classifier = nn.Sequential(
        #     nn.Linear(self.resnet.fc.out_features, 65)
        # )
        self.classifier = nn.Linear(2048, 65)
    def forward(self, x):
        x = self.resnet(x)
        return self.classifier(x)

# %%
# trainning
def train(model, epochs):
    model = model.to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=3e-3)
    scheduler = torch.optim.lr_scheduler.MultiStepLR(optimizer, milestones=[30,100], gamma=0.2)
    criterion = nn.CrossEntropyLoss()
    best_acc = 0.

    for epoch in range(epochs):
        model.train()        
        train_loss, valid_loss = 0, 0
        train_acc, valid_acc = 0, 0
        for i, (img, label) in enumerate(trainLoader):
            img, label = img.to(device), label.to(device)
            optimizer.zero_grad()
            output = model(img)
            pred = output.max(1, keepdim=True)[1] # get the index of the max log-probability
            train_acc += pred.eq(label.view_as(pred)).sum().item()
            loss = criterion(output, label)
            train_loss += loss.item()
            loss.backward()
            optimizer.step()                
        scheduler.step()
        train_loss /= (i+1)
        train_acc /= len(trainLoader.dataset)
        print("Epoch: {:02}".format(epoch))
        print(" | train_loss: {:6f}, train_acc: {:.2%}".format(train_loss, train_acc))
        model.eval()
        with torch.no_grad(): # This will free the GPU memory used for back-prop
            for i, (img, label) in enumerate(validLoader):
                img, label = img.to(device), label.to(device)
                output = model(img)
                valid_loss += criterion(output, label).item() # sum up batch loss
                pred = output.max(1, keepdim=True)[1] # get the index of the max log-probability
                valid_acc += pred.eq(label.view_as(pred)).sum().item()
                # resultClass = torch.argmax(output, dim=1)
                # acc += (resultClass == target).sum()
            valid_loss /= (i+1)
            valid_acc /= len(validLoader.dataset)
        
        save_checkpoint(os.path.join(ckpt_path, "settingC_test_last.pth"), model, optimizer)
        print(" | valid_loss: {:6f}, valid_acc: {:.2%}".format(valid_loss, valid_acc))
        
        if valid_acc > best_acc:
            save_checkpoint(os.path.join(ckpt_path, "settingC_test_best.pth"), model, optimizer)
            print("  -> Save checkpoint for epoch {}".format(epoch+1))
            best_acc = valid_acc

# %%
model = settingC(ckpt_path=pretrained_path).to(device)
# print(model)
train(model, 100)
# Out:
# Epoch: 00
#  | train_loss: 5.550504, train_acc: 14.60%
#  | valid_loss: 3.164134, valid_acc: 19.95%
#   -> Save checkpoint for epoch 1
# Epoch: 01
#  | train_loss: 2.639077, train_acc: 34.24%
#  | valid_loss: 2.786921, valid_acc: 33.50%
#   -> Save checkpoint for epoch 2
# Epoch: 02
#  | train_loss: 1.915874, train_acc: 47.51%
#  | valid_loss: 2.533525, valid_acc: 38.92%
#   -> Save checkpoint for epoch 3
# Epoch: 03
#  | train_loss: 1.556225, train_acc: 55.58%
#  | valid_loss: 3.741956, valid_acc: 37.68%
# Epoch: 04
#  | train_loss: 1.234808, train_acc: 64.01%
#  | valid_loss: 2.615451, valid_acc: 39.66%
#   -> Save checkpoint for epoch 5
# Epoch: 05
#  | train_loss: 0.906804, train_acc: 72.56%
#  | valid_loss: 3.737534, valid_acc: 41.13%
#   -> Save checkpoint for epoch 6
# Epoch: 06
#  | train_loss: 0.635545, train_acc: 80.23%
#  | valid_loss: 3.193446, valid_acc: 44.33%
#   -> Save checkpoint for epoch 7
# Epoch: 07
#  | train_loss: 0.535339, train_acc: 83.42%
#  | valid_loss: 3.220927, valid_acc: 39.41%
# Epoch: 08
#  | train_loss: 0.317856, train_acc: 90.18%
#  | valid_loss: 3.912990, valid_acc: 44.58%
#   -> Save checkpoint for epoch 9
# Epoch: 09
#  | train_loss: 0.182565, train_acc: 94.91%
#  | valid_loss: 2.941303, valid_acc: 41.63%
# Epoch: 10
#  | train_loss: 0.145881, train_acc: 96.00%
#  | valid_loss: 3.261619, valid_acc: 43.84%
# Epoch: 11
#  | train_loss: 0.092814, train_acc: 97.77%
#  | valid_loss: 3.317218, valid_acc: 46.06%
#   -> Save checkpoint for epoch 12
# Epoch: 12
#  | train_loss: 0.071638, train_acc: 98.20%
#  | valid_loss: 3.517746, valid_acc: 45.81%
# Epoch: 13
#  | train_loss: 0.058234, train_acc: 98.76%
#  | valid_loss: 3.707547, valid_acc: 46.31%
#   -> Save checkpoint for epoch 14
# Epoch: 14
#  | train_loss: 0.056053, train_acc: 98.73%
#  | valid_loss: 3.464759, valid_acc: 45.07%
# Epoch: 15
#  | train_loss: 0.043376, train_acc: 99.06%
#  | valid_loss: 3.451403, valid_acc: 45.32%
# Epoch: 16
#  | train_loss: 0.041702, train_acc: 98.96%
#  | valid_loss: 3.960953, valid_acc: 44.58%
# Epoch: 17
#  | train_loss: 0.053613, train_acc: 98.84%
#  | valid_loss: 3.733104, valid_acc: 44.33%
# Epoch: 18
#  | train_loss: 0.059273, train_acc: 98.43%
#  | valid_loss: 3.274085, valid_acc: 46.80%
#   -> Save checkpoint for epoch 19
# Epoch: 19
#  | train_loss: 0.064035, train_acc: 98.38%
#  | valid_loss: 4.433042, valid_acc: 43.60%
# Epoch: 20
#  | train_loss: 0.064493, train_acc: 98.41%
#  | valid_loss: 3.376454, valid_acc: 44.09%
# Epoch: 21
#  | train_loss: 0.058238, train_acc: 98.81%
#  | valid_loss: 4.326952, valid_acc: 48.77%
#   -> Save checkpoint for epoch 22
# Epoch: 22
#  | train_loss: 0.055191, train_acc: 98.63%
#  | valid_loss: 4.055511, valid_acc: 47.78%
# Epoch: 23
#  | train_loss: 0.049796, train_acc: 98.56%
#  | valid_loss: 4.085911, valid_acc: 44.33%
# Epoch: 24
#  | train_loss: 0.057913, train_acc: 98.53%
#  | valid_loss: 4.038170, valid_acc: 43.10%
# Epoch: 25
#  | train_loss: 0.075865, train_acc: 97.87%
#  | valid_loss: 3.939726, valid_acc: 44.09%
# Epoch: 26
#  | train_loss: 0.114200, train_acc: 96.79%
#  | valid_loss: 4.190960, valid_acc: 41.87%
# Epoch: 27
#  | train_loss: 0.181499, train_acc: 94.63%
#  | valid_loss: 4.939376, valid_acc: 40.15%
# Epoch: 28
#  | train_loss: 0.274323, train_acc: 92.33%
#  | valid_loss: 6.746387, valid_acc: 40.15%
# Epoch: 29
#  | train_loss: 0.240470, train_acc: 92.63%
#  | valid_loss: 7.648978, valid_acc: 38.42%
# Epoch: 30
#  | train_loss: 0.104650, train_acc: 96.61%
#  | valid_loss: 4.331050, valid_acc: 45.81%
# Epoch: 31
#  | train_loss: 0.022454, train_acc: 99.32%
#  | valid_loss: 5.007927, valid_acc: 48.52%
# Epoch: 32
#  | train_loss: 0.015668, train_acc: 99.57%
#  | valid_loss: 4.779742, valid_acc: 48.77%
# Epoch: 33
#  | train_loss: 0.012242, train_acc: 99.49%
#  | valid_loss: 4.819699, valid_acc: 48.77%
# Epoch: 34
#  | train_loss: 0.010801, train_acc: 99.62%
#  | valid_loss: 4.804832, valid_acc: 47.78%
# Epoch: 35
#  | train_loss: 0.011049, train_acc: 99.52%
#  | valid_loss: 4.701964, valid_acc: 48.28%
# Epoch: 36
#  | train_loss: 0.011126, train_acc: 99.57%
#  | valid_loss: 4.690240, valid_acc: 48.03%
# Epoch: 37
#  | train_loss: 0.010977, train_acc: 99.49%
#  | valid_loss: 4.748438, valid_acc: 48.03%
# Epoch: 38
#  | train_loss: 0.011380, train_acc: 99.52%
#  | valid_loss: 4.758924, valid_acc: 47.04%
# Epoch: 39
#  | train_loss: 0.011488, train_acc: 99.57%
#  | valid_loss: 4.724199, valid_acc: 47.54%
# Epoch: 40
#  | train_loss: 0.010048, train_acc: 99.60%
#  | valid_loss: 4.787800, valid_acc: 47.54%
# Epoch: 41
#  | train_loss: 0.010992, train_acc: 99.52%
#  | valid_loss: 4.850243, valid_acc: 47.54%
# Epoch: 42
#  | train_loss: 0.010256, train_acc: 99.52%
#  | valid_loss: 4.804867, valid_acc: 46.31%
# Epoch: 43
#  | train_loss: 0.011101, train_acc: 99.57%
#  | valid_loss: 4.765213, valid_acc: 47.04%
# Epoch: 44
#  | train_loss: 0.011850, train_acc: 99.49%
#  | valid_loss: 4.878188, valid_acc: 47.78%
# Epoch: 45
#  | train_loss: 0.009363, train_acc: 99.54%
#  | valid_loss: 4.796641, valid_acc: 47.54%
# Epoch: 46
#  | train_loss: 0.009014, train_acc: 99.57%
#  | valid_loss: 4.770561, valid_acc: 47.54%
# Epoch: 47
#  | train_loss: 0.011588, train_acc: 99.57%
#  | valid_loss: 4.726841, valid_acc: 47.78%
# Epoch: 48
#  | train_loss: 0.011593, train_acc: 99.49%
#  | valid_loss: 4.886931, valid_acc: 47.29%
# Epoch: 49
#  | train_loss: 0.009293, train_acc: 99.57%
#  | valid_loss: 4.941922, valid_acc: 47.78%
# Epoch: 50
#  | train_loss: 0.011682, train_acc: 99.49%
#  | valid_loss: 4.830833, valid_acc: 47.78%
# Epoch: 51
#  | train_loss: 0.008876, train_acc: 99.62%
#  | valid_loss: 4.685362, valid_acc: 48.03%
# Epoch: 52
#  | train_loss: 0.013602, train_acc: 99.42%
#  | valid_loss: 4.618244, valid_acc: 47.78%
# Epoch: 53
#  | train_loss: 0.009141, train_acc: 99.54%
#  | valid_loss: 4.758860, valid_acc: 48.28%
# Epoch: 54
#  | train_loss: 0.009092, train_acc: 99.47%
#  | valid_loss: 4.761639, valid_acc: 48.03%
# Epoch: 55
#  | train_loss: 0.010083, train_acc: 99.52%
#  | valid_loss: 4.778939, valid_acc: 48.28%
# Epoch: 56
#  | train_loss: 0.011577, train_acc: 99.49%
#  | valid_loss: 4.757781, valid_acc: 48.03%
# Epoch: 57
#  | train_loss: 0.010363, train_acc: 99.57%
#  | valid_loss: 4.678096, valid_acc: 48.03%
# Epoch: 58
#  | train_loss: 0.008947, train_acc: 99.57%
#  | valid_loss: 4.654036, valid_acc: 49.26%
#   -> Save checkpoint for epoch 59
# Epoch: 59
#  | train_loss: 0.011918, train_acc: 99.52%
#  | valid_loss: 4.674352, valid_acc: 48.52%
# Epoch: 60
#  | train_loss: 0.010842, train_acc: 99.52%
#  | valid_loss: 4.682420, valid_acc: 48.77%
# Epoch: 61
#  | train_loss: 0.010553, train_acc: 99.54%
#  | valid_loss: 4.654638, valid_acc: 47.78%
# Epoch: 62
#  | train_loss: 0.011228, train_acc: 99.47%
#  | valid_loss: 4.688486, valid_acc: 48.03%
# Epoch: 63
#  | train_loss: 0.010168, train_acc: 99.52%
#  | valid_loss: 4.679089, valid_acc: 48.52%
# Epoch: 64
#  | train_loss: 0.011815, train_acc: 99.49%
#  | valid_loss: 4.643017, valid_acc: 49.01%
# Epoch: 65
#  | train_loss: 0.010415, train_acc: 99.52%
#  | valid_loss: 4.768100, valid_acc: 48.28%
# Epoch: 66
#  | train_loss: 0.011131, train_acc: 99.49%
#  | valid_loss: 4.686776, valid_acc: 48.28%
# Epoch: 67
#  | train_loss: 0.008887, train_acc: 99.60%
#  | valid_loss: 4.696472, valid_acc: 48.52%
# Epoch: 68
#  | train_loss: 0.012346, train_acc: 99.57%
#  | valid_loss: 4.763195, valid_acc: 49.01%
# Epoch: 69
#  | train_loss: 0.011453, train_acc: 99.52%
#  | valid_loss: 4.786108, valid_acc: 47.54%
# Epoch: 70
#  | train_loss: 0.009621, train_acc: 99.57%
#  | valid_loss: 4.856649, valid_acc: 48.28%
# Epoch: 71
#  | train_loss: 0.009794, train_acc: 99.54%
#  | valid_loss: 4.867423, valid_acc: 48.77%
# Epoch: 72
#  | train_loss: 0.009652, train_acc: 99.57%
#  | valid_loss: 4.869521, valid_acc: 48.28%
# Epoch: 73
#  | train_loss: 0.010826, train_acc: 99.52%
#  | valid_loss: 4.876368, valid_acc: 48.28%
# Epoch: 74
#  | train_loss: 0.011427, train_acc: 99.49%
#  | valid_loss: 4.999138, valid_acc: 49.26%
# Epoch: 75
#  | train_loss: 0.010824, train_acc: 99.49%
#  | valid_loss: 5.004513, valid_acc: 48.28%
# Epoch: 76
#  | train_loss: 0.010001, train_acc: 99.47%
#  | valid_loss: 4.759676, valid_acc: 48.28%
# Epoch: 77
#  | train_loss: 0.011589, train_acc: 99.57%
#  | valid_loss: 4.779218, valid_acc: 48.28%
# Epoch: 78
#  | train_loss: 0.012313, train_acc: 99.47%
#  | valid_loss: 4.769152, valid_acc: 47.04%
# Epoch: 79
#  | train_loss: 0.010957, train_acc: 99.47%
#  | valid_loss: 4.698351, valid_acc: 47.54%
# Epoch: 80
#  | train_loss: 0.013133, train_acc: 99.54%
#  | valid_loss: 4.565684, valid_acc: 48.52%
# Epoch: 81
#  | train_loss: 0.012078, train_acc: 99.49%
#  | valid_loss: 4.661160, valid_acc: 47.54%
# Epoch: 82
#  | train_loss: 0.013573, train_acc: 99.54%
#  | valid_loss: 4.641716, valid_acc: 48.28%
# Epoch: 83
#  | train_loss: 0.010746, train_acc: 99.44%
#  | valid_loss: 4.682984, valid_acc: 47.54%
# Epoch: 84
#  | train_loss: 0.011477, train_acc: 99.42%
#  | valid_loss: 4.735525, valid_acc: 47.78%
# Epoch: 85
#  | train_loss: 0.012764, train_acc: 99.62%
#  | valid_loss: 4.643873, valid_acc: 48.77%
# Epoch: 86
#  | train_loss: 0.013282, train_acc: 99.49%
#  | valid_loss: 4.694944, valid_acc: 47.54%
# Epoch: 87
#  | train_loss: 0.010414, train_acc: 99.60%
#  | valid_loss: 4.702948, valid_acc: 48.28%
# Epoch: 88
#  | train_loss: 0.010378, train_acc: 99.60%
#  | valid_loss: 4.728433, valid_acc: 49.01%
# Epoch: 89
#  | train_loss: 0.012911, train_acc: 99.54%
#  | valid_loss: 4.746717, valid_acc: 49.01%
# Epoch: 90
#  | train_loss: 0.013060, train_acc: 99.54%
#  | valid_loss: 4.813540, valid_acc: 48.03%
# Epoch: 91
#  | train_loss: 0.010393, train_acc: 99.60%
#  | valid_loss: 4.668143, valid_acc: 48.03%
# Epoch: 92
#  | train_loss: 0.010467, train_acc: 99.52%
#  | valid_loss: 4.757193, valid_acc: 48.03%
# Epoch: 93
#  | train_loss: 0.012970, train_acc: 99.42%
#  | valid_loss: 4.800506, valid_acc: 48.52%
# Epoch: 94
#  | train_loss: 0.011552, train_acc: 99.52%
#  | valid_loss: 4.842770, valid_acc: 48.03%
# Epoch: 95
#  | train_loss: 0.010200, train_acc: 99.62%
#  | valid_loss: 4.730754, valid_acc: 47.78%
# Epoch: 96
#  | train_loss: 0.015662, train_acc: 99.47%
#  | valid_loss: 4.749533, valid_acc: 47.29%
# Epoch: 97
#  | train_loss: 0.010739, train_acc: 99.49%
#  | valid_loss: 4.771102, valid_acc: 48.28%
# Epoch: 98
#  | train_loss: 0.010149, train_acc: 99.54%
#  | valid_loss: 4.898694, valid_acc: 48.03%
# Epoch: 99
#  | train_loss: 0.011365, train_acc: 99.54%
#  | valid_loss: 4.739596, valid_acc: 48.28%

# %%
retrain_model = settingC(retrain_path).to(device)
# print(retrain_model)
train(retrain_model)

# %%
model_test = settingC_test(ckpt_path=pretrained_path).to(device)
# print(model_test)
train(model_test, 100)
# Out:
# Epoch: 00
#  | train_loss: 53.111701, train_acc: 3.70%
#  | valid_loss: 68.357141, valid_acc: 4.19%
#   -> Save checkpoint for epoch 1
# Epoch: 01
#  | train_loss: 28.632619, train_acc: 4.83%
#  | valid_loss: 30.741114, valid_acc: 5.42%
#   -> Save checkpoint for epoch 2
# Epoch: 02
#  | train_loss: 11.392763, train_acc: 9.92%
#  | valid_loss: 12.966138, valid_acc: 13.05%
#   -> Save checkpoint for epoch 3
# Epoch: 03
#  | train_loss: 4.984563, train_acc: 18.10%
#  | valid_loss: 4.375611, valid_acc: 19.70%
#   -> Save checkpoint for epoch 4
# Epoch: 04
#  | train_loss: 3.163594, train_acc: 27.06%
#  | valid_loss: 4.450042, valid_acc: 21.18%
#   -> Save checkpoint for epoch 5
# Epoch: 05
#  | train_loss: 3.106811, train_acc: 29.61%
#  | valid_loss: 4.137927, valid_acc: 22.91%
#   -> Save checkpoint for epoch 6
# Epoch: 06
#  | train_loss: 2.755565, train_acc: 36.70%
#  | valid_loss: 3.463210, valid_acc: 33.74%
#   -> Save checkpoint for epoch 7
# Epoch: 07
#  | train_loss: 2.420236, train_acc: 41.33%
#  | valid_loss: 4.157493, valid_acc: 29.31%
# Epoch: 08
#  | train_loss: 1.963191, train_acc: 49.30%
#  | valid_loss: 2.654119, valid_acc: 38.18%
#   -> Save checkpoint for epoch 9
# Epoch: 09
#  | train_loss: 1.660273, train_acc: 55.40%
#  | valid_loss: 3.945379, valid_acc: 35.47%
# Epoch: 10
#  | train_loss: 1.322025, train_acc: 62.49%
#  | valid_loss: 4.362628, valid_acc: 36.70%
# Epoch: 11
#  | train_loss: 1.100446, train_acc: 67.70%
#  | valid_loss: 3.041395, valid_acc: 40.15%
#   -> Save checkpoint for epoch 12
# Epoch: 12
#  | train_loss: 0.775145, train_acc: 75.70%
#  | valid_loss: 3.104338, valid_acc: 42.12%
#   -> Save checkpoint for epoch 13
# Epoch: 13
#  | train_loss: 0.537119, train_acc: 82.64%
#  | valid_loss: 3.445274, valid_acc: 39.16%
# Epoch: 14
#  | train_loss: 0.482059, train_acc: 84.86%
#  | valid_loss: 3.888498, valid_acc: 38.67%
# Epoch: 15
#  | train_loss: 0.403295, train_acc: 87.22%
#  | valid_loss: 4.050119, valid_acc: 39.66%
# Epoch: 16
#  | train_loss: 0.295755, train_acc: 90.61%
#  | valid_loss: 4.205638, valid_acc: 39.16%
# Epoch: 17
#  | train_loss: 0.216189, train_acc: 93.39%
#  | valid_loss: 5.525650, valid_acc: 40.15%
# Epoch: 18
#  | train_loss: 0.140608, train_acc: 96.13%
#  | valid_loss: 3.776512, valid_acc: 38.18%
# Epoch: 19
#  | train_loss: 0.124205, train_acc: 96.68%
#  | valid_loss: 4.222350, valid_acc: 40.89%
# Epoch: 20
#  | train_loss: 0.089931, train_acc: 97.82%
#  | valid_loss: 4.919374, valid_acc: 40.39%
# Epoch: 21
#  | train_loss: 0.074111, train_acc: 98.30%
#  | valid_loss: 4.902956, valid_acc: 41.38%
# Epoch: 22
#  | train_loss: 0.101206, train_acc: 97.09%
#  | valid_loss: 4.851899, valid_acc: 38.42%
# Epoch: 23
#  | train_loss: 0.151822, train_acc: 95.80%
#  | valid_loss: 7.302937, valid_acc: 36.95%
# Epoch: 24
#  | train_loss: 0.170813, train_acc: 94.61%
#  | valid_loss: 4.949809, valid_acc: 37.68%
# Epoch: 25
#  | train_loss: 0.134897, train_acc: 95.85%
#  | valid_loss: 5.669526, valid_acc: 42.36%
#   -> Save checkpoint for epoch 26
# Epoch: 26
#  | train_loss: 0.104330, train_acc: 96.81%
#  | valid_loss: 5.333710, valid_acc: 37.68%
# Epoch: 27
#  | train_loss: 0.127507, train_acc: 96.48%
#  | valid_loss: 5.046779, valid_acc: 39.41%
# Epoch: 28
#  | train_loss: 0.111670, train_acc: 96.58%
#  | valid_loss: 4.510995, valid_acc: 41.13%
# Epoch: 29
#  | train_loss: 0.124491, train_acc: 96.36%
#  | valid_loss: 5.777028, valid_acc: 38.92%
# Epoch: 30
#  | train_loss: 0.060976, train_acc: 98.30%
#  | valid_loss: 4.650886, valid_acc: 41.38%
# Epoch: 31
#  | train_loss: 0.020796, train_acc: 99.34%
#  | valid_loss: 4.517517, valid_acc: 41.38%
# Epoch: 32
#  | train_loss: 0.018036, train_acc: 99.22%
#  | valid_loss: 4.535949, valid_acc: 40.39%
# Epoch: 33
#  | train_loss: 0.016751, train_acc: 99.47%
#  | valid_loss: 4.431835, valid_acc: 40.39%
# Epoch: 34
#  | train_loss: 0.014589, train_acc: 99.49%
#  | valid_loss: 4.555415, valid_acc: 40.64%
# Epoch: 35
#  | train_loss: 0.012700, train_acc: 99.60%
#  | valid_loss: 4.280665, valid_acc: 40.64%
# Epoch: 36
#  | train_loss: 0.016785, train_acc: 99.54%
#  | valid_loss: 4.767770, valid_acc: 42.12%
# Epoch: 37
#  | train_loss: 0.013235, train_acc: 99.54%
#  | valid_loss: 4.382729, valid_acc: 41.63%
# Epoch: 38
#  | train_loss: 0.015890, train_acc: 99.44%
#  | valid_loss: 4.580526, valid_acc: 41.63%
# Epoch: 39
#  | train_loss: 0.014675, train_acc: 99.52%
#  | valid_loss: 4.787817, valid_acc: 41.13%
# Epoch: 40
#  | train_loss: 0.015258, train_acc: 99.47%
#  | valid_loss: 4.648271, valid_acc: 40.39%
# Epoch: 41
#  | train_loss: 0.014448, train_acc: 99.52%
#  | valid_loss: 4.951792, valid_acc: 41.63%
# Epoch: 42
#  | train_loss: 0.012506, train_acc: 99.52%
#  | valid_loss: 4.645231, valid_acc: 41.38%
# Epoch: 43
#  | train_loss: 0.011379, train_acc: 99.60%
#  | valid_loss: 4.772719, valid_acc: 41.63%
# Epoch: 44
#  | train_loss: 0.014174, train_acc: 99.47%
#  | valid_loss: 4.722612, valid_acc: 42.12%
# Epoch: 45
#  | train_loss: 0.013069, train_acc: 99.52%
#  | valid_loss: 4.653582, valid_acc: 41.87%
# Epoch: 46
#  | train_loss: 0.013842, train_acc: 99.44%
#  | valid_loss: 4.532532, valid_acc: 41.87%
# Epoch: 47
#  | train_loss: 0.012099, train_acc: 99.44%
#  | valid_loss: 4.597035, valid_acc: 42.61%
#   -> Save checkpoint for epoch 48
# Epoch: 48
#  | train_loss: 0.010961, train_acc: 99.44%
#  | valid_loss: 4.697542, valid_acc: 42.36%
# Epoch: 49
#  | train_loss: 0.012143, train_acc: 99.47%
#  | valid_loss: 4.603260, valid_acc: 42.61%
# Epoch: 50
#  | train_loss: 0.014482, train_acc: 99.49%
#  | valid_loss: 4.798906, valid_acc: 42.61%
# Epoch: 51
#  | train_loss: 0.014723, train_acc: 99.44%
#  | valid_loss: 4.514176, valid_acc: 42.36%
# Epoch: 52
#  | train_loss: 0.012449, train_acc: 99.44%
#  | valid_loss: 4.562000, valid_acc: 42.36%
# Epoch: 53
#  | train_loss: 0.011774, train_acc: 99.49%
#  | valid_loss: 4.764060, valid_acc: 41.87%
# Epoch: 54
#  | train_loss: 0.012236, train_acc: 99.49%
#  | valid_loss: 4.806260, valid_acc: 41.63%
# Epoch: 55
#  | train_loss: 0.012761, train_acc: 99.42%
#  | valid_loss: 4.639417, valid_acc: 42.12%
# Epoch: 56
#  | train_loss: 0.015780, train_acc: 99.39%
#  | valid_loss: 4.940049, valid_acc: 41.63%
# Epoch: 57
#  | train_loss: 0.016651, train_acc: 99.42%
#  | valid_loss: 4.636861, valid_acc: 41.87%
# Epoch: 58
#  | train_loss: 0.014922, train_acc: 99.44%
#  | valid_loss: 4.687054, valid_acc: 42.61%
# Epoch: 59
#  | train_loss: 0.014803, train_acc: 99.44%
#  | valid_loss: 4.459893, valid_acc: 42.12%
# Epoch: 60
#  | train_loss: 0.014441, train_acc: 99.54%
#  | valid_loss: 4.937301, valid_acc: 43.60%
#   -> Save checkpoint for epoch 61
# Epoch: 61
#  | train_loss: 0.016503, train_acc: 99.44%
#  | valid_loss: 4.720526, valid_acc: 43.60%
# Epoch: 62
#  | train_loss: 0.014124, train_acc: 99.52%
#  | valid_loss: 4.458255, valid_acc: 43.35%
# Epoch: 63
#  | train_loss: 0.013220, train_acc: 99.52%
#  | valid_loss: 4.757892, valid_acc: 42.86%
# Epoch: 64
#  | train_loss: 0.012836, train_acc: 99.47%
#  | valid_loss: 4.583646, valid_acc: 43.35%
# Epoch: 65
#  | train_loss: 0.012325, train_acc: 99.47%
#  | valid_loss: 4.498691, valid_acc: 42.36%
# Epoch: 66
#  | train_loss: 0.014510, train_acc: 99.52%
#  | valid_loss: 5.071114, valid_acc: 42.61%
# Epoch: 67
#  | train_loss: 0.013048, train_acc: 99.57%
#  | valid_loss: 4.371349, valid_acc: 42.36%
# Epoch: 68
#  | train_loss: 0.015662, train_acc: 99.54%
#  | valid_loss: 4.750017, valid_acc: 42.61%
# Epoch: 69
#  | train_loss: 0.016884, train_acc: 99.37%
#  | valid_loss: 4.788933, valid_acc: 43.60%
# Epoch: 70
#  | train_loss: 0.010935, train_acc: 99.57%
#  | valid_loss: 4.397787, valid_acc: 41.87%
# Epoch: 71
#  | train_loss: 0.012543, train_acc: 99.42%
#  | valid_loss: 4.665641, valid_acc: 42.86%
# Epoch: 72
#  | train_loss: 0.014901, train_acc: 99.57%
#  | valid_loss: 4.343636, valid_acc: 41.38%
# Epoch: 73
#  | train_loss: 0.010650, train_acc: 99.54%
#  | valid_loss: 4.835404, valid_acc: 41.63%
# Epoch: 74
#  | train_loss: 0.010305, train_acc: 99.65%
#  | valid_loss: 4.637686, valid_acc: 42.36%
# Epoch: 75
#  | train_loss: 0.012815, train_acc: 99.57%
#  | valid_loss: 4.326653, valid_acc: 42.86%
# Epoch: 76
#  | train_loss: 0.016865, train_acc: 99.52%
#  | valid_loss: 4.734784, valid_acc: 43.10%
# Epoch: 77
#  | train_loss: 0.010757, train_acc: 99.47%
#  | valid_loss: 4.370136, valid_acc: 42.86%
# Epoch: 78
#  | train_loss: 0.014066, train_acc: 99.44%
#  | valid_loss: 4.436969, valid_acc: 43.10%
# Epoch: 79
#  | train_loss: 0.014153, train_acc: 99.49%
#  | valid_loss: 4.671476, valid_acc: 42.12%
# Epoch: 80
#  | train_loss: 0.015513, train_acc: 99.52%
#  | valid_loss: 5.106268, valid_acc: 42.12%
# Epoch: 81
#  | train_loss: 0.016791, train_acc: 99.57%
#  | valid_loss: 4.436619, valid_acc: 42.12%
# Epoch: 82
#  | train_loss: 0.011882, train_acc: 99.60%
#  | valid_loss: 4.584467, valid_acc: 42.12%
# Epoch: 83
#  | train_loss: 0.016456, train_acc: 99.42%
#  | valid_loss: 4.799736, valid_acc: 42.36%
# Epoch: 84
#  | train_loss: 0.014031, train_acc: 99.52%
#  | valid_loss: 4.712400, valid_acc: 42.36%
# Epoch: 85
#  | train_loss: 0.014119, train_acc: 99.60%
#  | valid_loss: 5.056869, valid_acc: 42.36%
# Epoch: 86
#  | train_loss: 0.017709, train_acc: 99.52%
#  | valid_loss: 4.617921, valid_acc: 41.87%
# Epoch: 87
#  | train_loss: 0.011453, train_acc: 99.52%
#  | valid_loss: 4.667373, valid_acc: 43.60%
# Epoch: 88
#  | train_loss: 0.013717, train_acc: 99.60%
#  | valid_loss: 4.815401, valid_acc: 42.12%
# Epoch: 89
#  | train_loss: 0.016168, train_acc: 99.49%
#  | valid_loss: 4.045636, valid_acc: 42.86%
# Epoch: 90
#  | train_loss: 0.017990, train_acc: 99.52%
#  | valid_loss: 4.778232, valid_acc: 42.61%
# Epoch: 91
#  | train_loss: 0.015478, train_acc: 99.47%
#  | valid_loss: 4.754371, valid_acc: 44.09%
#   -> Save checkpoint for epoch 92
# Epoch: 92
#  | train_loss: 0.013452, train_acc: 99.54%
#  | valid_loss: 4.602917, valid_acc: 43.84%
# Epoch: 93
#  | train_loss: 0.018906, train_acc: 99.39%
#  | valid_loss: 4.899005, valid_acc: 44.58%
#   -> Save checkpoint for epoch 94
# Epoch: 94
#  | train_loss: 0.011102, train_acc: 99.57%
#  | valid_loss: 4.686293, valid_acc: 44.09%
# Epoch: 95
#  | train_loss: 0.015747, train_acc: 99.49%
#  | valid_loss: 4.341567, valid_acc: 42.86%
# Epoch: 96
#  | train_loss: 0.015627, train_acc: 99.54%
#  | valid_loss: 4.705211, valid_acc: 42.86%
# Epoch: 97
#  | train_loss: 0.015526, train_acc: 99.54%
#  | valid_loss: 4.141058, valid_acc: 44.09%
# Epoch: 98
#  | train_loss: 0.014545, train_acc: 99.54%
#  | valid_loss: 4.287057, valid_acc: 43.84%
# Epoch: 99
#  | train_loss: 0.016079, train_acc: 99.49%
#  | valid_loss: 4.672982, valid_acc: 42.36%
