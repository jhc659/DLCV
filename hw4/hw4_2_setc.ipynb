# %%
import os
import glob
import json 
import time
import math
import random

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
import torchvision
import torchvision.transforms as transforms
import pandas as pd
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np
from tensorboardX import SummaryWriter


from byol_pytorch import BYOL
from torchvision import models

# %%
train_path = "/data/dlcv/hw4/office/train"
valid_path = "/data/dlcv/hw4/office/val"
train_csv = "/data/dlcv/hw4/office/train.csv"
valid_csv = "/data/dlcv/hw4/office/val.csv"
label2id_path = "./label2id.json"
ckpt_path = "./ckpt/finetune"
pretrained_path = "/data/jhccc/dlcv/hw4-jhc659/ckpt/resnetLast.pth"
retrain_path = "/data/jhccc/dlcv/hw4-jhc659/ckpt/finetune/settingC2_best.pth"
os.makedirs(ckpt_path, exist_ok=True)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
torch.cuda.set_device(4)
print('Device used:', device)

img_size = 128
train_bz = 64
valid_bz = 200
# Out:
# Device used: cuda

# %%
class dataset(Dataset):
    def __init__(self, inputPath, csvPath, label2idPath, transform=None):
        self.inputPath = inputPath
        self.transform = transform
        with open(label2idPath, 'r') as j:
            self.label2id = json.loads(j.read())
        self.inputName = []
        df = pd.read_csv(csvPath)
        for i in range(len(df)):
            self.inputName.append((df.loc[i].filename, self.label2id[df.loc[i].label]))
        print(self.inputName[0])
        
    def __getitem__(self, index):
        img = Image.open(os.path.join(self.inputPath, self.inputName[index][0]))
        if self.transform:
            img = self.transform(img)
        id = self.inputName[index][1]
        return img, id

    def __len__(self):
        return len(self.inputName)

img_transform = transforms.Compose([
    transforms.Resize(size=128),
    transforms.CenterCrop(128),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485,0.456,0.406], std=[0.229,0.224,0.225])
])

def imshow(img):
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))

def save_checkpoint(ckpt_path, model, optimizer):
    state = {'model_state_dict': model.state_dict(),
             'optimizer_state_dict': optimizer.state_dict(),}
    torch.save(state, ckpt_path)

def load_checkpoint(ckpt_path, device=device):
    ckpt = torch.load(ckpt_path, map_location=device)
    return ckpt

def epoch_time(start_time, end_time):
    elapsed_time = end_time - start_time
    elapsed_mins = int(elapsed_time / 60)
    elapsed_secs = int(elapsed_time - (elapsed_mins * 60))
    return elapsed_mins, elapsed_secs

# %%
trainDS = dataset(inputPath=train_path, csvPath=train_csv, label2idPath=label2id_path, transform=img_transform)
trainLoader = DataLoader(dataset=trainDS, batch_size=train_bz, shuffle=True, num_workers=4)

print('# images in trainset:', len(trainDS))
# print('# images in validset:', len(validDS))

# dataiter = iter(validLoader)
# images, labels = dataiter.next()
# # print(labels)
# print('Image tensor in each batch:', images.shape, images.dtype)
# print('Label tensor in each batch:', labels.shape, labels.dtype)
# Out:
# ('Couch00015.jpg', 13)
# ('Fork00005.jpg', 24)
# # images in trainset: 3951
# # images in validset: 406

# %%
class settingC(nn.Module):
    def __init__(self, ckpt_path=None) -> None:
        super().__init__()
        self.resnet = models.resnet50(weights=None)
        if ckpt_path is not None:
            ckpt = load_checkpoint(ckpt_path, device)
            self.resnet.load_state_dict(ckpt['model_state_dict'])
        self.resnet = nn.Sequential(*list(self.resnet.children())[:-1])
        # self.classifier = nn.Sequential(
        #     nn.Linear(self.resnet.fc.out_features, 65)
        # )
        self.classifier = nn.Linear(2048, 65)
    def forward(self, x):
        x = self.resnet(x).flatten(1)
        return self.classifier(x)

# %%
# trainning
def train(model, epochs, retrain=False):
    model = model.to(device)
    if retrain:
        optimizer = torch.optim.RAdam(model.parameters(), lr=3e-4, weight_decay=5e-3)
        scheduler = torch.optim.lr_scheduler.MultiStepLR(optimizer, milestones=[30,100], gamma=0.9)
    else:         
        optimizer = torch.optim.Adam(model.parameters(), lr=3e-3)
        scheduler = torch.optim.lr_scheduler.MultiStepLR(optimizer, milestones=[30,100], gamma=0.9)
    criterion = nn.CrossEntropyLoss()
    best_acc = 0.

    for epoch in range(epochs):
        model.train()        
        train_loss, valid_loss = 0, 0
        train_acc, valid_acc = 0, 0
        for i, (img, label) in enumerate(trainLoader):
            img, label = img.to(device), label.to(device)
            optimizer.zero_grad()
            output = model(img)
            pred = output.max(1, keepdim=True)[1] # get the index of the max log-probability
            train_acc += pred.eq(label.view_as(pred)).sum().item()
            loss = criterion(output, label)
            train_loss += loss.item()
            loss.backward()
            optimizer.step()                
        scheduler.step()
        train_loss /= (i+1)
        train_acc /= len(trainLoader.dataset)
        print("Epoch: {:02}".format(epoch))
        print(" | train_loss: {:6f}, train_acc: {:.2%}".format(train_loss, train_acc))
        model.eval()
        with torch.no_grad(): # This will free the GPU memory used for back-prop
            for i, (img, label) in enumerate(validLoader):
                img, label = img.to(device), label.to(device)
                output = model(img)
                valid_loss += criterion(output, label).item() # sum up batch loss
                pred = output.max(1, keepdim=True)[1] # get the index of the max log-probability
                valid_acc += pred.eq(label.view_as(pred)).sum().item()
                # resultClass = torch.argmax(output, dim=1)
                # acc += (resultClass == target).sum()
            valid_loss /= (i+1)
            valid_acc /= len(validLoader.dataset)
        
        save_checkpoint(os.path.join(ckpt_path, "settingC_last.pth"), model, optimizer)
        print(" | valid_loss: {:6f}, valid_acc: {:.2%}".format(valid_loss, valid_acc))
        
        if valid_acc > best_acc:
            save_checkpoint(os.path.join(ckpt_path, "settingC_best.pth"), model, optimizer)
            print("  -> Save checkpoint for epoch {}".format(epoch+1))
            best_acc = valid_acc

# %%
model = settingC(ckpt_path=pretrained_path).to(device)
# print(model)
train(model, 100)
# Out:
# Epoch: 00
#  | train_loss: 31.810889, train_acc: 2.15%
#  | valid_loss: 12.474689, valid_acc: 4.19%
#   -> Save checkpoint for epoch 1
# Epoch: 01
#  | train_loss: 6.774861, train_acc: 4.30%
#  | valid_loss: 5.965753, valid_acc: 5.17%
#   -> Save checkpoint for epoch 2
# Epoch: 02
#  | train_loss: 4.845631, train_acc: 6.91%
#  | valid_loss: 4.518285, valid_acc: 8.37%
#   -> Save checkpoint for epoch 3
# Epoch: 03
#  | train_loss: 5.058013, train_acc: 10.00%
#  | valid_loss: 4.210298, valid_acc: 12.07%
#   -> Save checkpoint for epoch 4
# Epoch: 04
#  | train_loss: 4.810023, train_acc: 12.43%
#  | valid_loss: 5.451992, valid_acc: 13.55%
#   -> Save checkpoint for epoch 5
# Epoch: 05
#  | train_loss: 4.355129, train_acc: 17.11%
#  | valid_loss: 5.255645, valid_acc: 16.01%
#   -> Save checkpoint for epoch 6
# Epoch: 06
#  | train_loss: 4.437893, train_acc: 18.07%
#  | valid_loss: 4.348756, valid_acc: 17.73%
#   -> Save checkpoint for epoch 7
# Epoch: 07
#  | train_loss: 3.866360, train_acc: 24.17%
#  | valid_loss: 4.455556, valid_acc: 20.20%
#   -> Save checkpoint for epoch 8
# Epoch: 08
#  | train_loss: 3.658560, train_acc: 27.13%
#  | valid_loss: 3.466661, valid_acc: 23.15%
#   -> Save checkpoint for epoch 9
# Epoch: 09
#  | train_loss: 3.226225, train_acc: 30.65%
#  | valid_loss: 3.443495, valid_acc: 23.40%
#   -> Save checkpoint for epoch 10
# Epoch: 10
#  | train_loss: 3.140363, train_acc: 34.52%
#  | valid_loss: 3.805922, valid_acc: 28.82%
#   -> Save checkpoint for epoch 11
# Epoch: 11
#  | train_loss: 2.601773, train_acc: 40.80%
#  | valid_loss: 3.745893, valid_acc: 25.12%
# Epoch: 12
#  | train_loss: 2.292179, train_acc: 45.43%
#  | valid_loss: 5.828022, valid_acc: 25.62%
# Epoch: 13
#  | train_loss: 1.984128, train_acc: 51.58%
#  | valid_loss: 3.733509, valid_acc: 28.82%
# Epoch: 14
#  | train_loss: 1.727051, train_acc: 57.18%
#  | valid_loss: 4.265863, valid_acc: 31.28%
#   -> Save checkpoint for epoch 15
# Epoch: 15
#  | train_loss: 1.547023, train_acc: 61.20%
#  | valid_loss: 5.524010, valid_acc: 27.59%
# Epoch: 16
#  | train_loss: 1.441025, train_acc: 62.52%
#  | valid_loss: 4.525429, valid_acc: 27.83%
# Epoch: 17
#  | train_loss: 1.029826, train_acc: 70.79%
#  | valid_loss: 3.791038, valid_acc: 31.28%
# Epoch: 18
#  | train_loss: 0.877736, train_acc: 75.65%
#  | valid_loss: 5.704095, valid_acc: 30.30%
# Epoch: 19
#  | train_loss: 0.640193, train_acc: 80.81%
#  | valid_loss: 3.844329, valid_acc: 33.99%
#   -> Save checkpoint for epoch 20
# Epoch: 20
#  | train_loss: 0.437027, train_acc: 86.81%
#  | valid_loss: 5.459960, valid_acc: 26.35%
# Epoch: 21
#  | train_loss: 0.414387, train_acc: 87.83%
#  | valid_loss: 5.441994, valid_acc: 27.09%
# Epoch: 22
#  | train_loss: 0.352927, train_acc: 89.85%
#  | valid_loss: 5.227189, valid_acc: 31.53%
# Epoch: 23
#  | train_loss: 0.263709, train_acc: 91.34%
#  | valid_loss: 6.229731, valid_acc: 28.57%
# Epoch: 24
#  | train_loss: 0.281400, train_acc: 91.95%
#  | valid_loss: 5.061085, valid_acc: 29.31%
# Epoch: 25
#  | train_loss: 0.349328, train_acc: 89.52%
#  | valid_loss: 6.589473, valid_acc: 29.31%
# Epoch: 26
#  | train_loss: 0.339805, train_acc: 90.28%
#  | valid_loss: 6.840157, valid_acc: 25.86%
# Epoch: 27
#  | train_loss: 0.305710, train_acc: 90.74%
#  | valid_loss: 5.917529, valid_acc: 26.35%
# Epoch: 28
#  | train_loss: 0.255907, train_acc: 92.71%
#  | valid_loss: 6.694418, valid_acc: 31.03%
# Epoch: 29
#  | train_loss: 0.163519, train_acc: 94.94%
#  | valid_loss: 5.148413, valid_acc: 35.22%
#   -> Save checkpoint for epoch 30
# Epoch: 30
#  | train_loss: 0.169069, train_acc: 94.91%
#  | valid_loss: 5.339080, valid_acc: 30.79%
# Epoch: 31
#  | train_loss: 0.183394, train_acc: 94.53%
#  | valid_loss: 4.768098, valid_acc: 31.53%
# Epoch: 32
#  | train_loss: 0.179410, train_acc: 94.74%
#  | valid_loss: 5.418714, valid_acc: 31.28%
# Epoch: 33
#  | train_loss: 0.185410, train_acc: 94.74%
#  | valid_loss: 5.074198, valid_acc: 32.51%
# Epoch: 34
#  | train_loss: 0.160417, train_acc: 95.27%
#  | valid_loss: 5.522320, valid_acc: 28.33%
# Epoch: 35
#  | train_loss: 0.165341, train_acc: 95.55%
#  | valid_loss: 7.383366, valid_acc: 33.00%
# Epoch: 36
#  | train_loss: 0.273259, train_acc: 92.71%
#  | valid_loss: 5.772254, valid_acc: 31.28%
# Epoch: 37
#  | train_loss: 0.283905, train_acc: 91.93%
#  | valid_loss: 7.295923, valid_acc: 29.80%
# Epoch: 38
#  | train_loss: 0.273047, train_acc: 92.33%
#  | valid_loss: 7.176066, valid_acc: 31.28%
# Epoch: 39
#  | train_loss: 0.226447, train_acc: 94.25%
#  | valid_loss: 7.398214, valid_acc: 31.28%
# Epoch: 40
#  | train_loss: 0.165602, train_acc: 95.44%
#  | valid_loss: 7.419551, valid_acc: 32.51%
# Epoch: 41
#  | train_loss: 0.130942, train_acc: 96.33%
#  | valid_loss: 6.191945, valid_acc: 33.99%
# Epoch: 42
#  | train_loss: 0.147165, train_acc: 96.13%
#  | valid_loss: 7.098804, valid_acc: 32.76%
# Epoch: 43
#  | train_loss: 0.104230, train_acc: 97.39%
#  | valid_loss: 8.687050, valid_acc: 29.80%
# Epoch: 44
#  | train_loss: 0.114000, train_acc: 97.24%
#  | valid_loss: 6.255948, valid_acc: 33.74%
# Epoch: 45
#  | train_loss: 0.115207, train_acc: 96.71%
#  | valid_loss: 9.071659, valid_acc: 32.27%
# Epoch: 46
#  | train_loss: 0.155095, train_acc: 96.03%
#  | valid_loss: 6.063506, valid_acc: 30.54%
# Epoch: 47
#  | train_loss: 0.333233, train_acc: 92.26%
#  | valid_loss: 7.579654, valid_acc: 28.82%
# Epoch: 48
#  | train_loss: 0.334957, train_acc: 91.57%
#  | valid_loss: 7.825530, valid_acc: 31.53%
# Epoch: 49
#  | train_loss: 0.283381, train_acc: 92.79%
#  | valid_loss: 7.161774, valid_acc: 31.53%
# Epoch: 50
#  | train_loss: 0.154472, train_acc: 96.05%
#  | valid_loss: 6.528266, valid_acc: 32.51%
# Epoch: 51
#  | train_loss: 0.159155, train_acc: 95.98%
#  | valid_loss: 7.420334, valid_acc: 28.82%
# Epoch: 52
#  | train_loss: 0.072209, train_acc: 97.82%
#  | valid_loss: 7.646501, valid_acc: 31.53%
# Epoch: 53
#  | train_loss: 0.063444, train_acc: 98.28%
#  | valid_loss: 7.488717, valid_acc: 32.02%
# Epoch: 54
#  | train_loss: 0.060434, train_acc: 98.48%
#  | valid_loss: 6.324852, valid_acc: 35.22%
# Epoch: 55
#  | train_loss: 0.076807, train_acc: 98.13%
#  | valid_loss: 6.792606, valid_acc: 33.99%
# Epoch: 56
#  | train_loss: 0.073816, train_acc: 98.35%
#  | valid_loss: 6.820076, valid_acc: 32.51%
# Epoch: 57
#  | train_loss: 0.090197, train_acc: 97.77%
#  | valid_loss: 9.331763, valid_acc: 33.00%
# Epoch: 58
#  | train_loss: 0.085936, train_acc: 97.60%
#  | valid_loss: 7.652266, valid_acc: 32.27%
# Epoch: 59
#  | train_loss: 0.110056, train_acc: 97.27%
#  | valid_loss: 7.084343, valid_acc: 32.02%
# Epoch: 60
#  | train_loss: 0.126474, train_acc: 97.14%
#  | valid_loss: 8.380831, valid_acc: 32.27%
# Epoch: 61
#  | train_loss: 0.110736, train_acc: 97.24%
#  | valid_loss: 8.658967, valid_acc: 32.51%
# Epoch: 62
#  | train_loss: 0.090054, train_acc: 97.54%
#  | valid_loss: 7.838451, valid_acc: 29.06%
# Epoch: 63
#  | train_loss: 0.122302, train_acc: 97.04%
#  | valid_loss: 11.346479, valid_acc: 31.77%
# Epoch: 64
#  | train_loss: 0.168120, train_acc: 95.75%
#  | valid_loss: 7.465327, valid_acc: 31.77%
# Epoch: 65
#  | train_loss: 0.165905, train_acc: 96.28%
#  | valid_loss: 8.918014, valid_acc: 28.08%
# Epoch: 66
#  | train_loss: 0.169570, train_acc: 95.95%
#  | valid_loss: 7.448502, valid_acc: 31.53%
# Epoch: 67
#  | train_loss: 0.111758, train_acc: 97.37%
#  | valid_loss: 6.540475, valid_acc: 31.77%
# Epoch: 68
#  | train_loss: 0.144332, train_acc: 96.46%
#  | valid_loss: 7.698590, valid_acc: 34.24%
# Epoch: 69
#  | train_loss: 0.099119, train_acc: 97.52%
#  | valid_loss: 7.617025, valid_acc: 32.76%
# Epoch: 70
#  | train_loss: 0.078768, train_acc: 98.18%
#  | valid_loss: 8.445317, valid_acc: 33.50%
# Epoch: 71
#  | train_loss: 0.071815, train_acc: 98.56%
#  | valid_loss: 7.193517, valid_acc: 30.54%
# Epoch: 72
#  | train_loss: 0.073869, train_acc: 98.28%
#  | valid_loss: 6.799312, valid_acc: 32.02%
# Epoch: 73
#  | train_loss: 0.056797, train_acc: 98.03%
#  | valid_loss: 7.499911, valid_acc: 34.48%
# Epoch: 74
#  | train_loss: 0.086198, train_acc: 97.95%
#  | valid_loss: 7.592690, valid_acc: 33.74%
# Epoch: 75
#  | train_loss: 0.061695, train_acc: 98.28%
#  | valid_loss: 7.071942, valid_acc: 32.27%
# Epoch: 76
#  | train_loss: 0.053330, train_acc: 98.46%
#  | valid_loss: 6.740853, valid_acc: 33.25%
# Epoch: 77
#  | train_loss: 0.070566, train_acc: 98.13%
#  | valid_loss: 6.784809, valid_acc: 34.24%
# Epoch: 78
#  | train_loss: 0.088179, train_acc: 97.49%
#  | valid_loss: 7.320268, valid_acc: 32.27%
# Epoch: 79
#  | train_loss: 0.091681, train_acc: 97.60%
#  | valid_loss: 7.623872, valid_acc: 31.28%
# Epoch: 80
#  | train_loss: 0.095437, train_acc: 97.44%
#  | valid_loss: 6.976478, valid_acc: 30.30%
# Epoch: 81
#  | train_loss: 0.092536, train_acc: 97.57%
#  | valid_loss: 8.801593, valid_acc: 32.51%
# Epoch: 82
#  | train_loss: 0.103571, train_acc: 97.39%
#  | valid_loss: 9.097260, valid_acc: 33.00%
# Epoch: 83
#  | train_loss: 0.088415, train_acc: 97.44%
#  | valid_loss: 8.221882, valid_acc: 32.02%
# Epoch: 84
#  | train_loss: 0.148105, train_acc: 96.61%
#  | valid_loss: 9.002570, valid_acc: 30.79%
# Epoch: 85
#  | train_loss: 0.081630, train_acc: 97.60%
#  | valid_loss: 6.654791, valid_acc: 34.73%
# Epoch: 86
#  | train_loss: 0.055520, train_acc: 98.58%
#  | valid_loss: 6.765664, valid_acc: 34.48%
# Epoch: 87
#  | train_loss: 0.036465, train_acc: 99.04%
#  | valid_loss: 7.269250, valid_acc: 34.24%
# Epoch: 88
#  | train_loss: 0.030064, train_acc: 99.27%
#  | valid_loss: 6.521830, valid_acc: 34.73%
# Epoch: 89
#  | train_loss: 0.032984, train_acc: 99.14%
#  | valid_loss: 6.580290, valid_acc: 35.47%
#   -> Save checkpoint for epoch 90
# Epoch: 90
#  | train_loss: 0.023903, train_acc: 99.37%
#  | valid_loss: 6.519198, valid_acc: 33.99%
# Epoch: 91
#  | train_loss: 0.024736, train_acc: 99.42%
#  | valid_loss: 6.661612, valid_acc: 36.21%
#   -> Save checkpoint for epoch 92
# Epoch: 92
#  | train_loss: 0.024734, train_acc: 99.32%
#  | valid_loss: 7.219197, valid_acc: 36.70%
#   -> Save checkpoint for epoch 93
# Epoch: 93
#  | train_loss: 0.015902, train_acc: 99.47%
#  | valid_loss: 6.819473, valid_acc: 34.48%
# Epoch: 94
#  | train_loss: 0.018815, train_acc: 99.42%
#  | valid_loss: 6.546121, valid_acc: 36.45%
# Epoch: 95
#  | train_loss: 0.016519, train_acc: 99.47%
#  | valid_loss: 6.946301, valid_acc: 36.70%
# Epoch: 96
#  | train_loss: 0.023951, train_acc: 99.32%
#  | valid_loss: 7.400840, valid_acc: 35.96%
# Epoch: 97
#  | train_loss: 0.018842, train_acc: 99.39%
#  | valid_loss: 7.490122, valid_acc: 33.99%
# Epoch: 98
#  | train_loss: 0.017557, train_acc: 99.44%
#  | valid_loss: 8.901755, valid_acc: 31.77%
# Epoch: 99
#  | train_loss: 0.019976, train_acc: 99.29%
#  | valid_loss: 8.241032, valid_acc: 32.51%

# %%
retrain_model = settingC().to(device)
retrain_model.load_state_dict(torch.load(retrain_path, map_location=device)['model_state_dict'])
# print(retrain_model)
train(retrain_model, 50, retrain=True)
# Out:
# Epoch: 00
#  | train_loss: 0.035047, train_acc: 99.24%
#  | valid_loss: 3.636503, valid_acc: 46.80%
#   -> Save checkpoint for epoch 1
# Epoch: 01
#  | train_loss: 0.032012, train_acc: 99.27%
#  | valid_loss: 3.483169, valid_acc: 47.29%
#   -> Save checkpoint for epoch 2
# Epoch: 02
#  | train_loss: 0.025648, train_acc: 99.37%
#  | valid_loss: 3.281645, valid_acc: 46.31%
# Epoch: 03
#  | train_loss: 0.030107, train_acc: 99.32%
#  | valid_loss: 3.656586, valid_acc: 47.29%
# Epoch: 04
#  | train_loss: 0.032642, train_acc: 99.34%
#  | valid_loss: 3.376266, valid_acc: 47.29%
# Epoch: 05
#  | train_loss: 0.031442, train_acc: 99.39%
#  | valid_loss: 3.323275, valid_acc: 46.06%
# Epoch: 06
#  | train_loss: 0.039632, train_acc: 99.37%
#  | valid_loss: 3.038504, valid_acc: 46.06%
# Epoch: 07
#  | train_loss: 0.041333, train_acc: 99.32%
#  | valid_loss: 3.041623, valid_acc: 46.06%
# Epoch: 08
#  | train_loss: 0.041243, train_acc: 99.29%
#  | valid_loss: 2.879581, valid_acc: 44.83%
# Epoch: 09
#  | train_loss: 0.052448, train_acc: 99.32%
#  | valid_loss: 2.779730, valid_acc: 47.78%
#   -> Save checkpoint for epoch 10
# Epoch: 10
#  | train_loss: 0.056602, train_acc: 99.22%
#  | valid_loss: 2.642745, valid_acc: 46.80%
# Epoch: 11
#  | train_loss: 0.062174, train_acc: 99.19%
#  | valid_loss: 2.735581, valid_acc: 46.80%
# Epoch: 12
#  | train_loss: 0.062328, train_acc: 99.27%
#  | valid_loss: 2.688755, valid_acc: 47.04%
# Epoch: 13
#  | train_loss: 0.073139, train_acc: 99.27%
#  | valid_loss: 2.976287, valid_acc: 47.54%
# Epoch: 14
#  | train_loss: 0.085185, train_acc: 99.06%
#  | valid_loss: 2.499023, valid_acc: 46.31%
# Epoch: 15
#  | train_loss: 0.094404, train_acc: 98.96%
#  | valid_loss: 2.654542, valid_acc: 46.06%
# Epoch: 16
#  | train_loss: 0.107029, train_acc: 98.79%
#  | valid_loss: 2.566282, valid_acc: 48.03%
#   -> Save checkpoint for epoch 17
# Epoch: 17
#  | train_loss: 0.099096, train_acc: 99.06%
#  | valid_loss: 2.635311, valid_acc: 45.57%
# Epoch: 18
#  | train_loss: 0.114260, train_acc: 98.76%
#  | valid_loss: 2.503185, valid_acc: 46.80%
# Epoch: 19
#  | train_loss: 0.112857, train_acc: 98.86%
#  | valid_loss: 2.710159, valid_acc: 46.80%
# Epoch: 20
#  | train_loss: 0.130398, train_acc: 98.68%
#  | valid_loss: 2.555855, valid_acc: 47.04%
# Epoch: 21
#  | train_loss: 0.138762, train_acc: 98.51%
#  | valid_loss: 2.512859, valid_acc: 47.29%
# Epoch: 22
#  | train_loss: 0.141237, train_acc: 98.61%
#  | valid_loss: 2.711243, valid_acc: 47.78%
# Epoch: 23
#  | train_loss: 0.149158, train_acc: 98.61%
#  | valid_loss: 2.729487, valid_acc: 47.29%
# Epoch: 24
#  | train_loss: 0.155290, train_acc: 98.20%
#  | valid_loss: 2.385715, valid_acc: 46.06%
# Epoch: 25
#  | train_loss: 0.171077, train_acc: 97.85%
#  | valid_loss: 2.341755, valid_acc: 46.55%
# Epoch: 26
#  | train_loss: 0.186212, train_acc: 98.08%
#  | valid_loss: 2.382782, valid_acc: 45.57%
# Epoch: 27
#  | train_loss: 0.188879, train_acc: 97.70%
#  | valid_loss: 2.341386, valid_acc: 46.06%
# Epoch: 28
#  | train_loss: 0.202832, train_acc: 97.34%
#  | valid_loss: 2.338477, valid_acc: 45.07%
# Epoch: 29
#  | train_loss: 0.214205, train_acc: 97.04%
#  | valid_loss: 2.407602, valid_acc: 46.80%
# Epoch: 30
#  | train_loss: 0.217746, train_acc: 96.99%
#  | valid_loss: 2.473838, valid_acc: 47.04%
# Epoch: 31
#  | train_loss: 0.203768, train_acc: 97.52%
#  | valid_loss: 2.369330, valid_acc: 46.55%
# Epoch: 32
#  | train_loss: 0.236693, train_acc: 96.68%
#  | valid_loss: 2.489737, valid_acc: 45.07%
# Epoch: 33
#  | train_loss: 0.235892, train_acc: 96.74%
#  | valid_loss: 2.405101, valid_acc: 45.81%
# Epoch: 34
#  | train_loss: 0.246577, train_acc: 96.33%
#  | valid_loss: 2.544524, valid_acc: 43.60%
# Epoch: 35
#  | train_loss: 0.269515, train_acc: 95.65%
#  | valid_loss: 2.531831, valid_acc: 47.04%
# Epoch: 36
#  | train_loss: 0.259741, train_acc: 96.23%
#  | valid_loss: 2.531705, valid_acc: 46.31%
# Epoch: 37
#  | train_loss: 0.279574, train_acc: 95.42%
#  | valid_loss: 2.282100, valid_acc: 47.29%
# Epoch: 38
#  | train_loss: 0.285512, train_acc: 95.62%
#  | valid_loss: 2.577719, valid_acc: 45.57%
# Epoch: 39
#  | train_loss: 0.306724, train_acc: 94.89%
#  | valid_loss: 2.570645, valid_acc: 45.57%
# Epoch: 40
#  | train_loss: 0.304984, train_acc: 95.14%
#  | valid_loss: 2.544580, valid_acc: 46.06%
# Epoch: 41
#  | train_loss: 0.309934, train_acc: 95.09%
#  | valid_loss: 2.530103, valid_acc: 46.06%
# Epoch: 42
#  | train_loss: 0.315009, train_acc: 95.17%
#  | valid_loss: 2.562284, valid_acc: 45.32%
# Epoch: 43
#  | train_loss: 0.341308, train_acc: 93.75%
#  | valid_loss: 2.483410, valid_acc: 45.57%
# Epoch: 44
#  | train_loss: 0.355978, train_acc: 93.52%
#  | valid_loss: 2.445898, valid_acc: 45.57%
# Epoch: 45
#  | train_loss: 0.369333, train_acc: 93.19%
#  | valid_loss: 2.474894, valid_acc: 45.57%
# Epoch: 46
#  | train_loss: 0.379203, train_acc: 92.89%
#  | valid_loss: 2.334905, valid_acc: 45.57%
# Epoch: 47
#  | train_loss: 0.385207, train_acc: 92.63%
#  | valid_loss: 2.331198, valid_acc: 47.29%
# Epoch: 48
#  | train_loss: 0.393448, train_acc: 92.71%
#  | valid_loss: 2.164353, valid_acc: 44.58%
# Epoch: 49
#  | train_loss: 0.418896, train_acc: 91.50%
#  | valid_loss: 2.447731, valid_acc: 45.81%

# %%
class testdataset(Dataset):
    def __init__(self, inputPath, csvPath, transform=None):
        self.inputPath = inputPath
        self.transform = transform
        # with open(label2idPath, 'r') as j:
        #     self.label2id = json.loads(j.read())
        # self.inputName = sorted(os.listdir(inputPath))
        self.inputName = []
        self.df = pd.read_csv(csvPath)
        for i in range(len(self.df)):
            self.inputName.append((self.df.loc[i].id, self.df.loc[i].filename))
        print(self.inputName[0])
        
    def __getitem__(self, index):
        img = Image.open(os.path.join(self.inputPath, self.inputName[index][1]))
        if self.transform:
            img = self.transform(img)
        id = self.inputName[index][0]
        filename = self.inputName[index][1]
        return img, id, filename

    def __len__(self):
        return len(self.inputName)

# %%
validDS = testdataset(inputPath=valid_path, csvPath=valid_csv, transform=img_transform)
validLoader = DataLoader(dataset=validDS, batch_size=1, shuffle=False, num_workers=1)
# Out:
# (0, 'Fork00005.jpg')

# %%
test_model = settingC().to(device)
test_model.load_state_dict(torch.load(retrain_path, map_location=device)['model_state_dict'])
# Out:
# <All keys matched successfully>

# %%
with open(label2id_path, 'r') as j:
    label2num = json.loads(j.read())
num2label = dict([val, key] for key, val in label2num.items())
num2label
# Out:
# {13: 'Couch',
#  27: 'Helmet',
#  48: 'Refrigerator',
#  0: 'Alarm_Clock',
#  4: 'Bike',
#  5: 'Bottle',
#  7: 'Calculator',
#  10: 'Chair',
#  36: 'Mouse',
#  34: 'Monitor',
#  59: 'Table',
#  42: 'Pen',
#  43: 'Pencil',
#  22: 'Flowers',
#  52: 'Shelf',
#  32: 'Laptop',
#  56: 'Speaker',
#  54: 'Sneakers',
#  45: 'Printer',
#  8: 'Calendar',
#  3: 'Bed',
#  30: 'Knives',
#  1: 'Backpack',
#  41: 'Paper_Clip',
#  9: 'Candles',
#  55: 'Soda',
#  11: 'Clipboards',
#  24: 'Fork',
#  18: 'Exit_Sign',
#  31: 'Lamp_Shade',
#  63: 'Trash_Can',
#  12: 'Computer',
#  50: 'Scissors',
#  64: 'Webcam',
#  53: 'Sink',
#  44: 'Postit_Notes',
#  25: 'Glasses',
#  20: 'File_Cabinet',
#  47: 'Radio',
#  6: 'Bucket',
#  16: 'Drill',
#  15: 'Desk_Lamp',
#  62: 'Toys',
#  29: 'Keyboard',
#  38: 'Notebook',
#  49: 'Ruler',
#  61: 'ToothBrush',
#  35: 'Mop',
#  21: 'Flipflops',
#  39: 'Oven',
#  58: 'TV',
#  17: 'Eraser',
#  60: 'Telephone',
#  28: 'Kettle',
#  14: 'Curtains',
#  37: 'Mug',
#  19: 'Fan',
#  46: 'Push_Pin',
#  2: 'Batteries',
#  40: 'Pan',
#  33: 'Marker',
#  57: 'Spoon',
#  51: 'Screwdriver',
#  26: 'Hammer',
#  23: 'Folder'}

# %%
criterion = nn.CrossEntropyLoss()
test_model.eval()
result = {"id":[], "filename":[], "label":[]}
with torch.no_grad(): # This will free the GPU memory used for back-prop
    for i, (img, id, filename) in enumerate(validLoader):
        img = img.to(device)
        output = test_model(img)
        # valid_loss += criterion(output, label).item() # sum up batch loss
        pred_label = output.max(1, keepdim=True)[1] # get the index of the max log-probability
        # valid_acc += pred.eq(label.view_as(pred)).sum().item()
        result["id"].append(int(id))
        result["filename"].append(filename[0])
        result["label"].append(num2label[int(pred_label)])

# %%
origin = pd.read_csv(valid_csv)
test = pd.read_csv("./pred.csv")
result = pd.DataFrame(result)
print(sum(origin.label == result.label)/len(origin.label))
print(sum(origin.label == test.label)/len(origin.label))
# Out:
# 0.49261083743842365
# 0.49261083743842365

# %%
result.to_csv("./output.csv", index=False)
