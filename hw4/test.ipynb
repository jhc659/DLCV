# %%
# !python DirectVoxGO/run.py --config DirectVoxGO/configs/nerf/hotdog.py --render_test #--dump_images /mnt/sda/jhccc/hw4-jhc659/output/test1
# Out:
# /home/r11922166/anaconda3/envs/dlcv/lib/python3.10/site-packages/mmcv/__init__.py:20: UserWarning: On January 1, 2023, MMCV will release v2.0.0, in which it will remove components related to the training process and add a data transformation module. In addition, it will rename the package names mmcv to mmcv-lite and mmcv-full to mmcv. See https://github.com/open-mmlab/mmcv/blob/master/docs/en/compatibility.md for more details.
#   warnings.warn(
# Using /home/r11922166/.cache/torch_extensions/py310_cu102 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /home/r11922166/.cache/torch_extensions/py310_cu102/adam_upd_cuda/build.ninja...
# Building extension module adam_upd_cuda...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module adam_upd_cuda...
# ...

# %%
# !python DirectVoxGO/run.py --config DirectVoxGO/configs/nerf/hotdog.py --render_only --render_test --ft_path ./hw4_1_fine.tar --dump_images ./output/trybest --json_path /mnt/sda/DLCV2/hw4_data/hotdog/transforms_test.json
# Out:
# /home/r11922166/anaconda3/envs/dlcv/lib/python3.10/site-packages/mmcv/__init__.py:20: UserWarning: On January 1, 2023, MMCV will release v2.0.0, in which it will remove components related to the training process and add a data transformation module. In addition, it will rename the package names mmcv to mmcv-lite and mmcv-full to mmcv. See https://github.com/open-mmlab/mmcv/blob/master/docs/en/compatibility.md for more details.
#   warnings.warn(
# Using /home/r11922166/.cache/torch_extensions/py310_cu102 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /home/r11922166/.cache/torch_extensions/py310_cu102/adam_upd_cuda/build.ninja...
# Building extension module adam_upd_cuda...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module adam_upd_cuda...
# ...

# %%
# N_iter += 1000
# !python3 grade.py /mnt/sda/jhccc/hw4-jhc659/output/trybest /mnt/sda/DLCV2/hw4_data/hotdog/val
# Out:
#   0%|                                                    | 0/50 [00:00<?, ?it/s]init_lpips: lpips_alex
# Setting up [LPIPS] perceptual loss: trunk [alex], v[0.1], spatial [off]
# /home/r11922166/anaconda3/envs/dlcv/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and will be removed in 0.15, please use 'weights' instead.
#   warnings.warn(
# /home/r11922166/anaconda3/envs/dlcv/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and will be removed in 0.15. The current behavior is equivalent to passing `weights=AlexNet_Weights.IMAGENET1K_V1`. You can also use `weights=AlexNet_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Loading model from: /home/r11922166/anaconda3/envs/dlcv/lib/python3.10/site-packages/lpips/weights/v0.1/alex.pth
# init_lpips: lpips_vgg
# ...

# %%
# num_voxels = 160**3/5
# !python3 grade.py /mnt/sda/jhccc/hw4-jhc659/output/test2 /mnt/sda/DLCV2/hw4_data/hotdog/val
# Out:
#   0%|                                                    | 0/50 [00:00<?, ?it/s]init_lpips: lpips_alex
# Setting up [LPIPS] perceptual loss: trunk [alex], v[0.1], spatial [off]
# /home/r11922166/anaconda3/envs/dlcv/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and will be removed in 0.15, please use 'weights' instead.
#   warnings.warn(
# /home/r11922166/anaconda3/envs/dlcv/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and will be removed in 0.15. The current behavior is equivalent to passing `weights=AlexNet_Weights.IMAGENET1K_V1`. You can also use `weights=AlexNet_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Loading model from: /home/r11922166/anaconda3/envs/dlcv/lib/python3.10/site-packages/lpips/weights/v0.1/alex.pth
# init_lpips: lpips_vgg
# ...

# %%
# N_iters / 2
# !python3 grade.py /mnt/sda/jhccc/hw4-jhc659/output/test1 /mnt/sda/DLCV2/hw4_data/hotdog/val
# Out:
#   0%|                                                    | 0/50 [00:00<?, ?it/s]init_lpips: lpips_alex
# Setting up [LPIPS] perceptual loss: trunk [alex], v[0.1], spatial [off]
# /home/r11922166/anaconda3/envs/dlcv/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and will be removed in 0.15, please use 'weights' instead.
#   warnings.warn(
# /home/r11922166/anaconda3/envs/dlcv/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and will be removed in 0.15. The current behavior is equivalent to passing `weights=AlexNet_Weights.IMAGENET1K_V1`. You can also use `weights=AlexNet_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Loading model from: /home/r11922166/anaconda3/envs/dlcv/lib/python3.10/site-packages/lpips/weights/v0.1/alex.pth
# init_lpips: lpips_vgg
# ...

# %%
# !python3 grade.py /mnt/sda/jhccc/hw4-jhc659/output/default /mnt/sda/DLCV2/hw4_data/hotdog/val
# Out:
#   0%|                                                    | 0/50 [00:00<?, ?it/s]init_lpips: lpips_alex
# Setting up [LPIPS] perceptual loss: trunk [alex], v[0.1], spatial [off]
# /home/r11922166/anaconda3/envs/dlcv/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and will be removed in 0.15, please use 'weights' instead.
#   warnings.warn(
# /home/r11922166/anaconda3/envs/dlcv/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and will be removed in 0.15. The current behavior is equivalent to passing `weights=AlexNet_Weights.IMAGENET1K_V1`. You can also use `weights=AlexNet_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Loading model from: /home/r11922166/anaconda3/envs/dlcv/lib/python3.10/site-packages/lpips/weights/v0.1/alex.pth
# init_lpips: lpips_vgg
# ...

# %%
# !bash hw4_download.sh
# Out:
# --2022-12-12 22:45:53--  https://www.dropbox.com/s/ka1ovof70g5jlr7/hw4_1_fine.tar?dl=1
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.85.18, 2620:100:6035:18::a27d:5512
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.85.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /s/dl/ka1ovof70g5jlr7/hw4_1_fine.tar [following]
# --2022-12-12 22:45:54--  https://www.dropbox.com/s/dl/ka1ovof70g5jlr7/hw4_1_fine.tar
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc3beb2a7bd0eb4986cde7ca12fe.dl.dropboxusercontent.com/cd/0/get/BydVNs8w1zWDDKKgJQJ71D6gmTm7nWSQzUD5adoaVExPP5A5F1-saGLydQXjbQ6nd0pLs79QKKzjQLbsurh2r-sts5JNlFaJcHiaEQVEZ1MHkOR3jqW4PflTDgnBydqanIIPwWU0Tmgi-ar0QtgqxMHPoVKxHjPyfnlwfbTnXFEX3NJ8uKlNKZXqtzjHP_At8qQ/file?dl=1# [following]
# ...

# %%
# !bash hw4_1.sh /mnt/sda/DLCV2/hw4_data/hotdog/transforms_test.json /mnt/sda/jhccc/hw4-jhc659/output
# Out:
# /home/r11922166/anaconda3/envs/dlcv/lib/python3.10/site-packages/mmcv/__init__.py:20: UserWarning: On January 1, 2023, MMCV will release v2.0.0, in which it will remove components related to the training process and add a data transformation module. In addition, it will rename the package names mmcv to mmcv-lite and mmcv-full to mmcv. See https://github.com/open-mmlab/mmcv/blob/master/docs/en/compatibility.md for more details.
#   warnings.warn(
# Using /home/r11922166/.cache/torch_extensions/py310_cu102 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /home/r11922166/.cache/torch_extensions/py310_cu102/adam_upd_cuda/build.ninja...
# Building extension module adam_upd_cuda...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module adam_upd_cuda...
# ...

# %%
# !python3 grade.py /mnt/sda/jhccc/hw4-jhc659/output /mnt/sda/DLCV2/hw4_data/hotdog/val
# Out:
#   0%|                                                    | 0/50 [00:00<?, ?it/s]init_lpips: lpips_alex
# Setting up [LPIPS] perceptual loss: trunk [alex], v[0.1], spatial [off]
# /home/r11922166/anaconda3/envs/dlcv/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and will be removed in 0.15, please use 'weights' instead.
#   warnings.warn(
# /home/r11922166/anaconda3/envs/dlcv/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and will be removed in 0.15. The current behavior is equivalent to passing `weights=AlexNet_Weights.IMAGENET1K_V1`. You can also use `weights=AlexNet_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Loading model from: /home/r11922166/anaconda3/envs/dlcv/lib/python3.10/site-packages/lpips/weights/v0.1/alex.pth
# init_lpips: lpips_vgg
# ...

# %%
# !bash hw4_2.sh /data/dlcv/hw4/office/val.csv /data/dlcv/hw4/office/val ./pred.csv
# Out:
# Device used: cuda
# (405, 'Notebook00032.jpg')
# | To csv ...
