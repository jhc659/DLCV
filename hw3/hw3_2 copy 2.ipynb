# %%
import os
import glob
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms

from torch.utils.data import Dataset, DataLoader
import numpy as np
import clip
import json 
import time
import math

import random
import pandas as pd
from PIL import Image
import matplotlib.pyplot as plt
from tokenizers import Tokenizer
os.environ['TOKENIZERS_PARALLELISM'] = 'false'
# os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
# os.environ["CUDA_VISIBLE_DEVICES"] = "2, 5"

# %%
train_dir = "/data/dlcv/hw3/hw3_data/p2_data/images/train"
valid_dir = "/data/dlcv/hw3/hw3_data/p2_data/images/val"
train_json_dir = "/data/dlcv/hw3/hw3_data/p2_data/train.json"
val_json_dir = "/data/dlcv/hw3/hw3_data/p2_data/val.json"
ckpt_dir = "./p2"
tokenizer = Tokenizer.from_file("caption_tokenizer.json")
# device = torch.device("cuda:2" if torch.cuda.is_available() else "cpu")
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
if device == "cuda":
    torch.cuda.set_device(0)

print('Device used:', device)
# Out:
# Device used: cuda

# %%
with open(train_json_dir, 'r') as j:
    caption_json = json.loads(j.read())
# print(caption_json["images"][i].values() for i in range(10))
print(type(caption_json["images"][0]))
# print(type([0]*80))
# Out:
# <class 'dict'>

# %%
class p2dataset(Dataset):
    def __init__(self, inputPath, json_dir, transform=None):
        self.inputPath = inputPath
        self.transform = transform
        self.inputName = sorted(os.listdir(inputPath))
        with open(json_dir, 'r') as j:
            caption_json = json.loads(j.read())
        self.caption_json = caption_json
        self.filecap = {}
        for dic in self.caption_json["images"]:
            self.filecap[dic['id']] = {"filename" : dic["file_name"], "captions": []}
        for dic in self.caption_json["annotations"]:
            self.filecap[dic['image_id']]['captions'].append(dic['caption'])
        self.files = [dic for dic in self.filecap.values()]
        
    def __getitem__(self, index):
        img = Image.open(os.path.join(self.inputPath, self.files[index]['filename']))
        if self.transform:
            img = self.transform(img)
        
        cap = self.files[index]['captions'][random.randint(0, len(self.files[index]['captions'])-1)]
        tokenized_caption = tokenizer.enable_padding(length=100)
        tokenized_caption = tokenizer.encode(cap)
        # [# of str, str len]
        return img, torch.Tensor(tokenized_caption.ids).long(), self.files[index]['filename'].replace(".jpg", "")

    def __len__(self):
        return len(self.inputName)

# %%
enc, preprocess = clip.load('ViT-L/14@336px')

# %%
train_dataset = p2dataset(train_dir, train_json_dir, transform=preprocess)
valid_dataset = p2dataset(valid_dir, val_json_dir, transform=preprocess)
print('# images in train:', len(train_dataset))
print('# images in valid:', len(valid_dataset))

train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True, num_workers=4)
valid_loader = DataLoader(valid_dataset, batch_size=1, shuffle=False, num_workers=0)

dataiter = iter(valid_loader)
images, ids, filename = dataiter.next()
# print(images[0])
# print(ids)
# print(filename)
# def imshow(img):
#     npimg = img.numpy()
#     plt.imshow(np.transpose(npimg, (1, 2, 0)))
# # show images
# imshow(torchvision.utils.make_grid(images))
# Out:
# # images in train: 10604
# # images in valid: 1789

# %% [markdown]
# ### Model

# %%
class Encoder(nn.Module):
    def __init__(self):
        super().__init__()
        self.clip_encoder, __ = clip.load('ViT-L/14@336px', device)
        self.clip_encoder = self.clip_encoder.float()
        #override vit's forward
        vit = self.clip_encoder.visual
        bound_method = vit_forward.__get__(vit, vit.__class__)
        setattr(vit, 'forward', bound_method)
        #Freeze model parameters
        for param in self.clip_encoder.parameters():
            param.requires_grad = False
    
    def forward(self, x):
        return self.clip_encoder.encode_image(x)

def vit_forward(self, x):
    x = self.conv1(x)  # shape = [*, width, grid, grid]
    x = x.reshape(x.shape[0], x.shape[1], -1)  # shape = [*, width, grid ** 2]
    x = x.permute(0, 2, 1)  # shape = [*, grid ** 2, width]
    x = torch.cat([self.class_embedding.to(x.dtype) + torch.zeros(x.shape[0], 1, x.shape[-1], dtype=x.dtype, device=x.device), x], dim=1)  # shape = [*, grid ** 2 + 1, width]
    x = x + self.positional_embedding.to(x.dtype)
    x = self.ln_pre(x)

    x = x.permute(1, 0, 2)  # NLD -> LND
    x = self.transformer(x)
    x = x.permute(1, 0, 2)  # LND -> NLD

    x = self.ln_post(x[:,1:,:])
    
    if self.proj is not None:
            x = x @ self.proj
            
    return x   


class PositionwiseFeedforwardLayer(nn.Module):
    def __init__(self, hid_dim, pf_dim, dropout):
        super().__init__()
        
        self.fc_1 = nn.Linear(hid_dim, pf_dim)
        self.fc_2 = nn.Linear(pf_dim, hid_dim)
        
        self.dropout = nn.Dropout(dropout)
        
    def forward(self, x):
        
        #x = [batch size, seq len, hid dim]
        
        x = self.dropout(torch.relu(self.fc_1(x)))
        
        #x = [batch size, seq len, pf dim]
        
        x = self.fc_2(x)
        
        #x = [batch size, seq len, hid dim]
        
        return x
    
class MultiHeadAttentionLayer(nn.Module):
    def __init__(self, hid_dim, n_heads, dropout, device):
        super().__init__()
        
        assert hid_dim % n_heads == 0
        
        self.hid_dim = hid_dim
        self.n_heads = n_heads
        self.head_dim = hid_dim // n_heads
        
        self.fc_q = nn.Linear(hid_dim, hid_dim)
        self.fc_k = nn.Linear(hid_dim, hid_dim)
        self.fc_v = nn.Linear(hid_dim, hid_dim)
        
        self.fc_o = nn.Linear(hid_dim, hid_dim)
        
        self.dropout = nn.Dropout(dropout)
        
        self.scale = torch.sqrt(torch.FloatTensor([self.head_dim])).to(device)
        
    def forward(self, query, key, value, mask = None):
        
        batch_size = query.shape[0]
        # print("query = [batch size, query len, hid dim]:", query.shape)
        # print("key = [batch size, key len, hid dim]:", key.shape)
        # print("value = [batch size, value len, hid dim]", value.shape)
        #query = [batch size, query len, hid dim]
        #key = [batch size, key len, hid dim]
        #value = [batch size, value len, hid dim]
                
        Q = self.fc_q(query)
        K = self.fc_k(key)
        V = self.fc_v(value)
        # print("Q = [batch size, query len, hid dim]:", Q.shape)
        # print("K = [batch size, key len, hid dim]:", K.shape)
        # print("V = [batch size, value len, hid dim]", V.shape)
        #Q = [batch size, query len, hid dim]
        #K = [batch size, key len, hid dim]
        #V = [batch size, value len, hid dim]
                        
        Q = Q.view(batch_size, -1, self.n_heads, self.head_dim).permute(0, 2, 1, 3)
        K = K.view(batch_size, -1, self.n_heads, self.head_dim).permute(0, 2, 1, 3)
        V = V.view(batch_size, -1, self.n_heads, self.head_dim).permute(0, 2, 1, 3)
        # print("Q = [batch size, n heads, query len, head dim]:", Q.shape)
        # print("K = [batch size, n heads, key len, head dim]:", K.shape)
        # print("V = [batch size, n heads, value len, head dim]", V.shape)
        #Q = [batch size, n heads, query len, head dim]
        #K = [batch size, n heads, key len, head dim]
        #V = [batch size, n heads, value len, head dim]
                
        energy = torch.matmul(Q, K.permute(0, 1, 3, 2)) / self.scale
        # print("energy = [batch size, n heads, query len, key len]: ", energy.shape)
        #energy = [batch size, n heads, query len, key len]
        
        if mask is not None:
            energy = energy.masked_fill(mask == 0, -1e10)
        
        attention = torch.softmax(energy, dim = -1)
        # print("attention = [batch size, n heads, query len, key len]: ", attention.shape)      
        #attention = [batch size, n heads, query len, key len]
                
        x = torch.matmul(self.dropout(attention), V)
        # print("x = [batch size, n heads, query len, key len]: ", x.shape)
        #x = [batch size, n heads, query len, head dim]
        
        x = x.permute(0, 2, 1, 3).contiguous()
        # print("x = [batch size, n heads, query len, key len]: ", x.shape)    
        #x = [batch size, query len, n heads, head dim]
        
        x = x.view(batch_size, -1, self.hid_dim)
        # print("x = [batch size, n heads, query len, key len]: ", x.shape)            
        #x = [batch size, query len, hid dim]
        
        x = self.fc_o(x)
        # print("x = [batch size, n heads, query len, key len]: ", x.shape)                    
        #x = [batch size, query len, hid dim]
        
        return x, attention

class DecoderLayer(nn.Module):
    def __init__(self, 
                 hid_dim, 
                 n_heads, 
                 pf_dim, 
                 dropout, 
                 device):
        super().__init__()
        
        self.self_attn_layer_norm = nn.LayerNorm(hid_dim)
        self.enc_attn_layer_norm = nn.LayerNorm(hid_dim)
        self.ff_layer_norm = nn.LayerNorm(hid_dim)
        self.self_attention = MultiHeadAttentionLayer(hid_dim, n_heads, dropout, device)
        self.encoder_attention = MultiHeadAttentionLayer(hid_dim, n_heads, dropout, device)
        self.positionwise_feedforward = PositionwiseFeedforwardLayer(hid_dim, 
                                                                     pf_dim, 
                                                                     dropout)
        self.dropout = nn.Dropout(dropout)
        
    def forward(self, trg, enc_src, trg_mask, src_mask=None):
        
        #trg = [batch size, trg len, hid dim]
        #enc_src = [batch size, src len, hid dim]
        #trg_mask = [batch size, 1, trg len, trg len]
        #src_mask = [batch size, 1, 1, src len]
        
        #self attention
        # print("Start self attention.....")
        _trg, _ = self.self_attention(trg, trg, trg, trg_mask)
        
        #dropout, residual connection and layer norm
        trg = self.self_attn_layer_norm(trg + self.dropout(_trg))
        # print("trg = [batch size, trg len, hid dim]:", trg.shape)    
        #trg = [batch size, trg len, hid dim]
            
        #encoder attention
        # print("Start encoder attention.....")
        _trg, attention = self.encoder_attention(trg, enc_src, enc_src, src_mask)
        
        #dropout, residual connection and layer norm
        trg = self.enc_attn_layer_norm(trg + self.dropout(_trg))
        # print("trg = [batch size, trg len, hid dim]:", trg.shape)            
        #trg = [batch size, trg len, hid dim]
        
        #positionwise feedforward
        _trg = self.positionwise_feedforward(trg)
        
        #dropout, residual and layer norm
        trg = self.ff_layer_norm(trg + self.dropout(_trg))
        # print("trg = [batch size, trg len, hid dim]:", trg.shape)
        #trg = [batch size, trg len, hid dim]
        #attention = [batch size, n heads, trg len, src len]
        
        return trg, attention
    
class Decoder(nn.Module):
    def __init__(self, 
                 output_dim, 
                 hid_dim, 
                 n_layers, 
                 n_heads, 
                 pf_dim, 
                 dropout, 
                 device,
                 max_length = 100):
        super().__init__()
        
        self.device = device
        
        self.tok_embedding = nn.Embedding(output_dim, hid_dim)
        self.pos_embedding = nn.Embedding(max_length, hid_dim)
        
        self.layers = nn.ModuleList([DecoderLayer(hid_dim, 
                                                  n_heads, 
                                                  pf_dim, 
                                                  dropout, 
                                                  device)
                                     for _ in range(n_layers)])
        
        self.fc_out = nn.Linear(hid_dim, output_dim)
        
        self.dropout = nn.Dropout(dropout)
        
        self.scale = torch.sqrt(torch.FloatTensor([hid_dim])).to(device)
        
    def forward(self, trg, enc_src, trg_mask, src_mask=None):
        
        #trg = [batch size, trg len]
        #enc_src = [batch size, src len, hid dim]
        #trg_mask = [batch size, 1, trg len, trg len]
        #src_mask = [batch size, 1, 1, src len]
                
        batch_size = trg.shape[0]
        trg_len = trg.shape[1]
        
        pos = torch.arange(0, trg_len).unsqueeze(0).repeat(batch_size, 1).to(self.device)
        # print("pos = [batch size, trg len]:", pos.shape)       
        #pos = [batch size, trg len]
            
        trg = self.dropout((self.tok_embedding(trg) * self.scale) + self.pos_embedding(pos))
        # print("trg = [batch size, trg len, hid dim]:", trg.shape)
        #trg = [batch size, trg len, hid dim]
        
        for layer in self.layers:
            trg, attention = layer(trg, enc_src, trg_mask, src_mask)
        
        # print("trg = [batch size, trg len, hid dim]: ", trg.shape)
        # print("attention = [batch size, n heads, trg len, src len]: ", attention.shape)
        #trg = [batch size, trg len, hid dim]
        #attention = [batch size, n heads, trg len, src len]
        
        output = self.fc_out(trg)
        # print("output = [batch size, trg len, output dim]:", output.shape)
        #output = [batch size, trg len, output dim]
            
        return output, attention
    
class Transformer(nn.Module):
    def __init__(self,  
                 decoder,  
                 trg_pad_idx, 
                 device):
        super().__init__()
        
        self.decoder = decoder
        self.trg_pad_idx = trg_pad_idx
        self.device = device
    
    def make_trg_mask(self, trg):
        
        #trg = [batch size, trg len]
        trg_pad_mask = (trg != self.trg_pad_idx).unsqueeze(1).unsqueeze(2)
        
        # print("trg_pad_mask = [batch size, 1, 1, trg len]:", trg_pad_mask.shape)
        #trg_pad_mask = [batch size, 1, 1, trg len]
        
        trg_len = trg.shape[1]
        
        trg_sub_mask = torch.tril(torch.ones((trg_len, trg_len))).bool().to(device)
        # print("trg_sub_mask = [trg len, trg len]: ",trg_sub_mask.shape)
        
        #trg_sub_mask = [trg len, trg len]
            
        trg_mask = trg_pad_mask & trg_sub_mask
        
        #trg_mask = [batch size, 1, trg len, trg len]
        
        # print("trg_mask = [batch size, 1, trg len, trg len]:", trg_mask.shape)

        return trg_mask

    def forward(self, src, enc_src, trg):
        
        #src = [batch size, src len]
        #trg = [batch size, trg len]
        src_mask = torch.ones((src.shape[0],1,1,1)).bool().to(device)
        # print("src_mask = [batch size, 1, 1, src len]:", src_mask.shape)
        
        trg_mask = self.make_trg_mask(trg)
        # print("trg_mask = [batch size, 1, trg len, trg len]:", trg_mask.shape)
        #src_mask = [batch size, 1, 1, src len]
        #trg_mask = [batch size, 1, trg len, trg len]
        
        # enc_src = self.encoder(img)#.unsqueeze(1).float()
        # print("enc_src = [batch size, src len, hid dim]: ", enc_src.shape)
        #enc_src = [batch size, src len, hid dim]
                
        output, attention = self.decoder(trg, enc_src, trg_mask)
        
        # print("output = [batch size, trg len, output dim]:", output.shape)
        #output = [batch size, trg len, output dim]
        #attention = [batch size, n heads, trg len, src len]
        
        return output, attention

def initialize_weights(m):
    if hasattr(m, 'weight') and m.weight.dim() > 1:
        nn.init.xavier_uniform_(m.weight.data)

def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

def epoch_time(start_time, end_time):
    elapsed_time = end_time - start_time
    elapsed_mins = int(elapsed_time / 60)
    elapsed_secs = int(elapsed_time - (elapsed_mins * 60))
    return elapsed_mins, elapsed_secs

def get_loss(pred, ans, vocab_size=18022, label_smoothing=0.01, pad=0):
    # took this "normalizing" from tensor2tensor. We subtract it for
    # readability. This makes no difference on learning.
    confidence = 1.0 - label_smoothing
    low_confidence = (1.0 - confidence) / float(vocab_size - 1)
    normalizing = -(
        confidence * math.log(confidence) + float(vocab_size - 1) *
        low_confidence * math.log(low_confidence + 1e-20))

    one_hot = torch.zeros_like(pred).scatter_(1, ans.unsqueeze(1), 1)
    one_hot = one_hot * confidence + (1 - one_hot) * low_confidence
    log_pred = F.log_softmax(pred, dim=1)
    #print("=========test2=========", log_pred)

    xent = -(one_hot * log_pred).sum(dim=1)
    xent = xent.masked_select(ans != pad)
    loss = (xent - normalizing).mean()
    return loss

def train(model, enc, train_loader, optimizer, criterion, clip):
    
    model.train()
    enc = enc.to(device)

    epoch_loss = 0
    
    for img, trg, _ in train_loader:
        
        
        img, trg = img.to(device), trg.to(device)
        # print("img: ", img.shape)
        # print("trg: ", trg[:,:-1].shape)
        # output, _ = model(img, trg[:,:-1])
        with torch.no_grad():
            enc_src = enc(img).float().to(device)
        output, attention = model(img, enc_src, trg)
        # output, attention = model(img, trg[:,:-1])
        # print("output = [batch size, trg len, output dim]:", output.shape)                
        # output = [batch size, trg len - 1, output dim]
        # trg = [batch size, trg len]
            
        output_dim = output.shape[-1]
            
        output = output.contiguous().view(-1, output_dim)
        # print("output", output.shape)
        # trg = trg[:,1:].contiguous().view(-1)
        # print("trg", trg.shape)     
        ans = torch.roll(trg, -1)
        ans[:, -1] = 0
        ans = ans.view(-1)               
        #output = [batch size * trg len - 1, output dim]
        #trg = [batch size * trg len - 1]
            
        loss = criterion(output, ans)
        # loss = get_loss(output, ans, 18022, 0.1, 0)
        # print(f'| Loss: {loss:.3f}')
        optimizer.zero_grad()             

        loss.backward()
        
        # torch.nn.utils.clip_grad_norm_(model.parameters(), clip)
        
        optimizer.step()
        
        epoch_loss += loss.item()
        
    return epoch_loss / len(train_loader.dataset)

def evaluate(model, enc, valid_loader, criterion):
    
    model.eval()
    enc = enc.to(device)
    epoch_loss = 0
    
    with torch.no_grad():
    
        for img, trg, _ in valid_loader:
            img, trg = img.to(device), trg.to(device)
            # output, _ = model(img, trg)
            with torch.no_grad():
                enc_src = enc(img).float().to(device)
            output, _ = model(img, enc_src, trg)
            #output = [batch size, trg len - 1, output dim]
            #trg = [batch size, trg len]
            
            output_dim = output.shape[-1]
            
            output = output.contiguous().view(-1, output_dim)
            # ans = trg[:,1:].contiguous().view(-1)
            ans = torch.roll(trg, -1)
            ans[:, -1] = 0
            ans = ans.view(-1)
            #output = [batch size * trg len - 1, output dim]
            #trg = [batch size * trg len - 1]
            
            loss = criterion(output, ans)
            # loss = get_loss(output, ans, 18022, 0.1, 0)

            epoch_loss += loss.item()
        
    return epoch_loss / len(valid_loader.dataset)

# %%
OUTPUT_DIM = 18022
HID_DIM = 768
ENC_LAYERS = 3
DEC_LAYERS = 3
ENC_HEADS = 8
DEC_HEADS = 8
ENC_PF_DIM = 512
DEC_PF_DIM = 512
ENC_DROPOUT = 0.1
DEC_DROPOUT = 0.1
TRG_PAD_IDX = 0
LEARNING_RATE = 6e-5
PAD = 0
BOS = 2
EOS = 3

# enc, _ = clip.load('ViT-L/14@336px')

enc = Encoder()

dec = Decoder(OUTPUT_DIM, 
              HID_DIM, 
              DEC_LAYERS, 
              DEC_HEADS, 
              DEC_PF_DIM, 
              DEC_DROPOUT, 
              device)
model = Transformer(dec, TRG_PAD_IDX, device).to(device)
print(f'The model has {count_parameters(model):,} trainable parameters')
model = model.apply(initialize_weights)
optimizer = torch.optim.Adam(model.parameters(), lr = LEARNING_RATE)
criterion = nn.CrossEntropyLoss(ignore_index = TRG_PAD_IDX, label_smoothing=0.1)
# Out:
# The model has 44,327,782 trainable parameters

# %%
N_EPOCHS = 25
CLIP = 1

best_valid_loss = float('inf')

for epoch in range(N_EPOCHS):
    
    start_time = time.time()
    
    train_loss = train(model, enc, train_loader, optimizer, criterion, CLIP)
    valid_loss = evaluate(model, enc, valid_loader, criterion)
    
    end_time = time.time()
    
    epoch_mins, epoch_secs = epoch_time(start_time, end_time)
    
    if valid_loss < best_valid_loss:
        best_valid_loss = valid_loss
        print(f"| save model for {epoch}")
        torch.save(model.state_dict(), os.path.join(ckpt_dir, f'ViT-Llayer3_{epoch}.pt'))
    
    print(f'Epoch: {epoch+1:02} | Time: {epoch_mins}m {epoch_secs}s')
    print(f'\tTrain Loss: {train_loss:.3f} | Train PPL: {math.exp(train_loss):7.3f}')
    print(f'\t Val. Loss: {valid_loss:.3f} |  Val. PPL: {math.exp(valid_loss):7.3f}')
# Out:
# | save model for 0
# Epoch: 01 | Time: 8m 22s
# 	Train Loss: 0.115 | Train PPL:   1.122
# 	 Val. Loss: 5.975 |  Val. PPL: 393.284
# | save model for 1
# Epoch: 02 | Time: 7m 39s
# 	Train Loss: 0.089 | Train PPL:   1.093
# 	 Val. Loss: 5.362 |  Val. PPL: 213.239
# | save model for 2
# Epoch: 03 | Time: 7m 36s
# 	Train Loss: 0.083 | Train PPL:   1.086
# 	 Val. Loss: 5.137 |  Val. PPL: 170.226
# | save model for 3
# Epoch: 04 | Time: 8m 38s
# 	Train Loss: 0.080 | Train PPL:   1.083
# 	 Val. Loss: 4.963 |  Val. PPL: 143.001
# | save model for 4
# Epoch: 05 | Time: 8m 40s
# 	Train Loss: 0.078 | Train PPL:   1.081
# 	 Val. Loss: 4.891 |  Val. PPL: 133.073
# | save model for 5
# Epoch: 06 | Time: 9m 14s
# 	Train Loss: 0.076 | Train PPL:   1.079
# 	 Val. Loss: 4.794 |  Val. PPL: 120.745
# | save model for 6
# Epoch: 07 | Time: 8m 38s
# 	Train Loss: 0.075 | Train PPL:   1.078
# 	 Val. Loss: 4.745 |  Val. PPL: 114.967
# | save model for 7
# Epoch: 08 | Time: 9m 27s
# 	Train Loss: 0.074 | Train PPL:   1.077
# 	 Val. Loss: 4.679 |  Val. PPL: 107.628
# | save model for 8
# Epoch: 09 | Time: 9m 25s
# 	Train Loss: 0.072 | Train PPL:   1.075
# 	 Val. Loss: 4.544 |  Val. PPL:  94.045
# | save model for 9
# Epoch: 10 | Time: 9m 18s
# 	Train Loss: 0.071 | Train PPL:   1.074
# 	 Val. Loss: 4.537 |  Val. PPL:  93.406
# | save model for 10
# Epoch: 11 | Time: 14m 11s
# 	Train Loss: 0.070 | Train PPL:   1.073
# 	 Val. Loss: 4.457 |  Val. PPL:  86.198
# | save model for 11
# Epoch: 12 | Time: 9m 26s
# 	Train Loss: 0.069 | Train PPL:   1.072
# 	 Val. Loss: 4.434 |  Val. PPL:  84.242
# | save model for 12
# Epoch: 13 | Time: 9m 27s
# 	Train Loss: 0.068 | Train PPL:   1.071
# 	 Val. Loss: 4.371 |  Val. PPL:  79.084
# | save model for 13
# Epoch: 14 | Time: 10m 49s
# 	Train Loss: 0.068 | Train PPL:   1.070
# 	 Val. Loss: 4.354 |  Val. PPL:  77.824
# | save model for 14
# Epoch: 15 | Time: 15m 53s
# 	Train Loss: 0.067 | Train PPL:   1.069
# 	 Val. Loss: 4.291 |  Val. PPL:  73.006
# | save model for 15
# Epoch: 16 | Time: 17m 21s
# 	Train Loss: 0.066 | Train PPL:   1.069
# 	 Val. Loss: 4.266 |  Val. PPL:  71.261
# Epoch: 17 | Time: 13m 27s
# 	Train Loss: 0.066 | Train PPL:   1.068
# 	 Val. Loss: 4.272 |  Val. PPL:  71.690
# | save model for 17
# Epoch: 18 | Time: 13m 49s
# 	Train Loss: 0.065 | Train PPL:   1.067
# 	 Val. Loss: 4.179 |  Val. PPL:  65.304
# | save model for 18
# Epoch: 19 | Time: 10m 51s
# 	Train Loss: 0.065 | Train PPL:   1.067
# 	 Val. Loss: 4.140 |  Val. PPL:  62.789
# | save model for 19
# Epoch: 20 | Time: 16m 19s
# 	Train Loss: 0.064 | Train PPL:   1.066
# 	 Val. Loss: 4.109 |  Val. PPL:  60.912
# Epoch: 21 | Time: 15m 33s
# 	Train Loss: 0.064 | Train PPL:   1.066
# 	 Val. Loss: 4.115 |  Val. PPL:  61.242
# | save model for 21
# Epoch: 22 | Time: 10m 47s
# 	Train Loss: 0.063 | Train PPL:   1.065
# 	 Val. Loss: 4.076 |  Val. PPL:  58.884
# | save model for 22
# Epoch: 23 | Time: 16m 42s
# 	Train Loss: 0.063 | Train PPL:   1.065
# 	 Val. Loss: 4.060 |  Val. PPL:  57.978
# | save model for 23
# Epoch: 24 | Time: 12m 16s
# 	Train Loss: 0.062 | Train PPL:   1.064
# 	 Val. Loss: 4.053 |  Val. PPL:  57.599
# | save model for 24
# Epoch: 25 | Time: 8m 20s
# 	Train Loss: 0.062 | Train PPL:   1.064
# 	 Val. Loss: 4.053 |  Val. PPL:  57.593

# %%
# def test(testmodel, valid_loader):
#     predict = {}
#     testmodel.eval()
        
#     with torch.no_grad():
        
#         for i, (img, trg, filename) in enumerate(valid_loader):
#             img, trg = img.to(device), trg.to(device)
#             out, _ = testmodel(img, trg)
#             text = out.argmax(2, keepdim=False)
#             text = text.cpu().numpy().squeeze().tolist()
#             text = tokenizer.decode(text)
#             # text = tokenizer.decode(text[:text.index(3)+1])
            
#             predict[filename[0]] = text
        
#     return predict


# def generate_square_subsequent_mask(sz: int, device='cpu') -> torch.Tensor:
#     return torch.triu(torch.full((sz, sz), float('-inf'), device=device), diagonal=1)

# def inference(testmodel, valid_loader):
#     pred = {}
#     BOS = 2
#     EOS = 3
#     max_len = 77
#     testmodel.eval()
    
#     for i, (img, _, filename) in enumerate(valid_loader):
#         img = img.to(device)
#         batch_size = img.shape[0]
        
#         trg_indexes = torch.zeros((batch_size, max_len), dtype=torch.int32)
#         trg_indexes[:, 0] = BOS
#         # print(trg_indexes)
#         trg_indexes = trg_indexes.to(device)
        
#         with torch.no_grad():
#             enc_src = testmodel.encoder(img)
                   
#             for index in range(1, max_len):
#                 trg_mask = testmodel.make_trg_mask(trg_indexes)
#                 out, attention = testmodel.decoder(trg_indexes, enc_src, trg_mask)
#                 pred_token = out.argmax(2)
#                 trg_indexes[:,index] = pred_token[:,index]
#                 # print(pred_token[:,index])
#                 if pred_token[:,index] == EOS:
#                     break
#                 # print(trg_indexes)
#             trg_indexes = trg_indexes.cpu().numpy().squeeze().tolist()
#         caption = tokenizer.decode(trg_indexes)
#         # print(caption)
#         pred[filename[0]] = caption
#     return pred    

# def inference2(testmodel, valid_loader):
#     dict = {}
#     testmodel.eval()
#     max_len = 77
#     with torch.no_grad():
#         for img, _, filename in valid_loader:
#             img = img.to(device)
            
#             trg_indexes = [BOS]
#             with torch.no_grad():
#                 enc_src = testmodel.encoder(img)
                
#                 for i in range(max_len):
#                     trg_tensor = torch.LongTensor(trg_indexes).unsqueeze(0).to(device)
#                     # trg_mask = generate_square_subsequent_mask(trg_tensor.shape[1], device)
#                     trg_mask = testmodel.make_trg_mask(trg_tensor)
#                     out, attention = testmodel.decoder(trg_tensor, enc_src, trg_mask)
#                     # out, attention = testmodel(img, trg_tensor)
                    
#                     # print(out.argmax(2).shape)
#                     pred_token = out.argmax(2)[:,i].item()
#                     # print(out.argmax(2))
#                     trg_indexes.append(pred_token)
#                     # print(trg_indexes)
#                     if(pred_token == EOS):
#                         break
#             caption = tokenizer.decode(trg_indexes)
#             # print(caption)
#             dict[filename[0]] = caption
#     return dict

# %%
class valdataset(Dataset):
    def __init__(self, inputPath,  transform=None):
        self.inputPath = inputPath
        self.transform = transform
        self.inputName = sorted(os.listdir(inputPath))        
        
    def __getitem__(self, index):
        img = Image.open(os.path.join(self.inputPath, self.inputName[index]))
        if self.transform:
            img = self.transform(img)
        
        return img, self.inputName[index].replace(".jpg", "")

    def __len__(self):
        return len(self.inputName)

def imshow(img):
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
# show images

# %%
inference_dataset = valdataset(valid_dir, transform=preprocess)
print('# images in valid:', len(inference_dataset))

inference_loader = DataLoader(inference_dataset, batch_size=1, shuffle=False, num_workers=0)

dataiter = iter(inference_loader)
images,  filename = dataiter.next()
print(filename[0])
# imshow(torchvision.utils.make_grid(images))

# %%
def test(testmodel, valid_loader):
    predict = {}
    testmodel.eval()
        
    with torch.no_grad():
        
        for i, (img, trg, filename) in enumerate(valid_loader):
            img, trg = img.to(device), trg.to(device)
            out, _ = testmodel(img, trg)
            text = out.argmax(2, keepdim=False)
            text = text.cpu().numpy().squeeze().tolist()
            text = tokenizer.decode(text)
            # text = tokenizer.decode(text[:text.index(3)+1])
            
            predict[filename[0]] = text
        
    return predict

def inference(enc, testmodel, valid_loader):
    pred = {}
    BOS = 2
    EOS = 3
    max_len = 77
    testmodel.eval()
    
    for i, (img, _, filename) in enumerate(valid_loader):
        img = img.to(device)
        batch_size = img.shape[0]
        
        trg_indexes = torch.zeros((batch_size, max_len), dtype=torch.int32)
        trg_indexes[:, 0] = BOS
        # print(trg_indexes)
        trg_indexes = trg_indexes.to(device)
        
        with torch.no_grad():
            enc_src = enc(img).float().to(device)
                               
            for index in range(1, max_len):
                # trg_mask = testmodel.make_trg_mask(trg_indexes)
                # out, attention = testmodel.decoder(trg_indexes, enc_src, trg_mask)
                out, attention = testmodel(img, enc_src, trg_indexes)
                
                pred_token = out.argmax(2)[:,-1].item()
                # print("pred: ",pred_token)
                trg_indexes[:,index] = pred_token
                # print(pred_token[:,index])
                if pred_token == EOS:
                    break
                # print("trg: ", trg_indexes)
            trg_indexes = trg_indexes.cpu().numpy().squeeze().tolist()
        caption = tokenizer.decode(trg_indexes)
        # print(caption)
        pred[filename[0]] = caption
    return pred    

def inference2(enc, testmodel, valid_loader):
    dict = {}
    testmodel.eval()
    max_len = 77
    with torch.no_grad():
        for img, _, filename in valid_loader:
            img = img.to(device)
            trg_indexes = [BOS]
            with torch.no_grad():
                enc_src = testmodel.enc(img).float().to(device)
                
                for i in range(max_len):
                    trg_tensor = torch.LongTensor(trg_indexes).unsqueeze(0).to(device)
                    # trg_mask = generate_square_subsequent_mask(trg_tensor.shape[1], device)
                    # trg_mask = testmodel.make_trg_mask(trg_tensor)
                    out, attention = testmodel(img, enc_src, trg_tensor)
                    # out, attention = testmodel.decoder(enc_src, trg_tensor)
                    
                    # print(out.argmax(2).shape)
                    pred_token = out.argmax(2)[:,-1].item()
                    # print(out.argmax(2))
                    trg_indexes.append(pred_token)
                    # print(trg_indexes)
                    if(pred_token == EOS):
                        break
            
            caption = tokenizer.decode(trg_indexes)
            print(caption)
            dict[filename[0]] = caption
    return dict

# %%
# load model
enc = Encoder()

dec = Decoder(OUTPUT_DIM, 
              HID_DIM, 
              DEC_LAYERS, 
              DEC_HEADS, 
              DEC_PF_DIM, 
              DEC_DROPOUT, 
              device)
testmodel = Transformer(enc, dec, TRG_PAD_IDX, device).to(device)

print(f'The model has {count_parameters(testmodel):,} trainable parameters')
# model = model.apply(initialize_weights)
optimizer = torch.optim.Adam(testmodel.parameters(), lr = LEARNING_RATE)
criterion = nn.CrossEntropyLoss(ignore_index = TRG_PAD_IDX)
testmodel.load_state_dict(torch.load(os.path.join(ckpt_dir, 'ViT-L14336pxlayer3_17.pt')))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /data/jhccc/dlcv/hw3-jhc659/hw3_2 copy 2.ipynb Cell 12 in <cell line: 2>()
#       <a href='vscode-notebook-cell://ssh-remote%2B140.112.29.93/data/jhccc/dlcv/hw3-jhc659/hw3_2%20copy%202.ipynb#X15sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> # load model
# ----> <a href='vscode-notebook-cell://ssh-remote%2B140.112.29.93/data/jhccc/dlcv/hw3-jhc659/hw3_2%20copy%202.ipynb#X15sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> enc = Encoder()
#       <a href='vscode-notebook-cell://ssh-remote%2B140.112.29.93/data/jhccc/dlcv/hw3-jhc659/hw3_2%20copy%202.ipynb#X15sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> dec = Decoder(OUTPUT_DIM,
#       <a href='vscode-notebook-cell://ssh-remote%2B140.112.29.93/data/jhccc/dlcv/hw3-jhc659/hw3_2%20copy%202.ipynb#X15sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a>               HID_DIM,
#       <a href='vscode-notebook-cell://ssh-remote%2B140.112.29.93/data/jhccc/dlcv/hw3-jhc659/hw3_2%20copy%202.ipynb#X15sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a>               DEC_LAYERS,
#    (...)
#       <a href='vscode-notebook-cell://ssh-remote%2B140.112.29.93/data/jhccc/dlcv/hw3-jhc659/hw3_2%20copy%202.ipynb#X15sdnNjb2RlLXJlbW90ZQ%3D%3D?line=8'>9</a>               DEC_DROPOUT,
#      <a href='vscode-notebook-cell://ssh-remote%2B140.112.29.93/data/jhccc/dlcv/hw3-jhc659/hw3_2%20copy%202.ipynb#X15sdnNjb2RlLXJlbW90ZQ%3D%3D?line=9'>10</a>               device)
#      <a href='vscode-notebook-cell://ssh-remote%2B140.112.29.93/data/jhccc/dlcv/hw3-jhc659/hw3_2%20copy%202.ipynb#X15sdnNjb2RlLXJlbW90ZQ%3D%3D?line=10'>11</a> testmodel = Transformer(enc, dec, TRG_PAD_IDX, device).to(device)
#
# /data/jhccc/dlcv/hw3-jhc659/hw3_2 copy 2.ipynb Cell 12 in Encoder.__init__(self)
#       <a href='vscode-notebook-cell://ssh-remote%2B140.112.29.93/data/jhccc/dlcv/hw3-jhc659/hw3_2%20copy%202.ipynb#X15sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> def __init__(self):
#       <a href='vscode-notebook-cell://ssh-remote%2B140.112.29.93/data/jhccc/dlcv/hw3-jhc659/hw3_2%20copy%202.ipynb#X15sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a>     super().__init__()
# ----> <a href='vscode-notebook-cell://ssh-remote%2B140.112.29.93/data/jhccc/dlcv/hw3-jhc659/hw3_2%20copy%202.ipynb#X15sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a>     self.clip_encoder, __ = clip.load('ViT-L/14@336px', device)
#       <a href='vscode-notebook-cell://ssh-remote%2B140.112.29.93/data/jhccc/dlcv/hw3-jhc659/hw3_2%20copy%202.ipynb#X15sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a>     self.clip_encoder = self.clip_encoder.float()
#       <a href='vscode-notebook-cell://ssh-remote%2B140.112.29.93/data/jhccc/dlcv/hw3-jhc659/hw3_2%20copy%202.ipynb#X15sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a>     #override vit's forward
#
# File ~/anaconda3/envs/dlcv/lib/python3.8/site-packages/clip/clip.py:129, in load(name, device, jit, download_root)
#     126 with open(model_path, 'rb') as opened_file:
#     127     try:
#     128         # loading JIT archive
# --> 129         model = torch.jit.load(opened_file, map_location=device if jit else "cpu").eval()
#     130         state_dict = None
#     131     except RuntimeError:
#     132         # loading saved state dict
#
# File ~/anaconda3/envs/dlcv/lib/python3.8/site-packages/torch/jit/_serialization.py:164, in load(f, map_location, _extra_files)
#     162     cpp_module = torch._C.import_ir_module(cu, str(f), map_location, _extra_files)
#     163 else:
# --> 164     cpp_module = torch._C.import_ir_module_from_buffer(
#     165         cu, f.read(), map_location, _extra_files
#     166     )
#     168 # TODO: Pretty sure this approach loses ConstSequential status and such
#     169 return wrap_cpp_module(cpp_module)
#
# KeyboardInterrupt:

# %%
pred = inference(testmodel, valid_loader)

# %%
pred
# Out:
# {'000000165547': 'a man in is holding on and of .',
#  '000000518586': 'a man is on in holding and a board .',
#  '000000249720': 'a man is on in holding and a dog',
#  '000000122934': 'a man in is holding on and of .',
#  '000000393258': 'a man in is holding and a - - - - - - hat shirt shirt shirt shirt - - shirt - - shirt - - - - shirt shirt - - shirt - - - - - shirt - shirt - - - - - shirt shirt - - - - - - - - shirt - - - - - - - - - - shirt shirt - - - - - - -',
#  '000000266041': 'a man in is holding a - hat and - tie .',
#  '000000053015': 'a man in and is holding a cake .',
#  '000000039540': 'a plate of and of food on .',
#  '000000320039': 'a man in and is holding on of .',
#  '000000014941': 'a plate with , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , ,',
#  '000000304355': 'a bathroom with toilet and and and sink .',
#  '000000096514': 'a man in is holding on and a board .',
#  '000000578703': 'a bathroom with sink and and and sink',
#  '000000350966': 'a man is on with and on a bench .',
#  '000000201220': 'a man in and is holding a cake .',
#  '000000309100': 'a man is on in holding a board',
#  '000000298726': 'a man in is holding on and a board .',
#  '000000214742': 'a man is on in and holding a board .',
#  '000000135356': 'a man in is holding on and of .',
#  '000000279806': 'a man in is riding on a board',
#  '000000163361': 'a man in is holding a kite on .',
#  '000000135978': 'a man in is holding on and a board .',
#  '000000163460': 'a man in is holding on and a board',
#  '000000434129': 'a man in is holding on and of of .',
#  '000000575428': 'a man in is holding on and of of .',
#  '000000046912': 'a man in is holding on and of .',
#  '000000377326': 'a man is on in and holding a board .',
#  '000000302219': 'a man in is holding on and of .',
#  '000000300655': 'a man in is on with on and .',
#  '000000178748': 'a plate of and of food on .',
#  '000000519299': 'a man is on holding on of and .',
#  '000000216303': 'a man in is holding on and of of .',
#  '000000038892': 'a man in is holding a and - - hat - hat - hat hat and tie and on . . on .',
#  '000000487151': 'a man in is on with and on and .',
#  '000000461883': 'a dog is on in with on and .',
#  '000000470313': 'a bathroom with toilet and and and sink .',
#  '000000137490': 'a man in is on holding a board .',
#  '000000491965': 'a man is on in and holding of food .',
#  '000000056400': 'a man in is holding on and with and .',
#  '000000042055': 'a man in is holding on a board .',
#  '000000164594': 'a man in is holding on and a board .',
#  '000000303215': 'a man is on holding in and and .',
#  '000000481891': 'a man in and is holding a frisbee .',
#  '000000301755': 'a man in is holding on and a board .',
#  '000000047940': 'a man in is holding on and in .',
#  '000000192233': 'a plate with and of food on on a table .',
#  '000000417590': 'a man is on in and holding a board .',
#  '000000164899': 'a man in is holding on and a table .',
#  '000000368505': 'a man in is holding on and a board .',
#  '000000513778': 'a bathroom with sink and , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , ,',
#  '000000352476': 'a man is on in and holding a board .',
#  '000000259879': 'a man is on in and holding a frisbee .',
#  '000000178361': 'a man in is holding a and frisbee .',
#  '000000020972': 'a man in is holding a kite in .',
#  '000000367881': 'a man in is holding on on of .',
#  '000000451305': 'a man in is holding on and of of .',
#  '000000485294': 'a bathroom with sink and and sink',
#  '000000177990': 'a man in is holding on and of .',
#  '000000540159': 'a man in is holding on and a board .',
#  '000000096539': 'a plate of of food and on .',
#  '000000147904': 'a man in is a holding a tennis racket .',
#  '000000546642': 'a man in is holding on and a board .',
#  '000000307989': 'a man in is holding and a cake on .',
#  '000000267840': 'a man in is holding on on of .',
#  '000000405675': 'a man in is holding a and kite .',
#  '000000378823': 'a man is on in holding and a board',
#  '000000394322': 'a man in is holding on and of .',
#  '000000411043': 'a man in is holding on and of .',
#  '000000137573': 'a man in is holding on and of of .',
#  '000000301155': 'a man in is holding on and a board .',
#  '000000333156': 'a plate of and food on with and on .',
#  '000000241068': 'a man in is holding on and a board .',
#  '000000285734': 'a man in is on and holding a frisbee .',
#  '000000408143': 'a man is on with and on and .',
#  '000000491872': 'a man is on holding in and and a bathroom .',
#  '000000084123': 'a man in is holding on on of .',
#  '000000102996': 'a man in is holding a and - - - hat hat and - hat hat and - tie and tie tie . and in .',
#  '000000251044': 'a man in is holding on and of .',
#  '000000201859': 'a man is on in and holding a board .',
#  '000000579326': 'a man in is holding on and in',
#  '000000370038': 'a man in is holding on and a table .',
#  '000000548729': 'a man in is holding on and of of .',
#  '000000140197': 'a man in is holding and a woman in .',
#  '000000353836': 'a man in is holding on and a board .',
#  '000000491681': 'a man in is riding a wave on .',
#  '000000289941': 'a man in and is holding a cake .',
#  '000000540834': 'a man is on in and holding and a - - - - - - - - - - shirt shirt shirt shirt shirt shirt - - - - shirt shirt - shirt - - - - - shirt - - - - - - shirt - shirt shirt - - - - - - - shirt - - - - - - - - - - shirt shirt - - - - - - -',
#  '000000318825': 'a man in is holding a and tennis racket .',
#  '000000226874': 'a man in is holding a hat and on board',
#  '000000118432': 'a man in is holding on on of .',
#  '000000146640': 'a man in is holding on and a board',
#  '000000113757': 'a man in is holding on and a table .',
#  '000000346702': 'a man in is holding on and a board .',
#  '000000296871': 'a man is on holding a board in .',
#  '000000136572': 'a man in is holding on and of .',
#  '000000238602': 'a man in is holding on and in .',
#  '000000460972': 'a man in is on holding on and of .',
#  '000000210766': 'a woman in is holding in and .',
#  '000000006789': 'a train is on on tracks near .',
#  '000000502275': 'a plate of and of food on .',
#  '000000370399': 'a man is on in and holding a frisbee .',
#  '000000437618': 'a bathroom with , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , ,',
#  '000000099389': 'a man in is holding on and a board .',
#  '000000536294': 'a man in is riding a wave on .',
#  '000000106096': 'a man in is holding on and of .',
#  '000000032960': 'a man is on with and on of .',
#  '000000206587': 'a train is on on tracks near .',
#  '000000102466': 'a man in is holding on a board',
#  '000000397903': 'a man in is holding on and of .',
#  '000000074001': 'a man in is holding on in and .',
#  '000000213023': 'a man in is holding on and of .',
#  '000000082740': 'a man is on in holding and a board',
#  '000000553852': 'a man in is holding on and a board .',
#  '000000557396': 'a man in is holding on and in .',
#  '000000397658': 'a man in is holding on and of of .',
#  '000000315474': 'a man in is holding on and of .',
#  '000000049667': 'a man in is holding on and a board .',
#  '000000336937': 'a man is on in holding and a kite .',
#  '000000302302': 'a bathroom with and sink , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , ,',
#  '000000013414': 'a man is on with on and holding of .',
#  '000000137507': 'a plate of with and food on on .',
#  '000000481281': 'a plate of of food with and on .',
#  '000000358247': 'a man in is holding on and a board .',
#  '000000420610': 'a plate of and of food on .',
#  '000000423588': 'a man is on in holding and a board .',
#  '000000033798': 'a bathroom with and toilet and and on .',
#  '000000425676': 'a bathroom with and sink and and .',
#  '000000168898': 'a plate of and food on with and',
#  '000000423919': 'a man in is holding on and a table .',
#  '000000306313': 'a man in is holding on on and .',
#  '000000504452': 'a man is on in holding a board',
#  '000000091636': 'a man is on in holding and of of .',
#  '000000482907': 'a man in and a blue blue and blue blue and blue and blue blue and blue blue and and blue blue and blue and blue blue and blue and and blue and blue and blue and blue and and flying flying in',
#  '000000053677': 'a man in is holding on and of of .',
#  '000000033717': 'a plate of with and vegetables on on .',
#  '000000329806': 'a man is on in holding and a board .',
#  '000000332074': 'a man is on with and on of and .',
#  '000000022051': 'a plate of and of food on on',
#  '000000439902': 'a plate of with and vegetables on .',
#  '000000523123': 'a man in is holding on and of .',
#  '000000252280': 'a man in is holding and a - - - - - - hat shirt shirt hat - and - hat - hat hat - - hat - - shirt - - hat - - hat - - shirt and - - - - - - tie tie tie and and - - tie tie tie and and tie - tie and - and - - tie tie tie in tie tie and and tie tie',
#  '000000150616': 'a man in is holding on and a board .',
#  '000000369601': 'a man in and is holding a - cake and on .',
#  '000000189600': 'a man in is holding on and of .',
#  '000000071095': 'a baseball player is on in with and',
#  '000000301753': 'a dog is on in in and .',
#  '000000272357': 'a man is on in and playing with on .',
#  '000000265971': 'a man in is holding a tennis and tennis .',
#  '000000043404': 'a man in is holding on and of .',
#  '000000429160': 'a bathroom with , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , ,',
#  '000000095482': 'a man in is holding a tennis and tennis .',
#  '000000488069': 'a man in is holding on and of .',
#  '000000553129': 'a plate with , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , ,',
#  '000000570594': 'a man is on holding in and of .',
#  '000000047916': 'a dog is on in in and .',
#  '000000240655': 'a man in is holding on and a cake .',
#  '000000289263': 'a man is on holding in and and a of .',
#  '000000480438': 'a bathroom with sink , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , ,',
#  '000000172673': 'a man in is holding on and of .',
#  '000000159151': 'a man in is holding on and of .',
#  '000000195267': 'a man in is holding on and of .',
#  '000000087483': 'a man is in and holding in and of .',
#  '000000126540': 'a man in is holding on and of .',
#  '000000544538': 'a man is on with and on of .',
#  '000000050034': 'a man is on with and on and a board .',
#  '000000438046': 'a man in is holding and a woman in .',
#  '000000217561': 'a plate with , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , ,',
#  '000000326021': 'a man in is holding and a - woman in',
#  '000000168805': 'a man in is holding on in and .',
#  '000000580766': 'a man in is holding on and of of .',
#  '000000443652': 'a bathroom with sink and and sink .',
#  '000000224247': 'a man is on in and holding a kite .',
#  '000000146773': 'a man in is holding and a woman in .',
#  '000000366421': 'a man in is holding on and of .',
#  '000000518908': 'a man is on in holding and a board',
#  '000000172886': 'a bathroom with sink and and , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , ,',
#  '000000494404': 'a bathroom with sink and , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , ,',
#  '000000022979': 'a man is on with and holding and a woman .',
#  '000000380828': 'a man in is holding on and of of .',
#  '000000151432': 'a man in is holding a - shirt and - - - - shirt shirt and - - - shirt hat - - - shirt - - - - shirt shirt and - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -',
#  '000000215549': 'a man in is holding on and of of people .',
#  '000000044421': 'a man in is holding on and of of .',
#  '000000099707': 'a man is on holding in and and of .',
#  '000000512145': 'a plate with and of , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , ,',
#  '000000161940': 'a man is on with and on and a plate .',
#  '000000370819': 'a plate of and food on with and on .',
#  '000000438848': 'a man in is holding on and with of .',
#  '000000168775': 'a plate of and of vegetables on .',
#  '000000563730': 'a plate with , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , ,',
#  '000000509185': 'a man is on holding in and and .',
#  '000000287830': 'a man in is riding on on board',
#  '000000324710': 'a man in is holding on and of .',
#  '000000026501': 'a man in is holding on and of .',
#  '000000073981': 'a man in is holding on and a board .',
#  '000000377911': 'a man in is holding a and woman in .',
#  '000000098268': 'a man is on in and holding a cake .',
#  '000000382557': 'a man in is holding on and a board .',
#  '000000473433': 'a man in is holding on and of .',
#  '000000307048': 'a man is on in and holding and a - - - - - - - - - - - shirt shirt - shirt shirt - hat - - shirt shirt - shirt - - - - - shirt - - - - - - shirt tie tie tie - tie - - tie - - shirt - - - shirt tie - - - - - shirt shirt - - - - - - -',
#  '000000162855': 'a man in is holding a frisbee in .',
#  '000000494456': 'a man in is holding on and of .',
#  '000000047611': 'a plate of , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , ,',
#  '000000175318': 'a man in is holding on and a board .',
#  '000000010217': 'a man in is holding on and of .',
#  '000000124210': 'a man is on in holding and a dog',
#  '000000113897': 'a bathroom with toilet and and and sink .',
#  '000000548464': 'a man in is holding on and a board .',
#  '000000549932': 'a man in is holding on and a board',
#  '000000415153': 'a man is on in and holding of .',
#  '000000036508': 'a plate of and food on with and food .',
#  '000000519446': 'a cat sitting on on next next to .',
#  '000000222866': 'a plate of and of vegetables on .',
#  '000000402115': 'a man in is holding on and a table .',
#  '000000345160': 'a man in is holding on and a plate .',
#  '000000486846': 'a plate of with and vegetables on .',
#  '000000191893': 'a man is on in and holding a kite .',
#  '000000224037': 'a man is on in and holding and of people .',
#  '000000445267': 'a bathroom with and sink and , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , ,',
#  '000000126345': 'a man in is holding on in and .',
#  '000000191078': 'a plate of and of food on .',
#  '000000051339': 'a man in is holding and a - - - - - - tennis racket - - tennis racket and - racket and - - - - - - tennis racket and racket - and - - - - tennis - racket in and - and - - racket - is and on and - - - - - - - - - - - - - - - - - - - - - -',
#  '000000266437': 'a man in is holding on and on .',
#  '000000163309': 'a man in is holding a and kite .',
#  '000000138022': 'a man in is holding on and a board .',
#  '000000092815': 'a man in is holding on and a plate .',
#  '000000470801': 'a man in is holding on and on of .',
#  '000000311904': 'a man in is holding a and - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -',
#  '000000579696': 'a man in is holding on and a board .',
#  '000000406201': 'a plate of and of vegetables on .',
#  '000000575012': 'a man is on with and holding on .',
#  '000000381037': 'a man in is holding on and of .',
#  '000000383209': 'a man in is holding on and with of .',
#  '000000063434': 'a man in is holding on and of .',
#  '000000156532': 'a man is on in and holding and a board .',
#  '000000038064': 'a man in is holding on and in .',
#  '000000160886': 'a bathroom with sink and , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , ,',
#  '000000468972': 'a man in is holding on and a board .',
#  '000000168692': 'a man is on with and on and .',
#  '000000556892': 'a man is on in and holding and of .',
#  '000000397980': 'a man in is holding and a tennis racket .',
#  '000000309222': 'a man in is holding on and of .',
#  '000000145391': 'a man in is holding on and a board .',
#  '000000215303': 'a man in is holding on and a table .',
#  '000000456574': 'a man in is holding on and of of .',
#  '000000247394': 'a bathroom with toilet and and and sink .',
#  '000000275744': 'a man is on with and on of and .',
#  '000000560637': 'a man in is holding a and frisbee .',
#  '000000286176': 'a man in is holding and a woman in .',
#  '000000549112': 'a plate of , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , ,',
#  '000000275117': 'a man in is holding a and woman on .',
#  '000000054924': 'a man in is holding a - - umbrella and .',
#  '000000303667': 'a plate with , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , ,',
#  '000000390769': 'a man in is holding on and a board .',
#  '000000500784': 'a plate with , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , ,',
#  '000000297976': 'a bathroom with and sink and and .',
#  '000000264909': 'a man is on in holding and of .',
#  '000000200681': 'a man in is holding and a frisbee in .',
#  '000000344521': 'a plate of and of food on .',
#  '000000111944': 'a man riding on on skis in .',
#  '000000054870': 'a plate of and food on with on .',
#  '000000426342': 'a man is in and holding a frisbee in .',
#  '000000344368': 'a man is on with and on and a board .',
#  '000000302710': 'a man in is holding on and a board',
#  '000000127119': 'a man in is holding on and a board',
#  '000000260099': 'a train is on on tracks near .',
#  '000000003771': 'a bathroom with and sink and in .',
#  '000000349896': 'a clock tower on on on of .',
#  '000000274591': 'a man in is holding on and in .',
#  '000000098322': 'a man is on with and on and of .',
#  '000000053665': 'a man in is riding a wave on .',
#  '000000189694': 'a bathroom with sink and , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , ,',
#  '000000011182': 'a man in is holding on and of .',
#  '000000354027': 'a man in is holding on and of .',
#  '000000107511': 'a man in is holding on and a board .',
#  '000000141426': 'a man in is holding on and of .',
#  '000000158588': 'a man is on in and holding of of .',
#  '000000425522': 'a man in is holding on and of .',
#  '000000042288': 'a man is on in holding and a board .',
#  '000000303814': 'a man is on holding on and of .',
#  '000000068205': 'a man in is holding on and in .',
#  '000000015797': 'a man is on in holding and and a board .',
#  '000000034708': 'a man in is holding a and - - - hat hat - hat hat and - tie and tie tie and . tie . .',
#  '000000098187': 'a bathroom with toilet and and and sink .',
#  '000000378311': 'a plate of and of food on .',
#  '000000219546': 'a plate of of food and on .',
#  '000000406155': 'a man in is riding on a board',
#  '000000006393': 'a bathroom with sink , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , ,',
#  '000000267802': 'a man is on in and holding a board .',
#  '000000523597': 'a man in is holding on and a board .',
#  '000000079836': 'a man in is on holding on of .',
#  '000000005418': 'a man in is holding a frisbee in .',
#  '000000474388': 'a man in is holding a - frisbee in .',
#  '000000532580': 'a man is on in and holding of .',
#  '000000223857': 'a man in is holding on and a board .',
#  '000000215024': 'a person riding on on on beach in',
#  '000000020147': 'a bathroom with toilet and and sink in',
#  '000000287846': 'a man is on holding on in and .',
#  '000000182736': 'a train on tracks on tracks near .',
#  '000000227851': 'a man is on holding in and and of .',
#  '000000349590': 'a plate of and food on with on .',
#  '000000266853': 'a bathroom with and toilet and on .',
#  '000000099747': 'a man in is holding on and a board .',
#  '000000393777': 'a man in is holding a and - - - - - - - - shirt - - - - - - - - - - - - - shirt - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -',
#  '000000092338': 'a man in is holding on and of .',
#  '000000114616': 'a man in is holding on and a board',
#  '000000029160': 'a man in is riding on a board',
#  '000000023051': 'a man in is holding on and of .',
#  '000000408363': 'a man in is holding on and a board .',
#  '000000575911': 'a bathroom with sink and , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , ,',
#  '000000513887': 'a man in is holding on and a plate .',
#  '000000470115': 'a man is on in and holding of and .',
#  '000000268058': 'a woman in is holding on and a plate .',
#  '000000136181': 'a man in is holding on a board board .',
#  '000000400265': 'a man in is on holding a board .',
#  '000000493751': 'a man in is holding on and on .',
#  '000000297414': 'a man in is holding on and a board .',
#  '000000148614': 'a bathroom with and sink , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , ,',
#  '000000370095': 'a man in is holding a frisbee in .',
#  '000000339019': 'a man is on a holding board in',
#  '000000574208': 'a man in is holding a frisbee in .',
#  '000000528011': 'a man is on in holding a board',
#  '000000009813': 'a man in is holding on and a board .',
#  '000000429170': 'a man in is holding on on and of .',
#  '000000273196': 'a man in is holding on and a board .',
#  '000000492025': 'a man in is holding on and a of .',
#  '000000185360': 'a man in is holding on and a board .',
#  '000000062824': 'a man in is holding on and a board .',
#  '000000471625': 'a man is on in and holding of .',
#  '000000354368': 'a man in is holding on and of .',
#  '000000217393': 'a man in is holding on on of .',
#  '000000032909': 'a man in is holding on and of of .',
#  '000000232627': 'a man in is holding on in and .',
#  '000000117201': 'a man is on in holding and a kite .',
#  '000000156282': 'a man in is holding a kite on .',
#  '000000169683': 'a man in is a and holding a frisbee .',
#  '000000441054': 'a man in is holding on in and .',
#  '000000472295': 'a man is on in holding and and a dog .',
#  '000000321603': 'a man in is holding and a cake .',
#  '000000554445': 'a man in is holding on and of .',
#  '000000281676': 'a man in is holding on and a board .',
#  '000000330356': 'a clock tower on on in near .',
#  '000000176527': 'a man riding on on board on beach .',
#  '000000523252': 'a train is on on tracks next .',
#  '000000350491': 'a man is on in and holding and a of .',
#  '000000175136': 'a man is on with and on of and .',
#  '000000085852': 'a man in is holding on and a board .',
#  '000000330419': 'a man in is holding a and - - - - - - umbrella hat hat and hat and - hat - and hat - on - - - hat - - - - - - - - - - - - - - - - - hat - - - - - - - - - - - - - - - - - - - - - - - - - - - -',
#  '000000049068': 'a bathroom with and sink and , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , ,',
#  '000000524979': 'a man in is holding a and woman in .',
#  '000000030403': 'a man in is on holding a board .',
#  '000000255315': 'a man in is holding on and a board .',
#  '000000445668': 'a man in is riding on on a board .',
#  '000000066191': 'a plate of with and vegetables on .',
#  '000000079924': 'a plate of and of food on .',
#  '000000082576': 'a man in is riding on on board',
#  '000000282841': 'a man in is holding on and a table .',
#  '000000326555': 'a man in is holding on and holding .',
#  '000000254929': 'a plate of and of food on .',
#  '000000100409': 'a man in and is holding a cake on .',
#  '000000462632': 'a plate of , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , ,',
#  '000000536879': 'a man in is holding on and a table .',
#  '000000192079': 'a plate of and food on with and on .',
#  '000000500420': 'a man in is holding a and on board .',
#  '000000361751': 'a man in is holding on and of of .',
#  '000000291144': 'a man in is holding on and of of .',
#  '000000143696': 'a man in is holding on and of of .',
#  '000000310757': 'a plate of , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , ,',
#  '000000489798': 'a man in is holding on and a board .',
#  '000000452297': 'a bathroom with , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , ,',
#  '000000199819': 'a plate of and food on with on .',
#  '000000552018': 'a man in is holding on and a board .',
#  '000000419723': 'a man in is holding on and of .',
#  '000000344025': 'a man in is holding on and a table .',
#  '000000106206': 'a man is on holding in and and a woman .',
#  '000000394132': 'a man in a shirt and is a on',
#  '000000161539': 'a man is on in and holding a - - - - - - - - shirt - shirt - shirt shirt - - shirt - - - - shirt shirt - - - - - - - - - - - - - - - - shirt shirt - - - - - - - - - - - - - - - - - - - - - - - - - - -',
#  '000000347648': 'a man is in holding and a cake .',
#  '000000326592': 'a bathroom with toilet and and and sink',
#  '000000173997': 'a man in is holding on and a board .',
#  '000000401758': 'a man is in holding and on of .',
#  '000000213799': 'a man in is holding a and woman on .',
#  '000000253474': 'a man is on in and holding and of .',
#  '000000559136': 'a man in is riding on on snow covered .',
#  '000000248956': 'a man is on in holding and of .',
#  '000000381318': 'a man in is holding on and a plate .',
#  '000000366683': 'a plate of with and , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , ,',
#  '000000019491': 'a plate of and food on with on .',
#  '000000171201': 'a man is on holding in and .',
#  '000000404027': 'a man in is holding on and a board .',
#  '000000286106': 'a man in is holding on and of .',
#  '000000253825': 'a man is on holding in and holding and .',
#  '000000536403': 'a man in is holding on and of .',
#  '000000331223': 'a man in is holding a and woman on .',
#  '000000432798': 'a man in is holding on and with of .',
#  '000000342060': 'a man is on on with and on of .',
#  '000000207458': 'a man is on in and holding a dog .',
#  '000000257864': 'a plate of of food and on .',
#  '000000146675': 'a man in is holding a - - shirt and - - - shirt - shirt and - - - shirt - - - shirt - - - - shirt shirt - - - - - - - - - - - - - - - - shirt - - - - - - - - - - - - - - - - - - - - - - - - - - - -',
#  '000000411177': 'a man in is holding on and a board .',
#  '000000110617': 'a man in is holding on and a board',
#  '000000169872': 'a man in is holding on and a board .',
#  '000000454810': 'a bathroom with toilet and and and sink',
#  '000000082312': 'a man in is holding on and of .',
#  '000000373578': 'a man in is holding on and a board',
#  '000000121503': 'a man in is holding on and in .',
#  '000000015984': 'a man is in and holding a of of .',
#  '000000515355': 'a plate with , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , ,',
#  '000000478517': 'a man in is holding on and a board .',
#  '000000389753': 'a bathroom with and sink , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , ,',
#  '000000418226': 'a man in is holding on and of .',
#  '000000252617': 'a man is on a holding a board .',
#  '000000415714': 'a man in is riding on on board .',
#  '000000181403': 'a man in is holding a - hat and and on .',
#  '000000353130': 'a plate of of food and on .',
#  '000000405334': 'a man in is holding and a cake .',
#  '000000357402': 'a man is on holding in and and a room',
#  '000000342387': 'a plate of and of food on .',
#  '000000198495': 'a man in is holding on and a board .',
#  '000000537727': 'a man in is holding a and - - - - - - hat hat hat - hat - hat hat - hat hat - - hat - - hat - - hat - - hat - tie - tie and tie - tie tie and tie tie tie and and . . . and tie . . . on . . . . . . .',
#  '000000373857': 'a man in is holding on and in .',
#  '000000480223': 'a plate of of vegetables and on on a plate',
#  '000000469130': 'a man in is riding on on a board',
#  '000000190406': 'a man in is holding on and a board .',
#  '000000435187': 'a man in is holding on and of of .',
#  '000000511420': 'a woman in is holding in and and .',
#  '000000099543': 'a man in is holding on and of .',
#  '000000115636': 'a man in is holding a - - - - shirt shirt and - - - - shirt - - shirt - - - - - shirt - - shirt - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -',
#  '000000138185': 'a plate of and of food on .',
#  '000000053800': 'a man in is holding and a woman in .',
#  '000000561619': 'a plate of with , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , ,',
#  '000000396167': 'a man in is holding on and a board',
#  '000000448275': 'a man in is holding on and a board .',
#  '000000406050': 'a man is on in and holding a board .',
#  '000000320203': 'a man is on holding in and and .',
#  '000000387506': 'a man is on in and holding a board .',
#  '000000578467': 'a man in is holding and a - - - - - - hat hat shirt - shirt - - shirt - - hat - - hat - - shirt - - shirt - - - - - shirt - - - - - - shirt - shirt - - - - - - - - shirt - - - - - - - - - - shirt - - - - - - - -',
#  '000000503207': 'a man in is holding on and of .',
#  '000000009214': 'a man in is holding a of and .',
#  '000000054627': 'a bathroom with and sink and , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , ,',
#  '000000143098': 'a man is on in and holding a frisbee .',
#  '000000069266': 'a man in is holding a and - - - hat - hat hat and tie and tie and tie and tie . . .',
#  '000000457453': 'a man in is on holding a board .',
#  '000000177173': 'a man in is holding and a - - cake with and on .',
#  '000000065357': 'a man in is holding a and woman on .',
#  '000000070240': 'a man in is holding on and in .',
#  '000000139734': 'a plate with , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , ,',
#  '000000010496': 'a man is on in holding and a board .',
#  '000000285250': 'a man in and a blue blue and blue and blue blue and blue and blue flying on',
#  '000000520451': 'a man in is holding a - - - - shirt shirt and - - - shirt - - - shirt - - shirt - - shirt - - shirt - - - - - - - - - - shirt - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -',
#  '000000521772': 'a man in is holding on and of of .',
#  '000000138514': 'a man in is holding on and on of .',
#  '000000049643': 'a man is on in and holding and a - - - - - - - - - - - - - - - - - - - - shirt - - shirt - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -',
#  '000000192866': 'a man in is holding on and of .',
#  '000000466839': 'a bathroom with toilet and and and sink',
#  '000000359141': 'a man in is holding on and in',
#  '000000234749': 'a plate of and of food on .',
#  '000000000620': 'a man in is holding on and a board .',
#  '000000496517': 'a man in is holding on and a plate .',
#  '000000272785': 'a man in is holding on and a board .',
#  '000000533522': 'a man in and is holding a cake .',
#  '000000361638': 'a bathroom with sink and and sink .',
#  '000000160014': 'a man in is holding on and a board',
#  '000000376362': 'a man in is holding a and kite .',
#  '000000298793': 'a man in is on holding on of .',
#  '000000465969': 'a man in is holding a - hat and - - hat - hat hat and - tie and tie tie . . and .',
#  '000000133660': 'a man is on in holding and a board',
#  '000000382171': 'a man is on in and holding a of .',
#  '000000157238': 'a man is on in holding and a board',
#  '000000057883': 'a man in is riding a wave on .',
#  '000000580082': 'a man is on in and holding and of .',
#  '000000280023': 'a plate of and of food on .',
#  '000000406755': 'a man in is holding on and a table .',
#  '000000117691': 'a man in is holding on and of .',
#  '000000465080': 'a man in is holding a - frisbee in .',
#  '000000190297': 'a man is on holding in and and',
#  '000000507370': 'a bathroom with and sink , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , ,',
#  '000000531474': 'a man in is holding on and a board .',
#  '000000089101': 'a man in is holding on and of of .',
#  '000000031578': 'a man is in and holding a dog in .',
#  '000000353652': 'a man in is holding on and of .',
#  '000000546531': 'a bathroom with sink and and and sink .',
#  '000000200612': 'a man in is holding on and of .',
#  '000000304040': 'a man in is holding on and a board .',
#  '000000143569': 'a man is on in holding and of .',
#  '000000494768': 'a man is on with and on and of .',
#  '000000379165': 'a man in is holding on and a plate .',
#  '000000333621': 'a man in is holding on and of .',
#  '000000154955': 'a man is on a holding a board .',
#  '000000305451': 'a man in is holding and a cake with .',
#  '000000418505': 'a man in is holding on and a board .',
#  '000000535874': 'a man in is holding and a woman on .',
#  '000000241860': 'a man in is holding on and a board .',
#  '000000399241': 'a person riding on on on beach in',
#  '000000524646': 'a man in is holding and a kite in .',
#  '000000351141': 'a man in is holding on and of .',
#  '000000477321': 'a man in is holding a kite in .',
#  '000000387153': 'a plate with and of , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , ,',
#  '000000084157': 'a plate of with and pizza on on',
#  '000000415201': 'a plate of and food on with on .',
#  '000000027675': 'a man in is holding on and of of .',
#  '000000295642': 'a train is on on tracks near .',
#  '000000387181': 'a man in is holding on and a board .',
#  '000000178849': 'a man is on with and on and holding .',
#  '000000143192': 'a man in is holding on and of .',
#  '000000577176': 'a man is on with and on of and .',
#  '000000477782': 'a man in is holding on and a board',
#  '000000215107': 'a man is on holding in and .',
#  '000000471480': 'a man in is holding on and a board',
#  '000000536827': 'a man is on in and holding a board .',
#  '000000197408': 'a man in is holding on and of of .',
#  '000000088377': 'a man in is holding on and of of .',
#  '000000260373': 'a man in is holding on and a board .',
#  '000000290724': 'a man is on in holding and a board .',
#  '000000184355': 'a man is on in holding and of of .',
#  '000000105172': 'a man in is holding a and - - hat hat and on .',
#  '000000448139': 'a man is in and holding a frisbee .',
#  '000000271373': 'a man is on in holding and a board .',
#  '000000581204': 'a plate of with and vegetables on on .',
#  '000000278335': 'a man in is and a shirt holding and on',
#  '000000292844': 'a man in is holding on and of of .',
#  '000000428039': 'a man in is holding on and a board .',
#  '000000267417': 'a man is on in and holding a frisbee .',
#  '000000495615': 'a man in is holding on and in .',
#  '000000376422': 'a plate of and of food on .',
#  '000000483517': 'a man in is holding on and in .',
#  '000000207142': 'a plate of with and vegetables on .',
#  '000000141207': 'a man in is riding on on board',
#  '000000038196': 'a man is on in and holding of .',
#  '000000341639': 'a man is on in and holding and a of of .',
#  '000000064389': 'a plate with , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , ,',
#  '000000495079': 'a man in is a shirt and holding a frisbee .',
#  '000000131696': 'a man in is holding on and of of .',
#  '000000054003': 'a man in is holding on and a board .',
#  '000000330400': 'a man is on in holding and a board .',
#  '000000015733': 'a man is on in holding a board .',
#  '000000300514': 'a plate of of food and on on .',
#  '000000362811': 'a man in is holding on and a board .',
#  '000000353937': 'a man in is holding on and of .',
#  '000000572063': 'a man in is holding on and a board .',
#  '000000313113': 'a plate of and food on with and .',
#  '000000499852': 'a man in is holding on and of of .',
#  '000000060005': 'a man in is on holding on of of .',
#  '000000184282': 'a man is on in and holding a board .',
#  '000000285893': 'a man is on with and on and .',
#  '000000099070': 'a man is on with and on and a woman .',
#  '000000205126': 'a man is on holding and in and .',
#  '000000313280': 'a man in is holding on and a board .',
#  '000000299643': 'a man in is holding on and a board .',
#  '000000409678': 'a plate of of food and on .',
#  '000000198289': 'a plate with , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , ,',
#  '000000040100': 'a train is on on tracks on tracks .',
#  '000000111188': 'a man in is holding on and of of .',
#  '000000111940': 'a man in is holding on and of of .',
#  '000000467137': 'a man is on in and holding of .',
#  '000000229707': 'a man in is holding and a woman in .',
#  '000000312446': 'a bathroom with , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , ,',
#  '000000468132': 'a man in and is on with and on of .',
#  '000000452737': 'a man in is holding and a woman in .',
#  '000000081954': 'a man in and is holding a cake .',
#  '000000239801': 'a plate of with , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , ,',
#  '000000316336': 'a plate of and of food on .',
#  '000000125672': 'a man in is holding on and a plate .',
#  '000000465495': 'a man in is holding on and of of .',
#  '000000400064': 'a man in and is holding a cake .',
#  '000000083601': 'a man in is holding a and woman on .',
#  '000000136154': 'a man in is holding on and of .',
#  '000000419678': 'a man in is holding on and a board .',
#  '000000291889': 'a man is on in and holding of .',
#  '000000456201': 'a man in is holding a - - hat and - - - hat - hat - - - hat - hat - - - - hat - - shirt - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -',
#  '000000403464': 'a man in is holding a - - - - - - - tennis racket racket and - - - - - - racket - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -',
#  '000000421534': 'a man in is holding on a board .',
#  '000000170562': 'a man in is holding and a - dog and on .',
#  '000000383329': 'a man is on with and on and a woman .',
#  '000000069424': 'a plate with , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , ,',
#  '000000361376': 'a plate of and of vegetables on .',
#  '000000297570': 'a bathroom with sink and sink and and',
#  '000000574829': 'a man in is holding on and of .',
#  '000000090498': 'a bathroom with and toilet and and on .',
#  '000000397717': 'a man is on on with and on .',
#  '000000406452': 'a man in is holding on and in .',
#  '000000059267': 'a man is on in holding and holding .',
#  '000000369568': 'a man in is holding on and a field of .',
#  '000000329175': 'a man is on on holding in and of .',
#  '000000456873': 'a plate with , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , ,',
#  '000000174496': 'a bathroom with and toilet and on .',
#  '000000487288': 'a man in and is holding a cake .',
#  '000000256465': 'a man in is holding on and of .',
#  '000000190334': 'a man in is holding on and a board .',
#  '000000224166': 'a plate of with and vegetables on .',
#  '000000154888': 'a man in is holding on and of .',
#  '000000580238': 'a man is on in and holding and of of .',
#  '000000361519': 'a man is on in holding and of .',
#  '000000021374': 'a man in is holding on and of .',
#  '000000162880': 'a man is on with on and on .',
#  '000000208319': 'a plate of with , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , ,',
#  '000000178178': 'a plate of and of food on .',
#  '000000365205': 'a man in and is holding a cake .',
#  '000000248391': 'a man in is holding on and a board .',
#  '000000192394': 'a man is on in holding and a board',
#  '000000243324': 'a man in and a shirt is on a board .',
#  '000000349552': 'a man is on in and holding a board .',
#  '000000480313': 'a man in is holding on and of of .',
#  '000000261196': 'a plate of and of food on .',
#  '000000141922': 'a man is in holding and a cake .',
#  '000000287886': 'a man in is holding on and in .',
#  '000000258129': 'a man in is holding on and a field .',
#  '000000125662': 'a man is on with and on and of',
#  '000000506659': 'a man in is holding on and a board .',
#  '000000529689': 'a man in is holding and a - umbrella .',
#  '000000097363': 'a man in is holding on and in',
#  '000000011323': 'a man in is holding a - - - - hat shirt - shirt and - - - - shirt - shirt - - - - - - - shirt shirt - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -',
#  '000000169448': 'a man in is holding a and - - - - - - hat hat hat - hat and - hat hat - hat - - hat - hat and hat - tie and and tie on tie and and . . . . .',
#  '000000191648': 'a man is on holding in and and .',
#  '000000304584': 'a man is on in and holding of .',
#  '000000336015': 'a man in is riding a snow board on .',
#  '000000017167': 'a man in is holding on and in .',
#  '000000166349': 'a man is on in and holding and a board .',
#  '000000001548': 'a man in is holding on and on of .',
#  '000000347131': 'a man is on with and holding and a woman .',
#  '000000382447': 'a plate with , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , ,',
#  '000000081971': 'a man in is holding on and of .',
#  '000000536010': 'a bathroom with toilet and and and sink .',
#  '000000244293': 'a man is on in and holding a board .',
#  '000000326853': 'a man in is holding on and a board',
#  '000000311475': 'a man in is holding on on of .',
#  '000000157301': 'a man in is holding on on of .',
#  '000000175142': 'a man in is holding on in and .',
#  '000000302576': 'a man in is holding on and a plate .',
#  '000000056323': 'a man in is holding on and a board .',
#  '000000189351': 'a man in is a holding a frisbee .',
#  '000000379567': 'a man in is holding on and a table .',
#  '000000111121': 'a baseball player is on in with and',
#  '000000372660': 'a man in is holding on a board .',
#  '000000559768': 'a man in is holding on and of .',
#  '000000323790': 'a plate with , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , ,',
#  '000000046359': 'a man is on holding a of and of .',
#  '000000205689': 'a man in is holding on and a board .',
#  '000000573659': 'a man in is holding on and of .',
#  '000000139040': 'a man in and is holding a cake .',
#  '000000459465': 'a man in is holding on and of of .',
#  '000000381301': 'a man in is holding on and a board .',
#  '000000105781': 'a man is on on with and a - - - - - - - - - - - - shirt shirt shirt hat shirt shirt hat hat - and hair - - - - hair - hair - hair - - - - - - hair is - - is - - - - - - - - - - - - - - - - - hair - - - - - - -',
#  '000000302489': 'a man in is holding on and of of .',
#  '000000068738': 'a man in is holding on and a cake .',
#  '000000008320': 'a man in is holding on and of of .',
#  '000000237394': 'a man in is holding on on of .',
#  '000000295476': 'a man in is holding on and of .',
#  '000000181850': 'a man in is holding on and a board .',
#  '000000209292': 'a bathroom with and toilet and and on .',
#  '000000428508': 'a man in is holding on and a field .',
#  '000000399932': 'a man in is riding on on board',
#  '000000096643': 'a bathroom with sink and , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , ,',
#  '000000243384': 'a man in is riding a board on .',
#  '000000035712': 'a man in is holding on and of .',
#  '000000014726': 'a man in is holding on and a board .',
#  '000000269327': 'a bathroom with and sink and and in',
#  '000000474387': 'a man is on with and a - - hat hat and and - - hat is on on on .',
#  '000000063330': 'a man is on in holding and of .',
#  '000000268036': 'a man in is holding and a - - - - - - - shirt shirt - - - shirt shirt - - - - - - - - shirt - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -',
#  '000000470995': 'a man in is on a holding board .',
#  '000000557467': 'a man is on in and holding a board .',
#  '000000564314': 'a man is on on holding in and .',
#  '000000540464': 'a man in is holding on and a plate .',
#  '000000280158': 'a man riding on on board on beach .',
#  '000000564926': 'a man is on in holding and on .',
#  '000000171536': 'a man in is holding and a woman on .',
#  '000000424665': 'a plate with , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , ,',
#  '000000385485': 'a man is on in and holding a board .',
#  '000000512634': 'a man in is holding on and a board .',
#  '000000156202': 'a man in is holding on and a table .',
#  '000000293304': 'a man in is holding on and of .',
#  '000000160137': 'a man in is holding on and in .',
#  '000000115642': 'a man in is holding on and with of .',
#  '000000013844': 'a man in is holding on and a board .',
#  '000000541082': 'a man in is holding a - - hat and - - - hat hat hat - - - hat hat hat - hat - - hat - - hat hair - tie - and tie and tie and tie on tie . . . . . . and on . . .',
#  '000000401969': 'a plate of , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , ,',
#  '000000162285': 'a plate with , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , ,',
#  '000000081784': 'a man in is riding a snow board',
#  '000000343503': 'a plate with and of food on .',
#  '000000293233': 'a man in is holding on and in .',
#  '000000307020': 'a man is on with and on and a plate .',
#  '000000288650': 'a man in is holding a and frisbee .',
#  '000000414495': 'a bathroom with sink and and , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , ,',
#  '000000182658': 'a man in and is holding on of .',
#  '000000144620': 'a man in is holding on and of .',
#  '000000498425': 'a plate of of food and on .',
#  '000000329133': 'a man in is holding on and of of .',
#  '000000368040': 'a man in is holding on and of .',
#  '000000403535': 'a man in is holding on and of of .',
# ...
#  '000000230503': 'a man is on in holding and a board .',
#  '000000285910': 'a plate of and of food on .',
#  '000000042818': 'a man is on in and holding a kite .',
#  '000000259591': 'a man in is holding on and of .',
#  '000000012103': 'a plate of , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , ,',
#  '000000254729': 'a man in is holding on a board .',
#  '000000373033': 'a man is on in and holding and of .',
#  '000000392723': 'a man in is holding on and in .',
#  '000000063182': 'a man in is holding on and a board .',
#  '000000088176': 'a man in is holding on and a board .',
#  '000000031865': 'a man in is holding on and of .',
#  '000000105904': 'a man in is holding on and a board .',
#  '000000038827': 'a bathroom with sink and , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , ,',
#  '000000038722': 'a man in is holding on and with of .',
#  '000000483530': 'a man in is a and blue and on',
#  '000000373923': 'a man in is riding on on board',
#  '000000230038': 'a plate with , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , ,',
#  '000000305267': 'a plate with , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , ,',
#  '000000053232': 'a man is on with and on and a board',
#  '000000284144': 'a plate with and of , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , ,',
#  '000000193594': 'a man in is holding on and a board .',
#  '000000112882': 'a bathroom with and sink and , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , ,',
#  '000000573184': 'a man is on on with and on .',
#  '000000128826': 'a man in is holding on and of .',
#  '000000175946': 'a man is on with and on and a woman .',
#  '000000233926': 'a man is on in and holding a board .',
#  '000000295257': 'a man in is holding and a - tennis racket .',
#  '000000530888': 'a man in is holding on and of .',
#  '000000058965': 'a baseball player is in in with and playing',
#  '000000124836': 'a plate of of food and on on a plate .',
#  '000000236155': 'a plate of and of food on .',
#  '000000447557': 'a man is in holding and a woman in',
#  '000000041413': 'a man in is holding on and a board .',
#  '000000281855': 'a bathroom with toilet and and and sink .',
#  '000000163192': 'a plate of , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , ,',
#  '000000032176': 'a man in is holding on and a board .',
#  '000000283382': 'a man in is holding on and of .',
#  '000000447726': 'a man is on in and holding and of of .',
#  '000000244349': 'a man in is holding on and in .',
#  '000000526680': 'a man in is holding a and woman on .',
#  '000000289204': 'a man in is holding on and of of .',
#  '000000296696': 'a man is on in and holding and a of of .',
#  '000000051530': 'a man in is holding and a - - - - - - dog hat shirt shirt and and - hat - hat hat - - hat - - hat - - tie - and tie tie tie and on in and and tie tie tie and holding . in . . .',
#  '000000056306': 'a man is on in and holding and a dog .',
#  '000000546285': 'a man in is holding on and a board .',
#  '000000176192': 'a man is on in holding and a board .',
#  '000000244582': 'a dog is on in with and on .',
#  '000000325287': 'a man in and is holding a cake .',
#  '000000517430': 'a man in is holding on and a board .',
#  '000000075557': 'a man in is a shirt and on a board .',
#  '000000345590': 'a bathroom with toilet and and sink in .',
#  '000000392315': 'a man is on in and holding and of .',
#  '000000098155': 'a man is in and holding a - cake and .',
#  '000000149572': 'a man in is holding a and woman on .',
#  '000000453586': 'a man is on in holding and on of .',
#  '000000018467': 'a plate of of food and on .',
#  '000000308838': 'a man riding on on a slope slope .',
#  '000000323964': 'a plate of with food and on .',
#  '000000550392': 'a plate with , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , ,',
#  '000000060602': 'a man is on in and holding and of .',
#  '000000189153': 'a man is on in and holding a - - - - - - - - - - - shirt shirt - shirt shirt - - shirt - - shirt - - shirt - - - - - - - - - - - - - - shirt shirt - - - - - - - - - - - - - - - - - - - - - - - - - - -',
#  '000000034973': 'a plate of of food and on .',
#  '000000581302': 'a man in is holding a - - shirt and - - - shirt - shirt - shirt - shirt - - shirt shirt - - hair - - shirt hair - shirt - - hair - - shirt - hair - - - - shirt hair - shirt - is - - - - - - - - - hair - - - - - - shirt hair - - hair - - hair -',
#  '000000146656': 'a man in is holding on and of .',
#  '000000124903': 'a man in is holding on and a board .',
#  '000000102445': 'a man in is holding a - - - shirt and - - shirt - - - - - shirt shirt - - - - - - - - shirt - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -',
#  '000000125729': 'a clock tower on on next of .',
#  '000000331314': 'a plate of and food on with and .',
#  '000000393394': 'a plate of of food and on .',
#  '000000438932': 'a plate of with and , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , ,',
#  '000000371092': 'a man in is holding on and a board .',
#  '000000055033': 'a man is in holding and a - - - - - - shirt shirt - shirt - - - shirt - - shirt - - - - - shirt shirt - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -',
#  '000000302141': 'a man is on in and holding a - - - - - - - - - - - - shirt shirt shirt shirt - - shirt - - shirt shirt - - - - - - - - - - - - - - shirt - shirt - - - - - - - - shirt - - - - - - - - - - - shirt - - - - - - -',
#  '000000002982': 'a man is on in and holding and of people .',
#  '000000469731': 'a man in is holding on and of .',
#  '000000166047': 'a man in is holding a frisbee in .',
#  '000000390969': 'a plate with , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , ,',
#  '000000564443': 'a man in is holding and a - - - - - - hat shirt shirt shirt - - shirt - - - shirt - - - - - shirt - - shirt - - shirt - - - - - - - - - shirt - shirt - - - - - - - - - - - - - - - - - - - - - - - - - - - -',
#  '000000231500': 'a man in is holding on and of .',
#  '000000568308': 'a man in is holding on and of of .',
#  '000000081259': 'a man in is holding on and of of .',
#  '000000016520': 'a baseball player is in in field .',
#  '000000242325': 'a man in is holding on and in .',
#  '000000140758': 'a man in is holding on and a plate .',
#  '000000092910': 'a plate of , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , ,',
#  '000000347267': 'a man is on in and holding and a woman in .',
#  '000000284722': 'a man is on with and on and a woman .',
#  '000000570019': 'a plate of of food and on on .',
#  '000000141240': 'a man in is holding on a board .',
#  '000000050470': 'a man in is holding a tennis and tennis racket .',
#  '000000125683': 'a man in is holding on and a board .',
#  '000000079831': 'a plate of and food on with and',
#  '000000253419': 'a man in is riding a wave on .',
#  '000000242029': 'a train is on on tracks next .',
#  '000000074411': 'a man is on in and playing with on .',
#  '000000571563': 'a man in is holding on and of of .',
#  '000000385672': 'a man in is holding a and - - - - - - shirt shirt shirt and - - - shirt - - hat - - shirt - - shirt - - - - - - - - - - shirt - - - - - - - shirt - - - - - - - - - - - - - - - - - - - - - - - - - - -',
#  '000000286673': 'a plate of with and vegetables on on .',
#  '000000462993': 'a man in is holding on and a board .',
#  '000000455549': 'a man in is holding on and a board .',
#  '000000486421': 'a man in is holding on and a field .',
#  '000000575274': 'a man in is holding on and of .',
#  '000000349566': 'a bathroom with toilet and and and sink',
#  '000000365833': 'a man is on in holding and a board .',
#  '000000048474': 'a man in is holding on and a board .',
#  '000000509267': 'a man in is holding on and of .',
#  '000000241918': 'a man in is holding on and of .',
#  '000000319781': 'a bathroom with toilet and and and on .',
#  '000000046171': 'a man in is holding on in and .',
#  '000000056193': 'a man in is holding on and a board',
#  '000000326496': 'a man in is holding on and of .',
#  '000000351288': 'a man is on in holding and a board .',
#  '000000352735': 'a man is on holding on in and .',
#  '000000429908': 'a plate of and of food on .',
#  '000000323462': 'a man in is holding on with and of .',
#  '000000182295': 'a man in is holding on and a board .',
#  '000000179758': 'a dog is on in with and on .',
#  '000000411445': 'a cat sitting on on next next to .',
#  '000000552579': 'a man is on in and holding a board .',
#  '000000402243': 'a bathroom with and toilet and on .',
#  '000000465414': 'a man is on in and holding of of .',
#  '000000565387': 'a man in is holding on and of of .',
#  '000000503318': 'a bathroom with and toilet and and on .',
#  '000000241790': 'a person in flying in sky sky .',
#  '000000365631': 'a man in is holding on and of of .',
#  '000000559830': 'a man in is holding on and of of .',
#  '000000269958': 'a man in is holding and a - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -',
#  '000000383760': 'a man in is riding a wave on .',
#  '000000317896': 'a man in is holding on and a plate .',
#  '000000041962': 'a man in is holding a tennis racket .',
#  '000000030151': 'a plate with , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , ,',
#  '000000028674': 'a man in is holding on and in .',
#  '000000344765': 'a plate of and of food on .',
#  '000000208779': 'a bathroom with , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , ,',
#  '000000392105': 'a man in is holding on and of .',
#  '000000179687': 'a man in is holding on in and .',
#  '000000532673': 'a man in is holding on and a baseball field .',
#  '000000302364': 'a man in is holding on and of .',
#  '000000240449': 'a man in is riding on on board',
#  '000000516329': 'a bathroom with toilet and and on .',
#  '000000064036': 'a man in is holding a frisbee in .',
#  '000000165064': 'a man in is holding a and tennis .',
#  '000000083093': 'a man in is holding on and of .',
#  '000000225053': 'a man in is holding a frisbee in .',
#  '000000573483': 'a plate of with and vegetables on on .',
#  '000000072396': 'a man in is holding on and of .',
#  '000000330916': 'a man in is holding and on of .',
#  '000000401458': 'a bathroom with sink and , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , ,',
#  '000000522464': 'a man in is holding on and of of .',
#  '000000322769': 'a bathroom with toilet and and and sink .',
#  '000000168349': 'a man in and is holding on of .',
#  '000000425470': 'a woman in is holding a pizza on .',
#  '000000382873': 'a man in is holding a - hat and on .',
#  '000000091681': 'a man in and is on holding a cake .',
#  '000000003461': 'a man is on in and holding and of .',
#  '000000339031': 'a man in is holding a and - - - - - - shirt shirt shirt - hat - - shirt - - shirt shirt - - - - shirt shirt - - - - - - - shirt - shirt - - - - - shirt - - - - - - - shirt - - - - - - - - - - - - - shirt - - - - - - -',
#  '000000458629': 'a man in is holding on and of .',
#  '000000534898': 'a man in is holding on and in .',
#  '000000319121': 'a man in is holding on and in',
#  '000000484418': 'a man in is holding on and a board .',
#  '000000170662': 'a man in is holding on and of .',
#  '000000051501': 'a man in and is holding a cake .',
#  '000000458603': 'a man in is holding on and of .',
#  '000000116633': 'a man is in riding on a board',
#  '000000166018': 'a man in is holding on and of of .',
#  '000000240889': 'a man in is holding on and a board',
#  '000000094884': 'a man in is holding a and - - - - - - shirt shirt shirt and tie and and tie tie . and in . and . .',
#  '000000018183': 'a plate of , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , ,',
#  '000000022198': 'a man is on holding in and .',
#  '000000435139': 'a bathroom with and , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , ,',
#  '000000484494': 'a man in is holding a frisbee in .',
#  '000000543042': 'a plate of and of vegetables on .',
#  '000000320429': 'a man in is holding and a - - hat hat and on in and - shirt - shirt and hat - hat hat - - hat and - tie and tie is on . . . .',
#  '000000525823': 'a man in is holding on and a board .',
#  '000000578856': 'a man in is holding a kite on .',
#  '000000383605': 'a man in is holding on and a board',
#  '000000402095': 'a man in is holding and a woman in .',
#  '000000401528': 'a plate with and of vegetables on .',
#  '000000196379': 'a man in is holding on and a board .',
#  '000000538444': 'a man in is holding a - - - - hat hat and - - hat - hat - hat - hat - hat - - hat - - hat - - hat - - - - - - - - shirt - - - shirt - shirt - - - - - - - - shirt - - - - - - - - - - - shirt - - - - - - -',
#  '000000542502': 'a man is in holding and a woman in .',
#  '000000144734': 'a man is on in and holding a board .',
#  '000000482751': 'a man in is holding on a board .',
#  '000000158737': 'a man is on in and playing with on .',
#  '000000089253': 'a man in is holding on and of .',
#  '000000559908': 'a woman in holding a and pizza on .',
#  '000000114229': 'a man in and is holding on of .',
#  '000000198426': 'a man in is holding on and a board .',
#  '000000556473': 'a man is on in holding and in .',
#  '000000100140': 'a man in is holding on and of .',
#  '000000057979': 'a man in is holding on and of .',
#  '000000217495': 'a man in is holding on and a board',
#  '000000422608': 'a man in is holding on and a board .',
#  '000000341219': 'a plate with , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , ,',
#  '000000224541': 'a plate with , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , ,',
#  '000000310558': 'a man in is holding a - - - hat shirt and - - hat - shirt - - shirt shirt - - - - - shirt - - shirt - - shirt - - - - - - - shirt - - - - - - shirt - - - - - - - - - - - - - - - - - - - - shirt - - - - - - -',
#  '000000557344': 'a plate with , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , ,',
#  '000000045923': 'a man in is holding on and a board .',
#  '000000457948': 'a man is on in and holding a board .',
#  '000000025516': 'a man in is riding on on snow covered .',
#  '000000457726': 'a man in is holding on and of of .',
#  '000000162087': 'a man in is holding on and a table .',
#  '000000081357': 'a man is on in holding and of .',
#  '000000425772': 'a man is on in and holding a board .',
#  '000000477759': 'a man in is holding on and a board .',
#  '000000216820': 'a plate of , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , ,',
#  ...}

# %%
with open("./p2/pred.json", "w") as f:
    json.dump(pred, f, indent=4)

# %%
dict2 = inference2(testmodel, valid_loader)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /data/jhccc/dlcv/hw3-jhc659/hw3_2 copy 2.ipynb Cell 16 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://ssh-remote%2B140.112.29.93/data/jhccc/dlcv/hw3-jhc659/hw3_2%20copy%202.ipynb#X22sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> dict2 = inference2(testmodel, valid_loader)
#
# /data/jhccc/dlcv/hw3-jhc659/hw3_2 copy 2.ipynb Cell 16 in inference2(testmodel, valid_loader)
#      <a href='vscode-notebook-cell://ssh-remote%2B140.112.29.93/data/jhccc/dlcv/hw3-jhc659/hw3_2%20copy%202.ipynb#X22sdnNjb2RlLXJlbW90ZQ%3D%3D?line=69'>70</a> trg_tensor = torch.LongTensor(trg_indexes).unsqueeze(0).to(device)
#      <a href='vscode-notebook-cell://ssh-remote%2B140.112.29.93/data/jhccc/dlcv/hw3-jhc659/hw3_2%20copy%202.ipynb#X22sdnNjb2RlLXJlbW90ZQ%3D%3D?line=70'>71</a> # trg_mask = generate_square_subsequent_mask(trg_tensor.shape[1], device)
#      <a href='vscode-notebook-cell://ssh-remote%2B140.112.29.93/data/jhccc/dlcv/hw3-jhc659/hw3_2%20copy%202.ipynb#X22sdnNjb2RlLXJlbW90ZQ%3D%3D?line=71'>72</a> # trg_mask = testmodel.make_trg_mask(trg_tensor)
#      <a href='vscode-notebook-cell://ssh-remote%2B140.112.29.93/data/jhccc/dlcv/hw3-jhc659/hw3_2%20copy%202.ipynb#X22sdnNjb2RlLXJlbW90ZQ%3D%3D?line=72'>73</a> # out, attention = testmodel.decoder(trg_tensor, enc_src, trg_mask)
# ---> <a href='vscode-notebook-cell://ssh-remote%2B140.112.29.93/data/jhccc/dlcv/hw3-jhc659/hw3_2%20copy%202.ipynb#X22sdnNjb2RlLXJlbW90ZQ%3D%3D?line=73'>74</a> out, attention = testmodel(img, trg_tensor)
#      <a href='vscode-notebook-cell://ssh-remote%2B140.112.29.93/data/jhccc/dlcv/hw3-jhc659/hw3_2%20copy%202.ipynb#X22sdnNjb2RlLXJlbW90ZQ%3D%3D?line=75'>76</a> # print(out.argmax(2).shape)
#      <a href='vscode-notebook-cell://ssh-remote%2B140.112.29.93/data/jhccc/dlcv/hw3-jhc659/hw3_2%20copy%202.ipynb#X22sdnNjb2RlLXJlbW90ZQ%3D%3D?line=76'>77</a> pred_token = out.argmax(2)[:,i].item()
#
# File ~/anaconda3/envs/dlcv/lib/python3.8/site-packages/torch/nn/modules/module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# /data/jhccc/dlcv/hw3-jhc659/hw3_2 copy 2.ipynb Cell 16 in Transformer.forward(self, img, trg)
#     <a href='vscode-notebook-cell://ssh-remote%2B140.112.29.93/data/jhccc/dlcv/hw3-jhc659/hw3_2%20copy%202.ipynb#X22sdnNjb2RlLXJlbW90ZQ%3D%3D?line=287'>288</a> def forward(self, img, trg):
#     <a href='vscode-notebook-cell://ssh-remote%2B140.112.29.93/data/jhccc/dlcv/hw3-jhc659/hw3_2%20copy%202.ipynb#X22sdnNjb2RlLXJlbW90ZQ%3D%3D?line=288'>289</a>
#     <a href='vscode-notebook-cell://ssh-remote%2B140.112.29.93/data/jhccc/dlcv/hw3-jhc659/hw3_2%20copy%202.ipynb#X22sdnNjb2RlLXJlbW90ZQ%3D%3D?line=289'>290</a>     #src = [batch size, src len]
#     <a href='vscode-notebook-cell://ssh-remote%2B140.112.29.93/data/jhccc/dlcv/hw3-jhc659/hw3_2%20copy%202.ipynb#X22sdnNjb2RlLXJlbW90ZQ%3D%3D?line=290'>291</a>     #trg = [batch size, trg len]
#     <a href='vscode-notebook-cell://ssh-remote%2B140.112.29.93/data/jhccc/dlcv/hw3-jhc659/hw3_2%20copy%202.ipynb#X22sdnNjb2RlLXJlbW90ZQ%3D%3D?line=291'>292</a>     # src_mask = torch.ones((src.shape[0],1,1,1)).bool().to(device)
#     <a href='vscode-notebook-cell://ssh-remote%2B140.112.29.93/data/jhccc/dlcv/hw3-jhc659/hw3_2%20copy%202.ipynb#X22sdnNjb2RlLXJlbW90ZQ%3D%3D?line=292'>293</a>     # print("src_mask = [batch size, 1, 1, src len]:", src_mask.shape)
# --> <a href='vscode-notebook-cell://ssh-remote%2B140.112.29.93/data/jhccc/dlcv/hw3-jhc659/hw3_2%20copy%202.ipynb#X22sdnNjb2RlLXJlbW90ZQ%3D%3D?line=294'>295</a>     trg_mask = self.make_trg_mask(trg)
#     <a href='vscode-notebook-cell://ssh-remote%2B140.112.29.93/data/jhccc/dlcv/hw3-jhc659/hw3_2%20copy%202.ipynb#X22sdnNjb2RlLXJlbW90ZQ%3D%3D?line=295'>296</a>     # print("trg_mask = [batch size, 1, trg len, trg len]:", trg_mask.shape)
#     <a href='vscode-notebook-cell://ssh-remote%2B140.112.29.93/data/jhccc/dlcv/hw3-jhc659/hw3_2%20copy%202.ipynb#X22sdnNjb2RlLXJlbW90ZQ%3D%3D?line=296'>297</a>     #src_mask = [batch size, 1, 1, src len]
#     <a href='vscode-notebook-cell://ssh-remote%2B140.112.29.93/data/jhccc/dlcv/hw3-jhc659/hw3_2%20copy%202.ipynb#X22sdnNjb2RlLXJlbW90ZQ%3D%3D?line=297'>298</a>     #trg_mask = [batch size, 1, trg len, trg len]
#     <a href='vscode-notebook-cell://ssh-remote%2B140.112.29.93/data/jhccc/dlcv/hw3-jhc659/hw3_2%20copy%202.ipynb#X22sdnNjb2RlLXJlbW90ZQ%3D%3D?line=299'>300</a>     enc_src = self.encoder(img)#.unsqueeze(1).float()
#
# /data/jhccc/dlcv/hw3-jhc659/hw3_2 copy 2.ipynb Cell 16 in Transformer.make_trg_mask(self, trg)
#     <a href='vscode-notebook-cell://ssh-remote%2B140.112.29.93/data/jhccc/dlcv/hw3-jhc659/hw3_2%20copy%202.ipynb#X22sdnNjb2RlLXJlbW90ZQ%3D%3D?line=269'>270</a> # print("trg_pad_mask = [batch size, 1, 1, trg len]:", trg_pad_mask.shape)
#     <a href='vscode-notebook-cell://ssh-remote%2B140.112.29.93/data/jhccc/dlcv/hw3-jhc659/hw3_2%20copy%202.ipynb#X22sdnNjb2RlLXJlbW90ZQ%3D%3D?line=270'>271</a> #trg_pad_mask = [batch size, 1, 1, trg len]
#     <a href='vscode-notebook-cell://ssh-remote%2B140.112.29.93/data/jhccc/dlcv/hw3-jhc659/hw3_2%20copy%202.ipynb#X22sdnNjb2RlLXJlbW90ZQ%3D%3D?line=272'>273</a> trg_len = trg.shape[1]
# --> <a href='vscode-notebook-cell://ssh-remote%2B140.112.29.93/data/jhccc/dlcv/hw3-jhc659/hw3_2%20copy%202.ipynb#X22sdnNjb2RlLXJlbW90ZQ%3D%3D?line=274'>275</a> trg_sub_mask = torch.tril(torch.ones((trg_len, trg_len))).bool().to(device)
#     <a href='vscode-notebook-cell://ssh-remote%2B140.112.29.93/data/jhccc/dlcv/hw3-jhc659/hw3_2%20copy%202.ipynb#X22sdnNjb2RlLXJlbW90ZQ%3D%3D?line=275'>276</a> # print("trg_sub_mask = [trg len, trg len]: ",trg_sub_mask.shape)
#     <a href='vscode-notebook-cell://ssh-remote%2B140.112.29.93/data/jhccc/dlcv/hw3-jhc659/hw3_2%20copy%202.ipynb#X22sdnNjb2RlLXJlbW90ZQ%3D%3D?line=276'>277</a>
#     <a href='vscode-notebook-cell://ssh-remote%2B140.112.29.93/data/jhccc/dlcv/hw3-jhc659/hw3_2%20copy%202.ipynb#X22sdnNjb2RlLXJlbW90ZQ%3D%3D?line=277'>278</a> #trg_sub_mask = [trg len, trg len]
#     <a href='vscode-notebook-cell://ssh-remote%2B140.112.29.93/data/jhccc/dlcv/hw3-jhc659/hw3_2%20copy%202.ipynb#X22sdnNjb2RlLXJlbW90ZQ%3D%3D?line=279'>280</a> trg_mask = trg_pad_mask & trg_sub_mask
#
# KeyboardInterrupt:

# %%
dict2

# %%
dict2
# Out:
# {'000000165547': 'a man in a blue shirt and white shirt is standing on a bench .',
#  '000000518586': 'a man is standing on a skateboard on a beach .',
#  '000000249720': 'a man in a blue shirt and white shirt is standing on a skateboard .',
#  '000000122934': 'a man in a blue shirt and black shirt is standing on a bench .',
#  '000000393258': 'a man in a blue shirt and black shirt is standing on a skateboard .',
#  '000000266041': 'a man is holding a tennis racket on a court .',
#  '000000053015': 'a man in a red shirt and white shirt and a red shirt is sitting on a table .',
#  '000000039540': 'a man in a red shirt and white shirt is sitting on a table .',
#  '000000320039': 'a man in a red shirt and white shirt and a woman are standing in front of a red shirt and a woman in front of a red shirt .',
#  '000000014941': 'a woman in a red shirt and a red shirt is sitting on a table .',
#  '000000304355': 'a man in a blue shirt and white shirt is standing on a skateboard .',
#  '000000096514': 'a man in a blue shirt and white shirt is standing on a bench .',
#  '000000578703': 'a man is standing on a beach with a surfboard .',
#  '000000350966': 'a man is standing on a bench in front of a building .',
#  '000000201220': 'a man in a red shirt and white shirt is standing in front of a laptop .',
#  '000000309100': 'a man is standing on a skateboard on a beach .',
#  '000000298726': 'a man in a blue shirt and white shirt is standing in a field .',
#  '000000214742': 'a man is standing on a bench with a skateboard .',
#  '000000135356': 'a man in a black shirt and white shirt is standing on a bed .',
#  '000000279806': 'a man riding a wave on a surfboard .',
#  '000000163361': 'a man in a blue shirt and blue shirt and blue sky .',
#  '000000135978': 'a man is standing in front of a building .',
#  '000000163460': 'a man in a blue shirt and black shirt is standing on a skateboard .',
#  '000000434129': 'a man in a black shirt and white shirt is standing on a skateboard .',
#  '000000575428': 'a man in a black shirt and white shirt is standing on a bench .',
#  '000000046912': 'a man in a blue shirt and black shirt is standing on a skateboard .',
#  '000000377326': 'a man is standing on a skateboard on a beach .',
#  '000000302219': 'a man in a black shirt and white shirt and white shirt is standing on a skateboard .',
#  '000000300655': 'a man in a blue shirt and black shirt is standing on a skateboard .',
#  '000000178748': 'a man is sitting on a table with a laptop on it .',
#  '000000519299': 'a man in a red shirt and white shirt is standing on a bed .',
#  '000000216303': 'a man is standing on a skateboard on a skateboard .',
#  '000000038892': 'a man in a black shirt and white shirt and white shirt is standing in a white shirt and a white shirt and a black shirt and white shirt and white shirt and white shirt and white shirt and a black shirt and white shirt and white shirt and white shirt and white shirt and a black shirt and a white shirt and white dog .',
#  '000000487151': 'a man in a black shirt and white shirt is standing on a skateboard .',
#  '000000461883': 'a man in a black shirt and white shirt is standing on a field .',
#  '000000470313': 'a bathroom with a toilet and a toilet .',
#  '000000137490': 'a man is standing on a skateboard on a skateboard .',
#  '000000491965': 'a man is standing on a bench with a red umbrella .',
#  '000000056400': 'a man in a black shirt and white shirt and white shirt is standing in front of a laptop .',
#  '000000042055': 'a man is holding a tennis racket on a court .',
#  '000000164594': 'a man in a black shirt and white shirt and white shirt is standing in a field .',
#  '000000303215': 'a man is standing on a beach with a large white and a large white dog .',
#  '000000481891': 'a man in a blue shirt and blue shirt is standing on a bench .',
#  '000000301755': 'a man is holding a tennis racket on a court .',
#  '000000047940': 'a man in a black shirt and white shirt is standing in front of a laptop .',
#  '000000192233': 'a man is holding a tennis racket on a court .',
#  '000000417590': 'a man is standing on a bench in the grass .',
#  '000000164899': 'a man in a black shirt and white shirt and white shirt is standing in a room .',
#  '000000368505': 'a man in a blue shirt and white shirt is standing on a skateboard .',
#  '000000513778': 'a man is standing on a beach with a kite .',
#  '000000352476': 'a man is standing on a bench in the air .',
#  '000000259879': 'a man is standing on a bench in the grass .',
#  '000000178361': 'a man is standing on a skateboard on a skateboard .',
#  '000000020972': 'a man is standing on a beach with a surfboard .',
#  '000000367881': 'a man in a blue shirt and white shirt is standing on a skateboard .',
#  '000000451305': 'a man in a blue shirt and black shirt is standing on a skateboard .',
#  '000000485294': 'a bathroom with a toilet and a sink .',
#  '000000177990': 'a man in a black shirt and white shirt and white shirt is standing in a black shirt and white shirt and white shirt and white shirt and a black shirt and white shirt and a black shirt and white shirt and white shirt and white shirt and a black shirt and a black shirt and white shirt and a black shirt and white shirt and white shirt and white shirt and white shirt and white shirt',
#  '000000540159': 'a man is standing on a bench in front of a building .',
#  '000000096539': 'a man is standing in a field with a red umbrella .',
#  '000000147904': 'a man in a blue shirt and blue shirt is standing on a skateboard .',
#  '000000546642': 'a man is standing on a bench with a skateboard .',
#  '000000307989': 'a man is holding a tennis racket on a court .',
#  '000000267840': 'a man in a blue shirt and white shirt is standing on a skateboard .',
#  '000000405675': 'a man is standing on a beach with a surfboard .',
#  '000000378823': 'a man is standing on a skateboard on a skateboard .',
#  '000000394322': 'a man in a black shirt and white shirt and white shirt is standing in front of a large building .',
#  '000000411043': 'a man in a blue shirt and black shirt is standing on a bench .',
#  '000000137573': 'a man is standing on a bench with a skateboard .',
#  '000000301155': 'a man in a blue shirt and blue shirt is standing on a bench .',
#  '000000333156': 'a man is standing on a bench with a tennis ball .',
#  '000000241068': 'a man is standing on a skateboard on a skateboard .',
#  '000000285734': 'a man in a blue shirt and black shirt is standing on a skateboard .',
#  '000000408143': 'a man in a blue shirt and white shirt is standing on a skateboard .',
#  '000000491872': 'a man is riding a skateboard on a beach .',
#  '000000084123': 'a man in a black shirt and white shirt is standing in front of a building .',
#  '000000102996': 'a man is standing in front of a building .',
#  '000000251044': 'a man in a red shirt and white shirt is standing in front of a laptop .',
#  '000000201859': 'a man in a blue shirt and white shirt is standing on a skateboard .',
#  '000000579326': 'a man in a black shirt and white shirt is standing in a field .',
#  '000000370038': 'a man in a black shirt and white shirt and white shirt is standing on a bed .',
#  '000000548729': 'a man in a blue shirt and black shirt is standing on a bench .',
#  '000000140197': 'a man in a black shirt and white shirt and white shirt is standing on a bench .',
#  '000000353836': 'a man in a red shirt and blue shirt is standing on a bench .',
#  '000000491681': 'a man in a blue shirt and blue shirt is riding a wave on a wave .',
#  '000000289941': 'a man in a white shirt and a black shirt and white shirt is standing on a bed .',
#  '000000540834': 'a man in a blue shirt and blue shirt is standing on a skateboard .',
#  '000000318825': 'a man in a blue shirt and blue shirt is standing on a skateboard .',
#  '000000226874': 'a man is holding a tennis racket on a court .',
#  '000000118432': 'a man in a blue shirt and white shirt is standing on a skateboard .',
#  '000000146640': 'a man in a blue shirt and blue shirt is standing on a skateboard .',
#  '000000113757': 'a man in a red shirt and black shirt is standing in front of a large building .',
#  '000000346702': 'a man is holding a tennis racket on a court .',
#  '000000296871': 'a man is standing on a bench in the middle of a field .',
#  '000000136572': 'a man in a blue shirt and blue shirt is standing on a bench .',
#  '000000238602': 'a man in a black shirt and white shirt is standing in front of a large building .',
#  '000000460972': 'a man in a black shirt and white shirt is standing on a skateboard .',
#  '000000210766': 'a woman in a red shirt and white shirt is standing in front of a red and a red and white dog .',
#  '000000006789': 'a man is standing on a skateboard on a skateboard .',
#  '000000502275': 'a plate with a pizza on it',
#  '000000370399': 'a man is standing in a field with a frisbee .',
#  '000000437618': 'a man is standing on a bench in the grass .',
#  '000000099389': 'a man is standing on a bench in front of a building .',
#  '000000536294': 'a man in a blue shirt and blue shirt is on a tennis court .',
#  '000000106096': 'a man in a blue shirt and white shirt is standing on a bench .',
#  '000000032960': 'a man is sitting on a bench with a red umbrella .',
#  '000000206587': 'a man is standing on a field with a kite .',
#  '000000102466': 'a man in a blue shirt and blue shirt is standing on a skateboard .',
#  '000000397903': 'a man is sitting on a bench with a laptop .',
#  '000000074001': 'a man in a black shirt and white shirt and white shirt is standing in a white shirt and a white shirt and a white shirt and white shirt and a white shirt and a white shirt and a white shirt and a white shirt and a white shirt and a black shirt .',
#  '000000213023': 'a man is standing on a bench with a skateboard .',
#  '000000082740': 'a man is standing on a skateboard on a beach .',
#  '000000553852': 'a man in a blue shirt and white shirt is standing on a skateboard .',
#  '000000557396': 'a man in a blue shirt and white shirt is standing on a skateboard .',
#  '000000397658': 'a man in a blue shirt and black shirt is standing on a bench .',
#  '000000315474': 'a man in a black shirt and white shirt is standing on a bench .',
#  '000000049667': 'a man in a red shirt and white shirt is standing in front of a building .',
#  '000000336937': 'a man is riding a skateboard on a beach .',
#  '000000302302': 'a man is standing on a beach with a kite .',
#  '000000013414': 'a man in a blue shirt and white shirt is standing on a skateboard .',
#  '000000137507': 'a woman in a red shirt and a red shirt is sitting on a table .',
#  '000000481281': 'a woman in a red shirt is holding a red umbrella .',
#  '000000358247': 'a man is standing on a bench in the middle of a field .',
#  '000000420610': 'a man in a red shirt and white shirt is standing in front of a large building .',
#  '000000423588': 'a man is riding a skateboard on a skateboard .',
#  '000000033798': 'a bathroom with a toilet and a sink .',
#  '000000425676': 'a man in a white shirt and a white shirt and a white dog on a white plate .',
#  '000000168898': 'a man is holding a tennis racket on a court .',
#  '000000423919': 'a man in a red shirt and white shirt is sitting on a table .',
#  '000000306313': 'a man in a black shirt and white shirt and white shirt is standing on a skateboard .',
#  '000000504452': 'a man is standing on a beach with a large clock .',
#  '000000091636': 'a man in a blue shirt and blue shirt is standing on a skateboard .',
#  '000000482907': 'a man in a blue shirt and blue shirt and blue sky .',
#  '000000053677': 'a man in a blue shirt and black shirt is standing on a skateboard .',
#  '000000033717': 'a man is standing on a bench in the grass .',
#  '000000329806': 'a man is standing on a beach with a kite .',
#  '000000332074': 'a man is standing on a skateboard on a skateboard .',
#  '000000022051': 'a man is holding a tennis racket on a court .',
#  '000000439902': 'a man in a red shirt and white shirt is standing in a kitchen .',
#  '000000523123': 'a man is holding a cell phone while holding a laptop .',
#  '000000252280': 'a man in a blue shirt and blue shirt is standing on a bench .',
#  '000000150616': 'a man in a blue shirt and white shirt is standing on a skateboard .',
#  '000000369601': 'a man in a black shirt and white shirt and white shirt is standing on a skateboard .',
#  '000000189600': 'a man in a black shirt and white shirt is standing on a bench .',
#  '000000071095': 'a baseball player is standing on the field .',
#  '000000301753': 'a man in a blue shirt and white shirt is standing on a skateboard .',
#  '000000272357': 'a man is standing on a field of a field .',
#  '000000265971': 'a man in a blue shirt and blue shirt is standing on a tennis court .',
#  '000000043404': 'a man in a blue shirt is standing on a skateboard .',
#  '000000429160': 'a man in a white shirt and a white shirt is standing on a bed .',
#  '000000095482': 'a man is holding a tennis racket on a tennis court .',
#  '000000488069': 'a man in a blue shirt and white shirt is standing on a skateboard .',
#  '000000553129': 'a man in a black shirt and white shirt and white shirt is standing in a kitchen .',
#  '000000570594': 'a man is standing on a skateboard on a skateboard .',
#  '000000047916': 'a man in a green shirt and white shirt is standing in a field .',
#  '000000240655': 'a man in a red shirt and black shirt is standing on a skateboard .',
#  '000000289263': 'a man is standing on a beach with a tennis racket .',
#  '000000480438': 'a bathroom with a sink and a sink .',
#  '000000172673': 'a man in a blue shirt and black shirt is standing on a bench .',
#  '000000159151': 'a man in a black shirt and white shirt and white shirt is standing in a room .',
#  '000000195267': 'a man in a white shirt and a white shirt is standing on a couch .',
#  '000000087483': 'a man in a black shirt and white shirt is standing on a bench .',
#  '000000126540': 'a man in a black shirt and white shirt is standing on a skateboard .',
#  '000000544538': 'a man is holding a cell phone while holding a cell phone .',
#  '000000050034': 'a man is standing on a skateboard on a skateboard .',
#  '000000438046': 'a man is holding a cell phone while holding a cell phone .',
#  '000000217561': 'a man in a red shirt and white shirt is standing on a bed .',
#  '000000326021': 'a man in a red shirt and blue shirt is standing in front of a red and white dog .',
#  '000000168805': 'a man in a black shirt and white shirt is standing on a bench .',
#  '000000580766': 'a man in a blue shirt and blue shirt is standing on a skateboard .',
#  '000000443652': 'a bathroom with a toilet and a toilet .',
#  '000000224247': 'a man is riding a wave on a beach .',
#  '000000146773': 'a man in a red shirt and white shirt is standing in front of a large building .',
#  '000000366421': 'a man in a blue shirt and white shirt is standing on a skateboard .',
#  '000000518908': 'a man is standing on a bench with a tennis racket .',
#  '000000172886': 'a bathroom with a sink and a sink .',
#  '000000494404': 'a man is standing on a beach with a surfboard .',
#  '000000022979': 'a man is standing on a skateboard on a skateboard .',
#  '000000380828': 'a man in a blue shirt and black shirt is standing on a skateboard .',
#  '000000151432': 'a man is standing on a skateboard on a beach .',
#  '000000215549': 'a man is standing on a bench in front of a building .',
#  '000000044421': 'a man in a blue shirt and black shirt is standing on a skateboard .',
#  '000000099707': 'a man is standing on a skateboard on a skateboard .',
#  '000000512145': 'a man in a red shirt and white shirt is sitting on a table .',
#  '000000161940': 'a woman in a red shirt and red shirt is standing in front of a red and a red and white plate .',
#  '000000370819': 'a woman is holding a pizza on a table .',
#  '000000438848': 'a woman in a red shirt and white shirt is standing in front of a red and a red and a red and white dog .',
#  '000000168775': 'a man is standing on a bench in a field .',
#  '000000563730': 'a man is standing on a table with a laptop on it .',
#  '000000509185': 'a man is standing on a beach with a surfboard .',
#  '000000287830': 'a man riding a wave on a surfboard .',
#  '000000324710': 'a man in a blue shirt and white shirt is standing on a skateboard .',
#  '000000026501': 'a man in a black shirt and white shirt is standing on a skateboard .',
#  '000000073981': 'a man in a blue shirt and black shirt is standing on a bench .',
#  '000000377911': 'a man in a red shirt and white shirt is standing in a room .',
#  '000000098268': 'a man in a blue shirt and white shirt is standing in a field .',
#  '000000382557': 'a man is standing on a beach with a tennis racket .',
#  '000000473433': 'a man in a black shirt and white shirt and white shirt is standing on a bed .',
#  '000000307048': 'a man in a black shirt and white shirt is standing on a skateboard .',
#  '000000162855': 'a man is standing on a field with a frisbee .',
#  '000000494456': 'a man in a blue shirt and black shirt is standing on a skateboard .',
#  '000000047611': 'a man in a white shirt and a white shirt and a black shirt is standing on a bed .',
#  '000000175318': 'a man in a red shirt and white shirt is standing in front of a large building .',
#  '000000010217': 'a man in a black shirt and white shirt and white shirt is standing on a bed .',
#  '000000124210': 'a man in a blue shirt and white shirt is standing on a skateboard .',
#  '000000113897': 'a bathroom with a toilet and a sink .',
#  '000000548464': 'a man in a blue shirt and blue shirt is standing on a skateboard .',
#  '000000549932': 'a man in a blue shirt and black shirt is standing on a bench .',
#  '000000415153': 'a man is standing on a bench in the grass .',
#  '000000036508': 'a woman is holding a pizza on a table .',
#  '000000519446': 'a man in a white shirt and a white shirt is standing on a bed .',
#  '000000222866': 'a plate of food with a pizza on it',
#  '000000402115': 'a man in a black shirt and white shirt and white shirt and a woman standing in a white shirt and a white shirt and a white shirt and a white shirt and a black shirt and a black shirt and a black shirt and white shirt and a white shirt and a black shirt and white shirt and a white shirt and a black shirt and white shirt and a black shirt .',
#  '000000345160': 'a man is standing on a bench with a red umbrella .',
#  '000000486846': 'a man in a red shirt and white shirt is standing on a table .',
#  '000000191893': 'a man is standing on a beach with a surfboard .',
#  '000000224037': 'a man is standing on a skateboard on a skateboard .',
#  '000000445267': 'a man in a white shirt and a white shirt is standing on a bed .',
#  '000000126345': 'a man in a black shirt and white shirt is standing in a field .',
#  '000000191078': 'a man in a red shirt and white shirt is standing on a table .',
#  '000000051339': 'a man is standing on a skateboard on a skateboard .',
#  '000000266437': 'a man is standing on a skateboard on a skateboard .',
#  '000000163309': 'a man in a blue shirt and blue shirt is riding a skateboard .',
#  '000000138022': 'a man in a blue shirt and white shirt is standing on a bench .',
#  '000000092815': 'a man in a red shirt and white shirt is standing on a table .',
#  '000000470801': 'a man is standing on a skateboard on a beach .',
#  '000000311904': 'a man in a red shirt and a red shirt is holding a red umbrella .',
#  '000000579696': 'a man in a blue shirt and white shirt is standing on a bench .',
#  '000000406201': 'a man is standing in a field with a large white dog .',
#  '000000575012': 'a man is standing on a skateboard on a skateboard .',
#  '000000381037': 'a man in a black shirt and white shirt and white shirt is standing in a black shirt and white shirt and white shirt and white shirt and white shirt and white shirt and white and white shirt and a black shirt and white shirt and white and white shirt and white and white and white shirt .',
#  '000000383209': 'a man in a black shirt and white shirt is standing in front of a laptop .',
#  '000000063434': 'a man in a red shirt and black shirt is standing on a bed .',
#  '000000156532': 'a man is riding a wave on a surfboard .',
#  '000000038064': 'a man in a blue shirt and white shirt is standing in a field .',
#  '000000160886': 'a bathroom with a toilet and a sink .',
#  '000000468972': 'a man is standing on a skateboard on a skateboard .',
#  '000000168692': 'a man is standing on a bench with a tennis racket .',
#  '000000556892': 'a man is standing on a skateboard on a skateboard .',
#  '000000397980': 'a man in a blue shirt and blue shirt is standing on a skateboard .',
#  '000000309222': 'a man in a red shirt and white shirt is standing on a bench .',
#  '000000145391': 'a man in a blue shirt and blue shirt is standing on a bench .',
#  '000000215303': 'a man in a black shirt and white shirt and white shirt is standing in a kitchen .',
#  '000000456574': 'a man in a blue shirt and blue shirt is standing on a skateboard .',
#  '000000247394': 'a man is standing on a beach with a kite .',
#  '000000275744': 'a man is standing on a bench with a large clock .',
#  '000000560637': 'a man is standing in a field with a large clock .',
#  '000000286176': 'a man in a red shirt and white shirt is standing in front of a large building .',
#  '000000549112': 'a plate with a pizza on it',
#  '000000275117': 'a man in a blue shirt and black shirt is standing on a skateboard .',
#  '000000054924': 'a man is standing on a bench in front of a building .',
#  '000000303667': 'a man in a white shirt and a white shirt and a white dog is standing in a room .',
#  '000000390769': 'a man in a blue shirt and blue shirt is standing on a skateboard .',
#  '000000500784': 'a man in a white shirt and a white shirt and a white cat sitting on a table .',
#  '000000297976': 'a man in a white shirt and a white shirt and a white shirt is standing on a bed .',
#  '000000264909': 'a man is standing on a skateboard on a beach .',
#  '000000200681': 'a man in a blue shirt and blue shirt is standing on a field .',
#  '000000344521': 'a man in a red shirt and white shirt is standing in front of a large building .',
#  '000000111944': 'a man riding a wave on a surfboard .',
#  '000000054870': 'a man in a black shirt and white shirt and white shirt is standing on a table .',
#  '000000426342': 'a man is standing on a field with a frisbee .',
#  '000000344368': 'a man is standing on a skateboard on a skateboard .',
#  '000000302710': 'a man in a blue shirt and blue shirt is standing on a bench .',
#  '000000127119': 'a man in a blue shirt and blue shirt is standing on a skateboard .',
#  '000000260099': 'a man is standing on a bench next to a building .',
#  '000000003771': 'a man in a white shirt and a white shirt is standing in a field .',
#  '000000349896': 'a man in a blue shirt is standing on a skateboard .',
#  '000000274591': 'a man in a blue shirt and blue shirt is standing on a skateboard .',
#  '000000098322': 'a man is standing on a skateboard on a skateboard .',
#  '000000053665': 'a man riding a wave on a wave .',
#  '000000189694': 'a man is standing on a skateboard on a skateboard .',
#  '000000011182': 'a man in a blue shirt and white shirt is standing on a skateboard .',
#  '000000354027': 'a man in a red shirt and white shirt is standing on a bench .',
#  '000000107511': 'a man in a blue shirt and white shirt is standing in a field .',
#  '000000141426': 'a man in a blue shirt and white shirt is standing in front of a building .',
#  '000000158588': 'a man is standing on a bench in front of a building .',
#  '000000425522': 'a man in a blue shirt and black shirt is standing on a skateboard .',
#  '000000042288': 'a man is riding a skateboard on a skateboard .',
#  '000000303814': 'a man is holding a tennis racket on a court .',
#  '000000068205': 'a man in a black shirt and white shirt and white shirt is standing in a room .',
#  '000000015797': 'a man is riding a skateboard on a skateboard .',
#  '000000034708': 'a man in a black shirt and white shirt and white shirt is standing in a room .',
#  '000000098187': 'a man is standing on a beach with a kite .',
#  '000000378311': 'a man in a blue shirt and white shirt is standing in a room .',
#  '000000219546': 'a plate of food with a pizza on it',
#  '000000406155': 'a man in a blue shirt and blue shirt is riding a wave .',
#  '000000006393': 'a man is holding a tennis racket on a court .',
#  '000000267802': 'a man in a blue shirt and blue shirt is standing on a skateboard .',
#  '000000523597': 'a man in a white shirt and a white shirt and a black shirt is standing on a bench .',
#  '000000079836': 'a man in a blue shirt and blue shirt is standing on a skateboard .',
#  '000000005418': 'a man is standing in front of a building .',
#  '000000474388': 'a man is standing on a bench in the middle of a field .',
#  '000000532580': 'a man is standing on a bench with a skateboard .',
#  '000000223857': 'a man in a blue shirt and blue shirt is standing on a bench .',
#  '000000215024': 'a man in a blue shirt is riding a wave .',
#  '000000020147': 'a man is standing in the grass with a dog .',
#  '000000287846': 'a man is standing on a skateboard on a beach .',
#  '000000182736': 'a man is standing on a bench in the grass .',
#  '000000227851': 'a man in a blue shirt and blue shirt is standing on a skateboard .',
#  '000000349590': 'a man is sitting on a table with a laptop .',
#  '000000266853': 'a man in a white shirt and a white shirt is standing in a field .',
#  '000000099747': 'a man in a blue shirt and white shirt is standing on a bench .',
#  '000000393777': 'a man is standing on a bench in the middle of a field .',
#  '000000092338': 'a man in a black shirt and white shirt is standing on a skateboard .',
#  '000000114616': 'a man in a blue shirt and blue shirt is standing on a bench .',
#  '000000029160': 'a man riding a wave on a wave .',
#  '000000023051': 'a man in a red shirt and white shirt is standing on a bench .',
#  '000000408363': 'a man in a blue shirt and black shirt is standing on a skateboard .',
#  '000000575911': 'a man is standing on a bench in the middle of a field .',
#  '000000513887': 'a man in a black shirt and white shirt and white shirt is standing on a bed .',
#  '000000470115': 'a man in a red shirt and white shirt is standing on a skateboard .',
#  '000000268058': 'a woman in a red shirt and white shirt is standing on a bed .',
#  '000000136181': 'a man is standing on a beach with a red umbrella .',
#  '000000400265': 'a man is standing on a bench in the air .',
#  '000000493751': 'a man in a blue shirt and blue shirt is standing on a skateboard .',
#  '000000297414': 'a man in a black shirt and white shirt and white shirt is standing on a skateboard .',
#  '000000148614': 'a man in a white shirt and a white shirt is standing on a bed .',
#  '000000370095': 'a man is standing on a bench in the grass .',
#  '000000339019': 'a man is standing on a beach with a kite .',
#  '000000574208': 'a man is standing in a field with a frisbee .',
#  '000000528011': 'a man is standing on a skateboard in the air .',
#  '000000009813': 'a man is standing next to a large building .',
#  '000000429170': 'a man in a blue shirt and white shirt is standing on a skateboard .',
#  '000000273196': 'a man in a blue shirt and white shirt is standing on a bench .',
#  '000000492025': 'a man in a blue shirt and white shirt is standing on a bench .',
#  '000000185360': 'a man is standing on a bench in the middle of a city .',
#  '000000062824': 'a man in a blue shirt and black shirt is standing on a bench .',
#  '000000471625': 'a man in a blue shirt and blue shirt is standing on a bench .',
#  '000000354368': 'a man in a blue shirt and white shirt is standing on a bench .',
#  '000000217393': 'a man in a blue shirt and white shirt is standing on a bench .',
#  '000000032909': 'a man in a black shirt and white shirt is standing on a bench .',
#  '000000232627': 'a man is standing in a field with a frisbee .',
#  '000000117201': 'a man is riding a wave on a surfboard .',
#  '000000156282': 'a man is standing on a beach with a blue sky .',
#  '000000169683': 'a man is standing on a skateboard on a skateboard .',
#  '000000441054': 'a man in a blue shirt and white shirt is standing in a field .',
#  '000000472295': 'a man is riding a skateboard on a skateboard .',
#  '000000321603': 'a woman in a red shirt and white shirt is holding a woman in a red shirt and a red umbrella .',
#  '000000554445': 'a man in a red shirt and white shirt is standing on a couch .',
#  '000000281676': 'a man in a blue shirt and blue shirt is standing on a skateboard .',
#  '000000330356': 'a man in a white shirt and a white shirt is standing in the middle of a field .',
#  '000000176527': 'a man is riding a wave on a surfboard .',
#  '000000523252': 'a man is standing on a bench next to a building .',
#  '000000350491': 'a man is standing on a bench in the grass .',
#  '000000175136': 'a man is standing on a bench with a red umbrella .',
#  '000000085852': 'a man is standing on a bench in the grass .',
#  '000000330419': 'a man is standing on a skateboard on a skateboard .',
#  '000000049068': 'a man in a blue shirt and white shirt is standing on a bed .',
#  '000000524979': 'a man in a blue shirt and white shirt is standing in front of a large building .',
#  '000000030403': 'a man is standing on a skateboard on a skateboard .',
#  '000000255315': 'a man is standing next to a large white dog .',
#  '000000445668': 'a man is riding a wave on a wave .',
#  '000000066191': 'a man in a red shirt and white shirt is standing in a field .',
#  '000000079924': 'a man in a red shirt and white shirt is standing on a bench .',
#  '000000082576': 'a man is riding a wave on a surfboard .',
#  '000000282841': 'a man in a red shirt and white shirt is standing in front of a laptop .',
#  '000000326555': 'a man in a red shirt and white shirt is standing on a skateboard .',
#  '000000254929': 'a man is holding a tennis racket on a court .',
#  '000000100409': 'a man in a blue shirt and white shirt is standing on a bed .',
#  '000000462632': 'a plate of food with a fork and a fork .',
#  '000000536879': 'a man in a red shirt and white shirt is standing in front of a red and a red and white photo of a red and white photo .',
#  '000000192079': 'a man is holding a tennis racket on a court .',
#  '000000500420': 'a man in a blue shirt and blue shirt is standing on a tennis court .',
#  '000000361751': 'a man in a blue shirt and blue shirt is standing on a bench .',
#  '000000291144': 'a man in a blue shirt and white shirt is standing on a skateboard .',
#  '000000143696': 'a man in a blue shirt and white shirt is standing on a bench .',
#  '000000310757': 'a plate with a fork and a fork .',
#  '000000489798': 'a man in a blue shirt and blue shirt is standing on a bench .',
#  '000000452297': 'a man is standing in a field with a dog .',
#  '000000199819': 'a woman is holding a tennis racket in a ball .',
#  '000000552018': 'a man is standing on a tennis court .',
#  '000000419723': 'a man in a black shirt and white shirt and white shirt is standing on a table .',
#  '000000344025': 'a man in a black shirt and white shirt and white shirt is standing in a room .',
#  '000000106206': 'a man is standing on a skateboard on a skateboard .',
#  '000000394132': 'a man in a blue shirt and a blue shirt and a blue and a blue and white and white and a blue and white blue and white and white and white and white and a blue and a blue and white and white dog on a beach .',
#  '000000161539': 'a man is standing on a bench in front of a building .',
#  '000000347648': 'a man in a red shirt and white shirt is standing on a bed .',
#  '000000326592': 'a man is standing on a bench in the water .',
#  '000000173997': 'a man in a blue shirt and white shirt is standing in front of a large building .',
#  '000000401758': 'a man is standing on a bench in the middle of a field .',
#  '000000213799': 'a man is standing on a bench in the middle of a field .',
#  '000000253474': 'a man is standing on a skateboard on a skateboard .',
#  '000000559136': 'a man is riding a wave on a surfboard .',
#  '000000248956': 'a man is standing on a bench in front of a building .',
#  '000000381318': 'a man in a red shirt and white shirt is standing on a table .',
#  '000000366683': 'a woman in a red shirt and white shirt is sitting on a table .',
#  '000000019491': 'a man in a black shirt and white shirt is standing in a kitchen .',
#  '000000171201': 'a man in a blue shirt and blue shirt is standing on a skateboard .',
#  '000000404027': 'a man in a blue shirt and black shirt is standing on a skateboard .',
#  '000000286106': 'a man in a blue shirt and white shirt is standing on a bench .',
#  '000000253825': 'a man in a blue shirt and blue shirt is standing on a bench .',
#  '000000536403': 'a man in a red shirt and white shirt is standing on a table .',
#  '000000331223': 'a man in a red shirt and white shirt is standing in front of a large building .',
#  '000000432798': 'a man in a black shirt and white shirt is standing in front of a laptop .',
#  '000000342060': 'a man is standing on a bench in the grass .',
#  '000000207458': 'a man is standing on a bench in the grass .',
#  '000000257864': 'a man is standing on a bench in a field .',
#  '000000146675': 'a man is standing on a bench in the middle of a blue sky .',
#  '000000411177': 'a man is sitting on a table with a laptop on it .',
#  '000000110617': 'a man is standing on a skateboard on a field .',
#  '000000169872': 'a man is standing on a bench with a skateboard .',
#  '000000454810': 'a man in a blue shirt and white shirt is standing on a skateboard .',
#  '000000082312': 'a man is standing on a bench with a red umbrella .',
#  '000000373578': 'a man is standing on a skateboard on a field .',
#  '000000121503': 'a man in a blue shirt and white shirt is standing on a skateboard .',
#  '000000015984': 'a man in a blue shirt and white shirt is standing in a field .',
#  '000000515355': 'a plate with a fork and a fork .',
#  '000000478517': 'a man is standing on a bench in the middle of a field .',
#  '000000389753': 'a man is standing on a bench in front of a building .',
#  '000000418226': 'a man in a black shirt and white shirt is standing next to a woman in front of a large white dog .',
#  '000000252617': 'a man is standing on a skateboard .',
#  '000000415714': 'a man is riding a skateboard on a beach .',
#  '000000181403': 'a man is standing on a bench with a tennis racket .',
#  '000000353130': 'a man is standing on a bench in a field .',
#  '000000405334': 'a man is holding a tennis racket on a court .',
#  '000000357402': 'a man is standing on a skateboard on a skateboard .',
#  '000000342387': 'a man in a red shirt and white shirt is standing on a wooden table .',
#  '000000198495': 'a man in a blue shirt and black shirt is standing on a bench .',
#  '000000537727': 'a man in a blue shirt and white shirt and a black shirt is standing on a skateboard .',
#  '000000373857': 'a man in a black shirt and white shirt is standing in front of a laptop .',
#  '000000480223': 'a man is standing on a field with a frisbee .',
#  '000000469130': 'a man is riding a wave on a wave .',
#  '000000190406': 'a man is standing on a bench in the middle of a city .',
#  '000000435187': 'a man in a blue shirt and white shirt is standing on a skateboard .',
#  '000000511420': 'a woman in a red shirt and red shirt is standing on a bed .',
#  '000000099543': 'a man in a black shirt and white shirt is standing on a skateboard .',
#  '000000115636': 'a man is standing on a bench in front of a building .',
#  '000000138185': 'a man is sitting on a table with a laptop .',
#  '000000053800': 'a man in a black shirt and white shirt is standing on a bed .',
#  '000000561619': 'a man in a blue shirt and white shirt is standing in a field .',
#  '000000396167': 'a man in a blue shirt and blue shirt is standing on a skateboard .',
#  '000000448275': 'a man is standing on a bench with a large dog .',
#  '000000406050': 'a man is standing on a bench in the middle of a field .',
#  '000000320203': 'a man is standing on a beach with a red umbrella .',
#  '000000387506': 'a man is riding a wave on a surfboard .',
#  '000000578467': 'a man in a blue shirt and black shirt is standing next to a woman in a blue shirt and white shirt and a blue shirt and white shirt and a red shirt and a red shirt and white shirt and white shirt and a black shirt and a black shirt and white dog .',
#  '000000503207': 'a man in a black shirt and white shirt is standing on a skateboard .',
#  '000000009214': 'a man in a blue shirt and blue shirt is standing in a field .',
#  '000000054627': 'a man is standing on a beach with a large blue shirt and a large blue shirt and a large blue umbrella .',
#  '000000143098': 'a man is standing on a bench in the grass .',
#  '000000069266': 'a man in a blue shirt and white shirt is standing next to a man in a white shirt and a black shirt and white shirt and white shirt and a white shirt and a white shirt and a white dog .',
#  '000000457453': 'a man is standing on a skateboard on a skateboard .',
#  '000000177173': 'a man is holding a tennis racket on a court .',
#  '000000065357': 'a man in a blue shirt and black shirt is standing in front of a building .',
#  '000000070240': 'a man in a blue shirt and white shirt is standing on a bench .',
#  '000000139734': 'a woman in a red shirt and a red shirt is sitting on a table .',
#  '000000010496': 'a man is standing on a bench in the middle of a field .',
#  '000000285250': 'a man in a blue shirt and blue sky .',
#  '000000520451': 'a man in a red shirt and red shirt is standing in front of a red and a red and white truck .',
#  '000000521772': 'a man is standing on a bench with a skateboard .',
#  '000000138514': 'a man is standing on a skateboard on a skateboard .',
#  '000000049643': 'a man is standing on a skateboard on a skateboard .',
#  '000000192866': 'a man in a blue shirt and blue shirt is standing on a skateboard .',
#  '000000466839': 'a man is standing on a field of a field .',
#  '000000359141': 'a man in a blue shirt and black shirt is standing on a bench .',
#  '000000234749': 'a man is standing on a bench in a field .',
#  '000000000620': 'a man in a red shirt and white shirt is standing on a bench .',
#  '000000496517': 'a man is holding a tennis racket on a court .',
#  '000000272785': 'a man in a black shirt and white shirt and white shirt is standing on a skateboard .',
#  '000000533522': 'a man in a red shirt and white shirt is standing in front of a laptop .',
#  '000000361638': 'a bathroom with a toilet and a sink .',
#  '000000160014': 'a man in a blue shirt and black shirt is standing on a skateboard .',
#  '000000376362': 'a man is riding a skateboard on a skateboard .',
#  '000000298793': 'a man in a blue shirt and white shirt is standing on a skateboard .',
#  '000000465969': 'a man in a blue shirt and black shirt is standing on a skateboard .',
#  '000000133660': 'a man is standing on a beach with a surfboard .',
#  '000000382171': 'a man is standing on a field of a field .',
#  '000000157238': 'a man is standing on a skateboard on a skateboard .',
#  '000000057883': 'a man riding a wave on a wave .',
#  '000000580082': 'a man in a blue shirt and black shirt is standing on a skateboard .',
#  '000000280023': 'a woman is standing in a field with a red umbrella .',
#  '000000406755': 'a man in a red shirt and white shirt is standing in front of a laptop .',
#  '000000117691': 'a man in a red shirt and white shirt is standing on a skateboard .',
#  '000000465080': 'a man in a blue shirt and blue shirt is standing on a bench .',
#  '000000190297': 'a man in a red shirt and white shirt is standing on a skateboard .',
#  '000000507370': 'a man is standing on a skateboard on a skateboard .',
#  '000000531474': 'a man in a black shirt and white shirt and white shirt is standing on a bench .',
#  '000000089101': 'a man in a blue shirt and black shirt is standing on a skateboard .',
#  '000000031578': 'a man in a red shirt and white shirt is standing on a bench .',
#  '000000353652': 'a man in a blue shirt and white shirt is standing on a skateboard .',
#  '000000546531': 'a man is standing on a skateboard in front of a building .',
#  '000000200612': 'a man in a blue shirt and white shirt is standing on a bench .',
#  '000000304040': 'a man in a blue shirt and white shirt is standing on a skateboard .',
#  '000000143569': 'a man is standing on a bench in front of a building .',
#  '000000494768': 'a man in a red shirt and white shirt is standing on a skateboard .',
#  '000000379165': 'a man in a red shirt and white shirt is standing in front of a laptop .',
#  '000000333621': 'a man is standing on a bench with a laptop .',
#  '000000154955': 'a man is standing on a skateboard .',
#  '000000305451': 'a man in a red shirt and white shirt is standing on a table .',
#  '000000418505': 'a man in a blue shirt and white shirt is standing in front of a large building .',
#  '000000535874': 'a man is holding a tennis racket on a court .',
#  '000000241860': 'a man in a red shirt and white shirt is standing on a bench .',
#  '000000399241': 'a man riding a wave on a wave .',
#  '000000524646': 'a man in a blue shirt and blue shirt is standing on a skateboard .',
#  '000000351141': 'a man is standing on a bench with a red umbrella .',
#  '000000477321': 'a man is standing on a beach with a surfboard .',
#  '000000387153': 'a man in a white shirt and a white shirt and a white shirt is standing in a kitchen .',
#  '000000084157': 'a pizza with a pizza on it is on a plate .',
#  '000000415201': 'a man is holding a cell phone in a room .',
#  '000000027675': 'a man in a red shirt and white shirt is standing on a bench .',
#  '000000295642': 'a man in a blue shirt is standing on a skateboard .',
#  '000000387181': 'a man in a blue shirt and black shirt is holding a cell phone .',
#  '000000178849': 'a man in a blue shirt and blue shirt is standing on a skateboard .',
#  '000000143192': 'a man in a black shirt and white shirt is standing in a room .',
#  '000000577176': 'a man is standing on a bench with a red umbrella .',
#  '000000477782': 'a man in a blue shirt and blue shirt is standing on a skateboard .',
#  '000000215107': 'a man in a blue shirt and blue shirt is standing on a skateboard .',
#  '000000471480': 'a man is standing on a bench in front of a building .',
#  '000000536827': 'a man is standing on a skateboard on a skateboard .',
#  '000000197408': 'a man in a black shirt and white shirt is standing on a skateboard .',
#  '000000088377': 'a man in a blue shirt and black shirt is standing on a bench .',
#  '000000260373': 'a man is standing on a skateboard on a skateboard .',
#  '000000290724': 'a man is standing on a skateboard on a skateboard .',
#  '000000184355': 'a man is standing on a bench in front of a building .',
#  '000000105172': 'a man is standing in a field with a dog .',
#  '000000448139': 'a man is standing on a field with a frisbee .',
#  '000000271373': 'a man is riding a skateboard on a skateboard .',
#  '000000581204': 'a man in a blue shirt and white shirt is standing in a field .',
#  '000000278335': 'a man is standing on a beach with a surfboard .',
#  '000000292844': 'a man in a black shirt and white shirt is standing on a bench .',
#  '000000428039': 'a man in a blue shirt and blue shirt is standing on a bench .',
#  '000000267417': 'a man is standing on a field with a frisbee .',
#  '000000495615': 'a man in a blue shirt and white shirt is standing on a bench .',
#  '000000376422': 'a man in a red shirt and white shirt is standing in front of a large building .',
#  '000000483517': 'a man in a blue shirt and blue shirt is standing on a skateboard .',
#  '000000207142': 'a plate with a pizza on it is on it .',
#  '000000141207': 'a man is standing on a beach with a surfboard .',
#  '000000038196': 'a man is standing on a bench with a frisbee .',
#  '000000341639': 'a man is standing on a bench in front of a building .',
#  '000000064389': 'a man is holding a cell phone in a room .',
#  '000000495079': 'a man is standing on a field with a frisbee .',
#  '000000131696': 'a man in a black shirt and white shirt is standing on a skateboard .',
#  '000000054003': 'a man is standing on a bench with a red umbrella .',
#  '000000330400': 'a man is standing on a skateboard on a beach .',
#  '000000015733': 'a man in a blue shirt and blue shirt is riding a wave on a wave .',
#  '000000300514': 'a woman in a red shirt and a red shirt is sitting on a table .',
#  '000000362811': 'a man is standing on a bench with a red umbrella .',
#  '000000353937': 'a man in a black shirt and white shirt is standing in front of a laptop .',
#  '000000572063': 'a man is standing on a bench in the middle of a field .',
#  '000000313113': 'a woman in a red shirt and a red shirt is sitting on a table .',
#  '000000499852': 'a man in a blue shirt and black shirt is standing on a bench .',
#  '000000060005': 'a man in a blue shirt and blue shirt is standing on a bench .',
#  '000000184282': 'a man is standing on a bench in the middle of a field .',
#  '000000285893': 'a man is standing on a bench in the middle of a field .',
#  '000000099070': 'a man in a blue shirt and white shirt is standing on a bench .',
#  '000000205126': 'a man is standing on a skateboard on a skateboard .',
#  '000000313280': 'a man in a blue shirt and blue shirt is standing on a skateboard .',
#  '000000299643': 'a man is standing on a bench in the middle of a field .',
#  '000000409678': 'a plate of food with a pizza on it',
#  '000000198289': 'a woman in a red shirt and a red shirt is standing in front of a red and a red and white dog .',
#  '000000040100': 'a man is standing on a bench in the grass .',
#  '000000111188': 'a man in a black shirt and white shirt is standing on a skateboard .',
#  '000000111940': 'a man in a blue shirt and black shirt is standing on a bench .',
#  '000000467137': 'a man in a blue shirt and blue shirt is standing on a skateboard .',
#  '000000229707': 'a man in a red shirt and red shirt is standing on a skateboard .',
#  '000000312446': 'a man in a white shirt and a white shirt and a white dog standing on a bed .',
#  '000000468132': 'a man in a black shirt and white shirt and white shirt is standing in a white shirt and a white shirt and a white shirt and a white shirt and a white shirt and a black shirt and a black shirt and white shirt and a black shirt .',
#  '000000452737': 'a man in a blue shirt and blue shirt is holding a tennis racket .',
#  '000000081954': 'a man in a black shirt and white shirt and white shirt is standing on a skateboard .',
#  '000000239801': 'a plate with a pizza on it is sitting on it .',
#  '000000316336': 'a man in a white shirt and a white shirt is standing in a room .',
#  '000000125672': 'a man in a blue shirt and white shirt is standing on a bench .',
#  '000000465495': 'a man in a blue shirt and white shirt is standing on a bench .',
#  '000000400064': 'a man in a red shirt and white shirt is standing on a table .',
#  '000000083601': 'a man is sitting on a bench in a room .',
#  '000000136154': 'a man in a blue shirt and blue shirt is standing on a skateboard .',
#  '000000419678': 'a man in a blue shirt and white shirt is standing on a bench .',
#  '000000291889': 'a man is standing on a bench in front of a building .',
#  '000000456201': 'a man is standing on a skateboard with a tennis racket .',
#  '000000403464': 'a man is standing on a bench in the middle of a city .',
#  '000000421534': 'a man is standing on a bench in the air .',
#  '000000170562': 'a man in a blue shirt and white shirt is standing on a skateboard .',
#  '000000383329': 'a man in a red shirt and red shirt is sitting on a table .',
#  '000000069424': 'a man in a white shirt and a white shirt is standing in a room .',
#  '000000361376': 'a man is standing on a field with a large white dog .',
#  '000000297570': 'a man is standing in the ocean with a kite .',
#  '000000574829': 'a man in a black shirt and white shirt and white shirt is standing on a bed .',
#  '000000090498': 'a man in a white shirt and a white shirt and a black shirt is standing on a bed .',
#  '000000397717': 'a man is standing on a bench with a skateboard .',
#  '000000406452': 'a man in a black shirt and white shirt is standing on a skateboard .',
#  '000000059267': 'a man is standing on a skateboard on a skateboard .',
#  '000000369568': 'a man in a blue shirt and black shirt is standing on a field .',
#  '000000329175': 'a man is standing on a skateboard on a skateboard .',
#  '000000456873': 'a woman is holding a tennis racket on a court .',
# ...
#  '000000038827': 'a bathroom with a toilet and a toilet .',
#  '000000038722': 'a man in a red shirt and white shirt is sitting on a table .',
#  '000000483530': 'a man in a blue shirt and a blue shirt and a blue and white and white and white and white and white and white and white and white and white dog on a beach .',
#  '000000373923': 'a man in a blue shirt and blue shirt is standing on a skateboard .',
#  '000000230038': 'a man in a red shirt and white shirt is standing on a bed .',
#  '000000305267': 'a woman in a red shirt and a red shirt is sitting on a table .',
#  '000000053232': 'a man in a black shirt and white shirt is standing on a skateboard .',
#  '000000284144': 'a man in a red shirt and white shirt is standing in front of a large building .',
#  '000000193594': 'a man in a black shirt and white shirt and white shirt is standing in a black shirt and white shirt and white shirt and white shirt and white shirt and white shirt and white and white shirt and a black shirt and white shirt and white shirt and white shirt and white and a black and white shirt and white shirt and white and white dog .',
#  '000000112882': 'a bathroom with a toilet and a sink .',
#  '000000573184': 'a man is standing on a skateboard on a skateboard .',
#  '000000128826': 'a man in a black shirt and white shirt is standing on a bench .',
#  '000000175946': 'a man is standing on a bench with a red umbrella .',
#  '000000233926': 'a man is standing on a bench in front of a building .',
#  '000000295257': 'a man in a blue shirt and blue shirt is standing on a skateboard .',
#  '000000530888': 'a man is standing on a bench in the grass .',
#  '000000058965': 'a baseball player is standing in the field .',
#  '000000124836': 'a man is standing on a field of a field .',
#  '000000236155': 'a man is holding a tennis racket on a court .',
#  '000000447557': 'a man is standing on a skateboard in the air .',
#  '000000041413': 'a man is standing on a skateboard on a skateboard .',
#  '000000281855': 'a man in a blue shirt and white shirt is standing on a skateboard .',
#  '000000163192': 'a plate with a pizza on it',
#  '000000032176': 'a man is standing on a bench in front of a building .',
#  '000000283382': 'a man is standing on a bench with a skateboard .',
#  '000000447726': 'a man is standing on a skateboard on a skateboard .',
#  '000000244349': 'a man in a blue shirt and white shirt is standing on a skateboard .',
#  '000000526680': 'a man in a blue shirt and black shirt is standing on a skateboard .',
#  '000000289204': 'a man in a blue shirt and blue shirt is standing on a skateboard .',
#  '000000296696': 'a man is riding a skateboard on a skateboard .',
#  '000000051530': 'a man in a blue shirt and white shirt is standing on a bench .',
#  '000000056306': 'a man in a black shirt and white shirt is standing on a bed .',
#  '000000546285': 'a man is standing on a skateboard on a skateboard .',
#  '000000176192': 'a man is standing on a skateboard on a beach .',
#  '000000244582': 'a man is standing in a field with a frisbee .',
#  '000000325287': 'a man in a blue shirt and white shirt and a woman standing in front of a large white shirt and a man in front of a large white shirt and a man in front of a large building .',
#  '000000517430': 'a man in a blue shirt and white shirt is standing on a bench .',
#  '000000075557': 'a man is standing on a bench in the middle of a field .',
#  '000000345590': 'a bathroom with a toilet and a toilet .',
#  '000000392315': 'a man is standing on a skateboard on a beach .',
#  '000000098155': 'a man is standing on a bench in front of a building .',
#  '000000149572': 'a man is holding a tennis racket on a court .',
#  '000000453586': 'a man is standing on a skateboard on a beach .',
#  '000000018467': 'a man is standing on a table with a red umbrella .',
#  '000000308838': 'a man riding a wave on a wave .',
#  '000000323964': 'a woman is holding a pizza on a table .',
#  '000000550392': 'a man in a red shirt and white shirt is standing on a bed .',
#  '000000060602': 'a man is standing on a skateboard on a beach .',
#  '000000189153': 'a man is standing on a bench in front of a building .',
#  '000000034973': 'a man is standing in a field of a kitchen .',
#  '000000581302': 'a man is holding a tennis racket on a court .',
#  '000000146656': 'a man is standing on a bench with a large white dog .',
#  '000000124903': 'a man in a blue shirt and white shirt is standing on a bench .',
#  '000000102445': 'a man in a blue shirt and blue shirt is standing on a bench .',
#  '000000125729': 'a man in a blue shirt and white shirt is standing on a skateboard .',
#  '000000331314': 'a man in a red shirt and a red shirt is sitting on a table .',
#  '000000393394': 'a plate of food with a pizza on it',
#  '000000438932': 'a man in a black shirt and white shirt and white shirt is standing in a room .',
#  '000000371092': 'a man in a blue shirt and black shirt is standing on a bench .',
#  '000000055033': 'a man in a blue shirt and black shirt is standing on a bench .',
#  '000000302141': 'a man is standing on a bench in the middle of a field .',
#  '000000002982': 'a man is standing on a skateboard on a beach .',
#  '000000469731': 'a man in a blue shirt and blue shirt is standing on a skateboard .',
#  '000000166047': 'a man is standing on a field with a tennis ball .',
#  '000000390969': 'a man in a red shirt and white shirt is standing on a bench .',
#  '000000564443': 'a man in a blue shirt and blue shirt is standing on a skateboard .',
#  '000000231500': 'a man is sitting on a table with a laptop .',
#  '000000568308': 'a man in a blue shirt and white shirt is standing on a bed .',
#  '000000081259': 'a man in a blue shirt and blue shirt is standing on a bench .',
#  '000000016520': 'a baseball player is standing in the grass .',
#  '000000242325': 'a man in a black shirt and white shirt is standing in a field .',
#  '000000140758': 'a man is standing on a bench in the middle of a field .',
#  '000000092910': 'a man is holding a tennis racket on a court .',
#  '000000347267': 'a man is standing on a skateboard on a skateboard .',
#  '000000284722': 'a man in a blue shirt and white shirt is standing on a bench .',
#  '000000570019': 'a plate of food with a pizza on it',
#  '000000141240': 'a man is sitting on a bench in the middle of a city .',
#  '000000050470': 'a man in a blue shirt and blue shirt is standing on a tennis court .',
#  '000000125683': 'a man in a black shirt and white shirt and white shirt is standing in a black shirt and white shirt and white shirt and white shirt and white shirt and white shirt and white and white shirt and a black shirt and white shirt and white and white shirt and white and white and white shirt .',
#  '000000079831': 'a man is standing on a bench with a red umbrella .',
#  '000000253419': 'a man in a blue shirt and blue shirt is flying a kite .',
#  '000000242029': 'a man is standing on a skateboard on a street .',
#  '000000074411': 'a man is standing on a field with a frisbee .',
#  '000000571563': 'a man is standing on a bench with a skateboard .',
#  '000000385672': 'a man is sitting on a bench in a field .',
#  '000000286673': 'a man is sitting on a table with a laptop .',
#  '000000462993': 'a man in a blue shirt and white shirt is standing on a bench .',
#  '000000455549': 'a man in a black shirt and white shirt and white shirt is standing in a white shirt and a white shirt and a white shirt and white shirt and a white shirt and a white shirt and a white shirt and a white shirt and a white shirt and a white shirt .',
#  '000000486421': 'a man is standing on a field with a frisbee .',
#  '000000575274': 'a man is standing on a bench with a skateboard .',
#  '000000349566': 'a man is standing on a field with a dog .',
#  '000000365833': 'a man is standing on a beach with a surfboard .',
#  '000000048474': 'a man in a blue shirt and white shirt is standing in a field .',
#  '000000509267': 'a man in a black shirt and white shirt is standing on a bench .',
#  '000000241918': 'a man in a blue shirt and blue shirt is standing on a skateboard .',
#  '000000319781': 'a man is standing on a bed with a laptop .',
#  '000000046171': 'a man in a black shirt and white shirt is standing on a bed .',
#  '000000056193': 'a man is standing on a bench in front of a building .',
#  '000000326496': 'a man is standing on a bench with a large clock .',
#  '000000351288': 'a man is riding a skateboard on a skateboard .',
#  '000000352735': 'a man is standing on a tennis court .',
#  '000000429908': 'a man in a red shirt and white shirt is standing in front of a large building .',
#  '000000323462': 'a man in a black shirt and white shirt is standing next to a woman in a white shirt .',
#  '000000182295': 'a man in a black shirt and white shirt is standing in a room .',
#  '000000179758': 'a man in a black shirt and white shirt is standing on a field .',
#  '000000411445': 'a man in a black shirt and white shirt is standing on a bed .',
#  '000000552579': 'a man is standing on a skateboard on a skateboard .',
#  '000000402243': 'a man in a black shirt and white shirt is standing on a bed .',
#  '000000465414': 'a man is standing on a skateboard on a bench .',
#  '000000565387': 'a man in a blue shirt and blue shirt is standing on a bench .',
#  '000000503318': 'a man in a blue shirt and white shirt and a white shirt and a white shirt and a white tie and a white dog on a bed .',
#  '000000241790': 'a man in a blue shirt and blue sky .',
#  '000000365631': 'a man in a blue shirt and blue shirt is standing on a bench .',
#  '000000559830': 'a man in a black shirt and white shirt is standing on a skateboard .',
#  '000000269958': 'a man in a blue shirt and blue shirt is standing on a skateboard .',
#  '000000383760': 'a man in a blue shirt and blue shirt and blue sky .',
#  '000000317896': 'a man in a red shirt and white shirt is standing on a bench .',
#  '000000041962': 'a man in a blue shirt and blue shirt is standing on a tennis court .',
#  '000000030151': 'a man in a black shirt and white shirt is standing on a bed .',
#  '000000028674': 'a man in a red shirt and white shirt is standing in a kitchen .',
#  '000000344765': 'a man in a black shirt and white shirt is standing in a room .',
#  '000000208779': 'a man in a white shirt and a white shirt is standing on a bed .',
#  '000000392105': 'a man in a red shirt and white shirt is standing on a bench .',
#  '000000179687': 'a man in a blue shirt is standing on a skateboard .',
#  '000000532673': 'a man in a black shirt and white shirt is standing in a field .',
#  '000000302364': 'a man in a red shirt and white shirt is standing on a bed .',
#  '000000240449': 'a man in a blue shirt and blue shirt is riding a skateboard .',
#  '000000516329': 'a man is holding a tennis racket on a court .',
#  '000000064036': 'a man is standing on a bench in the grass .',
#  '000000165064': 'a man is standing on a tennis court .',
#  '000000083093': 'a man in a red shirt and white shirt is standing on a couch .',
#  '000000225053': 'a man is standing on a bench in the grass .',
#  '000000573483': 'a man in a blue shirt and white shirt is standing in a field .',
#  '000000072396': 'a man in a blue shirt and white shirt is standing on a bench .',
#  '000000330916': 'a man in a black shirt and white shirt is standing on a skateboard .',
#  '000000401458': 'a man is standing on a bed with a white dog .',
#  '000000522464': 'a man in a black shirt and white shirt is standing on a bench .',
#  '000000322769': 'a man in a blue shirt and white shirt and a white shirt and a white shirt and a white dog on a white plate .',
#  '000000168349': 'a man in a red shirt and white shirt is standing on a couch .',
#  '000000425470': 'a woman is holding a tennis racket in a red shirt .',
#  '000000382873': 'a man is standing on a bench in the middle of a field .',
#  '000000091681': 'a man in a white shirt and a white shirt and a black shirt is standing on a bed .',
#  '000000003461': 'a man in a blue shirt and black shirt is standing on a skateboard .',
#  '000000339031': 'a man is standing on a skateboard in the air .',
#  '000000458629': 'a man in a blue shirt and white shirt is standing on a skateboard .',
#  '000000534898': 'a man in a blue shirt and white shirt is standing on a bench .',
#  '000000319121': 'a man in a blue shirt and white shirt is standing on a bench .',
#  '000000484418': 'a man in a blue shirt and blue shirt is standing on a bench .',
#  '000000170662': 'a man is standing on a bench in the grass .',
#  '000000051501': 'a man in a red shirt and white shirt is standing in front of a large building .',
#  '000000458603': 'a man in a black shirt and white shirt is standing on a bench .',
#  '000000116633': 'a man is riding a skateboard on a beach .',
#  '000000166018': 'a man in a blue shirt and black shirt is standing on a bench .',
#  '000000240889': 'a man is holding a tennis racket on a court .',
#  '000000094884': 'a man is standing in a field with a large clock on the side of it .',
#  '000000018183': 'a plate with a pizza on it',
#  '000000022198': 'a man is standing on a beach with a surfboard .',
#  '000000435139': 'a man in a white shirt and a white shirt is standing in a field .',
#  '000000484494': 'a man is standing on a bench in the grass .',
#  '000000543042': 'a man in a white shirt and a white shirt is standing on a bench .',
#  '000000320429': 'a man in a blue shirt and blue shirt is standing on a skateboard .',
#  '000000525823': 'a man in a black shirt and white shirt and white shirt is standing in front of a man in front of a large building .',
#  '000000578856': 'a man is standing on a beach with a tennis racket .',
#  '000000383605': 'a man is standing on a field with a frisbee .',
#  '000000402095': 'a man in a red shirt and white shirt is standing in front of a large building .',
#  '000000401528': 'a man in a red shirt is standing on a bed .',
#  '000000196379': 'a man in a blue shirt and white shirt is standing on a skateboard .',
#  '000000538444': 'a man is standing on a bench in front of a building .',
#  '000000542502': 'a man in a red shirt and blue shirt is standing in front of a red and white shirt and a red shirt and white shirt and a red shirt and a red shirt and a red shirt and a red shirt and white photo .',
#  '000000144734': 'a man is standing on a skateboard on a skateboard .',
#  '000000482751': 'a man is standing on a bench in the grass .',
#  '000000158737': 'a man is standing on a field of a field .',
#  '000000089253': 'a man in a black shirt and white shirt is standing on a bench .',
#  '000000559908': 'a man is holding a tennis racket in a ball .',
#  '000000114229': 'a man in a red shirt and white shirt is sitting on a table .',
#  '000000198426': 'a man in a red shirt and white shirt is standing in front of a large building .',
#  '000000556473': 'a man is standing on a beach with a kite .',
#  '000000100140': 'a man in a blue shirt and white shirt is standing on a bench .',
#  '000000057979': 'a man is standing on a skateboard on a skateboard .',
#  '000000217495': 'a man in a black shirt and white shirt and white shirt is standing on a bed .',
#  '000000422608': 'a man is standing on a bench in a field .',
#  '000000341219': 'a woman in a red shirt and white shirt is standing next to a woman in a white shirt .',
#  '000000224541': 'a man is standing on a table with a laptop .',
#  '000000310558': 'a man is standing on a bench in front of a building .',
#  '000000557344': 'a woman in a red shirt and a red shirt is sitting on a table .',
#  '000000045923': 'a man is standing on a bench in the air .',
#  '000000457948': 'a man is standing on a bench in the grass .',
#  '000000025516': 'a man in a blue shirt is riding a skateboard .',
#  '000000457726': 'a man in a blue shirt and blue shirt is standing on a bench .',
#  '000000162087': 'a man in a black shirt and white shirt and white shirt is standing on a bed .',
#  '000000081357': 'a man in a blue shirt and black shirt is standing on a skateboard .',
#  '000000425772': 'a man is standing on a bench in the water .',
#  '000000477759': 'a man in a black shirt and white shirt is standing in front of a building .',
#  '000000216820': 'a man is holding a tennis racket on a court .',
#  ...}

# %%
with open("./p2/dict2.json", "w") as f:
    json.dump(dict2, f, indent=4)

# %%
dict
# Out:
# {'000000165547': 'a bathroom with a toilet and a sink',
#  '000000518586': 'a man is standing on a bench next to a tree .',
#  '000000249720': 'a man in a white shirt and white shirt is standing in front of a tree .',
#  '000000122934': 'a man is standing on a bench in the air .',
#  '000000393258': 'a man in a blue shirt and white shirt is sitting on a bench .',
#  '000000266041': 'a man in a white shirt and white shirt is sitting on a bed .',
#  '000000053015': 'a woman in a white shirt is sitting on a table .',
#  '000000039540': 'a large kitchen with a table and a table .',
#  '000000320039': 'a woman in a white shirt and white shirt is sitting on a table .',
#  '000000014941': 'a woman is sitting on a table with a dog .',
#  '000000304355': 'a cat sitting on a bed with a white toilet .',
#  '000000096514': 'a man is sitting on a bench in the middle of a room .',
#  '000000578703': 'a man is riding a skateboard down a street .',
#  '000000350966': 'a train is parked on a street with a train .',
#  '000000201220': 'a man in a white shirt and a white shirt is holding a cell phone .',
#  '000000309100': 'a man in a blue shirt is standing on a field .',
#  '000000298726': 'a man in a blue shirt is playing a game of baseball .',
#  '000000214742': 'a street sign is parked in front of a building .',
#  '000000135356': 'a man in a white shirt and white shirt is sitting on a bed .',
#  '000000279806': 'a man in a blue shirt is riding a skateboard .',
#  '000000163361': 'a man is standing on a beach with a kite .',
#  '000000135978': 'a group of people standing in front of a building .',
#  '000000163460': 'a man in a blue shirt is playing tennis .',
#  '000000434129': 'a man is standing on a bench in front of a building .',
#  '000000575428': 'a group of people standing on a field .',
#  '000000046912': 'a man is standing on a bench in front of a building .',
#  '000000377326': 'a man in a blue shirt is riding a skateboard .',
#  '000000302219': 'a red fire hydrant sitting on a bench .',
#  '000000300655': 'a large train is on the beach with a large building .',
#  '000000178748': 'a small dog is sitting on a table .',
#  '000000519299': 'a man in a blue shirt is standing on a bench .',
#  '000000216303': 'a man is playing tennis on a tennis court .',
#  '000000038892': 'a cat sitting on a bed with a cat .',
#  '000000487151': 'a baseball player is playing baseball .',
#  '000000461883': 'a man is playing a game of tennis .',
#  '000000470313': 'a small dog is sitting on a bench .',
#  '000000137490': 'a man in a blue shirt is riding a skateboard .',
#  '000000491965': 'a man is standing next to a street sign .',
#  '000000056400': 'a man in a white shirt and a black shirt is holding a cell phone .',
#  '000000042055': 'a man is playing tennis .',
#  '000000164594': 'a man in a white shirt is standing in front of a building .',
#  '000000303215': 'a man is sitting on a table with a laptop .',
#  '000000481891': 'a woman in a white shirt is sitting on a table .',
#  '000000301755': 'a man is standing on a bench with a skateboard .',
#  '000000047940': 'a cat sitting on a bed with a laptop .',
#  '000000192233': 'a man in a red shirt is standing in front of a red shirt and white shirt and white shirt and white shirt and white shirt and white shirt and white shirt and white shirt is standing in front of a red shirt .',
#  '000000417590': 'a man in a baseball shirt is playing a game of baseball .',
#  '000000164899': 'a woman is sitting on a bench in a room .',
#  '000000368505': 'a man is standing on a bench in front of a building .',
#  '000000513778': 'a man is standing on a beach with a kite .',
#  '000000352476': 'a man is standing on a street with a large horse .',
#  '000000259879': 'a man is standing on a field with a frisbee .',
#  '000000178361': 'a man is sitting on a bench in front of a building .',
#  '000000020972': 'a man is sitting on a bench with a dog .',
#  '000000367881': 'a man is standing on a bench in the middle of a field .',
#  '000000451305': 'a man is sitting on a bench in front of a building .',
#  '000000485294': 'a bathroom with a sink and a sink',
#  '000000177990': 'a man in a red shirt is standing in front of a red shirt and white shirt and white shirt and white shirt and white shirt and white shirt is standing on a white shirt and white shirt .',
#  '000000540159': 'a cat sitting on a bench next to a laptop .',
#  '000000096539': 'a cat sitting on a bed with a cat on it .',
#  '000000147904': 'a man is riding a kite on a beach .',
#  '000000546642': 'a man is standing in the middle of a field .',
#  '000000307989': 'a woman is sitting on a table with a pizza .',
#  '000000267840': 'a man is standing on a field with a dog .',
#  '000000405675': 'a group of people are standing in a field .',
#  '000000378823': 'a man in a blue shirt and white shirt is standing in front of a building .',
#  '000000394322': 'a group of people standing in front of a building .',
#  '000000411043': 'a group of people standing in a field .',
#  '000000137573': 'a man in a white shirt is standing in front of a tree .',
#  '000000301155': 'a group of people are standing on a street .',
#  '000000333156': 'a woman is sitting on a table with a cake .',
#  '000000241068': 'a man is standing on a beach with a kite .',
#  '000000285734': 'a baseball player is playing tennis on a field .',
#  '000000408143': 'a man is sitting on a table with a laptop .',
#  '000000491872': 'a person is sitting on a beach with a blue umbrella .',
#  '000000084123': 'a large clock tower with a clock on it .',
#  '000000102996': 'a man is standing in the middle of a building .',
#  '000000251044': 'a man in a white shirt and white shirt is holding a cell phone .',
#  '000000201859': 'a man riding a skateboard down a street .',
#  '000000579326': 'a woman in a white shirt is sitting on a bench .',
#  '000000370038': 'a man in a white shirt and white shirt is standing in front of a building .',
#  '000000548729': 'a man in a blue shirt and white shirt is standing in front of a red shirt and a red shirt and white shirt and white shirt and white shirt and white shirt is standing in a red shirt .',
#  '000000140197': 'a man in a blue shirt and white shirt is standing on a sidewalk .',
#  '000000353836': 'a man in a blue shirt is sitting on a bench .',
#  '000000491681': 'a man in a blue shirt is riding a wave .',
#  '000000289941': 'a woman is sitting on a table with a cake .',
#  '000000540834': 'a man is standing in front of a large room .',
#  '000000318825': 'a man is playing tennis on a tennis court .',
#  '000000226874': 'a plate of food with a plate of food .',
#  '000000118432': 'a man is standing on a bench in front of a building .',
#  '000000146640': 'a man in a white shirt and white shirt is standing in front of a white shirt and a white shirt and a white shirt and a white dog .',
#  '000000113757': 'a cat sitting on a bed in a room .',
#  '000000346702': 'a cat sitting on a bed with a toilet .',
#  '000000296871': 'a man in a blue shirt is sitting on a bench .',
#  '000000136572': 'a man in a red shirt and white shirt is standing in front of a building .',
#  '000000238602': 'a man in a white shirt and white shirt is sitting on a couch .',
#  '000000460972': 'a group of people standing on a field .',
#  '000000210766': 'a cat sitting on a bed with a toilet .',
#  '000000006789': 'a train is parked on a street with a train station .',
#  '000000502275': 'a plate of food with a plate of food .',
#  '000000370399': 'a man in a red shirt is standing on a bench .',
#  '000000437618': 'a group of people standing on a beach with a kite .',
#  '000000099389': 'a man is sitting on a table with a laptop .',
#  '000000536294': 'a man is riding a tennis racket on a beach .',
#  '000000106096': 'a bathroom with a sink and a sink',
#  '000000032960': 'a man in a red shirt is riding a skateboard .',
#  '000000206587': 'a group of people standing in a field of grass .',
#  '000000102466': 'a large white dog is sitting on a beach .',
#  '000000397903': 'a black and white dog is sitting on a bench .',
#  '000000074001': 'a man in a white shirt is standing in front of a building .',
#  '000000213023': 'a group of people standing in a field .',
#  '000000082740': 'a man is standing on a bench with a skateboard .',
#  '000000553852': 'a large clock on a street with a clock on it .',
#  '000000557396': 'a large clock tower with a clock on it .',
#  '000000397658': 'a man in a white shirt and white shirt is standing in front of a building .',
#  '000000315474': 'a group of people standing on a street .',
#  '000000049667': 'a man in a white shirt and white shirt is standing in the middle of a room .',
#  '000000336937': 'a man is standing on a bench in the background .',
#  '000000302302': 'a group of people standing on a beach with a kite .',
#  '000000013414': 'a man is sitting on a bed with a laptop .',
#  '000000137507': 'a cat sitting on a table with a laptop .',
#  '000000481281': 'a woman in a white shirt is sitting on a bed .',
#  '000000358247': 'a man in a blue shirt and white shirt is standing on a sidewalk .',
#  '000000420610': 'a man is sitting on a table with a laptop .',
#  '000000423588': 'a man riding a skateboard down a snowy slope .',
#  '000000033798': 'a kitchen with a sink and a sink',
#  '000000425676': 'a baseball player is standing on a field .',
#  '000000168898': 'a plate of food with a plate of food .',
#  '000000423919': 'a cat sitting on a bed with a white toilet .',
#  '000000306313': 'a cat sitting on top of a bed .',
#  '000000504452': 'a man is standing on a skateboard in the air .',
#  '000000091636': 'a man in a blue shirt and white shirt is standing on a skateboard .',
#  '000000482907': 'a man is riding a wave on a beach .',
#  '000000053677': 'a man is sitting on a bench with a red umbrella .',
#  '000000033717': 'a large clock tower with a large clock on it .',
#  '000000329806': 'a man is standing on a bench with a frisbee .',
#  '000000332074': 'a man in a blue shirt and white shirt is standing on a skateboard .',
#  '000000022051': 'a group of people standing on a beach .',
#  '000000439902': 'a man in a black shirt and white shirt is standing in front of a large room .',
#  '000000523123': 'a man in a white shirt and white shirt is sitting on a table .',
#  '000000252280': 'a group of people standing in a field .',
#  '000000150616': 'a bathroom with a toilet and a sink',
#  '000000369601': 'a man in a white shirt and white shirt is standing in front of a building .',
#  '000000189600': 'a man is standing next to a large dog .',
#  '000000071095': 'a white dog is sitting on a bench .',
#  '000000301753': 'a baseball player is standing on a field .',
#  '000000272357': 'a man in a blue shirt is playing a game of baseball .',
#  '000000265971': 'a man is playing tennis on a tennis court .',
#  '000000043404': 'a man in a white shirt is standing on a bench .',
#  '000000429160': 'a bathroom with a sink and a sink',
#  '000000095482': 'a large clock tower with a clock on it .',
#  '000000488069': 'a man in a blue shirt is standing on a skateboard .',
#  '000000553129': 'a man is sitting on a bench in a room .',
#  '000000570594': 'a man in a blue shirt is standing in the middle of a field .',
#  '000000047916': 'a man in a blue shirt is standing on a field .',
#  '000000240655': 'a man is sitting on a bench next to a red bus .',
#  '000000289263': 'a man in a blue shirt is standing on a beach .',
#  '000000480438': 'a plate of food with a plate of food .',
#  '000000172673': 'a man is sitting on a bench with a laptop .',
#  '000000159151': 'a man is standing on a bench with a cell phone .',
#  '000000195267': 'a man is standing in front of a large field .',
#  '000000087483': 'a group of people standing on a beach .',
#  '000000126540': 'a cat sitting on a bed with a laptop .',
#  '000000544538': 'a man in a white shirt and white shirt is sitting on a table .',
#  '000000050034': 'a man is sitting on a bench in a room .',
#  '000000438046': 'a cat sitting on a table with a laptop .',
#  '000000217561': 'a man is sitting on a bench with a dog .',
#  '000000326021': 'a woman in a white shirt is holding a white dog .',
#  '000000168805': 'a group of people standing on a road with a large building .',
#  '000000580766': 'a man is standing on a bench in front of a building .',
#  '000000443652': 'a bathroom with a toilet and a toilet .',
#  '000000224247': 'a man is riding a wave on a beach .',
#  '000000146773': 'a man in a white shirt and white shirt is sitting on a bed .',
#  '000000366421': 'a man is sitting on a bench in front of a building .',
#  '000000518908': 'a man in a white shirt and white shirt is sitting on a bench .',
#  '000000172886': 'a bathroom with a sink and a sink',
#  '000000494404': 'a man is standing on a beach with a kite .',
#  '000000022979': 'a man is sitting on a bench in front of a building .',
#  '000000380828': 'a cat sitting on a bed with a cat on it .',
#  '000000151432': 'a cat sitting on a bed with a laptop .',
#  '000000215549': 'a man in a white shirt and white shirt is playing a game of tennis .',
#  '000000044421': 'a man in a white shirt and white shirt is standing in front of a window .',
#  '000000099707': 'a man in a blue shirt and white shirt is standing on a skateboard .',
#  '000000512145': 'a man in a blue shirt and white shirt is holding a cell phone .',
#  '000000161940': 'a man in a white shirt is sitting on a bench .',
#  '000000370819': 'a plate of food with a plate of food .',
#  '000000438848': 'a man is standing on a bench next to a tree .',
#  '000000168775': 'a woman in a white shirt is sitting on a table .',
#  '000000563730': 'a white plate with a white and white plate of food .',
#  '000000509185': 'a man is riding a skateboard on a skateboard .',
#  '000000287830': 'a man in a blue shirt is riding a wave .',
#  '000000324710': 'a man is sitting on a bench in the middle of a room .',
#  '000000026501': 'a man in a white shirt is sitting on a bench .',
#  '000000073981': 'a man is standing on a bench in front of a building .',
#  '000000377911': 'a cat sitting on a bed with a cat on it .',
#  '000000098268': 'a baseball player is standing on a field .',
#  '000000382557': 'a man is riding a skateboard on a skateboard .',
#  '000000473433': 'a man in a white shirt and white shirt is standing in a room .',
#  '000000307048': 'a man is sitting on a table with a laptop .',
#  '000000162855': 'a man in a blue shirt is playing a tennis .',
#  '000000494456': 'a man in a blue shirt is riding a skateboard .',
#  '000000047611': 'a white plate with a white and a white plate of food .',
#  '000000175318': 'a man is sitting on a bench in front of a building .',
#  '000000010217': 'a plate of food with a plate of food .',
#  '000000124210': 'a man in a blue shirt is riding a skateboard .',
#  '000000113897': 'a bathroom with a sink and a sink',
#  '000000548464': 'a man in a blue shirt is standing on a bench .',
#  '000000549932': 'a man in a white shirt and white shirt is sitting on a bench .',
#  '000000415153': 'a man is standing on a bench in front of a building .',
#  '000000036508': 'a plate of food with a plate of food .',
#  '000000519446': 'a cat sitting on top of a table .',
#  '000000222866': 'a plate of food with a plate of food .',
#  '000000402115': 'a cat sitting on a bench next to a large building .',
#  '000000345160': 'a man in a white shirt and white shirt is holding a red umbrella .',
#  '000000486846': 'a man is sitting on a table with a laptop .',
#  '000000191893': 'a man is standing on a beach with a kite .',
#  '000000224037': 'a large clock on a street with a red sign .',
#  '000000445267': 'a small dog is sitting on a bench .',
#  '000000126345': 'a group of people standing in a field with a green field .',
#  '000000191078': 'a plate of food with a table and a plate of food .',
#  '000000051339': 'a man is standing on a bench with a tennis racket .',
#  '000000266437': 'a man in a blue shirt is standing on a skateboard .',
#  '000000163309': 'a woman in a blue shirt is holding a white dog .',
#  '000000138022': 'a man is standing on a street with a red and white bus .',
#  '000000092815': 'a woman is sitting on a table with a laptop .',
#  '000000470801': 'a man in a blue shirt is standing on a beach .',
#  '000000311904': 'a cat sitting on top of a bed .',
#  '000000579696': 'a cat sitting on top of a wooden bench .',
#  '000000406201': 'a bathroom with a toilet and a sink',
#  '000000575012': 'a woman is sitting on a table with a dog .',
#  '000000381037': 'a bathroom with a toilet and a toilet .',
#  '000000383209': 'a cat sitting on a bed with a white dog .',
#  '000000063434': 'a woman in a white shirt is sitting on a table .',
#  '000000156532': 'a man is riding a wave on a beach .',
#  '000000038064': 'a baseball player is standing in the grass .',
#  '000000160886': 'a cat sitting on a table with a laptop .',
#  '000000468972': 'a plate of food with a plate of food .',
#  '000000168692': 'a large clock tower with a red umbrella .',
#  '000000556892': 'a man is standing on a bench in the air .',
#  '000000397980': 'a man in a blue shirt is playing tennis .',
#  '000000309222': 'a man is riding a skateboard on a beach .',
#  '000000145391': 'a woman in a white shirt and white shirt is sitting on a bed .',
#  '000000215303': 'a man in a black shirt is standing in front of a building .',
#  '000000456574': 'a man in a blue shirt and white shirt is standing on a street .',
#  '000000247394': 'a man is riding a wave on a beach .',
#  '000000275744': 'a man is riding a skateboard on a skateboard .',
#  '000000560637': 'a large clock tower with a clock on it .',
#  '000000286176': 'a cat sitting on a table with a laptop .',
#  '000000549112': 'a cat sitting on a table with a laptop .',
#  '000000275117': 'a man is standing on a bench next to a tree .',
#  '000000054924': 'a man in a white shirt is sitting on a table .',
#  '000000303667': 'a man in a white shirt and white shirt is sitting on a couch .',
#  '000000390769': 'a man is sitting on a bench in front of a building .',
#  '000000500784': 'a bathroom with a sink and a sink',
#  '000000297976': 'a bathroom with a sink and a sink',
#  '000000264909': 'a group of people are standing on a street .',
#  '000000200681': 'a man in a white shirt is standing in a field .',
#  '000000344521': 'a plate of food with a plate of food .',
#  '000000111944': 'a man in a blue shirt is riding a skateboard .',
#  '000000054870': 'a woman is sitting on a bench with a white dog .',
#  '000000426342': 'a group of people standing in a field with a giraffe .',
#  '000000344368': 'a large white dog is sitting on a bench .',
#  '000000302710': 'a man in a blue shirt is standing in front of a large building .',
#  '000000127119': 'a baseball player is playing baseball .',
#  '000000260099': 'a group of people standing on a bench in front of a building .',
#  '000000003771': 'a man in a white shirt is standing in a field .',
#  '000000349896': 'a man is standing in the grass with a kite .',
#  '000000274591': 'a man is standing on a bench with a skateboard .',
#  '000000098322': 'a man in a blue shirt is standing in front of a large blue shirt and white shirt and white shirt and white shirt and white shirt and white shirt and white shirt and white shirt is standing in the snow .',
#  '000000053665': 'a man in a blue shirt is riding a wave .',
#  '000000189694': 'a cat sitting on a bed with a cat on it .',
#  '000000011182': 'a man in a red shirt is standing on a bench .',
#  '000000354027': 'a man in a white shirt is standing in front of a white shirt and a white dog .',
#  '000000107511': 'a man in a white shirt and white shirt is standing in front of a building .',
#  '000000141426': 'a man is sitting on a bench in front of a building .',
#  '000000158588': 'a large clock tower with a clock on it .',
#  '000000425522': 'a man in a blue shirt and white shirt is standing on a bench .',
#  '000000042288': 'a man in a blue shirt is riding a skateboard .',
#  '000000303814': 'a man in a blue shirt is riding a skateboard .',
#  '000000068205': 'a woman is sitting on a table with a laptop .',
#  '000000015797': 'a man in a blue shirt is riding a skateboard .',
#  '000000034708': 'a man in a white shirt and a white shirt is sitting on a table .',
#  '000000098187': 'a man is standing on a beach with a kite .',
#  '000000378311': 'a bathroom with a sink and a sink',
#  '000000219546': 'a cat sitting on a table with a laptop .',
#  '000000406155': 'a man in a blue shirt is riding a wave .',
#  '000000006393': 'a man is sitting on a bed with a white toilet .',
#  '000000267802': 'a man in a white shirt is standing on a bench .',
#  '000000523597': 'a cat sitting on a bed with a toilet .',
#  '000000079836': 'a man is riding a wave on a beach .',
#  '000000005418': 'a group of people standing in a field .',
#  '000000474388': 'a group of people standing on a field .',
#  '000000532580': 'a group of people are standing on a street .',
#  '000000223857': 'a man in a blue shirt is standing on a skateboard .',
#  '000000215024': 'a man is riding a wave on a surfboard .',
#  '000000020147': 'a group of people standing in a field .',
#  '000000287846': 'a man is standing on a beach with a kite .',
#  '000000182736': 'a man in a white shirt and white shirt is standing in a field .',
#  '000000227851': 'a man in a blue shirt is playing tennis .',
#  '000000349590': 'a plate of food with a plate of food .',
#  '000000266853': 'a dog is standing in the grass with a dog .',
#  '000000099747': 'a man in a white shirt is sitting on a bed .',
#  '000000393777': 'a man in a red shirt is sitting on a bench .',
#  '000000092338': 'a group of people standing in a field .',
#  '000000114616': 'a woman is sitting on a bench next to a white dog .',
#  '000000029160': 'a person riding a wave on a surfboard .',
#  '000000023051': 'a group of people standing in front of a building .',
#  '000000408363': 'a man in a white shirt and white shirt is sitting on a bench .',
#  '000000575911': 'a dog is sitting on a bench next to a tree .',
#  '000000513887': 'a cat sitting on a table with a laptop .',
#  '000000470115': 'a man is sitting on a bench next to a large dog .',
#  '000000268058': 'a plate of food with a plate of food .',
#  '000000136181': 'a group of people standing on a beach .',
#  '000000400265': 'a bathroom with a sink and a sink .',
#  '000000493751': 'a man is sitting on a bench in a field .',
#  '000000297414': 'a cat sitting on top of a bed .',
#  '000000148614': 'a bathroom with a sink and a sink',
#  '000000370095': 'a large bus parked on a street with a red sign .',
#  '000000339019': 'a man is standing on a beach with a kite .',
#  '000000574208': 'a man in a blue shirt is playing tennis .',
#  '000000528011': 'a man riding a skateboard on a beach .',
#  '000000009813': 'a man is standing on a bench in front of a building .',
#  '000000429170': 'a large train is on a road with a large building .',
#  '000000273196': 'a man in a white shirt is sitting on a bed .',
#  '000000492025': 'a man in a blue shirt is standing on a bench .',
#  '000000185360': 'a train is parked on the street with a building .',
#  '000000062824': 'a man is sitting on a bench in front of a building .',
#  '000000471625': 'a group of people are standing on a street .',
#  '000000354368': 'a man in a blue shirt is standing on a bench .',
#  '000000217393': 'a man in a blue shirt is standing on a field .',
#  '000000032909': 'a man is sitting on a bench in a room .',
#  '000000232627': 'a white dog is sitting on a bench .',
#  '000000117201': 'a man in a blue shirt is riding a skateboard .',
#  '000000156282': 'a large airplane is flying over a body of water .',
#  '000000169683': 'a group of people standing on a bench in a field .',
#  '000000441054': 'a white dog is standing in a field .',
#  '000000472295': 'a man in a blue shirt is riding a skateboard .',
#  '000000321603': 'a man in a white shirt and a black shirt is sitting on a table .',
#  '000000554445': 'a woman is sitting on a table with a laptop .',
#  '000000281676': 'a man in a blue shirt is standing on a bench .',
#  '000000330356': 'a group of people standing in a field with a kite .',
#  '000000176527': 'a man in a white shirt is standing on a skateboard .',
#  '000000523252': 'a group of people are standing on a street .',
#  '000000350491': 'a small dog is standing in the grass .',
#  '000000175136': 'a large clock on the side of a building .',
#  '000000085852': 'a man is standing on a bench in front of a tree .',
#  '000000330419': 'a man is riding a skateboard down a street .',
#  '000000049068': 'a man in a white shirt and white shirt is standing in a field .',
#  '000000524979': 'a man in a white shirt and white shirt is sitting on a bed .',
#  '000000030403': 'a large clock on the side of a street .',
#  '000000255315': 'a man is sitting on a bed with a toilet .',
#  '000000445668': 'a person is flying a kite in the air .',
#  '000000066191': 'a man in a red shirt is playing a game of baseball .',
#  '000000079924': 'a person is sitting on a bench in the water .',
#  '000000082576': 'a man is standing on a beach with a kite .',
#  '000000282841': 'a man is sitting on a bench in a room .',
#  '000000326555': 'a man in a blue shirt is riding a skateboard .',
#  '000000254929': 'a plate of food with a plate of food .',
#  '000000100409': 'a woman is sitting on a bed with a cat .',
#  '000000462632': 'a large white cat sitting on top of a table .',
#  '000000536879': 'a woman in a white shirt and white shirt is sitting on a table .',
#  '000000192079': 'a plate of food with a plate of food .',
#  '000000500420': 'a man is flying a kite in the air .',
#  '000000361751': 'a group of people standing on a bench .',
#  '000000291144': 'a cat sitting on a bed with a white dog .',
#  '000000143696': 'a large clock on a street with a clock on it .',
#  '000000310757': 'a white plate with a white plate of food .',
#  '000000489798': 'a man in a red shirt and white shirt is standing in front of a red and white shirt and white dog .',
#  '000000452297': 'a cat sitting on a bench next to a large white dog .',
#  '000000199819': 'a woman in a white shirt and a black shirt is holding a cake .',
#  '000000552018': 'a woman is sitting on a table with a cake .',
#  '000000419723': 'a cat sitting on a table with a laptop .',
#  '000000344025': 'a man in a white shirt and white shirt is sitting on a table .',
#  '000000106206': 'a man is holding a skateboard on a skateboard .',
#  '000000394132': 'a person is riding a skateboard on a snowy slope .',
#  '000000161539': 'a man in a blue shirt is sitting on a bench .',
#  '000000347648': 'a woman is sitting on a table with a laptop .',
#  '000000326592': 'a group of people standing in a field .',
#  '000000173997': 'a white dog is sitting on a table .',
#  '000000401758': 'a man in a blue shirt is standing on a bench .',
#  '000000213799': 'a man in a white shirt and white shirt is sitting on a table .',
#  '000000253474': 'a man in a blue shirt is riding a skateboard .',
#  '000000559136': 'a man in a blue shirt is riding a wave .',
#  '000000248956': 'a large clock tower with a clock on it .',
#  '000000381318': 'a plate of food with a plate of food .',
#  '000000366683': 'a plate of food with a plate of food .',
#  '000000019491': 'a woman in a white shirt is sitting on a table .',
#  '000000171201': 'a woman is sitting on a table with a laptop .',
#  '000000404027': 'a man in a blue shirt is riding a skateboard .',
#  '000000286106': 'a man in a blue shirt and white shirt is standing on a sidewalk .',
#  '000000253825': 'a man in a white shirt and white shirt is sitting on a bed .',
#  '000000536403': 'a woman is sitting on a table with a laptop .',
#  '000000331223': 'a man in a white shirt and white shirt is sitting on a table .',
#  '000000432798': 'a cat sitting on top of a table .',
#  '000000342060': 'a man in a blue shirt is standing on a skateboard .',
#  '000000207458': 'a man in a blue shirt is standing on a bench .',
#  '000000257864': 'a plate of food with a white plate of food .',
#  '000000146675': 'a man is holding a tennis racket on a tennis court .',
#  '000000411177': 'a kitchen with a sink and a sink',
#  '000000110617': 'a man in a white shirt is standing on a bench .',
#  '000000169872': 'a man in a red shirt and white shirt is sitting on a street .',
#  '000000454810': 'a man is standing on a bench next to a building .',
#  '000000082312': 'a man in a red shirt is standing on a street .',
#  '000000373578': 'a man is standing on a bench in the air .',
#  '000000121503': 'a train on a street with a red bus on it .',
#  '000000015984': 'a man in a white shirt and white shirt is standing in a field .',
#  '000000515355': 'a white plate with a white plate of food .',
#  '000000478517': 'a small dog is standing in the grass .',
#  '000000389753': 'a cat sitting on a bed with a laptop .',
#  '000000418226': 'a cat sitting on a bed with a cat on it .',
#  '000000252617': 'a man is sitting on a table with a laptop .',
#  '000000415714': 'a man in a blue shirt is standing on a beach .',
#  '000000181403': 'a man is sitting on a bench in a room .',
#  '000000353130': 'a large white cat sitting on top of a table .',
#  '000000405334': 'a woman is sitting on a table with a dog .',
#  '000000357402': 'a man is playing tennis on a tennis court .',
#  '000000342387': 'a large pizza with a white and a white plate of food .',
#  '000000198495': 'a man is standing on a bench with a dog .',
#  '000000537727': 'a large clock on a bed with a clock on it .',
#  '000000373857': 'a large clock tower with a clock on it .',
#  '000000480223': 'a man in a white shirt is standing on a bench .',
#  '000000469130': 'a man is riding a skateboard on a beach .',
#  '000000190406': 'a train is parked on a bench next to a train station .',
#  '000000435187': 'a group of people standing on a street .',
#  '000000511420': 'a large train is on the beach with a red umbrella .',
#  '000000099543': 'a woman is sitting on a table with a laptop .',
#  '000000115636': 'a man in a blue shirt and white shirt is standing in front of a large blue shirt and white shirt and white shirt and white shirt and white shirt and white shirt and white shirt and white dog .',
#  '000000138185': 'a man is sitting on a table with a laptop .',
#  '000000053800': 'a man is sitting on a table with a laptop .',
#  '000000561619': 'a man is sitting on a bench in front of a kitchen .',
#  '000000396167': 'a man in a blue shirt is holding a tennis racket .',
#  '000000448275': 'a man is standing on a bench with a dog .',
#  '000000406050': 'a man in a white shirt is sitting on a bench .',
#  '000000320203': 'a man in a blue shirt is standing on a beach .',
#  '000000387506': 'a man is standing on a beach with a kite .',
#  '000000578467': 'a man is standing next to a large dog .',
#  '000000503207': 'a man is riding a skateboard on a skateboard .',
#  '000000009214': 'a group of people standing in a field of grass .',
#  '000000054627': 'a group of people standing in a field of grass .',
#  '000000143098': 'a man is holding a tennis racket on a tennis court .',
#  '000000069266': 'a man in a blue shirt is sitting on a bench .',
#  '000000457453': 'a man in a white shirt and white shirt is standing in front of a large room .',
#  '000000177173': 'a man in a blue shirt is standing on a skateboard .',
#  '000000065357': 'a man is sitting on a table with a laptop .',
#  '000000070240': 'a man in a white shirt and white shirt is sitting on a bed .',
#  '000000139734': 'a cat sitting on a table with a laptop .',
#  '000000010496': 'a group of people are standing on a beach .',
#  '000000285250': 'a man in a blue shirt is riding a wave .',
#  '000000520451': 'a man in a red shirt and white shirt is standing in front of a building .',
#  '000000521772': 'a train is parked on the tracks in the background .',
#  '000000138514': 'a man is sitting on a bed with a laptop .',
#  '000000049643': 'a large clock tower with a clock on it .',
#  '000000192866': 'a man is standing on a bench next to a building .',
#  '000000466839': 'a dog is standing in the grass in the grass .',
#  '000000359141': 'a man in a blue shirt is playing a game of baseball .',
#  '000000234749': 'a cat sitting on a bed with a cat on it .',
#  '000000000620': 'a man is sitting on a bed with a laptop .',
#  '000000496517': 'a woman is sitting on a table with a cake .',
#  '000000272785': 'a man is sitting on a bench with a laptop .',
#  '000000533522': 'a man in a white shirt and white shirt is standing in a room .',
#  '000000361638': 'a bathroom with a toilet and a sink',
#  '000000160014': 'a woman is sitting on a table with a cat .',
#  '000000376362': 'a man is standing on a beach with a kite .',
#  '000000298793': 'a large clock tower with a clock on it .',
#  '000000465969': 'a man in a white shirt and a black shirt is sitting on a table .',
#  '000000133660': 'a man is standing on a beach with a dog .',
#  '000000382171': 'a white dog is sitting on a bench .',
#  '000000157238': 'a woman is sitting on a bed with a cat .',
#  '000000057883': 'a man is riding a wave on a beach .',
#  '000000580082': 'a man is standing next to a large building .',
#  '000000280023': 'a woman in a white shirt is standing in front of a white dog .',
#  '000000406755': 'a woman in a white shirt is sitting on a table .',
#  '000000117691': 'a man is standing on a beach with a kite .',
#  '000000465080': 'a small dog is standing in the grass .',
#  '000000190297': 'a man is sitting on a bench with a cell phone .',
#  '000000507370': 'a cat sitting on a bed with a toilet .',
#  '000000531474': 'a group of people standing in front of a building .',
#  '000000089101': 'a man is standing on a bench in front of a building .',
#  '000000031578': 'a woman in a white shirt is standing in front of a white dog .',
#  '000000353652': 'a train is on the beach with a train on it .',
#  '000000546531': 'a man in a blue shirt is standing on a sidewalk .',
#  '000000200612': 'a group of people standing in a field .',
#  '000000304040': 'a man is standing on a bench in front of a building .',
#  '000000143569': 'a man in a blue shirt and white shirt is standing in front of a building .',
#  '000000494768': 'a group of people standing next to a building .',
#  '000000379165': 'a woman is sitting on a table with a dog .',
#  '000000333621': 'a man in a white shirt and white shirt is sitting on a table .',
#  '000000154955': 'a man is sitting on a bench in front of a building .',
#  '000000305451': 'a woman is sitting on a table with a dog .',
#  '000000418505': 'a bathroom with a toilet and a sink',
#  '000000535874': 'a table with a white and a white plate of food .',
#  '000000241860': 'a man is sitting on a table with a laptop .',
#  '000000399241': 'a man is riding a wave on a beach .',
#  '000000524646': 'a man is riding a wave on a beach .',
#  '000000351141': 'a man in a blue shirt is standing on a skateboard .',
#  '000000477321': 'a man in a blue shirt is standing on a beach .',
#  '000000387153': 'a bathroom with a sink and a sink',
#  '000000084157': 'a plate of food with a white plate of food .',
#  '000000415201': 'a cat sitting on a bed with a cat on it .',
#  '000000027675': 'a train is parked on a street with a bus .',
#  '000000295642': 'a train is parked on the side of a train station .',
#  '000000387181': 'a man in a blue shirt and white shirt is sitting on a couch .',
#  '000000178849': 'a man in a blue shirt and white shirt is standing in front of a building .',
#  '000000143192': 'a man in a white shirt is standing in the grass .',
#  '000000577176': 'a man in a red shirt and white shirt is standing in front of a building .',
#  '000000477782': 'a man in a blue shirt and white shirt is playing a game of tennis .',
#  '000000215107': 'a man in a blue shirt is riding a skateboard .',
#  '000000471480': 'a group of people standing in a field .',
#  '000000536827': 'a red fire hydrant sitting on a bench .',
#  '000000197408': 'a man in a white shirt and white shirt is standing in front of a building .',
#  '000000088377': 'a man is sitting on a bench in front of a building .',
#  '000000260373': 'a man in a blue shirt is standing on a skateboard .',
#  '000000290724': 'a man is riding a skateboard down a street .',
#  '000000184355': 'a man is sitting on a bench next to a building .',
#  '000000105172': 'a dog is sitting on a bench in a field .',
#  '000000448139': 'a group of people standing in a field of grass .',
#  '000000271373': 'a man in a blue shirt is riding a skateboard .',
#  '000000581204': 'a man in a white shirt is sitting on a bench .',
#  '000000278335': 'a man is riding a skateboard on a skateboard .',
#  '000000292844': 'a man in a white shirt and white shirt is sitting on a bench .',
#  '000000428039': 'a group of people standing in a field .',
#  '000000267417': 'a man in a blue shirt and white shirt is playing a game of frisbee .',
#  '000000495615': 'a man in a blue shirt is holding a tennis racket .',
#  '000000376422': 'a cat sitting on a table with a laptop .',
#  '000000483517': 'a man in a red shirt and white shirt is standing on a bench .',
#  '000000207142': 'a cat sitting on a table with a white dog .',
#  '000000141207': 'a group of people are standing on a beach .',
#  '000000038196': 'a black and white dog sitting on a bench .',
#  '000000341639': 'a group of people standing in a field with a large green field .',
#  '000000064389': 'a cat sitting on a bed with a laptop .',
#  '000000495079': 'a man in a red shirt is playing a game of baseball .',
#  '000000131696': 'a man is riding a skateboard on a beach .',
#  '000000054003': 'a man in a blue shirt is holding a cell phone .',
#  '000000330400': 'a man in a blue shirt is riding a skateboard .',
#  '000000015733': 'a man in a blue shirt is riding a wave .',
#  '000000300514': 'a woman in a white shirt is sitting on a table .',
#  '000000362811': 'a cat sitting on a table with a laptop .',
#  '000000353937': 'a bathroom with a toilet and a sink',
#  '000000572063': 'a train is parked on the side of a road .',
#  '000000313113': 'a group of people sitting on a bench .',
#  '000000499852': 'a group of people standing in a field .',
#  '000000060005': 'a train is parked on a train track .',
#  '000000184282': 'a large plane is sitting on the beach .',
#  '000000285893': 'a man is playing a game of tennis .',
#  '000000099070': 'a man in a blue shirt is standing on a bench .',
#  '000000205126': 'a man in a blue shirt is standing on a beach .',
#  '000000313280': 'a man in a blue shirt and white shirt is standing on a street .',
#  '000000299643': 'a cat sitting on a table with a laptop .',
#  '000000409678': 'a cat sitting on a table with a white plate .',
#  '000000198289': 'a woman in a white shirt and white shirt is holding a white dog .',
#  '000000040100': 'a man is standing in the grass with a frisbee .',
#  '000000111188': 'a cat sitting on a bed with a toilet .',
#  '000000111940': 'a man is standing on a bench in front of a building .',
#  '000000467137': 'a man is standing on a bench with a red umbrella .',
#  '000000229707': 'a man in a white shirt and white shirt is sitting on a couch .',
#  '000000312446': 'a group of people standing on a bench .',
#  '000000468132': 'a man is standing on a bench in the background .',
#  '000000452737': 'a man in a blue shirt and white shirt is holding a cell phone .',
#  '000000081954': 'a cat sitting on top of a bed .',
#  '000000239801': 'a white plate with a white plate of food .',
#  '000000316336': 'a kitchen with a sink and a sink',
#  '000000125672': 'a man in a white shirt and white shirt is standing in a room .',
#  '000000465495': 'a man in a white shirt and white shirt is standing in front of a kitchen .',
#  '000000400064': 'a man in a white shirt and white shirt is sitting on a bed .',
#  '000000083601': 'a man in a red shirt is sitting on a bench .',
#  '000000136154': 'a train is parked on a street with a train station .',
#  '000000419678': 'a man in a white shirt and white shirt is sitting on a bed .',
#  '000000291889': 'a man in a blue shirt is standing on a bench .',
#  '000000456201': 'a man is sitting on a table with a laptop .',
#  '000000403464': 'a man in a red shirt and white shirt is standing in front of a street .',
#  '000000421534': 'a clock tower with a clock on it .',
#  '000000170562': 'a large dog is sitting on a bench .',
#  '000000383329': 'a man in a white shirt is sitting on a bed .',
#  '000000069424': 'a group of people standing in a field with a large blue sky .',
#  '000000361376': 'a plate of food with a plate of food .',
#  '000000297570': 'a man is flying a kite on a beach .',
#  '000000574829': 'a man in a blue shirt is standing on a sidewalk .',
#  '000000090498': 'a cat sitting on a bed next to a white toilet .',
#  '000000397717': 'a dog is standing in the grass with a dog .',
#  '000000406452': 'a man is standing in the middle of a field .',
#  '000000059267': 'a man is sitting on a bed with a cat .',
#  '000000369568': 'a group of people standing in a field of grass .',
#  '000000329175': 'a large clock on the side of a city street .',
#  '000000456873': 'a cat sitting on top of a bed .',
#  '000000174496': 'a cat sitting on top of a table .',
#  '000000487288': 'a woman is sitting on a bench with a dog .',
#  '000000256465': 'a man is sitting on a bed with a laptop .',
#  '000000190334': 'a man in a white shirt and white shirt is sitting on a table .',
#  '000000224166': 'a woman is sitting on a table with a dog .',
#  '000000154888': 'a man in a white shirt and white shirt is sitting on a table .',
#  '000000580238': 'a man is standing next to a dog .',
#  '000000361519': 'a man is riding a skateboard on a street .',
#  '000000021374': 'a person is riding a skateboard on a beach .',
#  '000000162880': 'a man is standing on a bench with a red umbrella .',
#  '000000208319': 'a man is standing on a beach with a kite .',
#  '000000178178': 'a bathroom with a toilet and a sink',
#  '000000365205': 'a man in a white shirt and white shirt is sitting on a bed .',
#  '000000248391': 'a man in a blue shirt is standing on a bench .',
#  '000000192394': 'a man is riding a skateboard on a beach .',
#  '000000243324': 'a man is riding a skateboard on a skateboard .',
#  '000000349552': 'a man in a blue shirt is riding a skateboard .',
#  '000000480313': 'a man in a white shirt and white shirt is sitting on a table .',
#  '000000261196': 'a plate of food with a plate of food .',
#  '000000141922': 'a man in a white shirt and white shirt is sitting on a couch .',
#  '000000287886': 'a cat sitting on a bed in a room .',
#  '000000258129': 'a man in a blue shirt is playing tennis .',
#  '000000125662': 'a large train is parked in front of a building .',
#  '000000506659': 'a man in a white shirt and white shirt is standing in front of a building .',
#  '000000529689': 'a man in a white shirt is standing in front of a building .',
#  '000000097363': 'a group of people standing in a field with a green field .',
#  '000000011323': 'a man in a blue shirt and white shirt is standing in front of a large room .',
#  '000000169448': 'a man in a black shirt is sitting on a bench .',
#  '000000191648': 'a man is standing on a beach with a kite .',
#  '000000304584': 'a man is standing on a bench with a skateboard .',
#  '000000336015': 'a man in a blue shirt is riding a wave .',
#  '000000017167': 'a man is standing on a bench with a frisbee .',
#  '000000166349': 'a man in a blue shirt is riding a skateboard .',
#  '000000001548': 'a man riding a skateboard down a snow covered slope .',
#  '000000347131': 'a woman is sitting on a table with a cake .',
#  '000000382447': 'a cat sitting on a table with a laptop .',
#  '000000081971': 'a woman is sitting on a table with a cake .',
#  '000000536010': 'a bathroom with a toilet and a sink',
#  '000000244293': 'a man in a blue shirt is standing on a street .',
#  '000000326853': 'a man in a white shirt and white shirt is sitting on a bench .',
#  '000000311475': 'a large plane is sitting on the beach .',
#  '000000157301': 'a man is sitting on a bench next to a laptop .',
#  '000000175142': 'a small dog is sitting on a bench .',
#  '000000302576': 'a woman is sitting on a table with a laptop .',
#  '000000056323': 'a man in a blue shirt is standing on a bench .',
#  '000000189351': 'a man is sitting on a bench in front of a building .',
#  '000000379567': 'a cat sitting on top of a table .',
#  '000000111121': 'a baseball player is playing baseball on a field .',
#  '000000372660': 'a man in a blue shirt and white shirt is standing in front of a large blue shirt and a large building .',
#  '000000559768': 'a plate of food with a plate of food .',
#  '000000323790': 'a plate of food with a plate of food .',
#  '000000046359': 'a man is standing on a beach with a kite .',
#  '000000205689': 'a man in a white shirt and white shirt is standing in a bathroom .',
#  '000000573659': 'a man is sitting on a table with a laptop .',
#  '000000139040': 'a man in a white shirt and white shirt is standing in front of a kitchen .',
#  '000000459465': 'a large train is on a field with a tree .',
#  '000000381301': 'a large white dog sitting on a bench .',
#  '000000105781': 'a man is standing on a bench in front of a building .',
#  '000000302489': 'a group of people are standing on a bench .',
#  '000000068738': 'a cat sitting on a table with a laptop .',
#  '000000008320': 'a group of people standing on a road with a large building .',
#  '000000237394': 'a train is parked on the side of a road .',
#  '000000295476': 'a man in a blue shirt is riding a skateboard .',
#  '000000181850': 'a man in a white shirt and white shirt is sitting on a bed .',
#  '000000209292': 'a man is standing next to a large building .',
#  '000000428508': 'a baseball player is playing tennis on a field .',
#  '000000399932': 'a man is standing on a beach with a kite .',
#  '000000096643': 'a man in a white shirt is sitting on a bed .',
#  '000000243384': 'a large clock tower with a clock on it .',
#  '000000035712': 'a large dog is standing in the grass .',
#  '000000014726': 'a woman is sitting on a bench in a room .',
#  '000000269327': 'a dog is standing on a bench in the water .',
#  '000000474387': 'a man in a red shirt is standing on a bench .',
#  '000000063330': 'a man is standing on a bench in front of a building .',
#  '000000268036': 'a man is standing on a bench in front of a building .',
#  '000000470995': 'a man in a red shirt is standing in front of a building .',
#  '000000557467': 'a man in a white shirt and white shirt is standing in front of a building .',
#  '000000564314': 'a group of people are standing on a road .',
#  '000000540464': 'a cat sitting on a bed with a laptop .',
#  '000000280158': 'a man in a blue shirt is riding a skateboard .',
#  '000000564926': 'a large dog is sitting on a bench .',
#  '000000171536': 'a woman is sitting on a table with a cake .',
#  '000000424665': 'a man in a red shirt is standing on a bench .',
#  '000000385485': 'a woman is sitting on a table with a dog .',
#  '000000512634': 'a plate of food with a plate of food .',
#  '000000156202': 'a woman is sitting on a table with a laptop .',
#  '000000293304': 'a large clock tower with a clock on it .',
#  '000000160137': 'a large clock tower with a clock on it .',
#  '000000115642': 'a cat sitting on a table with a laptop .',
#  '000000013844': 'a bathroom with a sink and a sink .',
#  '000000541082': 'a man is standing on a bench in front of a building .',
#  '000000401969': 'a large clock tower with a clock on it .',
#  '000000162285': 'a woman is sitting on a table with a dog .',
#  '000000081784': 'a man in a blue shirt is standing on a beach .',
#  '000000343503': 'a man is sitting on a bench with a red umbrella .',
#  '000000293233': 'a baseball player is standing on a field .',
#  '000000307020': 'a man is sitting on a bench in front of a building .',
#  '000000288650': 'a man in a blue shirt is standing on a bench .',
#  '000000414495': 'a man in a white shirt is standing on a skateboard .',
#  '000000182658': 'a man in a white shirt and white shirt is sitting on a bench .',
#  '000000144620': 'a man is standing on a bench with a frisbee .',
#  '000000498425': 'a man is sitting on a table with a laptop .',
#  '000000329133': 'a woman is sitting on a table with a laptop .',
#  '000000368040': 'a large airplane is sitting on the beach .',
#  '000000403535': 'a group of people standing in a field .',
#  '000000524651': 'a man is riding a skateboard on a skateboard .',
#  '000000388469': 'a white cat sitting on top of a table .',
#  '000000000368': 'a man in a blue shirt and white shirt is playing a game of frisbee .',
#  '000000478648': 'a cat sitting on a bed with a laptop .',
#  '000000211302': 'a white cat sitting on top of a table .',
#  '000000056699': 'a red fire hydrant is on a street .',
#  '000000532030': 'a man in a blue shirt is standing on a beach .',
# ...
#  '000000130011': 'a man is sitting on a bench with a dog .',
#  '000000035101': 'a red fire hydrant is on a street .',
#  '000000557314': 'a man is playing a game of tennis .',
#  '000000528903': 'a group of people standing in a field with a large building .',
#  '000000572001': 'a plate of food with a plate of food .',
#  '000000266486': 'a cat sitting on a bed with a toilet .',
#  '000000329797': 'a man in a white shirt is sitting on a bed .',
#  '000000144884': 'a woman is sitting on a bed with a white dog .',
#  '000000489695': 'a man in a blue shirt and white shirt is standing on a street .',
#  '000000346160': 'a bathroom with a toilet and a sink',
#  '000000324413': 'a man is standing on a bench next to a large building .',
#  '000000005757': 'a man is standing on a street with a red bus .',
#  '000000470114': 'a group of people standing on a road with a red fire hydrant .',
#  '000000463883': 'a cat sitting on top of a bed .',
#  '000000278287': 'a man is sitting on a bench in the middle of a city .',
#  '000000473042': 'a man in a blue shirt is playing a game of baseball .',
#  '000000209128': 'a baseball player is playing tennis on a field .',
#  '000000369140': 'a man in a blue shirt is riding a wave .',
#  '000000416622': 'a woman is sitting on a table with a dog .',
#  '000000014985': 'a man is standing next to a large building .',
#  '000000291321': 'a woman is sitting on a table with a laptop .',
#  '000000285018': 'a bathroom with a sink and a sink',
#  '000000248009': 'a man in a white shirt and white shirt is standing on a skateboard .',
#  '000000314788': 'a large train is on the beach with a large train .',
#  '000000213646': 'a giraffe is standing in the grass with a frisbee .',
#  '000000289621': 'a large clock tower with a clock on it .',
#  '000000032566': 'a man in a blue shirt is standing on a street .',
#  '000000419656': 'a man is sitting on a bench in front of a building .',
#  '000000567997': 'a man in a blue shirt is standing on a beach .',
#  '000000122586': 'a man in a blue shirt is riding a wave .',
#  '000000352041': 'a man is riding a skateboard on a skateboard .',
#  '000000230503': 'a man is riding a skateboard down a street .',
#  '000000285910': 'a woman is sitting on a table with a cake .',
#  '000000042818': 'a man is riding a wave on a beach .',
#  '000000259591': 'a man is sitting on a table with a laptop .',
#  '000000012103': 'a bathroom with a sink and a sink',
#  '000000254729': 'a man in a blue shirt is riding a wave .',
#  '000000373033': 'a man is riding a skateboard down a street .',
#  '000000392723': 'a small dog is standing in the middle of a tree .',
#  '000000063182': 'a group of people standing in a field with a green field .',
#  '000000088176': 'a man is standing on a street with a red sign .',
#  '000000031865': 'a cat sitting on a bed with a laptop .',
#  '000000105904': 'a man is sitting on a bench with a laptop .',
#  '000000038827': 'a small dog is sitting on a bench .',
#  '000000038722': 'a man in a white shirt and a black shirt is sitting on a table .',
#  '000000483530': 'a white cat sitting on top of a table .',
#  '000000373923': 'a man in a blue shirt is riding a skateboard .',
#  '000000230038': 'a man is sitting on a table with a laptop .',
#  '000000305267': 'a woman is sitting on a table with a laptop .',
#  '000000053232': 'a man is sitting on a bench in the background .',
#  '000000284144': 'a man is sitting on a bench in front of a building .',
#  '000000193594': 'a man in a blue shirt is standing next to a large building .',
#  '000000112882': 'a cat sitting on a bed with a laptop .',
#  '000000573184': 'a large plane is sitting on the beach .',
#  '000000128826': 'a man in a white shirt is sitting on a couch .',
#  '000000175946': 'a man in a white shirt and white shirt is sitting on a table .',
#  '000000233926': 'a man is standing next to a large dog .',
#  '000000295257': 'a baseball player is playing with a ball .',
#  '000000530888': 'a man is riding a skateboard on a skateboard .',
#  '000000058965': 'a man in a blue shirt is playing a game of baseball .',
#  '000000124836': 'a plate of food with a white plate of food .',
#  '000000236155': 'a woman is sitting on a bench in a room .',
#  '000000447557': 'a large clock tower with a clock on it .',
#  '000000041413': 'a man in a blue shirt is playing tennis .',
#  '000000281855': 'a man is riding a wave on a beach .',
#  '000000163192': 'a cat sitting on a table with a laptop .',
#  '000000032176': 'a man is standing on a bench in front of a building .',
#  '000000283382': 'a cat sitting on a bed with a laptop .',
#  '000000447726': 'a man is riding a skateboard down a street .',
#  '000000244349': 'a man is standing on a street with a large clock .',
#  '000000526680': 'a group of people are sitting on a bench .',
#  '000000289204': 'a man is standing on a bench in the water .',
#  '000000296696': 'a man in a blue shirt is riding a skateboard .',
#  '000000051530': 'a man in a blue shirt is standing on a bench .',
#  '000000056306': 'a man is sitting on a bench in a room .',
#  '000000546285': 'a man in a blue shirt is standing on a bench .',
#  '000000176192': 'a man is sitting on a table with a laptop .',
#  '000000244582': 'a white dog is sitting on a bed .',
#  '000000325287': 'a man in a white shirt and white shirt is sitting on a bench .',
#  '000000517430': 'a train is parked on a street with a train on it .',
#  '000000075557': 'a man is sitting on a bench in front of a building .',
#  '000000345590': 'a group of people standing in a field of water .',
#  '000000392315': 'a man in a blue shirt is riding a skateboard .',
#  '000000098155': 'a man in a white shirt and white shirt is standing in a room .',
#  '000000149572': 'a man in a red shirt is sitting on a bench .',
#  '000000453586': 'a man is standing on a beach with a kite .',
#  '000000018467': 'a plate of food with a white and a plate of food .',
#  '000000308838': 'a man riding a skateboard down a snow covered slope .',
#  '000000323964': 'a man in a blue shirt is holding a red umbrella .',
#  '000000550392': 'a man in a white shirt and white shirt is sitting on a bench .',
#  '000000060602': 'a man riding a skateboard down a street .',
#  '000000189153': 'a man is standing on a bench in the air .',
#  '000000034973': 'a bathroom with a sink and a sink',
#  '000000581302': 'a man is standing on a bench in the background .',
#  '000000146656': 'a group of people standing on a field .',
#  '000000124903': 'a man in a white shirt is standing in front of a building .',
#  '000000102445': 'a large clock tower with a clock on it .',
#  '000000125729': 'a group of people standing in a field with a kite .',
#  '000000331314': 'a cat sitting on top of a bed .',
#  '000000393394': 'a white cat sitting on a table with a white plate .',
#  '000000438932': 'a bathroom with a sink and a sink',
#  '000000371092': 'a man in a blue shirt and white shirt is sitting on a bench .',
#  '000000055033': 'a clock tower with a clock on it .',
#  '000000302141': 'a group of people standing on a beach .',
#  '000000002982': 'a man is standing on a bench with a skateboard .',
#  '000000469731': 'a man in a blue shirt is riding a skateboard .',
#  '000000166047': 'a man is standing on a beach with a kite .',
#  '000000390969': 'a man is sitting on a bench in front of a kitchen .',
#  '000000564443': 'a man in a blue shirt and white shirt is standing on a skateboard .',
#  '000000231500': 'a cat sitting on a table with a laptop .',
#  '000000568308': 'a group of people standing in a field .',
#  '000000081259': 'a group of people are standing on a street .',
#  '000000016520': 'a group of people standing in a field of grass .',
#  '000000242325': 'a man is standing in the grass with a frisbee .',
#  '000000140758': 'a man is standing on a bench in the background .',
#  '000000092910': 'a man is standing next to a large building .',
#  '000000347267': 'a woman is sitting on a table with a dog .',
#  '000000284722': 'a man in a white shirt is sitting on a bench .',
#  '000000570019': 'a plate of food with a plate of food .',
#  '000000141240': 'a man is sitting on a bench in front of a building .',
#  '000000050470': 'a man is playing tennis on a tennis court .',
#  '000000125683': 'a man in a white shirt is sitting on a bench .',
#  '000000079831': 'a plate of food with a plate of food .',
#  '000000253419': 'a man is riding a wave on a beach .',
#  '000000242029': 'a group of people are standing on a road .',
#  '000000074411': 'a man is standing on a bench in a field .',
#  '000000571563': 'a man in a blue shirt is riding a skateboard .',
#  '000000385672': 'a man in a white shirt is sitting on a bench .',
#  '000000286673': 'a woman is sitting on a table with a laptop .',
#  '000000462993': 'a bathroom with a sink and a sink',
#  '000000455549': 'a man in a white shirt is sitting on a couch .',
#  '000000486421': 'a group of people standing in a field with a large dog .',
#  '000000575274': 'a train is parked on the street with a train on it .',
#  '000000349566': 'a man in a white shirt and white shirt is standing in a bathroom .',
#  '000000365833': 'a man is standing on a beach with a kite .',
#  '000000048474': 'a group of people are sitting on a bench .',
#  '000000509267': 'a man in a blue shirt is standing on a bench .',
#  '000000241918': 'a man in a blue shirt is riding a skateboard .',
#  '000000319781': 'a man is standing on a bed with a dog .',
#  '000000046171': 'a large clock tower with a clock on it .',
#  '000000056193': 'a group of people are sitting on a bench .',
#  '000000326496': 'a man in a white shirt and white shirt is standing in front of a building .',
#  '000000351288': 'a man in a blue shirt is riding a skateboard .',
#  '000000352735': 'a red fire hydrant on a street with a red sign .',
#  '000000429908': 'a cat sitting on top of a table .',
#  '000000323462': 'a bathroom with a toilet and a sink',
#  '000000182295': 'a cat sitting on a table with a laptop .',
#  '000000179758': 'a man in a blue shirt is playing a game of baseball .',
#  '000000411445': 'a cat sitting on a bed with a toilet .',
#  '000000552579': 'a man in a blue shirt is standing on a bench .',
#  '000000402243': 'a bathroom with a sink and a sink',
#  '000000465414': 'a train is parked on the side of a road .',
#  '000000565387': 'a man in a blue shirt is riding a skateboard .',
#  '000000503318': 'a man in a white shirt and white shirt is standing in the middle of a grassy area .',
#  '000000241790': 'a man is standing on a beach with a kite .',
#  '000000365631': 'a man is standing on a bench with a skateboard .',
#  '000000559830': 'a man is standing on a bench with a kite .',
#  '000000269958': 'a man in a white shirt and white shirt is playing a game of frisbee .',
#  '000000383760': 'a man is riding a wave on a beach .',
#  '000000317896': 'a plate of food with a plate of food .',
#  '000000041962': 'a man is riding a skateboard on a beach .',
#  '000000030151': 'a man in a white shirt and white shirt is sitting on a bed .',
#  '000000028674': 'a man in a white shirt is holding a dog .',
#  '000000344765': 'a large clock tower with a clock on it .',
#  '000000208779': 'a woman is sitting on a table with a dog .',
#  '000000392105': 'a man is standing on a street with a red bus .',
#  '000000179687': 'a man in a white shirt is riding a skateboard .',
#  '000000532673': 'a man in a white shirt is standing in a field .',
#  '000000302364': 'a man in a white shirt and white shirt is standing in a field .',
#  '000000240449': 'a man is riding a skateboard on a skateboard .',
#  '000000516329': 'a man in a blue shirt and white shirt is standing on a skateboard .',
#  '000000064036': 'a man in a blue shirt is playing tennis .',
#  '000000165064': 'a man is standing in front of a large building .',
#  '000000083093': 'a man is standing next to a large dog .',
#  '000000225053': 'a man in a white shirt is standing in a field .',
#  '000000573483': 'a woman is sitting on a table with a dog .',
#  '000000072396': 'a large clock tower with a clock on it .',
#  '000000330916': 'a bathroom with a sink and a sink',
#  '000000401458': 'a man in a white shirt and white shirt is standing in front of a kitchen .',
#  '000000522464': 'a man in a white shirt is sitting on a bench .',
#  '000000322769': 'a bathroom with a sink and a sink',
#  '000000168349': 'a black and white dog sitting on a bench .',
#  '000000425470': 'a man in a white shirt and white shirt is sitting on a table .',
#  '000000382873': 'a baseball player is playing tennis .',
#  '000000091681': 'a group of people standing in front of a building .',
#  '000000003461': 'a man is standing on a bench in front of a building .',
#  '000000339031': 'a man in a blue shirt is riding a wave .',
#  '000000458629': 'a cat sitting on a bed with a white toilet .',
#  '000000534898': 'a man in a red shirt and white shirt is standing in front of a tree .',
#  '000000319121': 'a group of people standing in a field .',
#  '000000484418': 'a man is sitting on a bench next to a tree .',
#  '000000170662': 'a large train is on the beach with a kite .',
#  '000000051501': 'a man is sitting on a bench with a large umbrella .',
#  '000000458603': 'a man is standing in a field with a dog .',
#  '000000116633': 'a man is standing on a bench in the air .',
#  '000000166018': 'a cat sitting on a bed with a cat on it .',
#  '000000240889': 'a woman in a white shirt and white shirt is standing in a field .',
#  '000000094884': 'a man is standing next to a building .',
#  '000000018183': 'a bathroom with a sink and a sink',
#  '000000022198': 'a cat sitting on top of a bed .',
#  '000000435139': 'a group of people standing in a field .',
#  '000000484494': 'a large clock tower with a clock on it .',
#  '000000543042': 'a large white dog is sitting on a bench .',
#  '000000320429': 'a man in a blue shirt is riding a skateboard .',
#  '000000525823': 'a man in a white shirt and white shirt is standing in front of a large room .',
#  '000000578856': 'a man is flying a kite on a beach .',
#  '000000383605': 'a baseball player is playing baseball .',
#  '000000402095': 'a man in a white shirt and white shirt is sitting on a bench .',
#  '000000401528': 'a man in a white shirt and white shirt is standing in a room .',
#  '000000196379': 'a man is sitting on a bench in a room .',
#  '000000538444': 'a man in a white shirt and white shirt is sitting on a table .',
#  '000000542502': 'a man in a red shirt and white shirt is playing a game of tennis .',
#  '000000144734': 'a group of people standing on a street .',
#  '000000482751': 'a man is playing tennis on a tennis court .',
#  '000000158737': 'a dog is standing in the grass with a frisbee .',
#  '000000089253': 'a man in a white shirt is standing on a bench .',
#  '000000559908': 'a white plate with a white plate of food .',
#  '000000114229': 'a woman is sitting on a table with a laptop .',
#  '000000198426': 'a man in a red shirt is standing on a bench .',
#  '000000556473': 'a man is standing on a beach with a kite .',
#  '000000100140': 'a man is sitting on a bench in front of a building .',
#  '000000057979': 'a man is standing on a bench next to a skateboard .',
#  '000000217495': 'a woman in a white shirt and white shirt is sitting on a table .',
#  '000000422608': 'a man is standing on a bench with a horse .',
#  '000000341219': 'a man in a white shirt and white shirt is standing in front of a large white dog .',
#  '000000224541': 'a man is sitting on a bench with a dog .',
#  '000000310558': 'a man in a blue shirt and white shirt is sitting on a bench .',
#  '000000557344': 'a woman is sitting on a bench in a room .',
#  '000000045923': 'a man in a blue shirt is playing tennis .',
#  '000000457948': 'a man is standing on a bench in the background .',
#  '000000025516': 'a man in a blue shirt is riding a skateboard .',
#  '000000457726': 'a man is standing on a bench next to a building .',
#  '000000162087': 'a woman is sitting on a table with a laptop .',
#  '000000081357': 'a man in a blue shirt and white shirt is standing in front of a large white dog .',
#  '000000425772': 'a group of people are walking down a street .',
#  '000000477759': 'a man in a white shirt and white shirt is standing in front of a building .',
#  '000000216820': 'a plate of food with a plate of food .',
#  ...}

# %%
predict = test(testmodel, valid_loader)

# %%
print(len(predict))
# Out:
# 1789

# %%
with open("./p2/dict.json", "w") as f:
    json.dump(dict, f, indent=4)

with open("./p2/dict2.json", "w") as f:
    json.dump(dict2, f, indent=4)

# %%
for i in range(30):
    test = out.max(2, keepdim=True)[1][i]
    # print(out.max(2, keepdim=True)[1])
    test = test.cpu().numpy().squeeze().tolist()
    # print(test)
    test = test[:test.index(3)+1]
    print(tokenizer.decode(test))
# Out:
# table situated in corner of room with a vase for a center piece
# a black and white photo of a train driving .
# a woman is wearing a pink helmet and riding her bike through the city .
# a group of people driving a horse drawn carriage .
# a bunch of travel bags sit on a carpet floor
# a person with a tattoo holding a basketball
# a baby grabs for a bite of pizza that a man is eating .
# a full veggie pizza near a couple of plate of fries , are all ready to be eaten .
# a close up of a child eating food
# a small child is holding a stuffed bear
# a white toilet sitting in a bathroom next to a tub .
# a bird is standing on a shallow body of water .
# four ducks are in a grassy island of a parking lot with their heads down .
# a subway train pulling into the train station .
# a couple of people sitting inside of a car .
# three zebras and two other animals grazing .
# a group of men play a game of tennis together on a grass tennis court .
# two men standing in a store aisle with one holding a baseball bat .
# a man in a narrow kitchen area wiping a pan .
# a dirt bike rider doing a stunt jump in the air
# a multicolored airplane is flying in the air
# giraffe eating from a tree behind a rock .
# a red and blue bird that is sitting on a branch
# the blue and white hat has a bird on it
# a photo of a train with a person stand on the train .
# a train getting ready to go into a tunnel
# four cows drink from the water near each other .
# the back of the car is full of duffel bags and a pair of boots .
# a group of people on baseball field with trees in the background .
# a pot of soup is being prepared on the stove .
