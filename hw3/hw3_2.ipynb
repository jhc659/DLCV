# %%
import os
import glob
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import Dataset, DataLoader
import numpy as np
import clip
import json 
import time
import math

import random
import pandas as pd
from PIL import Image
import matplotlib.pyplot as plt
from tokenizers import Tokenizer
os.environ['TOKENIZERS_PARALLELISM'] = 'false'
# os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
# os.environ["CUDA_VISIBLE_DEVICES"] = "5"

# %%
x = torch.tensor([1, 2, 3, 4, 5, 6, 7, 8]).view(4, 2)
print(x)
print(torch.roll(x, -1))
# Out:
# tensor([[1, 2],
#         [3, 4],
#         [5, 6],
#         [7, 8]])
# tensor([[2, 3],
#         [4, 5],
#         [6, 7],
#         [8, 1]])

# %%
x = [1,2,3,4,5]
print(10 in x)
# Out:
# False

# %%
train_dir = "/data/dlcv/hw3/hw3_data/p2_data/images/train"
valid_dir = "/data/dlcv/hw3/hw3_data/p2_data/images/val"
train_json_dir = "/data/dlcv/hw3/hw3_data/p2_data/train.json"
val_json_dir = "/data/dlcv/hw3/hw3_data/p2_data/val.json"
ckpt_dir = "./p2"
tokenizer = Tokenizer.from_file("caption_tokenizer.json")
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# if device == "cuda":
torch.cuda.set_device(5)
print('Device used:', device)
# Out:
# Device used: cuda

# %%
class p2dataset(Dataset):
    def __init__(self, inputPath, json_dir, transform=None):
        self.inputPath = inputPath
        self.transform = transform
        self.inputName = sorted(os.listdir(inputPath))
        with open(json_dir, 'r') as j:
            caption_json = json.loads(j.read())
        self.caption_json = caption_json
        self.filecap = {}
        for dic in self.caption_json["images"]:
            self.filecap[dic['id']] = {"filename" : dic["file_name"], "captions": []}
        for dic in self.caption_json["annotations"]:
            self.filecap[dic['image_id']]['captions'].append(dic['caption'])
        self.files = [dic for dic in self.filecap.values()]
        
    def __getitem__(self, index):
        img = Image.open(os.path.join(self.inputPath, self.files[index]['filename']))
        if self.transform:
            img = self.transform(img)
        
        cap = self.files[index]['captions'][random.randint(0, len(self.files[index]['captions'])-1)]
        tokenized_caption = tokenizer.enable_padding(length=100)
        tokenized_caption = tokenizer.encode(cap)
        # [# of str, str len]
        return img, torch.Tensor(tokenized_caption.ids).long(), self.files[index]['filename'].replace(".jpg", "")

    def __len__(self):
        return len(self.inputName)

# %%
_, preprocess = clip.load("ViT-B/32", device)

# %%
preprocess
# Out:
# Compose(
#     Resize(size=224, interpolation=bicubic, max_size=None, antialias=None)
#     CenterCrop(size=(224, 224))
#     <function _convert_image_to_rgb at 0x7f59874690d0>
#     ToTensor()
#     Normalize(mean=(0.48145466, 0.4578275, 0.40821073), std=(0.26862954, 0.26130258, 0.27577711))
# )

# %%
train_dataset = p2dataset(train_dir, train_json_dir, transform=preprocess)
valid_dataset = p2dataset(valid_dir, val_json_dir, transform=preprocess)
print('# images in train:', len(train_dataset))
print('# images in valid:', len(valid_dataset))

train_loader = DataLoader(train_dataset, batch_size=72, shuffle=True, num_workers=4)
valid_loader = DataLoader(valid_dataset, batch_size=1, shuffle=False, num_workers=0)

dataiter = iter(valid_loader)
images, ids, filename = dataiter.next()
# print(images[0])
# print(ids)
# print(filename)
# def imshow(img):
#     npimg = img.numpy()
#     plt.imshow(np.transpose(npimg, (1, 2, 0)))
# # show images
# imshow(torchvision.utils.make_grid(images))
# Out:
# # images in train: 10604
# # images in valid: 1789

# %% [markdown]
# ### Model

# %%
class PositionwiseFeedforwardLayer(nn.Module):
    def __init__(self, hid_dim, pf_dim, dropout):
        super().__init__()
        
        self.fc_1 = nn.Linear(hid_dim, pf_dim)
        self.fc_2 = nn.Linear(pf_dim, hid_dim)
        
        self.dropout = nn.Dropout(dropout)
        
    def forward(self, x):
        
        #x = [batch size, seq len, hid dim]
        
        x = self.dropout(torch.relu(self.fc_1(x)))
        
        #x = [batch size, seq len, pf dim]
        
        x = self.fc_2(x)
        
        #x = [batch size, seq len, hid dim]
        
        return x
    
class MultiHeadAttentionLayer(nn.Module):
    def __init__(self, hid_dim, n_heads, dropout, device):
        super().__init__()
        
        assert hid_dim % n_heads == 0
        
        self.hid_dim = hid_dim
        self.n_heads = n_heads
        self.head_dim = hid_dim // n_heads
        
        self.fc_q = nn.Linear(hid_dim, hid_dim)
        self.fc_k = nn.Linear(hid_dim, hid_dim)
        self.fc_v = nn.Linear(hid_dim, hid_dim)
        
        self.fc_o = nn.Linear(hid_dim, hid_dim)
        
        self.dropout = nn.Dropout(dropout)
        
        self.scale = torch.sqrt(torch.FloatTensor([self.head_dim])).to(device)
        
    def forward(self, query, key, value, mask = None):
        
        batch_size = query.shape[0]
        # print("query = [batch size, query len, hid dim]:", query.shape)
        # print("key = [batch size, key len, hid dim]:", key.shape)
        # print("value = [batch size, value len, hid dim]", value.shape)
        #query = [batch size, query len, hid dim]
        #key = [batch size, key len, hid dim]
        #value = [batch size, value len, hid dim]
                
        Q = self.fc_q(query)
        K = self.fc_k(key)
        V = self.fc_v(value)
        # print("Q = [batch size, query len, hid dim]:", Q.shape)
        # print("K = [batch size, key len, hid dim]:", K.shape)
        # print("V = [batch size, value len, hid dim]", V.shape)
        #Q = [batch size, query len, hid dim]
        #K = [batch size, key len, hid dim]
        #V = [batch size, value len, hid dim]
                        
        Q = Q.view(batch_size, -1, self.n_heads, self.head_dim).permute(0, 2, 1, 3)
        K = K.view(batch_size, -1, self.n_heads, self.head_dim).permute(0, 2, 1, 3)
        V = V.view(batch_size, -1, self.n_heads, self.head_dim).permute(0, 2, 1, 3)
        # print("Q = [batch size, n heads, query len, head dim]:", Q.shape)
        # print("K = [batch size, n heads, key len, head dim]:", K.shape)
        # print("V = [batch size, n heads, value len, head dim]", V.shape)
        #Q = [batch size, n heads, query len, head dim]
        #K = [batch size, n heads, key len, head dim]
        #V = [batch size, n heads, value len, head dim]
                
        energy = torch.matmul(Q, K.permute(0, 1, 3, 2)) / self.scale
        # print("energy = [batch size, n heads, query len, key len]: ", energy.shape)
        #energy = [batch size, n heads, query len, key len]
        
        if mask is not None:
            energy = energy.masked_fill(mask == 0, -1e10)
        
        attention = torch.softmax(energy, dim = -1)
        # print("attention = [batch size, n heads, query len, key len]: ", attention.shape)      
        #attention = [batch size, n heads, query len, key len]
                
        x = torch.matmul(self.dropout(attention), V)
        # print("x = [batch size, n heads, query len, key len]: ", x.shape)
        #x = [batch size, n heads, query len, head dim]
        
        x = x.permute(0, 2, 1, 3).contiguous()
        # print("x = [batch size, n heads, query len, key len]: ", x.shape)    
        #x = [batch size, query len, n heads, head dim]
        
        x = x.view(batch_size, -1, self.hid_dim)
        # print("x = [batch size, n heads, query len, key len]: ", x.shape)            
        #x = [batch size, query len, hid dim]
        
        x = self.fc_o(x)
        # print("x = [batch size, n heads, query len, key len]: ", x.shape)                    
        #x = [batch size, query len, hid dim]
        
        return x, attention

class DecoderLayer(nn.Module):
    def __init__(self, 
                 hid_dim, 
                 n_heads, 
                 pf_dim, 
                 dropout, 
                 device):
        super().__init__()
        
        self.self_attn_layer_norm = nn.LayerNorm(hid_dim)
        self.enc_attn_layer_norm = nn.LayerNorm(hid_dim)
        self.ff_layer_norm = nn.LayerNorm(hid_dim)
        self.self_attention = MultiHeadAttentionLayer(hid_dim, n_heads, dropout, device)
        self.encoder_attention = MultiHeadAttentionLayer(hid_dim, n_heads, dropout, device)
        self.positionwise_feedforward = PositionwiseFeedforwardLayer(hid_dim, 
                                                                     pf_dim, 
                                                                     dropout)
        self.dropout = nn.Dropout(dropout)
        
    def forward(self, trg, enc_src, trg_mask, src_mask=None):
        
        #trg = [batch size, trg len, hid dim]
        #enc_src = [batch size, src len, hid dim]
        #trg_mask = [batch size, 1, trg len, trg len]
        #src_mask = [batch size, 1, 1, src len]
        
        #self attention
        # print("Start self attention.....")
        _trg, _ = self.self_attention(trg, trg, trg, trg_mask)
        
        #dropout, residual connection and layer norm
        trg = self.self_attn_layer_norm(trg + self.dropout(_trg))
        # print("trg = [batch size, trg len, hid dim]:", trg.shape)    
        #trg = [batch size, trg len, hid dim]
            
        #encoder attention
        # print("Start encoder attention.....")
        _trg, attention = self.encoder_attention(trg, enc_src, enc_src, src_mask)
        
        #dropout, residual connection and layer norm
        trg = self.enc_attn_layer_norm(trg + self.dropout(_trg))
        # print("trg = [batch size, trg len, hid dim]:", trg.shape)            
        #trg = [batch size, trg len, hid dim]
        
        #positionwise feedforward
        _trg = self.positionwise_feedforward(trg)
        
        #dropout, residual and layer norm
        trg = self.ff_layer_norm(trg + self.dropout(_trg))
        # print("trg = [batch size, trg len, hid dim]:", trg.shape)
        #trg = [batch size, trg len, hid dim]
        #attention = [batch size, n heads, trg len, src len]
        
        return trg, attention
    
class Decoder(nn.Module):
    def __init__(self, 
                 output_dim, 
                 hid_dim, 
                 n_layers, 
                 n_heads, 
                 pf_dim, 
                 dropout, 
                 device,
                 max_length = 100):
        super().__init__()
        
        self.device = device
        self._reset_parameters()

        self.tok_embedding = nn.Embedding(output_dim, hid_dim)
        self.pos_embedding = nn.Embedding(max_length, hid_dim)
        
        self.layers = nn.ModuleList([DecoderLayer(hid_dim, 
                                                  n_heads, 
                                                  pf_dim, 
                                                  dropout, 
                                                  device)
                                     for _ in range(n_layers)])
        
        self.fc_out = nn.Linear(hid_dim, output_dim)
        
        self.dropout = nn.Dropout(dropout)
        
        self.scale = torch.sqrt(torch.FloatTensor([hid_dim])).to(device)
        
    def forward(self, trg, enc_src, trg_mask, src_mask=None):
        
        #trg = [batch size, trg len]
        #enc_src = [batch size, src len, hid dim]
        #trg_mask = [batch size, 1, trg len, trg len]
        #src_mask = [batch size, 1, 1, src len]
                
        batch_size = trg.shape[0]
        trg_len = trg.shape[1]
        
        pos = torch.arange(0, trg_len).unsqueeze(0).repeat(batch_size, 1).to(self.device)
        # print("pos = [batch size, trg len]:", pos.shape)       
        #pos = [batch size, trg len]
            
        trg = self.dropout((self.tok_embedding(trg) * self.scale) + self.pos_embedding(pos))
        # print("trg = [batch size, trg len, hid dim]:", trg.shape)
        #trg = [batch size, trg len, hid dim]
        
        for layer in self.layers:
            trg, attention = layer(trg, enc_src, trg_mask, src_mask)
        
        # print("trg = [batch size, trg len, hid dim]: ", trg.shape)
        # print("attention = [batch size, n heads, trg len, src len]: ", attention.shape)
        #trg = [batch size, trg len, hid dim]
        #attention = [batch size, n heads, trg len, src len]
        
        output = self.fc_out(trg)
        # print("output = [batch size, trg len, output dim]:", output.shape)
        #output = [batch size, trg len, output dim]
            
        return output, attention
    
    def _reset_parameters(self):
        for p in self.parameters():
            if p.dim() > 1:
                nn.init.xavier_uniform_(p)
        
class Transformer(nn.Module):
    def __init__(self,  
                 decoder,  
                 trg_pad_idx, 
                 device):
        super().__init__()
        
        self.decoder = decoder
        self.trg_pad_idx = trg_pad_idx
        self.device = device
    
    def make_trg_mask(self, trg):
        
        #trg = [batch size, trg len]
        trg_pad_mask = (trg != self.trg_pad_idx).unsqueeze(1).unsqueeze(2)
        
        # print("trg_pad_mask = [batch size, 1, 1, trg len]:", trg_pad_mask.shape)
        #trg_pad_mask = [batch size, 1, 1, trg len]
        
        trg_len = trg.shape[1]
        
        trg_sub_mask = torch.tril(torch.ones((trg_len, trg_len))).bool().to(device)
        # print("trg_sub_mask = [trg len, trg len]: ",trg_sub_mask.shape)
        
        #trg_sub_mask = [trg len, trg len]
            
        trg_mask = trg_pad_mask & trg_sub_mask
        
        #trg_mask = [batch size, 1, trg len, trg len]
        
        # print("trg_mask = [batch size, 1, trg len, trg len]:", trg_mask.shape)

        return trg_mask

    def forward(self, enc_src, trg):
                
        trg_mask = self.make_trg_mask(trg)
        # print("trg_mask = [batch size, 1, trg len, trg len]:", trg_mask.shape)
        #src_mask = [batch size, 1, 1, src len]
        #trg_mask = [batch size, 1, trg len, trg len]
        
        # enc_src = self.encoder.encode_image(src).unsqueeze(1).float()
        # print("enc_src = [batch size, src len, hid dim]: ", enc_src.shape)
        #enc_src = [batch size, src len, hid dim]
                
        output, attention = self.decoder(trg, enc_src, trg_mask)
        
        # print("output = [batch size, trg len, output dim]:", output.shape)
        #output = [batch size, trg len, output dim]
        #attention = [batch size, n heads, trg len, src len]
        
        return output, attention

def initialize_weights(m):
    if hasattr(m, 'weight') and m.weight.dim() > 1:
        nn.init.xavier_uniform_(m.weight.data)

def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

def epoch_time(start_time, end_time):
    elapsed_time = end_time - start_time
    elapsed_mins = int(elapsed_time / 60)
    elapsed_secs = int(elapsed_time - (elapsed_mins * 60))
    return elapsed_mins, elapsed_secs

def train(model, enc, train_loader, optimizer, criterion, clip):
    
    model.train()
    enc = enc.to(device)

    epoch_loss = 0
    
    for img, trg, _ in train_loader:
                
        img, trg = img.to(device), trg.to(device)
        optimizer.zero_grad()
        for param in enc.parameters():
            param.requires_grad = False             
        # print("img: ", img.shape)
        # print("trg: ", trg[:,:-1].shape)
        # output, _ = model(img, trg[:,:-1])
        enc_src = enc.encode_image(img).unsqueeze(1).float()
        output, attention = model(enc_src, trg[:,:-1])
        # print("output = [batch size, trg len, output dim]:", output.shape)                
        # output = [batch size, trg len - 1, output dim]
        # trg = [batch size, trg len]
            
        output_dim = output.shape[-1]
            
        output = output.contiguous().view(-1, output_dim)
        # print("output", output.shape)
        trg = trg[:,1:].contiguous().view(-1)
        # print("trg", trg.shape)     
                        
        #output = [batch size * trg len - 1, output dim]
        #trg = [batch size * trg len - 1]
            
        loss = criterion(output, trg)
        # loss = get_loss(output, trg, 18022, 0.1, 0)
        # print(f'| Loss: {loss:.3f}')

        loss.backward()
        
        torch.nn.utils.clip_grad_norm_(model.parameters(), clip)
        
        optimizer.step()
        
        epoch_loss += loss.item()
        
    return epoch_loss / len(train_loader.dataset)

def evaluate(model, enc, valid_loader, criterion):
    
    model.eval()
    enc = enc.to(device)
    epoch_loss = 0
    
    with torch.no_grad():
    
        for img, trg, _ in valid_loader:
            img, trg = img.to(device), trg.to(device)
            for param in enc.parameters():
                param.requires_grad = False  
            enc_src = enc.encode_image(img).unsqueeze(1).float()
            output, _ = model(enc_src, trg[:,:-1])
            
            #output = [batch size, trg len - 1, output dim]
            #trg = [batch size, trg len]
            
            output_dim = output.shape[-1]
            
            output = output.contiguous().view(-1, output_dim)
            trg = trg[:,1:].contiguous().view(-1)
            
            #output = [batch size * trg len - 1, output dim]
            #trg = [batch size * trg len - 1]
            
            loss = criterion(output, trg)

            epoch_loss += loss.item()
        
    return epoch_loss / len(valid_loader.dataset)

# %%
OUTPUT_DIM = 18022
HID_DIM = 512
ENC_LAYERS = 3
DEC_LAYERS = 7
ENC_HEADS = 8
DEC_HEADS = 8
ENC_PF_DIM = 512
DEC_PF_DIM = 512
ENC_DROPOUT = 0.1
DEC_DROPOUT = 0.1
TRG_PAD_IDX = 0
LEARNING_RATE = 2e-5
PAD = 0
BOS = 2
EOS = 3

enc, _ = clip.load("ViT-B/32", device)

enc = enc.to(device).float()

for param in enc.parameters():
    param.requires_grad = False

dec = Decoder(OUTPUT_DIM, 
              HID_DIM, 
              DEC_LAYERS, 
              DEC_HEADS, 
              DEC_PF_DIM, 
              DEC_DROPOUT, 
              device)
model = Transformer(dec, TRG_PAD_IDX, device).to(device)
print(f'The model has {count_parameters(model):,} trainable parameters')
model = model.apply(initialize_weights)
optimizer = torch.optim.Adam(model.parameters(), lr = LEARNING_RATE)
criterion = nn.CrossEntropyLoss(ignore_index = TRG_PAD_IDX, label_smoothing=0.1)
# Out:
# The model has 36,931,174 trainable parameters

# %%
N_EPOCHS = 20
CLIP = 1

best_valid_loss = float('inf')

for epoch in range(N_EPOCHS):
    
    start_time = time.time()
    
    train_loss = train(model, enc, train_loader, optimizer, criterion, CLIP)
    valid_loss = evaluate(model, enc, valid_loader, criterion)
    
    end_time = time.time()
    
    epoch_mins, epoch_secs = epoch_time(start_time, end_time)
    
    if valid_loss < best_valid_loss:
        best_valid_loss = valid_loss
        torch.save(model.state_dict(), os.path.join(ckpt_dir, 'ViT-B_32declayer7.pt'))
    
    print(f'Epoch: {epoch+1:02} | Time: {epoch_mins}m {epoch_secs}s')
    print(f'\tTrain Loss: {train_loss:.3f} | Train PPL: {math.exp(train_loss):7.3f}')
    print(f'\t Val. Loss: {valid_loss:.3f} |  Val. PPL: {math.exp(valid_loss):7.3f}')
# Out:
# Epoch: 01 | Time: 2m 26s
# 	Train Loss: 0.118 | Train PPL:   1.125
# 	 Val. Loss: 7.426 |  Val. PPL: 1679.471
# Epoch: 02 | Time: 2m 11s
# 	Train Loss: 0.096 | Train PPL:   1.101
# 	 Val. Loss: 6.241 |  Val. PPL: 513.432
# Epoch: 03 | Time: 2m 24s
# 	Train Loss: 0.084 | Train PPL:   1.087
# 	 Val. Loss: 5.718 |  Val. PPL: 304.253
# Epoch: 04 | Time: 2m 30s
# 	Train Loss: 0.079 | Train PPL:   1.082
# 	 Val. Loss: 5.539 |  Val. PPL: 254.303
# Epoch: 05 | Time: 2m 52s
# 	Train Loss: 0.077 | Train PPL:   1.080
# 	 Val. Loss: 5.398 |  Val. PPL: 220.856
# Epoch: 06 | Time: 2m 50s
# 	Train Loss: 0.075 | Train PPL:   1.078
# 	 Val. Loss: 5.251 |  Val. PPL: 190.821
# Epoch: 07 | Time: 2m 32s
# 	Train Loss: 0.073 | Train PPL:   1.076
# 	 Val. Loss: 5.183 |  Val. PPL: 178.188
# Epoch: 08 | Time: 2m 51s
# 	Train Loss: 0.072 | Train PPL:   1.074
# 	 Val. Loss: 5.018 |  Val. PPL: 151.180
# Epoch: 09 | Time: 2m 57s
# 	Train Loss: 0.070 | Train PPL:   1.073
# 	 Val. Loss: 4.966 |  Val. PPL: 143.400
# Epoch: 10 | Time: 2m 57s
# 	Train Loss: 0.069 | Train PPL:   1.071
# 	 Val. Loss: 4.875 |  Val. PPL: 130.911
# Epoch: 11 | Time: 3m 4s
# 	Train Loss: 0.068 | Train PPL:   1.070
# 	 Val. Loss: 4.823 |  Val. PPL: 124.334
# Epoch: 12 | Time: 3m 3s
# 	Train Loss: 0.067 | Train PPL:   1.069
# 	 Val. Loss: 4.763 |  Val. PPL: 117.128
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /data/jhccc/dlcv/hw3-jhc659/hw3_2.ipynb Cell 9 in <cell line: 6>()
#       <a href='vscode-notebook-cell://ssh-remote%2B140.112.29.93/data/jhccc/dlcv/hw3-jhc659/hw3_2.ipynb#X13sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a> for epoch in range(N_EPOCHS):
#       <a href='vscode-notebook-cell://ssh-remote%2B140.112.29.93/data/jhccc/dlcv/hw3-jhc659/hw3_2.ipynb#X13sdnNjb2RlLXJlbW90ZQ%3D%3D?line=7'>8</a>     start_time = time.time()
# ---> <a href='vscode-notebook-cell://ssh-remote%2B140.112.29.93/data/jhccc/dlcv/hw3-jhc659/hw3_2.ipynb#X13sdnNjb2RlLXJlbW90ZQ%3D%3D?line=9'>10</a>     train_loss = train(model, enc, train_loader, optimizer, criterion, CLIP)
#      <a href='vscode-notebook-cell://ssh-remote%2B140.112.29.93/data/jhccc/dlcv/hw3-jhc659/hw3_2.ipynb#X13sdnNjb2RlLXJlbW90ZQ%3D%3D?line=10'>11</a>     valid_loss = evaluate(model, enc, valid_loader, criterion)
#      <a href='vscode-notebook-cell://ssh-remote%2B140.112.29.93/data/jhccc/dlcv/hw3-jhc659/hw3_2.ipynb#X13sdnNjb2RlLXJlbW90ZQ%3D%3D?line=12'>13</a>     end_time = time.time()
#
# /data/jhccc/dlcv/hw3-jhc659/hw3_2.ipynb Cell 9 in train(model, enc, train_loader, optimizer, criterion, clip)
#     <a href='vscode-notebook-cell://ssh-remote%2B140.112.29.93/data/jhccc/dlcv/hw3-jhc659/hw3_2.ipynb#X13sdnNjb2RlLXJlbW90ZQ%3D%3D?line=321'>322</a>     loss.backward()
#     <a href='vscode-notebook-cell://ssh-remote%2B140.112.29.93/data/jhccc/dlcv/hw3-jhc659/hw3_2.ipynb#X13sdnNjb2RlLXJlbW90ZQ%3D%3D?line=323'>324</a>     torch.nn.utils.clip_grad_norm_(model.parameters(), clip)
# --> <a href='vscode-notebook-cell://ssh-remote%2B140.112.29.93/data/jhccc/dlcv/hw3-jhc659/hw3_2.ipynb#X13sdnNjb2RlLXJlbW90ZQ%3D%3D?line=325'>326</a>     optimizer.step()
#     <a href='vscode-notebook-cell://ssh-remote%2B140.112.29.93/data/jhccc/dlcv/hw3-jhc659/hw3_2.ipynb#X13sdnNjb2RlLXJlbW90ZQ%3D%3D?line=327'>328</a>     epoch_loss += loss.item()
#     <a href='vscode-notebook-cell://ssh-remote%2B140.112.29.93/data/jhccc/dlcv/hw3-jhc659/hw3_2.ipynb#X13sdnNjb2RlLXJlbW90ZQ%3D%3D?line=329'>330</a> return epoch_loss / len(train_loader.dataset)
#
# File ~/anaconda3/envs/dlcv/lib/python3.8/site-packages/torch/optim/optimizer.py:113, in Optimizer._hook_for_profile.<locals>.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     111 profile_name = "Optimizer.step#{}.step".format(obj.__class__.__name__)
#     112 with torch.autograd.profiler.record_function(profile_name):
# --> 113     return func(*args, **kwargs)
#
# File ~/anaconda3/envs/dlcv/lib/python3.8/site-packages/torch/autograd/grad_mode.py:27, in _DecoratorContextManager.__call__.<locals>.decorate_context(*args, **kwargs)
#      24 @functools.wraps(func)
#      25 def decorate_context(*args, **kwargs):
#      26     with self.clone():
# ---> 27         return func(*args, **kwargs)
#
# File ~/anaconda3/envs/dlcv/lib/python3.8/site-packages/torch/optim/adam.py:157, in Adam.step(self, closure)
#     153                 max_exp_avg_sqs.append(state['max_exp_avg_sq'])
#     155             state_steps.append(state['step'])
# --> 157     adam(params_with_grad,
#     158          grads,
#     159          exp_avgs,
#     160          exp_avg_sqs,
#     161          max_exp_avg_sqs,
#     162          state_steps,
#     163          amsgrad=group['amsgrad'],
#     164          beta1=beta1,
#     165          beta2=beta2,
#     166          lr=group['lr'],
#     167          weight_decay=group['weight_decay'],
#     168          eps=group['eps'],
#     169          maximize=group['maximize'],
#     170          foreach=group['foreach'],
#     171          capturable=group['capturable'])
#     173 return loss
#
# File ~/anaconda3/envs/dlcv/lib/python3.8/site-packages/torch/optim/adam.py:213, in adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, foreach, capturable, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize)
#     210 else:
#     211     func = _single_tensor_adam
# --> 213 func(params,
#     214      grads,
#     215      exp_avgs,
#     216      exp_avg_sqs,
#     217      max_exp_avg_sqs,
#     218      state_steps,
#     219      amsgrad=amsgrad,
#     220      beta1=beta1,
#     221      beta2=beta2,
#     222      lr=lr,
#     223      weight_decay=weight_decay,
#     224      eps=eps,
#     225      maximize=maximize,
#     226      capturable=capturable)
#
# File ~/anaconda3/envs/dlcv/lib/python3.8/site-packages/torch/optim/adam.py:256, in _single_tensor_adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize, capturable)
#     253     assert param.is_cuda and step_t.is_cuda, "If capturable=True, params and state_steps must be CUDA tensors."
#     255 # update step
# --> 256 step_t += 1
#     258 if weight_decay != 0:
#     259     grad = grad.add(param, alpha=weight_decay)
#
# KeyboardInterrupt:

# %%
def test(testmodel, valid_loader):
    predict = {}
    testmodel.eval()
        
    with torch.no_grad():
        
        for i, (img, trg, filename) in enumerate(valid_loader):
            img, trg = img.to(device), trg.to(device)
            out, _ = testmodel(img, trg)
            text = out.argmax(2, keepdim=False)
            text = text.cpu().numpy().squeeze().tolist()
            text = tokenizer.decode(text)
            # text = tokenizer.decode(text[:text.index(3)+1])
            
            predict[filename[0]] = text
        
    return predict


def generate_square_subsequent_mask(sz: int, device='cpu') -> torch.Tensor:
    return torch.triu(torch.full((sz, sz), float('-inf'), device=device), diagonal=1)

def inference(testmodel, valid_loader):
    pred = {}
    BOS = 2
    EOS = 3
    max_len = 77
    testmodel.eval()
    
    for i, (img, _, filename) in enumerate(valid_loader):
        img = img.to(device)
        batch_size = img.shape[0]
        
        trg_indexes = torch.zeros((batch_size, max_len), dtype=torch.int32)
        trg_indexes[:, 0] = BOS
        # print(trg_indexes)
        trg_indexes = trg_indexes.to(device)
        
        with torch.no_grad():
            # enc_src = testmodel.encoder.encode_image(img).unsqueeze(1).float()
                   
            for index in range(1, max_len):
                
                out, attention = testmodel(img, trg_indexes)
                pred_token = out.argmax(2)
                trg_indexes[:,index] = pred_token[:,index]
                # print(pred_token[:,index])
                if pred_token[:,index] == EOS:
                    break
                # print(trg_indexes)
            trg_indexes = trg_indexes.cpu().numpy().squeeze().tolist()
        caption = tokenizer.decode(trg_indexes)
        # print(caption)
        pred[filename[0]] = caption
    return pred    

def inference2(testmodel, valid_loader):
    dict = {}
    testmodel.eval()
    max_len = 77
    with torch.no_grad():
        for img, _, filename in valid_loader:
            img = img.to(device)
            
            trg_indexes = [BOS]
            # with torch.no_grad():
            #     enc_src = testmodel.encoder.encode_image(img).unsqueeze(1).float()
                
            for i in range(max_len):
                trg_tensor = torch.LongTensor(trg_indexes).unsqueeze(0).to(device)
                # trg_mask = generate_square_subsequent_mask(trg_tensor.shape[1], device)
                # trg_mask = testmodel.make_trg_mask(trg_tensor)
                # out, attention = testmodel.decoder(trg_tensor, enc_src, trg_mask)
                out, attention = testmodel(img, trg_tensor)
                
                # print(out.argmax(2).shape)
                pred_token = out.argmax(2)[:,i].item()
                # print(out.argmax(2))
                trg_indexes.append(pred_token)
                # print(trg_indexes)
                if(pred_token == EOS):
                    break
            caption = tokenizer.decode(trg_indexes)
            # print(caption)
            dict[filename[0]] = caption
    return dict

def inference3(testmodel, valid_loader):
    pred = {}
    BOS = 2
    EOS = 3
    max_len = 77
    testmodel.eval()
    
    for i, (img, _, filename) in enumerate(valid_loader):
        img = img.to(device)
        batch_size = img.shape[0]
        
        trg_indexes = torch.zeros((batch_size, max_len), dtype=torch.int32)
        trg_indexes[:, 0] = BOS
        # print(trg_indexes)
        trg_indexes = trg_indexes.to(device)
        
        with torch.no_grad():
            enc_src = testmodel.encoder.encode_image(img).unsqueeze(1).float()
                   
            for index in range(1, max_len):
                
                out, attention = testmodel.decoder(img, trg_indexes)
                pred_token = out.argmax(2)
                trg_indexes[:,index] = pred_token[:,index]
                # print(pred_token[:,index])
                if pred_token[:,index] == EOS:
                    break
                # print(trg_indexes)
            trg_indexes = trg_indexes.cpu().numpy().squeeze().tolist()
        caption = tokenizer.decode(trg_indexes)
        # print(caption)
        pred[filename[0]] = caption
    return pred

# %%
# load model
enc, _ = clip.load("ViT-B/32", device)

enc = enc.to(device).float()

dec = Decoder(OUTPUT_DIM, 
              HID_DIM, 
              DEC_LAYERS, 
              DEC_HEADS, 
              DEC_PF_DIM, 
              DEC_DROPOUT, 
              device)
testmodel = Transformer(dec, TRG_PAD_IDX, device)
print(f'The model has {count_parameters(testmodel):,} trainable parameters')
model = model.apply(initialize_weights)
optimizer = torch.optim.Ainitialize_weightsdam(testmodel.parameters(), lr = LEARNING_RATE)
criterion = nn.CrossEntropyLoss(ignore_index = TRG_PAD_IDX)
testmodel.load_state_dict(torch.load(os.path.join(ckpt_dir, 'ViT-B_32declayer7.pt')))
# Out:
# The model has 36,931,174 trainable parameters
# <All keys matched successfully>

# %%
pred = inference(testmodel, valid_loader)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /data/jhccc/dlcv/hw3-jhc659/hw3_2.ipynb Cell 12 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://ssh-remote%2B140.112.29.93/data/jhccc/dlcv/hw3-jhc659/hw3_2.ipynb#X16sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> pred = inference(testmodel, valid_loader)
#
# /data/jhccc/dlcv/hw3-jhc659/hw3_2.ipynb Cell 12 in inference(testmodel, valid_loader)
#      <a href='vscode-notebook-cell://ssh-remote%2B140.112.29.93/data/jhccc/dlcv/hw3-jhc659/hw3_2.ipynb#X16sdnNjb2RlLXJlbW90ZQ%3D%3D?line=38'>39</a> with torch.no_grad():
#      <a href='vscode-notebook-cell://ssh-remote%2B140.112.29.93/data/jhccc/dlcv/hw3-jhc659/hw3_2.ipynb#X16sdnNjb2RlLXJlbW90ZQ%3D%3D?line=39'>40</a>     # enc_src = testmodel.encoder.encode_image(img).unsqueeze(1).float()
#      <a href='vscode-notebook-cell://ssh-remote%2B140.112.29.93/data/jhccc/dlcv/hw3-jhc659/hw3_2.ipynb#X16sdnNjb2RlLXJlbW90ZQ%3D%3D?line=41'>42</a>     for index in range(1, max_len):
# ---> <a href='vscode-notebook-cell://ssh-remote%2B140.112.29.93/data/jhccc/dlcv/hw3-jhc659/hw3_2.ipynb#X16sdnNjb2RlLXJlbW90ZQ%3D%3D?line=43'>44</a>         out, attention = testmodel(img, trg_indexes)
#      <a href='vscode-notebook-cell://ssh-remote%2B140.112.29.93/data/jhccc/dlcv/hw3-jhc659/hw3_2.ipynb#X16sdnNjb2RlLXJlbW90ZQ%3D%3D?line=44'>45</a>         pred_token = out.argmax(2)
#      <a href='vscode-notebook-cell://ssh-remote%2B140.112.29.93/data/jhccc/dlcv/hw3-jhc659/hw3_2.ipynb#X16sdnNjb2RlLXJlbW90ZQ%3D%3D?line=45'>46</a>         trg_indexes[:,index] = pred_token[:,index]
#
# File ~/anaconda3/envs/dlcv/lib/python3.8/site-packages/torch/nn/modules/module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# /data/jhccc/dlcv/hw3-jhc659/hw3_2.ipynb Cell 12 in Transformer.forward(self, enc_src, trg)
#     <a href='vscode-notebook-cell://ssh-remote%2B140.112.29.93/data/jhccc/dlcv/hw3-jhc659/hw3_2.ipynb#X16sdnNjb2RlLXJlbW90ZQ%3D%3D?line=255'>256</a> trg_mask = self.make_trg_mask(trg)
#     <a href='vscode-notebook-cell://ssh-remote%2B140.112.29.93/data/jhccc/dlcv/hw3-jhc659/hw3_2.ipynb#X16sdnNjb2RlLXJlbW90ZQ%3D%3D?line=256'>257</a> # print("trg_mask = [batch size, 1, trg len, trg len]:", trg_mask.shape)
#     <a href='vscode-notebook-cell://ssh-remote%2B140.112.29.93/data/jhccc/dlcv/hw3-jhc659/hw3_2.ipynb#X16sdnNjb2RlLXJlbW90ZQ%3D%3D?line=257'>258</a> #src_mask = [batch size, 1, 1, src len]
#     <a href='vscode-notebook-cell://ssh-remote%2B140.112.29.93/data/jhccc/dlcv/hw3-jhc659/hw3_2.ipynb#X16sdnNjb2RlLXJlbW90ZQ%3D%3D?line=258'>259</a> #trg_mask = [batch size, 1, trg len, trg len]
#    (...)
#     <a href='vscode-notebook-cell://ssh-remote%2B140.112.29.93/data/jhccc/dlcv/hw3-jhc659/hw3_2.ipynb#X16sdnNjb2RlLXJlbW90ZQ%3D%3D?line=261'>262</a> # print("enc_src = [batch size, src len, hid dim]: ", enc_src.shape)
#     <a href='vscode-notebook-cell://ssh-remote%2B140.112.29.93/data/jhccc/dlcv/hw3-jhc659/hw3_2.ipynb#X16sdnNjb2RlLXJlbW90ZQ%3D%3D?line=262'>263</a> #enc_src = [batch size, src len, hid dim]
# --> <a href='vscode-notebook-cell://ssh-remote%2B140.112.29.93/data/jhccc/dlcv/hw3-jhc659/hw3_2.ipynb#X16sdnNjb2RlLXJlbW90ZQ%3D%3D?line=264'>265</a> output, attention = self.decoder(trg, enc_src, trg_mask)
#     <a href='vscode-notebook-cell://ssh-remote%2B140.112.29.93/data/jhccc/dlcv/hw3-jhc659/hw3_2.ipynb#X16sdnNjb2RlLXJlbW90ZQ%3D%3D?line=266'>267</a> # print("output = [batch size, trg len, output dim]:", output.shape)
#     <a href='vscode-notebook-cell://ssh-remote%2B140.112.29.93/data/jhccc/dlcv/hw3-jhc659/hw3_2.ipynb#X16sdnNjb2RlLXJlbW90ZQ%3D%3D?line=267'>268</a> #output = [batch size, trg len, output dim]
#     <a href='vscode-notebook-cell://ssh-remote%2B140.112.29.93/data/jhccc/dlcv/hw3-jhc659/hw3_2.ipynb#X16sdnNjb2RlLXJlbW90ZQ%3D%3D?line=268'>269</a> #attention = [batch size, n heads, trg len, src len]
#     <a href='vscode-notebook-cell://ssh-remote%2B140.112.29.93/data/jhccc/dlcv/hw3-jhc659/hw3_2.ipynb#X16sdnNjb2RlLXJlbW90ZQ%3D%3D?line=270'>271</a> return output, attention
#
# File ~/anaconda3/envs/dlcv/lib/python3.8/site-packages/torch/nn/modules/module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# /data/jhccc/dlcv/hw3-jhc659/hw3_2.ipynb Cell 12 in Decoder.forward(self, trg, enc_src, trg_mask, src_mask)
#     <a href='vscode-notebook-cell://ssh-remote%2B140.112.29.93/data/jhccc/dlcv/hw3-jhc659/hw3_2.ipynb#X16sdnNjb2RlLXJlbW90ZQ%3D%3D?line=197'>198</a> pos = torch.arange(0, trg_len).unsqueeze(0).repeat(batch_size, 1).to(self.device)
#     <a href='vscode-notebook-cell://ssh-remote%2B140.112.29.93/data/jhccc/dlcv/hw3-jhc659/hw3_2.ipynb#X16sdnNjb2RlLXJlbW90ZQ%3D%3D?line=198'>199</a> # print("pos = [batch size, trg len]:", pos.shape)
#     <a href='vscode-notebook-cell://ssh-remote%2B140.112.29.93/data/jhccc/dlcv/hw3-jhc659/hw3_2.ipynb#X16sdnNjb2RlLXJlbW90ZQ%3D%3D?line=199'>200</a> #pos = [batch size, trg len]
# --> <a href='vscode-notebook-cell://ssh-remote%2B140.112.29.93/data/jhccc/dlcv/hw3-jhc659/hw3_2.ipynb#X16sdnNjb2RlLXJlbW90ZQ%3D%3D?line=201'>202</a> trg = self.dropout((self.tok_embedding(trg) * self.scale) + self.pos_embedding(pos))
#     <a href='vscode-notebook-cell://ssh-remote%2B140.112.29.93/data/jhccc/dlcv/hw3-jhc659/hw3_2.ipynb#X16sdnNjb2RlLXJlbW90ZQ%3D%3D?line=202'>203</a> # print("trg = [batch size, trg len, hid dim]:", trg.shape)
#     <a href='vscode-notebook-cell://ssh-remote%2B140.112.29.93/data/jhccc/dlcv/hw3-jhc659/hw3_2.ipynb#X16sdnNjb2RlLXJlbW90ZQ%3D%3D?line=203'>204</a> #trg = [batch size, trg len, hid dim]
#     <a href='vscode-notebook-cell://ssh-remote%2B140.112.29.93/data/jhccc/dlcv/hw3-jhc659/hw3_2.ipynb#X16sdnNjb2RlLXJlbW90ZQ%3D%3D?line=205'>206</a> for layer in self.layers:
#
# File ~/anaconda3/envs/dlcv/lib/python3.8/site-packages/torch/nn/modules/module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/anaconda3/envs/dlcv/lib/python3.8/site-packages/torch/nn/modules/sparse.py:158, in Embedding.forward(self, input)
#     157 def forward(self, input: Tensor) -> Tensor:
# --> 158     return F.embedding(
#     159         input, self.weight, self.padding_idx, self.max_norm,
#     160         self.norm_type, self.scale_grad_by_freq, self.sparse)
#
# File ~/anaconda3/envs/dlcv/lib/python3.8/site-packages/torch/nn/functional.py:2199, in embedding(input, weight, padding_idx, max_norm, norm_type, scale_grad_by_freq, sparse)
#    2193     # Note [embedding_renorm set_grad_enabled]
#    2194     # XXX: equivalent to
#    2195     # with torch.no_grad():
#    2196     #   torch.embedding_renorm_
#    2197     # remove once script supports set_grad_enabled
#    2198     _no_grad_embedding_renorm_(weight, input, max_norm, norm_type)
# -> 2199 return torch.embedding(weight, input, padding_idx, scale_grad_by_freq, sparse)
#
# RuntimeError: Expected all tensors to be on the same device, but found at least two devices, cpu and cuda:5! (when checking argument for argument index in method wrapper__index_select)

# %%
pred

# %%
with open("./p2/pred.json", "w") as f:
    json.dump(pred, f, indent=4)

# %%
dict2 = inference2(testmodel, valid_loader)

# %%
dict2
# Out:
# {'000000165547': 'a kitchen with a sink and a sink .',
#  '000000518586': 'a group of elephants are standing in the grass .',
#  '000000249720': 'a person riding a skateboard down a street .',
#  '000000122934': 'a man is riding a skateboard on the street .',
#  '000000393258': 'a woman in a white shirt is sitting on a table .',
#  '000000266041': 'a man in a black shirt and a black shirt is holding a cell phone .',
#  '000000053015': 'a group of people sitting on a table with a table .',
#  '000000039540': 'a woman is sitting on a table with a table .',
#  '000000320039': 'a man in a white shirt and a white shirt is standing in a table .',
#  '000000014941': 'a man is sitting on a bench with a red shirt .',
#  '000000304355': 'a cat is sitting on a bed with a laptop .',
#  '000000096514': 'a group of people sitting on a bench .',
#  '000000578703': 'a group of people standing on a beach .',
#  '000000350966': 'a train is parked on the side of a road .',
#  '000000201220': 'a woman standing next to a small small small child .',
#  '000000309100': 'a group of zebras standing in a field .',
#  '000000298726': 'a group of people playing frisbee on a field .',
#  '000000214742': 'a man in a blue shirt and white shirt is standing on a street .',
#  '000000135356': 'a man in a black shirt is standing in front of a building .',
#  '000000279806': 'a man in a white shirt is riding a snowboard .',
#  '000000163361': 'a group of people flying in the air .',
#  '000000135978': 'a group of people standing on a bench .',
#  '000000163460': 'a man in a black shirt is standing on a skateboard .',
#  '000000434129': 'a man is sitting on the street with a blue umbrella .',
#  '000000575428': 'a group of zebras standing in a field .',
#  '000000046912': 'a large large bus is parked on the street .',
#  '000000377326': 'a man in a blue shirt and white shirt is riding a surfboard .',
#  '000000302219': 'a woman is sitting on a bed with a white dog .',
#  '000000300655': 'a group of people are standing on a road .',
#  '000000178748': 'a table with a laptop and a laptop .',
#  '000000519299': 'a man in a red shirt is standing on the beach .',
#  '000000216303': 'a man in a blue shirt and white shirt is playing a game of tennis .',
#  '000000038892': 'a woman sitting on a table with a white hat .',
#  '000000487151': 'a group of people standing in a field of grass .',
#  '000000461883': 'a baseball player is standing on a field .',
#  '000000470313': 'a kitchen with a white sink and white sink',
#  '000000137490': 'a person riding a skateboard down a snowy slope .',
#  '000000491965': 'a group of people are sitting on a street .',
#  '000000056400': 'a man in a red shirt is holding a cell phone .',
#  '000000042055': 'a man is standing in front of a large large large large large large large large large large large large large large large large large large large large large large large large large large large large large large large building .',
#  '000000164594': 'a group of people standing in a field of grass .',
#  '000000303215': 'a woman is sitting in front of a large large large large large large large large large large large large large large large large large large large large large large large large large large large large large large large large large large large large large large large large large large large large large large large large large large large large large large large large large large large large large large group of white bear .',
#  '000000481891': 'a red dog sitting on a bench with a red umbrella .',
#  '000000301755': 'a man in a black shirt is standing on a bench .',
#  '000000047940': 'a cat is sitting on the side of a bench .',
#  '000000192233': 'a man in a red shirt is standing on a sidewalk .',
#  '000000417590': 'a group of people standing on a field .',
#  '000000164899': 'a group of people standing in front of a large large large large large large large large large large building .',
#  '000000368505': 'a large large large clock on a street .',
#  '000000513778': 'a large large large large airplane flying through the water .',
#  '000000352476': 'a group of people are parked on a street .',
#  '000000259879': 'a group of people standing on a bench .',
#  '000000178361': 'a man in a black shirt and white shirt is sitting on a bed .',
#  '000000020972': 'a cat sitting on the floor of a white toilet .',
#  '000000367881': 'a man in a black shirt is standing on a bench .',
#  '000000451305': 'a group of people standing on a bench .',
#  '000000485294': 'a white room with a white sink and a white sink .',
#  '000000177990': 'a woman in a red shirt is standing in a field .',
#  '000000540159': 'a large large white kitchen with a white laptop .',
#  '000000096539': 'a cat sitting on top of a bed .',
#  '000000147904': 'a group of people standing in the water with a blue sky .',
#  '000000546642': 'a group of people sitting on a bench .',
#  '000000307989': 'a group of people sitting on a table with a table .',
#  '000000267840': 'a large building with a red and white fire hydrant .',
#  '000000405675': 'a man in a blue shirt is standing on a bench .',
#  '000000378823': 'a group of people standing in a bench .',
#  '000000394322': 'a man in a black shirt and white shirt is standing on a street with a large horse .',
#  '000000411043': 'a large large large large large large elephant with a green umbrella .',
#  '000000137573': 'a large large large large large large truck is sitting on the side of a road .',
#  '000000301155': 'a woman in a blue shirt is holding a blue shirt .',
#  '000000333156': 'a large red fire hydrant sitting on a bench .',
#  '000000241068': 'a group of people standing on a beach .',
#  '000000285734': 'a man in a red shirt is playing a ball .',
#  '000000408143': 'a man in a black shirt and white shirt is sitting on a bench .',
#  '000000491872': 'a person is sitting on a bench in the background .',
#  '000000084123': 'a large large large large large large elephant on a road .',
#  '000000102996': 'a white bear sitting on a bench .',
#  '000000251044': 'a woman sitting on a table with a white dog and a white dog .',
#  '000000201859': 'a group of people sitting on a bench .',
#  '000000579326': 'a group of people standing in front of a field .',
#  '000000370038': 'two people are sitting on a table with a large orange umbrella .',
#  '000000548729': 'a group of people standing in front of a large horse .',
#  '000000140197': 'a group of people standing in front of a building .',
#  '000000353836': 'a woman in a red shirt is sitting on a table .',
#  '000000491681': 'a person is flying a kite on the beach .',
#  '000000289941': 'a woman in a white shirt is sitting in a kitchen .',
#  '000000540834': 'a man is sitting on the street with a man in the background .',
#  '000000318825': 'a man is standing on a beach with a kite .',
#  '000000226874': 'a white plate with a white and white dog on it .',
#  '000000118432': 'two people are standing in the grass with a large horse .',
#  '000000146640': 'a red fire hydrant sitting on a table .',
#  '000000113757': 'a man in a black shirt is sitting on a table with a laptop and a laptop .',
#  '000000346702': 'a cat sitting on top of a bed .',
#  '000000296871': 'a man is standing on the street with a large yellow umbrella .',
#  '000000136572': 'a man sitting on top of a bench .',
#  '000000238602': 'a woman is sitting on a bed with a white hat .',
#  '000000460972': 'a group of people standing in the grass .',
#  '000000210766': 'a red and white red fire hydrant in front of a red wall .',
#  '000000006789': 'a train is parked on the side of a road .',
#  '000000502275': 'a white cat sitting on a table with a white bowl .',
#  '000000370399': 'a man in a blue shirt is standing on a bench .',
#  '000000437618': 'a group of elephants standing next to a tree .',
#  '000000099389': 'a group of people sitting on a table with a table .',
#  '000000536294': 'a man in a blue shirt is riding a wave .',
#  '000000106096': 'a man in a white shirt is standing in a large bathroom .',
#  '000000032960': 'a group of people standing in front of a large large large large large large large white lot of people .',
#  '000000206587': 'a group of sheep standing in a field .',
#  '000000102466': 'a large large plane is parked on the side of the side of the side of the side of the road .',
#  '000000397903': 'a man riding a skateboard down the street .',
#  '000000074001': 'a man is standing on the street with a motorcycle .',
#  '000000213023': 'a black and white fire hydrant on a street .',
#  '000000082740': 'two men are walking down a street with a horse .',
#  '000000553852': 'a man riding a skateboard on a bench .',
#  '000000557396': 'a group of people standing in front of a city street .',
#  '000000397658': 'a group of people standing on a street .',
#  '000000315474': 'a large large large large large large elephant .',
#  '000000049667': 'a small bathroom with a large toilet and a large wall .',
#  '000000336937': 'a man in a blue shirt is standing on a beach .',
#  '000000302302': 'a man in a blue shirt is flying a kite .',
#  '000000013414': 'a group of people sitting on a street with a building .',
#  '000000137507': 'a small cat sitting on a table with a table .',
#  '000000481281': 'a woman sitting on a bench with a black shirt and a black shirt .',
#  '000000358247': 'a man sitting on a couch with a laptop .',
#  '000000420610': 'a group of people sitting on a table with a table .',
#  '000000423588': 'a person riding a skateboard down a road .',
#  '000000033798': 'a white room with a white sink and a white window .',
#  '000000425676': 'a small dog is standing in the grass .',
#  '000000168898': 'a plate of food with a plate of food .',
#  '000000423919': 'a woman in a white shirt is sitting on a bed .',
#  '000000306313': 'a living room with a white chair and a white chair .',
#  '000000504452': 'a man in a blue shirt and white shirt is sitting on a beach .',
#  '000000091636': 'a man in a blue shirt and white shirt is standing in front of a large large large large large building .',
#  '000000482907': 'a large large boat is flying down the side of a street .',
#  '000000053677': 'a man in a black shirt and white shirt is standing on a street with a motorcycle .',
#  '000000033717': 'a large large large large large large large large large green airport .',
#  '000000329806': 'a group of elephants standing on a beach .',
#  '000000332074': 'a woman in a white shirt and white shirt is standing on a snow slope .',
#  '000000022051': 'a man in a blue shirt and white shirt is standing on a beach .',
#  '000000439902': 'a woman in a blue shirt is standing in front of a large large large large large large large large large large large large large building .',
#  '000000523123': 'a woman is standing in front of a white dog .',
#  '000000252280': 'a man in a blue shirt and white shirt is sitting on a bench .',
#  '000000150616': 'a white and white fire hydrant on a road .',
#  '000000369601': 'a group of people sitting on a bench .',
#  '000000189600': 'a man is playing a frisbee on a field .',
#  '000000071095': 'a group of people standing in front of a field .',
#  '000000301753': 'a baseball player is playing a game in the grass .',
#  '000000272357': 'a baseball player is playing a game of baseball .',
#  '000000265971': 'a man in a blue shirt is playing tennis .',
#  '000000043404': 'a group of people standing in front of a building .',
#  '000000429160': 'a group of people standing in front of a large large building .',
#  '000000095482': 'a group of people standing in front of a large large large large large large large large large large large large large large airplane .',
#  '000000488069': 'a man riding a skateboard on a street .',
#  '000000553129': 'a cat sitting on a bed with a cat on it .',
#  '000000570594': 'a group of elephants standing next to a tree .',
#  '000000047916': 'a group of people standing in the grass .',
#  '000000240655': 'a man is sitting on a bench with a red umbrella .',
#  '000000289263': 'a man in a blue shirt is standing on a beach .',
#  '000000480438': 'a table with a table with a table and a table .',
#  '000000172673': 'a group of people sitting on a bench .',
#  '000000159151': 'a man sitting on a bench with a black hair .',
#  '000000195267': 'a group of people standing on a beach .',
#  '000000087483': 'a group of people standing in a field of grass .',
#  '000000126540': 'a man in a white shirt is standing in a room .',
#  '000000544538': 'a man in a red shirt is standing on a bench .',
#  '000000050034': 'a man is sitting on a bench with a red shirt .',
#  '000000438046': 'a laptop with a laptop and a laptop on it .',
#  '000000217561': 'a white cat sitting on top of a bed .',
#  '000000326021': 'a little girl is holding a red shirt .',
#  '000000168805': 'a group of people sitting on a bench .',
#  '000000580766': 'a man in a blue shirt is standing on a bench .',
#  '000000443652': 'a group of people sitting on a table with a large umbrella .',
#  '000000224247': 'a group of people standing on a beach .',
#  '000000146773': 'a man in a white shirt is sitting on a bench .',
#  '000000366421': 'a man is sitting on a bench with a laptop .',
#  '000000518908': 'a man is sitting on a bench with a blue umbrella .',
#  '000000172886': 'a kitchen with a white sink and a white sink',
#  '000000494404': 'a small dog is standing on the water .',
#  '000000022979': 'a man is sitting on a bed with a laptop .',
#  '000000380828': 'a man is standing next to a large large large horse .',
#  '000000151432': 'a group of people sitting on a beach .',
#  '000000215549': 'a group of people standing on a street .',
#  '000000044421': 'a man in a blue shirt and white shirt is sitting on a bench .',
#  '000000099707': 'a group of people standing on a street with a building .',
#  '000000512145': 'a woman is holding a cake with a woman and a woman .',
#  '000000161940': 'a woman in a white shirt is holding a cell phone .',
#  '000000370819': 'a large cat sitting on a table with a red umbrella .',
#  '000000438848': 'a woman is sitting on a bench .',
#  '000000168775': 'a group of people standing in front of a wooden field .',
#  '000000563730': 'a white dog sitting on a table with a white bowl .',
#  '000000509185': 'a man riding a skateboard on the side of a skateboard .',
#  '000000287830': 'a person is flying a kite in the ocean .',
#  '000000324710': 'a black and white dog sitting on a bench .',
#  '000000026501': 'a man is sitting on the ground with a black shirt .',
#  '000000073981': 'a group of people standing in front of a fence .',
#  '000000377911': 'a cat sitting on top of a table with a laptop .',
#  '000000098268': 'a man in a black shirt is standing on a bench .',
#  '000000382557': 'a group of people sitting on a table with a large umbrella .',
#  '000000473433': 'a cat sitting on the floor of a bed .',
#  '000000307048': 'a group of people are standing on a bench .',
#  '000000162855': 'a man in a white shirt is playing a frisbee .',
#  '000000494456': 'a person riding a skateboard on a beach .',
#  '000000047611': 'a large large large large white cake with a white laptop and white laptop .',
#  '000000175318': 'a large red fire hydrant on the street .',
#  '000000010217': 'a plate with a white plate with a white plate of food on it .',
#  '000000124210': 'a group of people walking down a street with a large bike .',
#  '000000113897': 'a bathroom with a toilet and a toilet .',
#  '000000548464': 'a man in a blue shirt is standing on a beach .',
#  '000000549932': 'a group of people playing a game of people .',
#  '000000415153': 'a man is standing on a bench in front of a road .',
#  '000000036508': 'a plate with a pizza on it on it .',
#  '000000519446': 'a cat sitting on a bench on a bench .',
#  '000000222866': 'a plate of food with a plate of food on it',
#  '000000402115': 'a man sitting on a table with a laptop on it .',
#  '000000345160': 'a man in a red shirt is playing a game of soccer .',
#  '000000486846': 'a group of people standing in front of a large large large building .',
#  '000000191893': 'a large large train on the side of a city street .',
#  '000000224037': 'a large plane is sitting on the beach .',
#  '000000445267': 'a man in a black shirt is standing in a field .',
#  '000000126345': 'a group of people standing in a field of grass .',
#  '000000191078': 'a group of people sitting on top of a table .',
#  '000000051339': 'a group of people standing on a bench .',
#  '000000266437': 'a woman in a white shirt is sitting on a table .',
#  '000000163309': 'a person is sitting on the beach with a blue shirt and a blue shirt .',
#  '000000138022': 'a large large large large large large large large bus .',
#  '000000092815': 'a woman in a white shirt and white shirt is sitting on a table with a large woman in front of a large large large kitchen .',
#  '000000470801': 'a man in a blue shirt is standing in the air .',
#  '000000311904': 'a small cat sitting on top of a table .',
#  '000000579696': 'a man is sitting on a bench with a large dog .',
#  '000000406201': 'a cat sitting on top of a bed .',
#  '000000575012': 'a group of people sitting on a table with a large cake .',
#  '000000381037': 'a black and white cat sitting on top of a bed .',
#  '000000383209': 'a cat is standing in front of a bed .',
#  '000000063434': 'a man in a white shirt is sitting on a table with a laptop .',
#  '000000156532': 'two people are standing in the water with a large large large lot .',
#  '000000038064': 'a giraffe standing in the grass with a grassy field .',
#  '000000160886': 'a small teddy bear sitting on a table .',
#  '000000468972': 'a pizza with a white shirt and a white plate of food .',
#  '000000168692': 'a man is playing with a frisbee on the ground .',
#  '000000556892': 'a group of people sitting on a beach .',
#  '000000397980': 'a group of people playing soccer on a field .',
#  '000000309222': 'a large large large horse is parked in the water .',
#  '000000145391': 'a man sitting on a table with a cake on it .',
#  '000000215303': 'a group of people standing next to a large large elephant .',
#  '000000456574': 'a group of people standing on a bench .',
#  '000000247394': 'a man is flying a kite on the beach .',
#  '000000275744': 'a group of people standing on a bench .',
#  '000000560637': 'a group of people standing on a bench .',
#  '000000286176': 'a table with a table and a table with a table .',
#  '000000549112': 'a large white cake with a white hat on it .',
#  '000000275117': 'a man is sitting on the sidewalk with a black dog .',
#  '000000054924': 'a group of people sitting on a bench .',
#  '000000303667': 'a bathroom with a toilet and a toilet .',
#  '000000390769': 'a man in a blue shirt and white shirt is sitting on a bench .',
#  '000000500784': 'a cat sitting on a bed with a white toilet .',
#  '000000297976': 'a white room with a white sink and a white sink .',
#  '000000264909': 'a black and white horse is riding a skateboard .',
#  '000000200681': 'a giraffe is standing in the grass in the grass .',
#  '000000344521': 'a plate of food with a plate of vegetables and a plate .',
#  '000000111944': 'a person riding a snowboard on a snowy slope',
#  '000000054870': 'a plate of food with a plate of food on it',
#  '000000426342': 'a group of people standing in a field with a large giraffe in the grass .',
#  '000000344368': 'a cat sitting on top of a bench .',
#  '000000302710': 'a white and white fire hydrant on a road .',
#  '000000127119': 'a group of men in a field playing a game of baseball .',
#  '000000260099': 'a group of people walking down a street .',
#  '000000003771': 'a group of people standing in the grass .',
#  '000000349896': 'a group of people standing on a field with a kite in the background .',
#  '000000274591': 'a group of people standing on a street with a large umbrella .',
#  '000000098322': 'a man is riding a skateboard on a skateboard .',
#  '000000053665': 'a man is riding a wave on the beach .',
#  '000000189694': 'a cat sitting on a bed with a kitchen .',
#  '000000011182': 'a group of people standing on a road .',
#  '000000354027': 'a group of people standing in front of a red horse .',
#  '000000107511': 'a group of men standing in a field of grass .',
#  '000000141426': 'a group of people standing in a field .',
#  '000000158588': 'a group of people sitting on a bench .',
#  '000000425522': 'a group of people standing on a street with a building .',
#  '000000042288': 'a person is standing on a snowy slope',
#  '000000303814': 'a woman in a blue shirt is holding a red shirt .',
#  '000000068205': 'a woman is sitting on a table with a large laptop .',
#  '000000015797': 'a person riding a skateboard down a snow slope .',
#  '000000034708': 'a woman is sitting on a table with a white hat .',
#  '000000098187': 'a group of people standing on the beach .',
#  '000000378311': 'a man sitting on top of a table with a laptop .',
#  '000000219546': 'a white cat is sitting on a table with a white table .',
#  '000000406155': 'a man riding a wave on a wave .',
#  '000000006393': 'a man in a white shirt is standing on a bed .',
#  '000000267802': 'a group of people standing in front of a large large large large large large large large large large large large large large large large building .',
#  '000000523597': 'a man is sitting on the side of a bench .',
#  '000000079836': 'a group of people are standing on the beach .',
#  '000000005418': 'a man in a black shirt and white shirt is standing on a field .',
#  '000000474388': 'a group of people standing on a field .',
#  '000000532580': 'a group of people standing on a road with a large train on it .',
#  '000000223857': 'a man is standing on the ground with a black shirt .',
#  '000000215024': 'a man is flying a kite in the water .',
#  '000000020147': 'a group of elephants standing on a field .',
#  '000000287846': 'a man is standing on a beach with a blue shirt and a blue umbrella .',
#  '000000182736': 'a group of people standing on a field with a horse .',
#  '000000227851': 'a group of people standing in front of a large large large large field .',
#  '000000349590': 'a large plate with a large bowl of food on it .',
#  '000000266853': 'a giraffe standing in the grass next to a tree .',
#  '000000099747': 'a man in a white shirt and white shirt is sitting on a building .',
#  '000000393777': 'a man in a blue shirt is sitting on a bench .',
#  '000000092338': 'a group of people sitting on a beach .',
#  '000000114616': 'a group of people standing in a field .',
#  '000000029160': 'a large large large boat is flying in the water .',
#  '000000023051': 'a red train is parked in front of a building .',
#  '000000408363': 'a man in a blue shirt is sitting on a street with a large blue umbrella .',
#  '000000575911': 'a man sitting on a bench with a blue umbrella .',
#  '000000513887': 'a large large laptop sitting on a table .',
#  '000000470115': 'two men are standing on a street with a horse .',
#  '000000268058': 'a man sitting on a table with a red shirt and a red shirt .',
#  '000000136181': 'a white dog is sitting on the ground with a white board .',
#  '000000400265': 'a man in a blue shirt is riding a skateboard .',
#  '000000493751': 'a man is playing a game of tennis .',
#  '000000297414': 'a black and white cat is sitting on a bench .',
#  '000000148614': 'a white bathroom with a white toilet and a white toilet .',
#  '000000370095': 'a large large boat is on a beach .',
#  '000000339019': 'a group of people are sitting on a beach .',
#  '000000574208': 'a group of people standing on a field with a green mouth .',
#  '000000528011': 'a group of elephants standing on a dirt road .',
#  '000000009813': 'a group of elephants standing in a field .',
#  '000000429170': 'a group of people standing on a beach .',
#  '000000273196': 'a group of people sitting on the side of a bench .',
#  '000000492025': 'a group of people standing on a bench .',
#  '000000185360': 'a group of people sitting on a bench .',
#  '000000062824': 'a group of people are standing in front of a building .',
#  '000000471625': 'a group of people standing on a street with a group of people in the background .',
#  '000000354368': 'a group of people standing on a bench .',
#  '000000217393': 'two zebras are standing in a field with a large brown dog .',
#  '000000032909': 'a man sitting on a table with a white hat .',
#  '000000232627': 'a white dog sitting on a bench next to a wooden table .',
#  '000000117201': 'a person is standing on the snow with a large blue sky .',
#  '000000156282': 'a large large large airplane that is flying in the background .',
#  '000000169683': 'a man is riding a skateboard on the road .',
#  '000000441054': 'a group of sheep standing in a field .',
#  '000000472295': 'a large bird is riding on a snowy hill',
#  '000000321603': 'a woman in a white shirt and a white shirt is holding a black shirt .',
#  '000000554445': 'a man sitting on a bench with a large fire hydrant .',
#  '000000281676': 'a group of people sitting on a bench .',
#  '000000330356': 'a group of people standing in a field .',
#  '000000176527': 'a man in a white shirt is standing in the snow .',
#  '000000523252': 'a train is parked on the tracks with a train tracks .',
#  '000000350491': 'a group of zebras standing in front of a field .',
#  '000000175136': 'a large large large large train on a table .',
#  '000000085852': 'a dog is standing on the grass with a green mouth .',
#  '000000330419': 'a group of people standing on a field .',
#  '000000049068': 'a man in a white shirt and white shirt is standing in front of a large large large large large large large large large large large large large large large large large large large large large large large large building .',
#  '000000524979': 'a man in a white shirt is sitting on a table .',
#  '000000030403': 'a large bus is sitting on the side of a bench .',
#  '000000255315': 'a man is sitting on the side of a wooden bench .',
#  '000000445668': 'a large plane flying in the air .',
#  '000000066191': 'a young girl in a green shirt is playing a field .',
#  '000000079924': 'a large large large clock on the side of a building .',
#  '000000082576': 'a group of people are sitting on a beach .',
#  '000000282841': 'a cat is sitting on a bed with a white shirt .',
#  '000000326555': 'a man in a blue shirt and white shirt is riding a skateboard on a skateboard .',
#  '000000254929': 'a plate of food sitting on a table .',
#  '000000100409': 'a man is sitting on a bench with a black shirt and a black shirt .',
#  '000000462632': 'a large large large cake with a red hat on it .',
#  '000000536879': 'a woman in a black shirt is standing in front of a large large large room .',
#  '000000192079': 'a small small white bear sitting on top of a table .',
#  '000000500420': 'a man in a blue shirt is flying a kite .',
#  '000000361751': 'a group of people standing on a bench .',
#  '000000291144': 'a man in a white shirt and white shirt is standing in front of a large large large large large large large large building .',
#  '000000143696': 'two people are sitting on a bench in front of a building .',
#  '000000310757': 'a plate of food with a white plate with a white bowl of food on it .',
#  '000000489798': 'a group of people are sitting on the street .',
#  '000000452297': 'a man in a red shirt is sitting on a bench .',
#  '000000199819': 'a cat sitting on a bed with a laptop .',
#  '000000552018': 'a small dog is sitting on a table .',
#  '000000419723': 'a group of people sitting on a table with a table .',
#  '000000344025': 'a woman is sitting on a table with a woman in the background .',
#  '000000106206': 'a man in a blue shirt is sitting on a beach .',
#  '000000394132': 'a group of people standing on a beach .',
#  '000000161539': 'a group of people standing in front of a large large large building .',
#  '000000347648': 'a woman sitting on top of a table with a white umbrella .',
#  '000000326592': 'two men are standing on a field with a frisbee .',
#  '000000173997': 'a large bird sitting on a bench in the grass .',
#  '000000401758': 'a man in a white shirt and white shirt is standing in a white shirt and white shirt and a white shirt standing in a white shirt and white shirt in front of a white shirt .',
#  '000000213799': 'a large black and white fire hydrant sitting on a bench .',
#  '000000253474': 'a group of people standing on a bench .',
#  '000000559136': 'a person is flying a kite in the snow .',
#  '000000248956': 'a man is sitting on a bench with a red shirt .',
#  '000000381318': 'a group of people sitting on a table with a table .',
#  '000000366683': 'a woman is sitting on a table with a laptop .',
#  '000000019491': 'a man in a white shirt is standing in front of a kitchen .',
#  '000000171201': 'a woman in a white shirt is holding a white dog .',
#  '000000404027': 'a group of people standing in front of a dirt field .',
#  '000000286106': 'a woman sitting on top of a table with a laptop and a laptop .',
#  '000000253825': 'a large white vase with a white vase in it .',
#  '000000536403': 'a cat sitting on a table with a white dog .',
#  '000000331223': 'a man in a white shirt is sitting on a bench .',
#  '000000432798': 'a large cat sitting on top of a wooden bench .',
#  '000000342060': 'a man is riding a skateboard down a road .',
#  '000000207458': 'a man is standing on a skateboard with a skateboard .',
#  '000000257864': 'a small cat sitting on a table with a white bowl .',
#  '000000146675': 'a man in a blue shirt and blue shirt is holding a blue umbrella .',
#  '000000411177': 'a group of people sitting on a table with a table .',
#  '000000110617': 'a man in a black shirt is standing on a field .',
#  '000000169872': 'a large large bus is parked in front of a building .',
#  '000000454810': 'a large large building with a large clock on it .',
#  '000000082312': 'a group of people standing on a street with a large large large large large large large large large large large large large large large large large large large large large large group of people .',
#  '000000373578': 'a group of people standing on a field .',
#  '000000121503': 'a group of people walking down a street .',
#  '000000015984': 'a girl is standing on the grass with a dog .',
#  '000000515355': 'a white plate with a white plate with a white plate .',
#  '000000478517': 'a group of elephants standing next to a tree .',
#  '000000389753': 'a large large clock on the side of a building .',
#  '000000418226': 'a group of people sitting on a bench .',
#  '000000252617': 'a man is sitting on a bench with a blue shirt .',
#  '000000415714': 'a man in a blue shirt is standing on a beach .',
#  '000000181403': 'a man is riding a skateboard on a skateboard .',
#  '000000353130': 'a person is sitting on a table with a white hat .',
#  '000000405334': 'a man is sitting on a table with a table .',
#  '000000357402': 'a man is playing tennis on a tennis court .',
#  '000000342387': 'a woman is sitting on a table with a white shirt and a white hat .',
#  '000000198495': 'a man is sitting on a bench in the background .',
#  '000000537727': 'a cat is sitting on the floor of a bed .',
#  '000000373857': 'a man in a white shirt is sitting on a table with a large large white kitchen .',
#  '000000480223': 'a man in a black shirt is standing in a field of grass .',
#  '000000469130': 'a group of people are sitting on a beach .',
#  '000000190406': 'a man riding a skateboard down a street .',
#  '000000435187': 'a group of people standing in front of a field .',
#  '000000511420': 'a group of people sitting on the beach .',
#  '000000099543': 'a plate with a bowl of food on it .',
#  '000000115636': 'a man in a blue shirt is standing on a sidewalk .',
#  '000000138185': 'a woman standing in front of a white room with a white shirt and a white shirt .',
#  '000000053800': 'a man in a white shirt and white shirt is sitting in a room with a cat .',
#  '000000561619': 'a man in a white shirt and a white room with a laptop and a laptop .',
#  '000000396167': 'a man in a black shirt and white shirt is standing on a bench .',
#  '000000448275': 'a man is standing on a bench with a black shirt .',
#  '000000406050': 'a group of people standing on a bench .',
#  '000000320203': 'a man in a blue shirt is holding a red board .',
#  '000000387506': 'a large large large airplane sitting on the beach .',
#  '000000578467': 'a group of people standing in front of a large large large large large large building .',
#  '000000503207': 'a black and white dog is sitting on a bench .',
#  '000000009214': 'a group of zebras are standing on a field .',
#  '000000054627': 'a group of people standing on a field .',
#  '000000143098': 'a man in a red shirt is playing a baseball .',
#  '000000069266': 'a group of people sitting on the street with a red fire hydrant .',
#  '000000457453': 'a man in a blue shirt is standing in front of a building .',
#  '000000177173': 'a group of people sitting on a table .',
#  '000000065357': 'a group of people sitting on a bench .',
#  '000000070240': 'a man in a black shirt and white shirt is sitting on a bench .',
#  '000000139734': 'a white plate with a white and white bowl of food .',
#  '000000010496': 'a group of people standing on a beach in the water .',
#  '000000285250': 'a group of people flying down a beach .',
#  '000000520451': 'a group of people sitting on a bench .',
#  '000000521772': 'a train is parked on the road with a train .',
#  '000000138514': 'a man in a white shirt is sitting on a table with a laptop .',
#  '000000049643': 'a man is sitting on a bench in front of a building .',
#  '000000192866': 'a group of people standing next to a bus .',
#  '000000466839': 'a group of sheep standing in a field .',
#  '000000359141': 'a man in a white shirt and white shirt is playing a frisbee .',
#  '000000234749': 'a plate with a plate of food and a plate .',
#  '000000000620': 'a woman is sitting in a room with a white shirt and a white shirt .',
#  '000000496517': 'a woman is sitting on a table with a red shirt .',
#  '000000272785': 'a group of people sitting on a table with a large orange and white umbrella .',
#  '000000533522': 'a woman in a white shirt is standing in a room .',
#  '000000361638': 'a bathroom with a toilet and a toilet .',
#  '000000160014': 'a man in a black shirt is sitting on a bed .',
#  '000000376362': 'a group of people standing in the water .',
#  '000000298793': 'a man is sitting on a bench next to a large building .',
#  '000000465969': 'a woman in a white shirt is sitting in front of a large large large large large large large large large large large large large living room .',
#  '000000133660': 'a group of people are standing on the beach .',
#  '000000382171': 'a group of sheep standing in front of a field .',
#  '000000157238': 'a cat is sitting on a bed with a large teddy bear .',
#  '000000057883': 'a man riding a wave on a beach .',
#  '000000580082': 'a black and white cat sitting on a bench .',
#  '000000280023': 'a group of people sitting in front of a table .',
#  '000000406755': 'a woman is sitting on a table with a white shirt .',
#  '000000117691': 'a man in a blue shirt is standing on a bench .',
#  '000000465080': 'a group of people sitting on a bench .',
#  '000000190297': 'a white room with a white vase and a white white white table .',
#  '000000507370': 'a black and white cat sitting on top of a large large building .',
#  '000000531474': 'a man riding a skateboard down a street .',
#  '000000089101': 'a group of people standing on a road .',
#  '000000031578': 'a woman is standing on a bench with a white shirt .',
#  '000000353652': 'a man in a blue shirt is sitting on a bench .',
#  '000000546531': 'a red and white fire hydrant in front of a building .',
#  '000000200612': 'a large train is sitting on the side of a train station .',
#  '000000304040': 'a group of people sitting on a bench .',
#  '000000143569': 'a man in a blue shirt and white shirt is standing on a bench .',
#  '000000494768': 'a group of people sitting on a bench .',
#  '000000379165': 'a woman is sitting on a table with a white dog .',
#  '000000333621': 'a table with a table with a table and a table .',
#  '000000154955': 'a man in a white shirt and white shirt is sitting on a bed .',
#  '000000305451': 'a group of people standing on a bench .',
#  '000000418505': 'a small kitchen with a large white sink and a large kitchen .',
#  '000000535874': 'a group of people sitting on a table with a large orange and flowers .',
#  '000000241860': 'a large large fire hydrant on a table .',
#  '000000399241': 'a man flying a kite on a beach .',
#  '000000524646': 'a large plane is flying down the beach .',
#  '000000351141': 'a man in a blue shirt and white shirt is standing on a bench with a red shirt .',
#  '000000477321': 'a group of people standing on a beach .',
#  '000000387153': 'a kitchen with a sink and a sink',
#  '000000084157': 'a table with a table with a table and a table .',
#  '000000415201': 'a woman is sitting on a table with a white shirt .',
#  '000000027675': 'a group of people are standing in front of a building .',
#  '000000295642': 'a train is parked on the street with a train .',
#  '000000387181': 'a man is sitting on a bench with a black shirt .',
#  '000000178849': 'a man is sitting on the side of a skateboard .',
#  '000000143192': 'a man in a blue shirt is standing in front of a park .',
#  '000000577176': 'a group of people sitting on a street with a building .',
#  '000000477782': 'two men standing on a bench in a field .',
#  '000000215107': 'a group of people standing on a bench .',
#  '000000471480': 'a group of people walking down a street .',
#  '000000536827': 'a man in a blue shirt is standing on a bench .',
#  '000000197408': 'a man in a red shirt is standing in front of a building .',
#  '000000088377': 'a group of people sitting on a street with a large bus .',
#  '000000260373': 'a man is standing on a bench with a black shirt and a black shirt .',
#  '000000290724': 'a group of people sitting on a street with a building .',
#  '000000184355': 'a man is riding a skateboard down the street .',
#  '000000105172': 'a giraffe standing in front of a field .',
#  '000000448139': 'a group of people standing on a field with a large kite .',
#  '000000271373': 'a man in a white shirt is standing on a snow slope .',
#  '000000581204': 'a small pizza with a white bowl of food .',
#  '000000278335': 'a person is sitting on a table with a blue umbrella .',
#  '000000292844': 'a group of people sitting on a bench .',
#  '000000428039': 'a small dog is standing in front of a tree .',
#  '000000267417': 'a group of people are standing in a field .',
#  '000000495615': 'a woman is holding a frisbee in front of a green field .',
#  '000000376422': 'a laptop with a laptop and a laptop on it .',
#  '000000483517': 'a group of people standing in front of a tree .',
#  '000000207142': 'a woman is sitting on a table with a red hat .',
#  '000000141207': 'a group of people standing on the beach .',
#  '000000038196': 'a group of people sitting on a bench .',
#  '000000341639': 'a group of people standing in the grass .',
#  '000000064389': 'a man sitting on a bed with a laptop and a laptop .',
#  '000000495079': 'a group of people standing in a field .',
#  '000000131696': 'a man is standing on a bench with a horse .',
#  '000000054003': 'a man in a red shirt is standing in a field .',
#  '000000330400': 'a man is standing on the beach with a dog on the beach .',
#  '000000015733': 'a man riding a wave on a wave .',
#  '000000300514': 'a large kitchen with a large glass oven .',
#  '000000362811': 'a woman is sitting on a table with a white dog on it .',
#  '000000353937': 'a clock tower with a clock on it .',
#  '000000572063': 'a group of people standing on a road .',
#  '000000313113': 'a large red fire hydrant sitting on a table .',
#  '000000499852': 'a group of people standing in front of a field .',
#  '000000060005': 'a train is parked on the side of a train station .',
#  '000000184282': 'a group of people are sitting on a train field .',
#  '000000285893': 'a man in a green shirt is playing frisbee .',
#  '000000099070': 'a group of people standing in a large large building .',
#  '000000205126': 'a woman is sitting on a plate with a blue shirt .',
#  '000000313280': 'a man in a blue shirt and white shirt is sitting on a street .',
#  '000000299643': 'a small cat sitting on a table with a laptop .',
#  '000000409678': 'a small white cat sitting on a table .',
#  '000000198289': 'a woman is sitting on a table with a white dog .',
#  '000000040100': 'a group of people standing on a field with a tree in the grass .',
#  '000000111188': 'a man standing next to a black dog .',
#  '000000111940': 'a man is standing on a skateboard in front of a bench .',
#  '000000467137': 'a man is standing on a bench with a red umbrella .',
#  '000000229707': 'a woman is holding a cell phone in front of a large cake .',
#  '000000312446': 'a group of people are standing on the beach .',
#  '000000468132': 'a man in a blue shirt is standing on a bench .',
#  '000000452737': 'a man in a red shirt is holding a cell phone .',
#  '000000081954': 'a black and white dog standing in the grass .',
#  '000000239801': 'a white dog is sitting on a plate .',
#  '000000316336': 'a table with a laptop and a laptop on it',
#  '000000125672': 'a man in a red shirt and a black shirt is standing in front of a green field .',
#  '000000465495': 'a white room with a white chair and a laptop',
#  '000000400064': 'a man is standing on a bed with a black shirt and a black shirt .',
#  '000000083601': 'a woman is sitting on a table with a laptop .',
#  '000000136154': 'a red bus is parked on the street .',
#  '000000419678': 'a woman in a white shirt is holding a white dog .',
#  '000000291889': 'a man in a black shirt and white shirt is sitting on a table with a laptop and a laptop .',
#  '000000456201': 'a man is sitting on a bench in front of a wooden wall .',
#  '000000403464': 'a group of people are standing on a bench .',
#  '000000421534': 'a group of people standing on a street with a building .',
#  '000000170562': 'a man is sitting on a bench on the street .',
#  '000000383329': 'a red fire hydrant in front of a red fire hydrant .',
#  '000000069424': 'a group of people are standing on a beach .',
#  '000000361376': 'a plate of food with a pizza on it .',
#  '000000297570': 'a group of people flying a kite in the sky .',
#  '000000574829': 'a man in a black shirt is standing next to a large large horse .',
#  '000000090498': 'a white cat sitting on top of a wooden table .',
#  '000000397717': 'a group of elephants standing next to a tree .',
#  '000000406452': 'a group of people standing in front of a building .',
#  '000000059267': 'a cat sitting on a bed with a laptop .',
#  '000000369568': 'two men standing in a field with a black dog in the grass .',
#  '000000329175': 'two people are standing on a street with people in the background .',
#  '000000456873': 'a cat is sitting on a bed with a cat .',
#  '000000174496': 'a plate with a piece of food on it .',
#  '000000487288': 'a group of people standing in a room with a large dog in the background .',
#  '000000256465': 'a man is standing in front of a large large large large large large large large large large large large large large large large large large large large large large large large large large large large large large large large large large large man is sitting on the sidewalk .',
#  '000000190334': 'a group of people are standing in front of a building .',
#  '000000224166': 'a group of people standing in front of a table with a large red umbrella .',
#  '000000154888': 'a group of people standing in the water .',
#  '000000580238': 'a group of people standing on a bench .',
#  '000000361519': 'a group of people standing in the water .',
#  '000000021374': 'a man in a blue shirt is standing in front of a large large large large large large large building .',
#  '000000162880': 'a group of people sitting on a bench .',
#  '000000208319': 'a man in a blue shirt and white shirt is standing on a beach .',
#  '000000178178': 'a white room with a white sink and a white chair .',
#  '000000365205': 'a woman in a black shirt is holding a black shirt .',
#  '000000248391': 'a man in a black shirt and white shirt is sitting on a bench .',
#  '000000192394': 'a man is standing on a beach with a large blue umbrella .',
#  '000000243324': 'a group of people standing on a bench .',
#  '000000349552': 'a man in a blue shirt and blue shirt is sitting on a snowy hill .',
#  '000000480313': 'a group of people sitting on a table with a large cake .',
#  '000000261196': 'a pizza with a plate with a pizza on it .',
#  '000000141922': 'a group of people standing next to a street .',
#  '000000287886': 'a laptop sitting on top of a table .',
#  '000000258129': 'a group of people standing on a field .',
#  '000000125662': 'a group of people standing in front of a building .',
#  '000000506659': 'a man in a blue shirt and blue shirt is standing in front of a building .',
#  '000000529689': 'a group of people standing on top of a beach .',
#  '000000097363': 'a group of people standing in a field .',
#  '000000011323': 'a man is sitting on a bench with a red umbrella .',
#  '000000169448': 'a large large cat sitting on a wooden bench .',
#  '000000191648': 'a man is standing on the beach with a blue umbrella .',
#  '000000304584': 'a group of people are sitting on a bench .',
#  '000000336015': 'a man is riding a surfboard on a snowy hill .',
#  '000000017167': 'a man in a blue shirt is standing in front of a blue shirt .',
#  '000000166349': 'a man riding a wave on a wave .',
#  '000000001548': 'a group of people standing on the beach .',
#  '000000347131': 'a woman is sitting on a table with a white dog .',
#  '000000382447': 'a cat sitting on a bed next to a wooden table .',
#  '000000081971': 'a cat is sitting on a bed with a cat .',
#  '000000536010': 'a bathroom with a sink and a sink',
#  '000000244293': 'a large large large large boat is parked on the side of a street .',
#  '000000326853': 'a man is sitting on the side of a bench .',
#  '000000311475': 'a group of people are sitting on a beach .',
#  '000000157301': 'a man sitting on a bench next to a laptop .',
#  '000000175142': 'a group of people standing in front of a street with a building .',
#  '000000302576': 'a man in a white shirt is holding a cell phone .',
#  '000000056323': 'a man in a blue shirt and white shirt is standing on a street .',
#  '000000189351': 'a man in a white shirt is sitting on a bench .',
#  '000000379567': 'a cat sitting on top of a bed with a laptop on it .',
#  '000000111121': 'a baseball player is standing in a field .',
#  '000000372660': 'a man in a blue shirt and white shirt is standing next to a large large large large large large large large large large large large large large large large large cake .',
#  '000000559768': 'a person sitting on a table with a white cake on it .',
#  '000000323790': 'a plate with a sandwich and a white bowl of food',
#  '000000046359': 'a man in a blue shirt and blue shirt is standing on the beach with a blue sky .',
#  '000000205689': 'a man in a black shirt is standing in front of a building .',
#  '000000573659': 'a man sitting on a table with a laptop .',
#  '000000139040': 'a woman in a white shirt is standing in front of a kitchen .',
#  '000000459465': 'a large large large clock sitting on top of a wooden table .',
#  '000000381301': 'a large bus is parked on the street .',
#  '000000105781': 'a group of people are sitting on the beach .',
#  '000000302489': 'a group of people sitting on a bench .',
#  '000000068738': 'a man sitting on a table with a white dog on it .',
#  '000000008320': 'a group of people sitting on a bench .',
#  '000000237394': 'a large train parked on a road with a large train station .',
#  '000000295476': 'a man in a white shirt is standing on a snow slope .',
#  '000000181850': 'a woman is sitting on a table with a white dog on it .',
#  '000000209292': 'a small white bathroom with a white toilet and a white wall',
#  '000000428508': 'a man in a baseball shirt is playing baseball .',
#  '000000399932': 'a group of people sitting on a beach .',
#  '000000096643': 'a cat is sitting on the floor of a bed .',
#  '000000243384': 'a large white bathroom with a white clock on it .',
#  '000000035712': 'a white cat sitting on a bed with a laptop .',
#  '000000014726': 'a group of people sitting on a bench .',
#  '000000269327': 'a giraffe is standing in the grass .',
#  '000000474387': 'a white cat sitting on a table with a red umbrella .',
#  '000000063330': 'a large boat is parked on the beach .',
#  '000000268036': 'a group of people standing in front of a building .',
#  '000000470995': 'a man in a white shirt is standing on a bench .',
#  '000000557467': 'a large clock sitting on top of a building .',
# ...
#  '000000278287': 'a large large bird is sitting on a bench .',
#  '000000473042': 'a young boy is playing frisbee on a field .',
#  '000000209128': 'a group of people are standing on a field .',
#  '000000369140': 'a man riding a surfboard on a beach .',
#  '000000416622': 'a dog sitting on a bench in a field .',
#  '000000014985': 'a man in a blue shirt and white shirt is riding a skateboard on a street .',
#  '000000291321': 'a woman is sitting on a table with a large cake .',
#  '000000285018': 'a white bathroom with a white sink and a white sink .',
#  '000000248009': 'a black and white dog sitting on a bench .',
#  '000000314788': 'a train is parked on the side of a train station .',
#  '000000213646': 'a group of people standing on a field .',
#  '000000289621': 'a man is walking down the street with a motorcycle .',
#  '000000032566': 'a man in a blue shirt is standing on a beach .',
#  '000000419656': 'a man in a blue shirt is standing in front of a large building .',
#  '000000567997': 'a group of people standing on a bench .',
#  '000000122586': 'a person riding a snow board on a snow slope',
#  '000000352041': 'a man riding a skateboard on a skateboard .',
#  '000000230503': 'a man in a blue shirt is sitting on the street .',
#  '000000285910': 'a white cat sitting on top of a table .',
#  '000000042818': 'a man is standing on a beach with a blue shirt and a blue shirt .',
#  '000000259591': 'a cat sitting on a bed with a black hat .',
#  '000000012103': 'a bathroom with a toilet and a toilet .',
#  '000000254729': 'a man is sitting on a bench on a street .',
#  '000000373033': 'a man is riding a skateboard on a skateboard .',
#  '000000392723': 'a group of people standing in front of a building .',
#  '000000063182': 'a group of people standing in a field .',
#  '000000088176': 'a group of people walking down a street .',
#  '000000031865': 'a man sitting on a bed with a cat on it .',
#  '000000105904': 'a large large large large large large building with a large clock .',
#  '000000038827': 'a large large bird sitting on a field .',
#  '000000038722': 'a man in a blue shirt is standing in front of a large building .',
#  '000000483530': 'a white room with a white white and white white white white white chair .',
#  '000000373923': 'a person in a blue shirt and white shirt is standing on a snowy hill .',
#  '000000230038': 'a kitchen with a white kitchen and a table .',
#  '000000305267': 'a woman is holding a white dog on a table .',
#  '000000053232': 'a small small dog sitting on top of a table .',
#  '000000284144': 'a group of people are standing on a street with a motorcycle .',
#  '000000193594': 'a man standing on a bench in front of a large large large elephant .',
#  '000000112882': 'a white cat sitting on a bed with a white toilet .',
#  '000000573184': 'a large large train is parked on the side of a road .',
#  '000000128826': 'a woman is sitting on a table with a white shirt .',
#  '000000175946': 'a man in a white shirt and white shirt is sitting on a table with a laptop and a laptop .',
#  '000000233926': 'a group of people sitting on a bench .',
#  '000000295257': 'a group of people playing a game of baseball .',
#  '000000530888': 'a large large large large elephant sitting on a bench .',
#  '000000058965': 'two men are standing in a field of grass .',
#  '000000124836': 'a woman sitting on a table with a white hat .',
#  '000000236155': 'a woman sitting on a bed with a white hat .',
#  '000000447557': 'a man in a blue shirt and blue shirt is standing in front of a blue shirt .',
#  '000000041413': 'a man in a blue shirt and a blue shirt is playing tennis .',
#  '000000281855': 'a person is flying a wave on the beach .',
#  '000000163192': 'a white cat sitting on a table with a white chair .',
#  '000000032176': 'a black and white dog sitting on a bench .',
#  '000000283382': 'a man is sitting on the side of a bench .',
#  '000000447726': 'a group of people are parked in front of a city .',
#  '000000244349': 'a group of people walking down a street .',
#  '000000526680': 'a living room with a laptop and a laptop .',
#  '000000289204': 'a group of people riding on a street .',
#  '000000296696': 'a man is sitting on the beach with a large blue umbrella .',
#  '000000051530': 'a group of people standing in a field of grass .',
#  '000000056306': 'a group of people walking down a street .',
#  '000000546285': 'a group of people standing on a street with a large building .',
#  '000000176192': 'a cat sitting on a bed next to a bed .',
#  '000000244582': 'a dog standing in a field with a green mouth .',
#  '000000325287': 'a man in a blue shirt is riding a motorcycle .',
#  '000000517430': 'a red and white train parked in front of a street .',
#  '000000075557': 'a group of people are standing on a bench .',
#  '000000345590': 'a group of sheep standing in a field .',
#  '000000392315': 'a man riding a skateboard down a street .',
#  '000000098155': 'a man in a blue shirt and a white shirt is standing in a large building .',
#  '000000149572': 'a man in a black shirt is sitting on a bench .',
#  '000000453586': 'a group of people are sitting on the beach .',
#  '000000018467': 'a plate of food with a plate of food .',
#  '000000308838': 'a person is flying a kite on the beach .',
#  '000000323964': 'a woman in a white shirt is holding a white dog .',
#  '000000550392': 'a man in a black shirt is standing in front of a bench .',
#  '000000060602': 'a group of people walking down a street .',
#  '000000189153': 'a man in a blue shirt is standing in front of a large building .',
#  '000000034973': 'a small dog sitting on a table with a red mouth .',
#  '000000581302': 'a man is riding a skateboard on the beach .',
#  '000000146656': 'a group of people riding a boat on a beach .',
#  '000000124903': 'a large cat sitting on a table with a laptop .',
#  '000000102445': 'a man is sitting on a bench with a blue umbrella .',
#  '000000125729': 'a group of people standing in front of a large large kite .',
#  '000000331314': 'a group of people sitting on a bench .',
#  '000000393394': 'a kitchen with a white sink and a white sink',
#  '000000438932': 'a man in a white shirt and a white shirt is standing next to a white room with a white shirt .',
#  '000000371092': 'a man sitting on a table with a large white cake on it .',
#  '000000055033': 'a man in a white shirt and white shirt is standing on a bench .',
#  '000000302141': 'a large plane is sitting on the beach .',
#  '000000002982': 'a group of people standing in front of a building .',
#  '000000469731': 'a man riding a skateboard down a snowy slope .',
#  '000000166047': 'a man in a blue shirt is standing on a field .',
#  '000000390969': 'a group of people sitting on a street with a red umbrella .',
#  '000000564443': 'a group of people sitting on a bench .',
#  '000000231500': 'a man sitting on a table with a laptop on it .',
#  '000000568308': 'two people are standing in front of a building .',
#  '000000081259': 'a group of people sitting on a street with a large building .',
#  '000000016520': 'a group of sheep standing in a field .',
#  '000000242325': 'a group of people standing in a field with a tree .',
#  '000000140758': 'a group of people standing in the grass .',
#  '000000092910': 'a woman in a black shirt and white shirt is sitting on a table .',
#  '000000347267': 'a white dog with a white shirt and a white dog .',
#  '000000284722': 'a group of people standing on a bench .',
#  '000000570019': 'a white plate with a white bowl of food on it .',
#  '000000141240': 'a large large large white bear sitting on a bench .',
#  '000000050470': 'a man in a blue shirt is playing tennis .',
#  '000000125683': 'a man in a black shirt is standing in the background .',
#  '000000079831': 'a person sitting on a table with a table with a table .',
#  '000000253419': 'a large plane flying in the air with a kite .',
#  '000000242029': 'a train is parked on the side of a road .',
#  '000000074411': 'a train is parked on the road with a red and a red and white train and white train train .',
#  '000000571563': 'a man in a white shirt is standing in front of a large large large large large large large building .',
#  '000000385672': 'a black and white cat sitting on a bench .',
#  '000000286673': 'a pizza with a white bowl of food on it .',
#  '000000462993': 'a woman in a black shirt and white shirt is sitting in front of a room with a large room .',
#  '000000455549': 'a small cat sitting on a table with a white umbrella .',
#  '000000486421': 'a group of elephants standing in a field .',
#  '000000575274': 'a group of people standing on a bench .',
#  '000000349566': 'a group of zebras standing in a field .',
#  '000000365833': 'a group of zebras standing in a field .',
#  '000000048474': 'a group of people standing in front of a large large large large large large large large large large large large large large large large building .',
#  '000000509267': 'a group of people are standing in front of a building .',
#  '000000241918': 'a man in a blue shirt is standing on a snow slope .',
#  '000000319781': 'a man in a black shirt and white shirt is standing in front of a large large large large large large large large large large building .',
#  '000000046171': 'a man is sitting on a table with a large white umbrella .',
#  '000000056193': 'a red and white bus is parked on the street .',
#  '000000326496': 'a woman in a blue shirt is holding a blue umbrella .',
#  '000000351288': 'a group of people are sitting on a beach .',
#  '000000352735': 'a large large large large large building with a red umbrella .',
#  '000000429908': 'a table with a table with a table and a table .',
#  '000000323462': 'a cat sitting on top of a bed .',
#  '000000182295': 'a man in a blue shirt is standing on a street .',
#  '000000179758': 'a group of people standing in a field with a frisbee .',
#  '000000411445': 'a cat sitting on a bed with a white hat .',
#  '000000552579': 'a group of people standing in the water .',
#  '000000402243': 'a group of people sitting on a table with a laptop .',
#  '000000465414': 'a group of people walking down a street with a street .',
#  '000000565387': 'a man in a black shirt and white shirt is standing next to a large large large kitchen room .',
#  '000000503318': 'a man is standing on a beach with a blue umbrella .',
#  '000000241790': 'a large large large airplane flying in the sky .',
#  '000000365631': 'a group of people standing on a beach .',
#  '000000559830': 'a group of people standing on a bench .',
#  '000000269958': 'a group of people standing in front of a building .',
#  '000000383760': 'a group of people on a beach with a kite on it .',
#  '000000317896': 'a man in a white shirt is sitting on a table .',
#  '000000041962': 'a man in a blue shirt is sitting on a beach .',
#  '000000030151': 'a man in a black shirt is standing in front of a large black dog .',
#  '000000028674': 'a man is sitting on a bench with a red shirt .',
#  '000000344765': 'a large large large large large large clock on a wooden wall .',
#  '000000208779': 'a group of people standing next to a large large large elephant .',
#  '000000392105': 'a red train parked on the side of a street .',
#  '000000179687': 'a large large large clock tower with a blue umbrella .',
#  '000000532673': 'a group of zebras standing in a field .',
#  '000000302364': 'a woman in a white shirt is standing in a field .',
#  '000000240449': 'a person riding a snowboard on a snowy slope',
#  '000000516329': 'a woman in a white shirt is holding a white shirt and a white hat .',
#  '000000064036': 'a man in a blue shirt is playing a frisbee .',
#  '000000165064': 'a man is sitting on a beach with a kite .',
#  '000000083093': 'a group of people sitting on a bench .',
#  '000000225053': 'a man is playing a frisbee in a field .',
#  '000000573483': 'a plate with a pizza on it with a table .',
#  '000000072396': 'a large clock sitting on the side of a building .',
#  '000000330916': 'a large black and white cat sitting in front of a building .',
#  '000000401458': 'a group of men standing in front of a tree .',
#  '000000522464': 'a cat sitting on top of a table .',
#  '000000322769': 'a bathroom with a sink and a sink',
#  '000000168349': 'a woman in a white shirt and white shirt is standing in front of a bed .',
#  '000000425470': 'a woman in a red shirt is sitting on a table .',
#  '000000382873': 'a man is playing tennis on a field .',
#  '000000091681': 'a woman sitting on a table with a white dog on it .',
#  '000000003461': 'a group of people standing on a bench .',
#  '000000339031': 'a person is flying a kite in the water .',
#  '000000458629': 'a white dog is sitting on a bed .',
#  '000000534898': 'a man in a red shirt is playing a frisbee .',
#  '000000319121': 'a group of people standing in front of a field .',
#  '000000484418': 'a man sitting on a bench with a blue umbrella .',
#  '000000170662': 'a train is sitting on a field with a train .',
#  '000000051501': 'a man in a blue shirt and white shirt is standing in front of a building with a building with a building .',
#  '000000458603': 'a group of people standing on a bench .',
#  '000000116633': 'a man is sitting on a bench in the water .',
#  '000000166018': 'a kitchen with a white sink and a kitchen .',
#  '000000240889': 'a man is sitting on a bench on the street .',
#  '000000094884': 'a man sitting on a bench with a blue shirt .',
#  '000000018183': 'a bathroom with a sink and a toilet .',
#  '000000022198': 'a man in a blue shirt is riding a blue board .',
#  '000000435139': 'a group of people standing on a field .',
#  '000000484494': 'a large large horse is standing in front of a building .',
#  '000000543042': 'a group of people standing in front of a large large large large large large large large large large elephant .',
#  '000000320429': 'a man in a blue shirt is standing in front of a large large large large large large large boat .',
#  '000000525823': 'a man in a red shirt is standing in front of a building .',
#  '000000578856': 'a group of people standing on a beach with a kite .',
#  '000000383605': 'a baseball player is playing a game of baseball .',
#  '000000402095': 'a woman in a red shirt is holding a red shirt .',
#  '000000401528': 'a group of people standing on a field .',
#  '000000196379': 'a man in a blue shirt is standing on a street .',
#  '000000538444': 'a large large cat sitting on top of a table .',
#  '000000542502': 'a red fire hydrant sitting on the side of a street .',
#  '000000144734': 'a group of people sitting on a bench .',
#  '000000482751': 'a group of people sitting on a field .',
#  '000000158737': 'a group of people playing baseball in a field .',
#  '000000089253': 'a man is sitting on a bench with a black and a black dog .',
#  '000000559908': 'a white plate with a white bowl of food on it .',
#  '000000114229': 'a man in a white shirt and white shirt is sitting on a bed .',
#  '000000198426': 'a woman is sitting on a bench with a black shirt .',
#  '000000556473': 'a man riding a skateboard on a beach .',
#  '000000100140': 'a group of people are sitting in front of a building .',
#  '000000057979': 'a man is standing on a skateboard in the water .',
#  '000000217495': 'a man in a white shirt and white shirt is standing in front of a large large large large large large large picture of a group of people .',
#  '000000422608': 'a man in a green shirt is standing on a field .',
#  '000000341219': 'two men are sitting on a bench .',
#  '000000224541': 'a man with a hat and a laptop on a table .',
#  '000000310558': 'a man in a blue shirt is standing on a sidewalk .',
#  '000000557344': 'a man in a blue shirt is sitting on a table .',
#  '000000045923': 'a man in a blue shirt is holding a blue umbrella .',
#  '000000457948': 'a group of people standing in front of a bench .',
#  '000000025516': 'a man is standing on a snowy hill .',
#  '000000457726': 'a group of people sitting on a bench .',
#  '000000162087': 'a group of people sitting on a table .',
#  '000000081357': 'a man is sitting on a bench with a black shirt .',
#  '000000425772': 'a group of people are sitting on a city street .',
#  '000000477759': 'a large cat sitting in a room with a large clock in it .',
#  '000000216820': 'a plate of food with a white bowl of food .',
#  ...}

# %%
with open("./p2/dict2.json", "w") as f:
    json.dump(dict2, f, indent=4)

# %%
dict
# Out:
# {'000000165547': 'a bathroom with a toilet and a sink',
#  '000000518586': 'a man is standing on a bench next to a tree .',
#  '000000249720': 'a man in a white shirt and white shirt is standing in front of a tree .',
#  '000000122934': 'a man is standing on a bench in the air .',
#  '000000393258': 'a man in a blue shirt and white shirt is sitting on a bench .',
#  '000000266041': 'a man in a white shirt and white shirt is sitting on a bed .',
#  '000000053015': 'a woman in a white shirt is sitting on a table .',
#  '000000039540': 'a large kitchen with a table and a table .',
#  '000000320039': 'a woman in a white shirt and white shirt is sitting on a table .',
#  '000000014941': 'a woman is sitting on a table with a dog .',
#  '000000304355': 'a cat sitting on a bed with a white toilet .',
#  '000000096514': 'a man is sitting on a bench in the middle of a room .',
#  '000000578703': 'a man is riding a skateboard down a street .',
#  '000000350966': 'a train is parked on a street with a train .',
#  '000000201220': 'a man in a white shirt and a white shirt is holding a cell phone .',
#  '000000309100': 'a man in a blue shirt is standing on a field .',
#  '000000298726': 'a man in a blue shirt is playing a game of baseball .',
#  '000000214742': 'a street sign is parked in front of a building .',
#  '000000135356': 'a man in a white shirt and white shirt is sitting on a bed .',
#  '000000279806': 'a man in a blue shirt is riding a skateboard .',
#  '000000163361': 'a man is standing on a beach with a kite .',
#  '000000135978': 'a group of people standing in front of a building .',
#  '000000163460': 'a man in a blue shirt is playing tennis .',
#  '000000434129': 'a man is standing on a bench in front of a building .',
#  '000000575428': 'a group of people standing on a field .',
#  '000000046912': 'a man is standing on a bench in front of a building .',
#  '000000377326': 'a man in a blue shirt is riding a skateboard .',
#  '000000302219': 'a red fire hydrant sitting on a bench .',
#  '000000300655': 'a large train is on the beach with a large building .',
#  '000000178748': 'a small dog is sitting on a table .',
#  '000000519299': 'a man in a blue shirt is standing on a bench .',
#  '000000216303': 'a man is playing tennis on a tennis court .',
#  '000000038892': 'a cat sitting on a bed with a cat .',
#  '000000487151': 'a baseball player is playing baseball .',
#  '000000461883': 'a man is playing a game of tennis .',
#  '000000470313': 'a small dog is sitting on a bench .',
#  '000000137490': 'a man in a blue shirt is riding a skateboard .',
#  '000000491965': 'a man is standing next to a street sign .',
#  '000000056400': 'a man in a white shirt and a black shirt is holding a cell phone .',
#  '000000042055': 'a man is playing tennis .',
#  '000000164594': 'a man in a white shirt is standing in front of a building .',
#  '000000303215': 'a man is sitting on a table with a laptop .',
#  '000000481891': 'a woman in a white shirt is sitting on a table .',
#  '000000301755': 'a man is standing on a bench with a skateboard .',
#  '000000047940': 'a cat sitting on a bed with a laptop .',
#  '000000192233': 'a man in a red shirt is standing in front of a red shirt and white shirt and white shirt and white shirt and white shirt and white shirt and white shirt and white shirt is standing in front of a red shirt .',
#  '000000417590': 'a man in a baseball shirt is playing a game of baseball .',
#  '000000164899': 'a woman is sitting on a bench in a room .',
#  '000000368505': 'a man is standing on a bench in front of a building .',
#  '000000513778': 'a man is standing on a beach with a kite .',
#  '000000352476': 'a man is standing on a street with a large horse .',
#  '000000259879': 'a man is standing on a field with a frisbee .',
#  '000000178361': 'a man is sitting on a bench in front of a building .',
#  '000000020972': 'a man is sitting on a bench with a dog .',
#  '000000367881': 'a man is standing on a bench in the middle of a field .',
#  '000000451305': 'a man is sitting on a bench in front of a building .',
#  '000000485294': 'a bathroom with a sink and a sink',
#  '000000177990': 'a man in a red shirt is standing in front of a red shirt and white shirt and white shirt and white shirt and white shirt and white shirt is standing on a white shirt and white shirt .',
#  '000000540159': 'a cat sitting on a bench next to a laptop .',
#  '000000096539': 'a cat sitting on a bed with a cat on it .',
#  '000000147904': 'a man is riding a kite on a beach .',
#  '000000546642': 'a man is standing in the middle of a field .',
#  '000000307989': 'a woman is sitting on a table with a pizza .',
#  '000000267840': 'a man is standing on a field with a dog .',
#  '000000405675': 'a group of people are standing in a field .',
#  '000000378823': 'a man in a blue shirt and white shirt is standing in front of a building .',
#  '000000394322': 'a group of people standing in front of a building .',
#  '000000411043': 'a group of people standing in a field .',
#  '000000137573': 'a man in a white shirt is standing in front of a tree .',
#  '000000301155': 'a group of people are standing on a street .',
#  '000000333156': 'a woman is sitting on a table with a cake .',
#  '000000241068': 'a man is standing on a beach with a kite .',
#  '000000285734': 'a baseball player is playing tennis on a field .',
#  '000000408143': 'a man is sitting on a table with a laptop .',
#  '000000491872': 'a person is sitting on a beach with a blue umbrella .',
#  '000000084123': 'a large clock tower with a clock on it .',
#  '000000102996': 'a man is standing in the middle of a building .',
#  '000000251044': 'a man in a white shirt and white shirt is holding a cell phone .',
#  '000000201859': 'a man riding a skateboard down a street .',
#  '000000579326': 'a woman in a white shirt is sitting on a bench .',
#  '000000370038': 'a man in a white shirt and white shirt is standing in front of a building .',
#  '000000548729': 'a man in a blue shirt and white shirt is standing in front of a red shirt and a red shirt and white shirt and white shirt and white shirt and white shirt is standing in a red shirt .',
#  '000000140197': 'a man in a blue shirt and white shirt is standing on a sidewalk .',
#  '000000353836': 'a man in a blue shirt is sitting on a bench .',
#  '000000491681': 'a man in a blue shirt is riding a wave .',
#  '000000289941': 'a woman is sitting on a table with a cake .',
#  '000000540834': 'a man is standing in front of a large room .',
#  '000000318825': 'a man is playing tennis on a tennis court .',
#  '000000226874': 'a plate of food with a plate of food .',
#  '000000118432': 'a man is standing on a bench in front of a building .',
#  '000000146640': 'a man in a white shirt and white shirt is standing in front of a white shirt and a white shirt and a white shirt and a white dog .',
#  '000000113757': 'a cat sitting on a bed in a room .',
#  '000000346702': 'a cat sitting on a bed with a toilet .',
#  '000000296871': 'a man in a blue shirt is sitting on a bench .',
#  '000000136572': 'a man in a red shirt and white shirt is standing in front of a building .',
#  '000000238602': 'a man in a white shirt and white shirt is sitting on a couch .',
#  '000000460972': 'a group of people standing on a field .',
#  '000000210766': 'a cat sitting on a bed with a toilet .',
#  '000000006789': 'a train is parked on a street with a train station .',
#  '000000502275': 'a plate of food with a plate of food .',
#  '000000370399': 'a man in a red shirt is standing on a bench .',
#  '000000437618': 'a group of people standing on a beach with a kite .',
#  '000000099389': 'a man is sitting on a table with a laptop .',
#  '000000536294': 'a man is riding a tennis racket on a beach .',
#  '000000106096': 'a bathroom with a sink and a sink',
#  '000000032960': 'a man in a red shirt is riding a skateboard .',
#  '000000206587': 'a group of people standing in a field of grass .',
#  '000000102466': 'a large white dog is sitting on a beach .',
#  '000000397903': 'a black and white dog is sitting on a bench .',
#  '000000074001': 'a man in a white shirt is standing in front of a building .',
#  '000000213023': 'a group of people standing in a field .',
#  '000000082740': 'a man is standing on a bench with a skateboard .',
#  '000000553852': 'a large clock on a street with a clock on it .',
#  '000000557396': 'a large clock tower with a clock on it .',
#  '000000397658': 'a man in a white shirt and white shirt is standing in front of a building .',
#  '000000315474': 'a group of people standing on a street .',
#  '000000049667': 'a man in a white shirt and white shirt is standing in the middle of a room .',
#  '000000336937': 'a man is standing on a bench in the background .',
#  '000000302302': 'a group of people standing on a beach with a kite .',
#  '000000013414': 'a man is sitting on a bed with a laptop .',
#  '000000137507': 'a cat sitting on a table with a laptop .',
#  '000000481281': 'a woman in a white shirt is sitting on a bed .',
#  '000000358247': 'a man in a blue shirt and white shirt is standing on a sidewalk .',
#  '000000420610': 'a man is sitting on a table with a laptop .',
#  '000000423588': 'a man riding a skateboard down a snowy slope .',
#  '000000033798': 'a kitchen with a sink and a sink',
#  '000000425676': 'a baseball player is standing on a field .',
#  '000000168898': 'a plate of food with a plate of food .',
#  '000000423919': 'a cat sitting on a bed with a white toilet .',
#  '000000306313': 'a cat sitting on top of a bed .',
#  '000000504452': 'a man is standing on a skateboard in the air .',
#  '000000091636': 'a man in a blue shirt and white shirt is standing on a skateboard .',
#  '000000482907': 'a man is riding a wave on a beach .',
#  '000000053677': 'a man is sitting on a bench with a red umbrella .',
#  '000000033717': 'a large clock tower with a large clock on it .',
#  '000000329806': 'a man is standing on a bench with a frisbee .',
#  '000000332074': 'a man in a blue shirt and white shirt is standing on a skateboard .',
#  '000000022051': 'a group of people standing on a beach .',
#  '000000439902': 'a man in a black shirt and white shirt is standing in front of a large room .',
#  '000000523123': 'a man in a white shirt and white shirt is sitting on a table .',
#  '000000252280': 'a group of people standing in a field .',
#  '000000150616': 'a bathroom with a toilet and a sink',
#  '000000369601': 'a man in a white shirt and white shirt is standing in front of a building .',
#  '000000189600': 'a man is standing next to a large dog .',
#  '000000071095': 'a white dog is sitting on a bench .',
#  '000000301753': 'a baseball player is standing on a field .',
#  '000000272357': 'a man in a blue shirt is playing a game of baseball .',
#  '000000265971': 'a man is playing tennis on a tennis court .',
#  '000000043404': 'a man in a white shirt is standing on a bench .',
#  '000000429160': 'a bathroom with a sink and a sink',
#  '000000095482': 'a large clock tower with a clock on it .',
#  '000000488069': 'a man in a blue shirt is standing on a skateboard .',
#  '000000553129': 'a man is sitting on a bench in a room .',
#  '000000570594': 'a man in a blue shirt is standing in the middle of a field .',
#  '000000047916': 'a man in a blue shirt is standing on a field .',
#  '000000240655': 'a man is sitting on a bench next to a red bus .',
#  '000000289263': 'a man in a blue shirt is standing on a beach .',
#  '000000480438': 'a plate of food with a plate of food .',
#  '000000172673': 'a man is sitting on a bench with a laptop .',
#  '000000159151': 'a man is standing on a bench with a cell phone .',
#  '000000195267': 'a man is standing in front of a large field .',
#  '000000087483': 'a group of people standing on a beach .',
#  '000000126540': 'a cat sitting on a bed with a laptop .',
#  '000000544538': 'a man in a white shirt and white shirt is sitting on a table .',
#  '000000050034': 'a man is sitting on a bench in a room .',
#  '000000438046': 'a cat sitting on a table with a laptop .',
#  '000000217561': 'a man is sitting on a bench with a dog .',
#  '000000326021': 'a woman in a white shirt is holding a white dog .',
#  '000000168805': 'a group of people standing on a road with a large building .',
#  '000000580766': 'a man is standing on a bench in front of a building .',
#  '000000443652': 'a bathroom with a toilet and a toilet .',
#  '000000224247': 'a man is riding a wave on a beach .',
#  '000000146773': 'a man in a white shirt and white shirt is sitting on a bed .',
#  '000000366421': 'a man is sitting on a bench in front of a building .',
#  '000000518908': 'a man in a white shirt and white shirt is sitting on a bench .',
#  '000000172886': 'a bathroom with a sink and a sink',
#  '000000494404': 'a man is standing on a beach with a kite .',
#  '000000022979': 'a man is sitting on a bench in front of a building .',
#  '000000380828': 'a cat sitting on a bed with a cat on it .',
#  '000000151432': 'a cat sitting on a bed with a laptop .',
#  '000000215549': 'a man in a white shirt and white shirt is playing a game of tennis .',
#  '000000044421': 'a man in a white shirt and white shirt is standing in front of a window .',
#  '000000099707': 'a man in a blue shirt and white shirt is standing on a skateboard .',
#  '000000512145': 'a man in a blue shirt and white shirt is holding a cell phone .',
#  '000000161940': 'a man in a white shirt is sitting on a bench .',
#  '000000370819': 'a plate of food with a plate of food .',
#  '000000438848': 'a man is standing on a bench next to a tree .',
#  '000000168775': 'a woman in a white shirt is sitting on a table .',
#  '000000563730': 'a white plate with a white and white plate of food .',
#  '000000509185': 'a man is riding a skateboard on a skateboard .',
#  '000000287830': 'a man in a blue shirt is riding a wave .',
#  '000000324710': 'a man is sitting on a bench in the middle of a room .',
#  '000000026501': 'a man in a white shirt is sitting on a bench .',
#  '000000073981': 'a man is standing on a bench in front of a building .',
#  '000000377911': 'a cat sitting on a bed with a cat on it .',
#  '000000098268': 'a baseball player is standing on a field .',
#  '000000382557': 'a man is riding a skateboard on a skateboard .',
#  '000000473433': 'a man in a white shirt and white shirt is standing in a room .',
#  '000000307048': 'a man is sitting on a table with a laptop .',
#  '000000162855': 'a man in a blue shirt is playing a tennis .',
#  '000000494456': 'a man in a blue shirt is riding a skateboard .',
#  '000000047611': 'a white plate with a white and a white plate of food .',
#  '000000175318': 'a man is sitting on a bench in front of a building .',
#  '000000010217': 'a plate of food with a plate of food .',
#  '000000124210': 'a man in a blue shirt is riding a skateboard .',
#  '000000113897': 'a bathroom with a sink and a sink',
#  '000000548464': 'a man in a blue shirt is standing on a bench .',
#  '000000549932': 'a man in a white shirt and white shirt is sitting on a bench .',
#  '000000415153': 'a man is standing on a bench in front of a building .',
#  '000000036508': 'a plate of food with a plate of food .',
#  '000000519446': 'a cat sitting on top of a table .',
#  '000000222866': 'a plate of food with a plate of food .',
#  '000000402115': 'a cat sitting on a bench next to a large building .',
#  '000000345160': 'a man in a white shirt and white shirt is holding a red umbrella .',
#  '000000486846': 'a man is sitting on a table with a laptop .',
#  '000000191893': 'a man is standing on a beach with a kite .',
#  '000000224037': 'a large clock on a street with a red sign .',
#  '000000445267': 'a small dog is sitting on a bench .',
#  '000000126345': 'a group of people standing in a field with a green field .',
#  '000000191078': 'a plate of food with a table and a plate of food .',
#  '000000051339': 'a man is standing on a bench with a tennis racket .',
#  '000000266437': 'a man in a blue shirt is standing on a skateboard .',
#  '000000163309': 'a woman in a blue shirt is holding a white dog .',
#  '000000138022': 'a man is standing on a street with a red and white bus .',
#  '000000092815': 'a woman is sitting on a table with a laptop .',
#  '000000470801': 'a man in a blue shirt is standing on a beach .',
#  '000000311904': 'a cat sitting on top of a bed .',
#  '000000579696': 'a cat sitting on top of a wooden bench .',
#  '000000406201': 'a bathroom with a toilet and a sink',
#  '000000575012': 'a woman is sitting on a table with a dog .',
#  '000000381037': 'a bathroom with a toilet and a toilet .',
#  '000000383209': 'a cat sitting on a bed with a white dog .',
#  '000000063434': 'a woman in a white shirt is sitting on a table .',
#  '000000156532': 'a man is riding a wave on a beach .',
#  '000000038064': 'a baseball player is standing in the grass .',
#  '000000160886': 'a cat sitting on a table with a laptop .',
#  '000000468972': 'a plate of food with a plate of food .',
#  '000000168692': 'a large clock tower with a red umbrella .',
#  '000000556892': 'a man is standing on a bench in the air .',
#  '000000397980': 'a man in a blue shirt is playing tennis .',
#  '000000309222': 'a man is riding a skateboard on a beach .',
#  '000000145391': 'a woman in a white shirt and white shirt is sitting on a bed .',
#  '000000215303': 'a man in a black shirt is standing in front of a building .',
#  '000000456574': 'a man in a blue shirt and white shirt is standing on a street .',
#  '000000247394': 'a man is riding a wave on a beach .',
#  '000000275744': 'a man is riding a skateboard on a skateboard .',
#  '000000560637': 'a large clock tower with a clock on it .',
#  '000000286176': 'a cat sitting on a table with a laptop .',
#  '000000549112': 'a cat sitting on a table with a laptop .',
#  '000000275117': 'a man is standing on a bench next to a tree .',
#  '000000054924': 'a man in a white shirt is sitting on a table .',
#  '000000303667': 'a man in a white shirt and white shirt is sitting on a couch .',
#  '000000390769': 'a man is sitting on a bench in front of a building .',
#  '000000500784': 'a bathroom with a sink and a sink',
#  '000000297976': 'a bathroom with a sink and a sink',
#  '000000264909': 'a group of people are standing on a street .',
#  '000000200681': 'a man in a white shirt is standing in a field .',
#  '000000344521': 'a plate of food with a plate of food .',
#  '000000111944': 'a man in a blue shirt is riding a skateboard .',
#  '000000054870': 'a woman is sitting on a bench with a white dog .',
#  '000000426342': 'a group of people standing in a field with a giraffe .',
#  '000000344368': 'a large white dog is sitting on a bench .',
#  '000000302710': 'a man in a blue shirt is standing in front of a large building .',
#  '000000127119': 'a baseball player is playing baseball .',
#  '000000260099': 'a group of people standing on a bench in front of a building .',
#  '000000003771': 'a man in a white shirt is standing in a field .',
#  '000000349896': 'a man is standing in the grass with a kite .',
#  '000000274591': 'a man is standing on a bench with a skateboard .',
#  '000000098322': 'a man in a blue shirt is standing in front of a large blue shirt and white shirt and white shirt and white shirt and white shirt and white shirt and white shirt and white shirt is standing in the snow .',
#  '000000053665': 'a man in a blue shirt is riding a wave .',
#  '000000189694': 'a cat sitting on a bed with a cat on it .',
#  '000000011182': 'a man in a red shirt is standing on a bench .',
#  '000000354027': 'a man in a white shirt is standing in front of a white shirt and a white dog .',
#  '000000107511': 'a man in a white shirt and white shirt is standing in front of a building .',
#  '000000141426': 'a man is sitting on a bench in front of a building .',
#  '000000158588': 'a large clock tower with a clock on it .',
#  '000000425522': 'a man in a blue shirt and white shirt is standing on a bench .',
#  '000000042288': 'a man in a blue shirt is riding a skateboard .',
#  '000000303814': 'a man in a blue shirt is riding a skateboard .',
#  '000000068205': 'a woman is sitting on a table with a laptop .',
#  '000000015797': 'a man in a blue shirt is riding a skateboard .',
#  '000000034708': 'a man in a white shirt and a white shirt is sitting on a table .',
#  '000000098187': 'a man is standing on a beach with a kite .',
#  '000000378311': 'a bathroom with a sink and a sink',
#  '000000219546': 'a cat sitting on a table with a laptop .',
#  '000000406155': 'a man in a blue shirt is riding a wave .',
#  '000000006393': 'a man is sitting on a bed with a white toilet .',
#  '000000267802': 'a man in a white shirt is standing on a bench .',
#  '000000523597': 'a cat sitting on a bed with a toilet .',
#  '000000079836': 'a man is riding a wave on a beach .',
#  '000000005418': 'a group of people standing in a field .',
#  '000000474388': 'a group of people standing on a field .',
#  '000000532580': 'a group of people are standing on a street .',
#  '000000223857': 'a man in a blue shirt is standing on a skateboard .',
#  '000000215024': 'a man is riding a wave on a surfboard .',
#  '000000020147': 'a group of people standing in a field .',
#  '000000287846': 'a man is standing on a beach with a kite .',
#  '000000182736': 'a man in a white shirt and white shirt is standing in a field .',
#  '000000227851': 'a man in a blue shirt is playing tennis .',
#  '000000349590': 'a plate of food with a plate of food .',
#  '000000266853': 'a dog is standing in the grass with a dog .',
#  '000000099747': 'a man in a white shirt is sitting on a bed .',
#  '000000393777': 'a man in a red shirt is sitting on a bench .',
#  '000000092338': 'a group of people standing in a field .',
#  '000000114616': 'a woman is sitting on a bench next to a white dog .',
#  '000000029160': 'a person riding a wave on a surfboard .',
#  '000000023051': 'a group of people standing in front of a building .',
#  '000000408363': 'a man in a white shirt and white shirt is sitting on a bench .',
#  '000000575911': 'a dog is sitting on a bench next to a tree .',
#  '000000513887': 'a cat sitting on a table with a laptop .',
#  '000000470115': 'a man is sitting on a bench next to a large dog .',
#  '000000268058': 'a plate of food with a plate of food .',
#  '000000136181': 'a group of people standing on a beach .',
#  '000000400265': 'a bathroom with a sink and a sink .',
#  '000000493751': 'a man is sitting on a bench in a field .',
#  '000000297414': 'a cat sitting on top of a bed .',
#  '000000148614': 'a bathroom with a sink and a sink',
#  '000000370095': 'a large bus parked on a street with a red sign .',
#  '000000339019': 'a man is standing on a beach with a kite .',
#  '000000574208': 'a man in a blue shirt is playing tennis .',
#  '000000528011': 'a man riding a skateboard on a beach .',
#  '000000009813': 'a man is standing on a bench in front of a building .',
#  '000000429170': 'a large train is on a road with a large building .',
#  '000000273196': 'a man in a white shirt is sitting on a bed .',
#  '000000492025': 'a man in a blue shirt is standing on a bench .',
#  '000000185360': 'a train is parked on the street with a building .',
#  '000000062824': 'a man is sitting on a bench in front of a building .',
#  '000000471625': 'a group of people are standing on a street .',
#  '000000354368': 'a man in a blue shirt is standing on a bench .',
#  '000000217393': 'a man in a blue shirt is standing on a field .',
#  '000000032909': 'a man is sitting on a bench in a room .',
#  '000000232627': 'a white dog is sitting on a bench .',
#  '000000117201': 'a man in a blue shirt is riding a skateboard .',
#  '000000156282': 'a large airplane is flying over a body of water .',
#  '000000169683': 'a group of people standing on a bench in a field .',
#  '000000441054': 'a white dog is standing in a field .',
#  '000000472295': 'a man in a blue shirt is riding a skateboard .',
#  '000000321603': 'a man in a white shirt and a black shirt is sitting on a table .',
#  '000000554445': 'a woman is sitting on a table with a laptop .',
#  '000000281676': 'a man in a blue shirt is standing on a bench .',
#  '000000330356': 'a group of people standing in a field with a kite .',
#  '000000176527': 'a man in a white shirt is standing on a skateboard .',
#  '000000523252': 'a group of people are standing on a street .',
#  '000000350491': 'a small dog is standing in the grass .',
#  '000000175136': 'a large clock on the side of a building .',
#  '000000085852': 'a man is standing on a bench in front of a tree .',
#  '000000330419': 'a man is riding a skateboard down a street .',
#  '000000049068': 'a man in a white shirt and white shirt is standing in a field .',
#  '000000524979': 'a man in a white shirt and white shirt is sitting on a bed .',
#  '000000030403': 'a large clock on the side of a street .',
#  '000000255315': 'a man is sitting on a bed with a toilet .',
#  '000000445668': 'a person is flying a kite in the air .',
#  '000000066191': 'a man in a red shirt is playing a game of baseball .',
#  '000000079924': 'a person is sitting on a bench in the water .',
#  '000000082576': 'a man is standing on a beach with a kite .',
#  '000000282841': 'a man is sitting on a bench in a room .',
#  '000000326555': 'a man in a blue shirt is riding a skateboard .',
#  '000000254929': 'a plate of food with a plate of food .',
#  '000000100409': 'a woman is sitting on a bed with a cat .',
#  '000000462632': 'a large white cat sitting on top of a table .',
#  '000000536879': 'a woman in a white shirt and white shirt is sitting on a table .',
#  '000000192079': 'a plate of food with a plate of food .',
#  '000000500420': 'a man is flying a kite in the air .',
#  '000000361751': 'a group of people standing on a bench .',
#  '000000291144': 'a cat sitting on a bed with a white dog .',
#  '000000143696': 'a large clock on a street with a clock on it .',
#  '000000310757': 'a white plate with a white plate of food .',
#  '000000489798': 'a man in a red shirt and white shirt is standing in front of a red and white shirt and white dog .',
#  '000000452297': 'a cat sitting on a bench next to a large white dog .',
#  '000000199819': 'a woman in a white shirt and a black shirt is holding a cake .',
#  '000000552018': 'a woman is sitting on a table with a cake .',
#  '000000419723': 'a cat sitting on a table with a laptop .',
#  '000000344025': 'a man in a white shirt and white shirt is sitting on a table .',
#  '000000106206': 'a man is holding a skateboard on a skateboard .',
#  '000000394132': 'a person is riding a skateboard on a snowy slope .',
#  '000000161539': 'a man in a blue shirt is sitting on a bench .',
#  '000000347648': 'a woman is sitting on a table with a laptop .',
#  '000000326592': 'a group of people standing in a field .',
#  '000000173997': 'a white dog is sitting on a table .',
#  '000000401758': 'a man in a blue shirt is standing on a bench .',
#  '000000213799': 'a man in a white shirt and white shirt is sitting on a table .',
#  '000000253474': 'a man in a blue shirt is riding a skateboard .',
#  '000000559136': 'a man in a blue shirt is riding a wave .',
#  '000000248956': 'a large clock tower with a clock on it .',
#  '000000381318': 'a plate of food with a plate of food .',
#  '000000366683': 'a plate of food with a plate of food .',
#  '000000019491': 'a woman in a white shirt is sitting on a table .',
#  '000000171201': 'a woman is sitting on a table with a laptop .',
#  '000000404027': 'a man in a blue shirt is riding a skateboard .',
#  '000000286106': 'a man in a blue shirt and white shirt is standing on a sidewalk .',
#  '000000253825': 'a man in a white shirt and white shirt is sitting on a bed .',
#  '000000536403': 'a woman is sitting on a table with a laptop .',
#  '000000331223': 'a man in a white shirt and white shirt is sitting on a table .',
#  '000000432798': 'a cat sitting on top of a table .',
#  '000000342060': 'a man in a blue shirt is standing on a skateboard .',
#  '000000207458': 'a man in a blue shirt is standing on a bench .',
#  '000000257864': 'a plate of food with a white plate of food .',
#  '000000146675': 'a man is holding a tennis racket on a tennis court .',
#  '000000411177': 'a kitchen with a sink and a sink',
#  '000000110617': 'a man in a white shirt is standing on a bench .',
#  '000000169872': 'a man in a red shirt and white shirt is sitting on a street .',
#  '000000454810': 'a man is standing on a bench next to a building .',
#  '000000082312': 'a man in a red shirt is standing on a street .',
#  '000000373578': 'a man is standing on a bench in the air .',
#  '000000121503': 'a train on a street with a red bus on it .',
#  '000000015984': 'a man in a white shirt and white shirt is standing in a field .',
#  '000000515355': 'a white plate with a white plate of food .',
#  '000000478517': 'a small dog is standing in the grass .',
#  '000000389753': 'a cat sitting on a bed with a laptop .',
#  '000000418226': 'a cat sitting on a bed with a cat on it .',
#  '000000252617': 'a man is sitting on a table with a laptop .',
#  '000000415714': 'a man in a blue shirt is standing on a beach .',
#  '000000181403': 'a man is sitting on a bench in a room .',
#  '000000353130': 'a large white cat sitting on top of a table .',
#  '000000405334': 'a woman is sitting on a table with a dog .',
#  '000000357402': 'a man is playing tennis on a tennis court .',
#  '000000342387': 'a large pizza with a white and a white plate of food .',
#  '000000198495': 'a man is standing on a bench with a dog .',
#  '000000537727': 'a large clock on a bed with a clock on it .',
#  '000000373857': 'a large clock tower with a clock on it .',
#  '000000480223': 'a man in a white shirt is standing on a bench .',
#  '000000469130': 'a man is riding a skateboard on a beach .',
#  '000000190406': 'a train is parked on a bench next to a train station .',
#  '000000435187': 'a group of people standing on a street .',
#  '000000511420': 'a large train is on the beach with a red umbrella .',
#  '000000099543': 'a woman is sitting on a table with a laptop .',
#  '000000115636': 'a man in a blue shirt and white shirt is standing in front of a large blue shirt and white shirt and white shirt and white shirt and white shirt and white shirt and white shirt and white dog .',
#  '000000138185': 'a man is sitting on a table with a laptop .',
#  '000000053800': 'a man is sitting on a table with a laptop .',
#  '000000561619': 'a man is sitting on a bench in front of a kitchen .',
#  '000000396167': 'a man in a blue shirt is holding a tennis racket .',
#  '000000448275': 'a man is standing on a bench with a dog .',
#  '000000406050': 'a man in a white shirt is sitting on a bench .',
#  '000000320203': 'a man in a blue shirt is standing on a beach .',
#  '000000387506': 'a man is standing on a beach with a kite .',
#  '000000578467': 'a man is standing next to a large dog .',
#  '000000503207': 'a man is riding a skateboard on a skateboard .',
#  '000000009214': 'a group of people standing in a field of grass .',
#  '000000054627': 'a group of people standing in a field of grass .',
#  '000000143098': 'a man is holding a tennis racket on a tennis court .',
#  '000000069266': 'a man in a blue shirt is sitting on a bench .',
#  '000000457453': 'a man in a white shirt and white shirt is standing in front of a large room .',
#  '000000177173': 'a man in a blue shirt is standing on a skateboard .',
#  '000000065357': 'a man is sitting on a table with a laptop .',
#  '000000070240': 'a man in a white shirt and white shirt is sitting on a bed .',
#  '000000139734': 'a cat sitting on a table with a laptop .',
#  '000000010496': 'a group of people are standing on a beach .',
#  '000000285250': 'a man in a blue shirt is riding a wave .',
#  '000000520451': 'a man in a red shirt and white shirt is standing in front of a building .',
#  '000000521772': 'a train is parked on the tracks in the background .',
#  '000000138514': 'a man is sitting on a bed with a laptop .',
#  '000000049643': 'a large clock tower with a clock on it .',
#  '000000192866': 'a man is standing on a bench next to a building .',
#  '000000466839': 'a dog is standing in the grass in the grass .',
#  '000000359141': 'a man in a blue shirt is playing a game of baseball .',
#  '000000234749': 'a cat sitting on a bed with a cat on it .',
#  '000000000620': 'a man is sitting on a bed with a laptop .',
#  '000000496517': 'a woman is sitting on a table with a cake .',
#  '000000272785': 'a man is sitting on a bench with a laptop .',
#  '000000533522': 'a man in a white shirt and white shirt is standing in a room .',
#  '000000361638': 'a bathroom with a toilet and a sink',
#  '000000160014': 'a woman is sitting on a table with a cat .',
#  '000000376362': 'a man is standing on a beach with a kite .',
#  '000000298793': 'a large clock tower with a clock on it .',
#  '000000465969': 'a man in a white shirt and a black shirt is sitting on a table .',
#  '000000133660': 'a man is standing on a beach with a dog .',
#  '000000382171': 'a white dog is sitting on a bench .',
#  '000000157238': 'a woman is sitting on a bed with a cat .',
#  '000000057883': 'a man is riding a wave on a beach .',
#  '000000580082': 'a man is standing next to a large building .',
#  '000000280023': 'a woman in a white shirt is standing in front of a white dog .',
#  '000000406755': 'a woman in a white shirt is sitting on a table .',
#  '000000117691': 'a man is standing on a beach with a kite .',
#  '000000465080': 'a small dog is standing in the grass .',
#  '000000190297': 'a man is sitting on a bench with a cell phone .',
#  '000000507370': 'a cat sitting on a bed with a toilet .',
#  '000000531474': 'a group of people standing in front of a building .',
#  '000000089101': 'a man is standing on a bench in front of a building .',
#  '000000031578': 'a woman in a white shirt is standing in front of a white dog .',
#  '000000353652': 'a train is on the beach with a train on it .',
#  '000000546531': 'a man in a blue shirt is standing on a sidewalk .',
#  '000000200612': 'a group of people standing in a field .',
#  '000000304040': 'a man is standing on a bench in front of a building .',
#  '000000143569': 'a man in a blue shirt and white shirt is standing in front of a building .',
#  '000000494768': 'a group of people standing next to a building .',
#  '000000379165': 'a woman is sitting on a table with a dog .',
#  '000000333621': 'a man in a white shirt and white shirt is sitting on a table .',
#  '000000154955': 'a man is sitting on a bench in front of a building .',
#  '000000305451': 'a woman is sitting on a table with a dog .',
#  '000000418505': 'a bathroom with a toilet and a sink',
#  '000000535874': 'a table with a white and a white plate of food .',
#  '000000241860': 'a man is sitting on a table with a laptop .',
#  '000000399241': 'a man is riding a wave on a beach .',
#  '000000524646': 'a man is riding a wave on a beach .',
#  '000000351141': 'a man in a blue shirt is standing on a skateboard .',
#  '000000477321': 'a man in a blue shirt is standing on a beach .',
#  '000000387153': 'a bathroom with a sink and a sink',
#  '000000084157': 'a plate of food with a white plate of food .',
#  '000000415201': 'a cat sitting on a bed with a cat on it .',
#  '000000027675': 'a train is parked on a street with a bus .',
#  '000000295642': 'a train is parked on the side of a train station .',
#  '000000387181': 'a man in a blue shirt and white shirt is sitting on a couch .',
#  '000000178849': 'a man in a blue shirt and white shirt is standing in front of a building .',
#  '000000143192': 'a man in a white shirt is standing in the grass .',
#  '000000577176': 'a man in a red shirt and white shirt is standing in front of a building .',
#  '000000477782': 'a man in a blue shirt and white shirt is playing a game of tennis .',
#  '000000215107': 'a man in a blue shirt is riding a skateboard .',
#  '000000471480': 'a group of people standing in a field .',
#  '000000536827': 'a red fire hydrant sitting on a bench .',
#  '000000197408': 'a man in a white shirt and white shirt is standing in front of a building .',
#  '000000088377': 'a man is sitting on a bench in front of a building .',
#  '000000260373': 'a man in a blue shirt is standing on a skateboard .',
#  '000000290724': 'a man is riding a skateboard down a street .',
#  '000000184355': 'a man is sitting on a bench next to a building .',
#  '000000105172': 'a dog is sitting on a bench in a field .',
#  '000000448139': 'a group of people standing in a field of grass .',
#  '000000271373': 'a man in a blue shirt is riding a skateboard .',
#  '000000581204': 'a man in a white shirt is sitting on a bench .',
#  '000000278335': 'a man is riding a skateboard on a skateboard .',
#  '000000292844': 'a man in a white shirt and white shirt is sitting on a bench .',
#  '000000428039': 'a group of people standing in a field .',
#  '000000267417': 'a man in a blue shirt and white shirt is playing a game of frisbee .',
#  '000000495615': 'a man in a blue shirt is holding a tennis racket .',
#  '000000376422': 'a cat sitting on a table with a laptop .',
#  '000000483517': 'a man in a red shirt and white shirt is standing on a bench .',
#  '000000207142': 'a cat sitting on a table with a white dog .',
#  '000000141207': 'a group of people are standing on a beach .',
#  '000000038196': 'a black and white dog sitting on a bench .',
#  '000000341639': 'a group of people standing in a field with a large green field .',
#  '000000064389': 'a cat sitting on a bed with a laptop .',
#  '000000495079': 'a man in a red shirt is playing a game of baseball .',
#  '000000131696': 'a man is riding a skateboard on a beach .',
#  '000000054003': 'a man in a blue shirt is holding a cell phone .',
#  '000000330400': 'a man in a blue shirt is riding a skateboard .',
#  '000000015733': 'a man in a blue shirt is riding a wave .',
#  '000000300514': 'a woman in a white shirt is sitting on a table .',
#  '000000362811': 'a cat sitting on a table with a laptop .',
#  '000000353937': 'a bathroom with a toilet and a sink',
#  '000000572063': 'a train is parked on the side of a road .',
#  '000000313113': 'a group of people sitting on a bench .',
#  '000000499852': 'a group of people standing in a field .',
#  '000000060005': 'a train is parked on a train track .',
#  '000000184282': 'a large plane is sitting on the beach .',
#  '000000285893': 'a man is playing a game of tennis .',
#  '000000099070': 'a man in a blue shirt is standing on a bench .',
#  '000000205126': 'a man in a blue shirt is standing on a beach .',
#  '000000313280': 'a man in a blue shirt and white shirt is standing on a street .',
#  '000000299643': 'a cat sitting on a table with a laptop .',
#  '000000409678': 'a cat sitting on a table with a white plate .',
#  '000000198289': 'a woman in a white shirt and white shirt is holding a white dog .',
#  '000000040100': 'a man is standing in the grass with a frisbee .',
#  '000000111188': 'a cat sitting on a bed with a toilet .',
#  '000000111940': 'a man is standing on a bench in front of a building .',
#  '000000467137': 'a man is standing on a bench with a red umbrella .',
#  '000000229707': 'a man in a white shirt and white shirt is sitting on a couch .',
#  '000000312446': 'a group of people standing on a bench .',
#  '000000468132': 'a man is standing on a bench in the background .',
#  '000000452737': 'a man in a blue shirt and white shirt is holding a cell phone .',
#  '000000081954': 'a cat sitting on top of a bed .',
#  '000000239801': 'a white plate with a white plate of food .',
#  '000000316336': 'a kitchen with a sink and a sink',
#  '000000125672': 'a man in a white shirt and white shirt is standing in a room .',
#  '000000465495': 'a man in a white shirt and white shirt is standing in front of a kitchen .',
#  '000000400064': 'a man in a white shirt and white shirt is sitting on a bed .',
#  '000000083601': 'a man in a red shirt is sitting on a bench .',
#  '000000136154': 'a train is parked on a street with a train station .',
#  '000000419678': 'a man in a white shirt and white shirt is sitting on a bed .',
#  '000000291889': 'a man in a blue shirt is standing on a bench .',
#  '000000456201': 'a man is sitting on a table with a laptop .',
#  '000000403464': 'a man in a red shirt and white shirt is standing in front of a street .',
#  '000000421534': 'a clock tower with a clock on it .',
#  '000000170562': 'a large dog is sitting on a bench .',
#  '000000383329': 'a man in a white shirt is sitting on a bed .',
#  '000000069424': 'a group of people standing in a field with a large blue sky .',
#  '000000361376': 'a plate of food with a plate of food .',
#  '000000297570': 'a man is flying a kite on a beach .',
#  '000000574829': 'a man in a blue shirt is standing on a sidewalk .',
#  '000000090498': 'a cat sitting on a bed next to a white toilet .',
#  '000000397717': 'a dog is standing in the grass with a dog .',
#  '000000406452': 'a man is standing in the middle of a field .',
#  '000000059267': 'a man is sitting on a bed with a cat .',
#  '000000369568': 'a group of people standing in a field of grass .',
#  '000000329175': 'a large clock on the side of a city street .',
#  '000000456873': 'a cat sitting on top of a bed .',
#  '000000174496': 'a cat sitting on top of a table .',
#  '000000487288': 'a woman is sitting on a bench with a dog .',
#  '000000256465': 'a man is sitting on a bed with a laptop .',
#  '000000190334': 'a man in a white shirt and white shirt is sitting on a table .',
#  '000000224166': 'a woman is sitting on a table with a dog .',
#  '000000154888': 'a man in a white shirt and white shirt is sitting on a table .',
#  '000000580238': 'a man is standing next to a dog .',
#  '000000361519': 'a man is riding a skateboard on a street .',
#  '000000021374': 'a person is riding a skateboard on a beach .',
#  '000000162880': 'a man is standing on a bench with a red umbrella .',
#  '000000208319': 'a man is standing on a beach with a kite .',
#  '000000178178': 'a bathroom with a toilet and a sink',
#  '000000365205': 'a man in a white shirt and white shirt is sitting on a bed .',
#  '000000248391': 'a man in a blue shirt is standing on a bench .',
#  '000000192394': 'a man is riding a skateboard on a beach .',
#  '000000243324': 'a man is riding a skateboard on a skateboard .',
#  '000000349552': 'a man in a blue shirt is riding a skateboard .',
#  '000000480313': 'a man in a white shirt and white shirt is sitting on a table .',
#  '000000261196': 'a plate of food with a plate of food .',
#  '000000141922': 'a man in a white shirt and white shirt is sitting on a couch .',
#  '000000287886': 'a cat sitting on a bed in a room .',
#  '000000258129': 'a man in a blue shirt is playing tennis .',
#  '000000125662': 'a large train is parked in front of a building .',
#  '000000506659': 'a man in a white shirt and white shirt is standing in front of a building .',
#  '000000529689': 'a man in a white shirt is standing in front of a building .',
#  '000000097363': 'a group of people standing in a field with a green field .',
#  '000000011323': 'a man in a blue shirt and white shirt is standing in front of a large room .',
#  '000000169448': 'a man in a black shirt is sitting on a bench .',
#  '000000191648': 'a man is standing on a beach with a kite .',
#  '000000304584': 'a man is standing on a bench with a skateboard .',
#  '000000336015': 'a man in a blue shirt is riding a wave .',
#  '000000017167': 'a man is standing on a bench with a frisbee .',
#  '000000166349': 'a man in a blue shirt is riding a skateboard .',
#  '000000001548': 'a man riding a skateboard down a snow covered slope .',
#  '000000347131': 'a woman is sitting on a table with a cake .',
#  '000000382447': 'a cat sitting on a table with a laptop .',
#  '000000081971': 'a woman is sitting on a table with a cake .',
#  '000000536010': 'a bathroom with a toilet and a sink',
#  '000000244293': 'a man in a blue shirt is standing on a street .',
#  '000000326853': 'a man in a white shirt and white shirt is sitting on a bench .',
#  '000000311475': 'a large plane is sitting on the beach .',
#  '000000157301': 'a man is sitting on a bench next to a laptop .',
#  '000000175142': 'a small dog is sitting on a bench .',
#  '000000302576': 'a woman is sitting on a table with a laptop .',
#  '000000056323': 'a man in a blue shirt is standing on a bench .',
#  '000000189351': 'a man is sitting on a bench in front of a building .',
#  '000000379567': 'a cat sitting on top of a table .',
#  '000000111121': 'a baseball player is playing baseball on a field .',
#  '000000372660': 'a man in a blue shirt and white shirt is standing in front of a large blue shirt and a large building .',
#  '000000559768': 'a plate of food with a plate of food .',
#  '000000323790': 'a plate of food with a plate of food .',
#  '000000046359': 'a man is standing on a beach with a kite .',
#  '000000205689': 'a man in a white shirt and white shirt is standing in a bathroom .',
#  '000000573659': 'a man is sitting on a table with a laptop .',
#  '000000139040': 'a man in a white shirt and white shirt is standing in front of a kitchen .',
#  '000000459465': 'a large train is on a field with a tree .',
#  '000000381301': 'a large white dog sitting on a bench .',
#  '000000105781': 'a man is standing on a bench in front of a building .',
#  '000000302489': 'a group of people are standing on a bench .',
#  '000000068738': 'a cat sitting on a table with a laptop .',
#  '000000008320': 'a group of people standing on a road with a large building .',
#  '000000237394': 'a train is parked on the side of a road .',
#  '000000295476': 'a man in a blue shirt is riding a skateboard .',
#  '000000181850': 'a man in a white shirt and white shirt is sitting on a bed .',
#  '000000209292': 'a man is standing next to a large building .',
#  '000000428508': 'a baseball player is playing tennis on a field .',
#  '000000399932': 'a man is standing on a beach with a kite .',
#  '000000096643': 'a man in a white shirt is sitting on a bed .',
#  '000000243384': 'a large clock tower with a clock on it .',
#  '000000035712': 'a large dog is standing in the grass .',
#  '000000014726': 'a woman is sitting on a bench in a room .',
#  '000000269327': 'a dog is standing on a bench in the water .',
#  '000000474387': 'a man in a red shirt is standing on a bench .',
#  '000000063330': 'a man is standing on a bench in front of a building .',
#  '000000268036': 'a man is standing on a bench in front of a building .',
#  '000000470995': 'a man in a red shirt is standing in front of a building .',
#  '000000557467': 'a man in a white shirt and white shirt is standing in front of a building .',
#  '000000564314': 'a group of people are standing on a road .',
#  '000000540464': 'a cat sitting on a bed with a laptop .',
#  '000000280158': 'a man in a blue shirt is riding a skateboard .',
#  '000000564926': 'a large dog is sitting on a bench .',
#  '000000171536': 'a woman is sitting on a table with a cake .',
#  '000000424665': 'a man in a red shirt is standing on a bench .',
#  '000000385485': 'a woman is sitting on a table with a dog .',
#  '000000512634': 'a plate of food with a plate of food .',
#  '000000156202': 'a woman is sitting on a table with a laptop .',
#  '000000293304': 'a large clock tower with a clock on it .',
#  '000000160137': 'a large clock tower with a clock on it .',
#  '000000115642': 'a cat sitting on a table with a laptop .',
#  '000000013844': 'a bathroom with a sink and a sink .',
#  '000000541082': 'a man is standing on a bench in front of a building .',
#  '000000401969': 'a large clock tower with a clock on it .',
#  '000000162285': 'a woman is sitting on a table with a dog .',
#  '000000081784': 'a man in a blue shirt is standing on a beach .',
#  '000000343503': 'a man is sitting on a bench with a red umbrella .',
#  '000000293233': 'a baseball player is standing on a field .',
#  '000000307020': 'a man is sitting on a bench in front of a building .',
#  '000000288650': 'a man in a blue shirt is standing on a bench .',
#  '000000414495': 'a man in a white shirt is standing on a skateboard .',
#  '000000182658': 'a man in a white shirt and white shirt is sitting on a bench .',
#  '000000144620': 'a man is standing on a bench with a frisbee .',
#  '000000498425': 'a man is sitting on a table with a laptop .',
#  '000000329133': 'a woman is sitting on a table with a laptop .',
#  '000000368040': 'a large airplane is sitting on the beach .',
#  '000000403535': 'a group of people standing in a field .',
#  '000000524651': 'a man is riding a skateboard on a skateboard .',
#  '000000388469': 'a white cat sitting on top of a table .',
#  '000000000368': 'a man in a blue shirt and white shirt is playing a game of frisbee .',
#  '000000478648': 'a cat sitting on a bed with a laptop .',
#  '000000211302': 'a white cat sitting on top of a table .',
#  '000000056699': 'a red fire hydrant is on a street .',
#  '000000532030': 'a man in a blue shirt is standing on a beach .',
# ...
#  '000000130011': 'a man is sitting on a bench with a dog .',
#  '000000035101': 'a red fire hydrant is on a street .',
#  '000000557314': 'a man is playing a game of tennis .',
#  '000000528903': 'a group of people standing in a field with a large building .',
#  '000000572001': 'a plate of food with a plate of food .',
#  '000000266486': 'a cat sitting on a bed with a toilet .',
#  '000000329797': 'a man in a white shirt is sitting on a bed .',
#  '000000144884': 'a woman is sitting on a bed with a white dog .',
#  '000000489695': 'a man in a blue shirt and white shirt is standing on a street .',
#  '000000346160': 'a bathroom with a toilet and a sink',
#  '000000324413': 'a man is standing on a bench next to a large building .',
#  '000000005757': 'a man is standing on a street with a red bus .',
#  '000000470114': 'a group of people standing on a road with a red fire hydrant .',
#  '000000463883': 'a cat sitting on top of a bed .',
#  '000000278287': 'a man is sitting on a bench in the middle of a city .',
#  '000000473042': 'a man in a blue shirt is playing a game of baseball .',
#  '000000209128': 'a baseball player is playing tennis on a field .',
#  '000000369140': 'a man in a blue shirt is riding a wave .',
#  '000000416622': 'a woman is sitting on a table with a dog .',
#  '000000014985': 'a man is standing next to a large building .',
#  '000000291321': 'a woman is sitting on a table with a laptop .',
#  '000000285018': 'a bathroom with a sink and a sink',
#  '000000248009': 'a man in a white shirt and white shirt is standing on a skateboard .',
#  '000000314788': 'a large train is on the beach with a large train .',
#  '000000213646': 'a giraffe is standing in the grass with a frisbee .',
#  '000000289621': 'a large clock tower with a clock on it .',
#  '000000032566': 'a man in a blue shirt is standing on a street .',
#  '000000419656': 'a man is sitting on a bench in front of a building .',
#  '000000567997': 'a man in a blue shirt is standing on a beach .',
#  '000000122586': 'a man in a blue shirt is riding a wave .',
#  '000000352041': 'a man is riding a skateboard on a skateboard .',
#  '000000230503': 'a man is riding a skateboard down a street .',
#  '000000285910': 'a woman is sitting on a table with a cake .',
#  '000000042818': 'a man is riding a wave on a beach .',
#  '000000259591': 'a man is sitting on a table with a laptop .',
#  '000000012103': 'a bathroom with a sink and a sink',
#  '000000254729': 'a man in a blue shirt is riding a wave .',
#  '000000373033': 'a man is riding a skateboard down a street .',
#  '000000392723': 'a small dog is standing in the middle of a tree .',
#  '000000063182': 'a group of people standing in a field with a green field .',
#  '000000088176': 'a man is standing on a street with a red sign .',
#  '000000031865': 'a cat sitting on a bed with a laptop .',
#  '000000105904': 'a man is sitting on a bench with a laptop .',
#  '000000038827': 'a small dog is sitting on a bench .',
#  '000000038722': 'a man in a white shirt and a black shirt is sitting on a table .',
#  '000000483530': 'a white cat sitting on top of a table .',
#  '000000373923': 'a man in a blue shirt is riding a skateboard .',
#  '000000230038': 'a man is sitting on a table with a laptop .',
#  '000000305267': 'a woman is sitting on a table with a laptop .',
#  '000000053232': 'a man is sitting on a bench in the background .',
#  '000000284144': 'a man is sitting on a bench in front of a building .',
#  '000000193594': 'a man in a blue shirt is standing next to a large building .',
#  '000000112882': 'a cat sitting on a bed with a laptop .',
#  '000000573184': 'a large plane is sitting on the beach .',
#  '000000128826': 'a man in a white shirt is sitting on a couch .',
#  '000000175946': 'a man in a white shirt and white shirt is sitting on a table .',
#  '000000233926': 'a man is standing next to a large dog .',
#  '000000295257': 'a baseball player is playing with a ball .',
#  '000000530888': 'a man is riding a skateboard on a skateboard .',
#  '000000058965': 'a man in a blue shirt is playing a game of baseball .',
#  '000000124836': 'a plate of food with a white plate of food .',
#  '000000236155': 'a woman is sitting on a bench in a room .',
#  '000000447557': 'a large clock tower with a clock on it .',
#  '000000041413': 'a man in a blue shirt is playing tennis .',
#  '000000281855': 'a man is riding a wave on a beach .',
#  '000000163192': 'a cat sitting on a table with a laptop .',
#  '000000032176': 'a man is standing on a bench in front of a building .',
#  '000000283382': 'a cat sitting on a bed with a laptop .',
#  '000000447726': 'a man is riding a skateboard down a street .',
#  '000000244349': 'a man is standing on a street with a large clock .',
#  '000000526680': 'a group of people are sitting on a bench .',
#  '000000289204': 'a man is standing on a bench in the water .',
#  '000000296696': 'a man in a blue shirt is riding a skateboard .',
#  '000000051530': 'a man in a blue shirt is standing on a bench .',
#  '000000056306': 'a man is sitting on a bench in a room .',
#  '000000546285': 'a man in a blue shirt is standing on a bench .',
#  '000000176192': 'a man is sitting on a table with a laptop .',
#  '000000244582': 'a white dog is sitting on a bed .',
#  '000000325287': 'a man in a white shirt and white shirt is sitting on a bench .',
#  '000000517430': 'a train is parked on a street with a train on it .',
#  '000000075557': 'a man is sitting on a bench in front of a building .',
#  '000000345590': 'a group of people standing in a field of water .',
#  '000000392315': 'a man in a blue shirt is riding a skateboard .',
#  '000000098155': 'a man in a white shirt and white shirt is standing in a room .',
#  '000000149572': 'a man in a red shirt is sitting on a bench .',
#  '000000453586': 'a man is standing on a beach with a kite .',
#  '000000018467': 'a plate of food with a white and a plate of food .',
#  '000000308838': 'a man riding a skateboard down a snow covered slope .',
#  '000000323964': 'a man in a blue shirt is holding a red umbrella .',
#  '000000550392': 'a man in a white shirt and white shirt is sitting on a bench .',
#  '000000060602': 'a man riding a skateboard down a street .',
#  '000000189153': 'a man is standing on a bench in the air .',
#  '000000034973': 'a bathroom with a sink and a sink',
#  '000000581302': 'a man is standing on a bench in the background .',
#  '000000146656': 'a group of people standing on a field .',
#  '000000124903': 'a man in a white shirt is standing in front of a building .',
#  '000000102445': 'a large clock tower with a clock on it .',
#  '000000125729': 'a group of people standing in a field with a kite .',
#  '000000331314': 'a cat sitting on top of a bed .',
#  '000000393394': 'a white cat sitting on a table with a white plate .',
#  '000000438932': 'a bathroom with a sink and a sink',
#  '000000371092': 'a man in a blue shirt and white shirt is sitting on a bench .',
#  '000000055033': 'a clock tower with a clock on it .',
#  '000000302141': 'a group of people standing on a beach .',
#  '000000002982': 'a man is standing on a bench with a skateboard .',
#  '000000469731': 'a man in a blue shirt is riding a skateboard .',
#  '000000166047': 'a man is standing on a beach with a kite .',
#  '000000390969': 'a man is sitting on a bench in front of a kitchen .',
#  '000000564443': 'a man in a blue shirt and white shirt is standing on a skateboard .',
#  '000000231500': 'a cat sitting on a table with a laptop .',
#  '000000568308': 'a group of people standing in a field .',
#  '000000081259': 'a group of people are standing on a street .',
#  '000000016520': 'a group of people standing in a field of grass .',
#  '000000242325': 'a man is standing in the grass with a frisbee .',
#  '000000140758': 'a man is standing on a bench in the background .',
#  '000000092910': 'a man is standing next to a large building .',
#  '000000347267': 'a woman is sitting on a table with a dog .',
#  '000000284722': 'a man in a white shirt is sitting on a bench .',
#  '000000570019': 'a plate of food with a plate of food .',
#  '000000141240': 'a man is sitting on a bench in front of a building .',
#  '000000050470': 'a man is playing tennis on a tennis court .',
#  '000000125683': 'a man in a white shirt is sitting on a bench .',
#  '000000079831': 'a plate of food with a plate of food .',
#  '000000253419': 'a man is riding a wave on a beach .',
#  '000000242029': 'a group of people are standing on a road .',
#  '000000074411': 'a man is standing on a bench in a field .',
#  '000000571563': 'a man in a blue shirt is riding a skateboard .',
#  '000000385672': 'a man in a white shirt is sitting on a bench .',
#  '000000286673': 'a woman is sitting on a table with a laptop .',
#  '000000462993': 'a bathroom with a sink and a sink',
#  '000000455549': 'a man in a white shirt is sitting on a couch .',
#  '000000486421': 'a group of people standing in a field with a large dog .',
#  '000000575274': 'a train is parked on the street with a train on it .',
#  '000000349566': 'a man in a white shirt and white shirt is standing in a bathroom .',
#  '000000365833': 'a man is standing on a beach with a kite .',
#  '000000048474': 'a group of people are sitting on a bench .',
#  '000000509267': 'a man in a blue shirt is standing on a bench .',
#  '000000241918': 'a man in a blue shirt is riding a skateboard .',
#  '000000319781': 'a man is standing on a bed with a dog .',
#  '000000046171': 'a large clock tower with a clock on it .',
#  '000000056193': 'a group of people are sitting on a bench .',
#  '000000326496': 'a man in a white shirt and white shirt is standing in front of a building .',
#  '000000351288': 'a man in a blue shirt is riding a skateboard .',
#  '000000352735': 'a red fire hydrant on a street with a red sign .',
#  '000000429908': 'a cat sitting on top of a table .',
#  '000000323462': 'a bathroom with a toilet and a sink',
#  '000000182295': 'a cat sitting on a table with a laptop .',
#  '000000179758': 'a man in a blue shirt is playing a game of baseball .',
#  '000000411445': 'a cat sitting on a bed with a toilet .',
#  '000000552579': 'a man in a blue shirt is standing on a bench .',
#  '000000402243': 'a bathroom with a sink and a sink',
#  '000000465414': 'a train is parked on the side of a road .',
#  '000000565387': 'a man in a blue shirt is riding a skateboard .',
#  '000000503318': 'a man in a white shirt and white shirt is standing in the middle of a grassy area .',
#  '000000241790': 'a man is standing on a beach with a kite .',
#  '000000365631': 'a man is standing on a bench with a skateboard .',
#  '000000559830': 'a man is standing on a bench with a kite .',
#  '000000269958': 'a man in a white shirt and white shirt is playing a game of frisbee .',
#  '000000383760': 'a man is riding a wave on a beach .',
#  '000000317896': 'a plate of food with a plate of food .',
#  '000000041962': 'a man is riding a skateboard on a beach .',
#  '000000030151': 'a man in a white shirt and white shirt is sitting on a bed .',
#  '000000028674': 'a man in a white shirt is holding a dog .',
#  '000000344765': 'a large clock tower with a clock on it .',
#  '000000208779': 'a woman is sitting on a table with a dog .',
#  '000000392105': 'a man is standing on a street with a red bus .',
#  '000000179687': 'a man in a white shirt is riding a skateboard .',
#  '000000532673': 'a man in a white shirt is standing in a field .',
#  '000000302364': 'a man in a white shirt and white shirt is standing in a field .',
#  '000000240449': 'a man is riding a skateboard on a skateboard .',
#  '000000516329': 'a man in a blue shirt and white shirt is standing on a skateboard .',
#  '000000064036': 'a man in a blue shirt is playing tennis .',
#  '000000165064': 'a man is standing in front of a large building .',
#  '000000083093': 'a man is standing next to a large dog .',
#  '000000225053': 'a man in a white shirt is standing in a field .',
#  '000000573483': 'a woman is sitting on a table with a dog .',
#  '000000072396': 'a large clock tower with a clock on it .',
#  '000000330916': 'a bathroom with a sink and a sink',
#  '000000401458': 'a man in a white shirt and white shirt is standing in front of a kitchen .',
#  '000000522464': 'a man in a white shirt is sitting on a bench .',
#  '000000322769': 'a bathroom with a sink and a sink',
#  '000000168349': 'a black and white dog sitting on a bench .',
#  '000000425470': 'a man in a white shirt and white shirt is sitting on a table .',
#  '000000382873': 'a baseball player is playing tennis .',
#  '000000091681': 'a group of people standing in front of a building .',
#  '000000003461': 'a man is standing on a bench in front of a building .',
#  '000000339031': 'a man in a blue shirt is riding a wave .',
#  '000000458629': 'a cat sitting on a bed with a white toilet .',
#  '000000534898': 'a man in a red shirt and white shirt is standing in front of a tree .',
#  '000000319121': 'a group of people standing in a field .',
#  '000000484418': 'a man is sitting on a bench next to a tree .',
#  '000000170662': 'a large train is on the beach with a kite .',
#  '000000051501': 'a man is sitting on a bench with a large umbrella .',
#  '000000458603': 'a man is standing in a field with a dog .',
#  '000000116633': 'a man is standing on a bench in the air .',
#  '000000166018': 'a cat sitting on a bed with a cat on it .',
#  '000000240889': 'a woman in a white shirt and white shirt is standing in a field .',
#  '000000094884': 'a man is standing next to a building .',
#  '000000018183': 'a bathroom with a sink and a sink',
#  '000000022198': 'a cat sitting on top of a bed .',
#  '000000435139': 'a group of people standing in a field .',
#  '000000484494': 'a large clock tower with a clock on it .',
#  '000000543042': 'a large white dog is sitting on a bench .',
#  '000000320429': 'a man in a blue shirt is riding a skateboard .',
#  '000000525823': 'a man in a white shirt and white shirt is standing in front of a large room .',
#  '000000578856': 'a man is flying a kite on a beach .',
#  '000000383605': 'a baseball player is playing baseball .',
#  '000000402095': 'a man in a white shirt and white shirt is sitting on a bench .',
#  '000000401528': 'a man in a white shirt and white shirt is standing in a room .',
#  '000000196379': 'a man is sitting on a bench in a room .',
#  '000000538444': 'a man in a white shirt and white shirt is sitting on a table .',
#  '000000542502': 'a man in a red shirt and white shirt is playing a game of tennis .',
#  '000000144734': 'a group of people standing on a street .',
#  '000000482751': 'a man is playing tennis on a tennis court .',
#  '000000158737': 'a dog is standing in the grass with a frisbee .',
#  '000000089253': 'a man in a white shirt is standing on a bench .',
#  '000000559908': 'a white plate with a white plate of food .',
#  '000000114229': 'a woman is sitting on a table with a laptop .',
#  '000000198426': 'a man in a red shirt is standing on a bench .',
#  '000000556473': 'a man is standing on a beach with a kite .',
#  '000000100140': 'a man is sitting on a bench in front of a building .',
#  '000000057979': 'a man is standing on a bench next to a skateboard .',
#  '000000217495': 'a woman in a white shirt and white shirt is sitting on a table .',
#  '000000422608': 'a man is standing on a bench with a horse .',
#  '000000341219': 'a man in a white shirt and white shirt is standing in front of a large white dog .',
#  '000000224541': 'a man is sitting on a bench with a dog .',
#  '000000310558': 'a man in a blue shirt and white shirt is sitting on a bench .',
#  '000000557344': 'a woman is sitting on a bench in a room .',
#  '000000045923': 'a man in a blue shirt is playing tennis .',
#  '000000457948': 'a man is standing on a bench in the background .',
#  '000000025516': 'a man in a blue shirt is riding a skateboard .',
#  '000000457726': 'a man is standing on a bench next to a building .',
#  '000000162087': 'a woman is sitting on a table with a laptop .',
#  '000000081357': 'a man in a blue shirt and white shirt is standing in front of a large white dog .',
#  '000000425772': 'a group of people are walking down a street .',
#  '000000477759': 'a man in a white shirt and white shirt is standing in front of a building .',
#  '000000216820': 'a plate of food with a plate of food .',
#  ...}

# %%
predict = test(testmodel, valid_loader)

# %%
print(len(predict))
# Out:
# 1789

# %%
with open("./p2/dict.json", "w") as f:
    json.dump(dict, f, indent=4)

with open("./p2/dict2.json", "w") as f:
    json.dump(dict2, f, indent=4)

# %%
for i in range(30):
    test = out.max(2, keepdim=True)[1][i]
    # print(out.max(2, keepdim=True)[1])
    test = test.cpu().numpy().squeeze().tolist()
    # print(test)
    test = test[:test.index(3)+1]
    print(tokenizer.decode(test))
# Out:
# table situated in corner of room with a vase for a center piece
# a black and white photo of a train driving .
# a woman is wearing a pink helmet and riding her bike through the city .
# a group of people driving a horse drawn carriage .
# a bunch of travel bags sit on a carpet floor
# a person with a tattoo holding a basketball
# a baby grabs for a bite of pizza that a man is eating .
# a full veggie pizza near a couple of plate of fries , are all ready to be eaten .
# a close up of a child eating food
# a small child is holding a stuffed bear
# a white toilet sitting in a bathroom next to a tub .
# a bird is standing on a shallow body of water .
# four ducks are in a grassy island of a parking lot with their heads down .
# a subway train pulling into the train station .
# a couple of people sitting inside of a car .
# three zebras and two other animals grazing .
# a group of men play a game of tennis together on a grass tennis court .
# two men standing in a store aisle with one holding a baseball bat .
# a man in a narrow kitchen area wiping a pan .
# a dirt bike rider doing a stunt jump in the air
# a multicolored airplane is flying in the air
# giraffe eating from a tree behind a rock .
# a red and blue bird that is sitting on a branch
# the blue and white hat has a bird on it
# a photo of a train with a person stand on the train .
# a train getting ready to go into a tunnel
# four cows drink from the water near each other .
# the back of the car is full of duffel bags and a pair of boots .
# a group of people on baseball field with trees in the background .
# a pot of soup is being prepared on the stove .
